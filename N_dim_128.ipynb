# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
import yaml
import pprint
import os
import time
# weights and biases for tracking of metrics
import wandb 
# make the plots inline again
# %matplotlib inline
# sometimes have to activate this to plot plots in notebook
# matplotlib.use('Qt5Agg')
from code import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load and pprint config

# %%
stream = open("config_fit_df.yaml", 'r')
config = yaml.load(stream, Loader = yaml.FullLoader)

# This is for the MLPs of the flow
config['HIDDEN_DIM_SPLINE_MLP'] = HIDDEN_DIM_SPLINE_MLP
config['HIDDEN_DIM_MOEBIUS_MLP'] = HIDDEN_DIM_MOEBIUS_MLP
config['HIDDEN_DIM_ROTATION_MLP'] = HIDDEN_DIM_ROTATION_MLP

### Set globabl variables and load data
BATCH_SIZE = config['BATCH_SIZE']

# NUM_FLOWS_COU = config['NUM_FLOWS_COU']
# NUM_FLOWS_CYL = config['NUM_FLOWS_CYL']
# NUM_CENTERS = config['NUM_CENTERS']
# NUM_BINS = config['NUM_BINS']
# NUM_DIM_DATA = config['NUM_DIM_DATA']

# flow params
NUM_DIM_DATA = 128
NUM_CENTERS = 8
NUM_BINS = 12
NUM_FLOWS_COU = 5
NUM_FLOWS_CYL = 5

CAP_HOUSEHOLDER_REFL = True

nr_mixtures = config['nr_mixtures']
epochs = config['epochs']
eval_iter = config['eval_iter']
print_iter = config['print_iter']
lookahead = config['lookahead']
nr_datapoints = config['nr_datapoints_eval']

lr = config['lr']
weight_decay = config['weight_decay']

# data parameters
# nr_mixtures = config['nr_mixtures']

# dataset type

dataset_type = config['dataset_type']

ITERS_PER_EPOCH = config['iters_per_epoch']

PROJECT_NAME = f'DIM_{NUM_DIM_DATA}'

pp = pprint.PrettyPrinter(indent=1)
pp.pprint(config)
# Out:
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 64,
#  'HIDDEN_DIM_ROTATION_MLP': 64,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'lookahead': 10,
#  'lr': 0.001,
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'print_iter': 10,
#  'weight_decay': 0.01}

# %% [markdown]
# ### get location and scale parameters

# %%
# # code for creating dataset on the poles
# from random import random
# eps = random()*0.2
# mu_list = np.array([[eps, eps, 1+eps],
#                          [eps, eps, -1+eps],
#                          [1, eps, eps]], dtype='float32')

# k_list = 1.5*np.array([13, 14,  12],dtype='float32')

# mu_list = mu_list / np.linalg.norm(mu_list,axis=1,keepdims=True)
# np.linalg.norm(mu_list,axis=1,keepdims=True)


if NUM_DIM_DATA == 3 and dataset_type == 'standard':

    mu_list = np.array([[-4.7503373e-01, -8.7996745e-01, -5.0922018e-04],
                        [-1.6167518e-01,  6.5595394e-01, -7.3728257e-01],
                        [ 2.6248896e-01,  6.9851363e-01,  6.6571641e-01],
                        [ 1.0,  0,  0.0]], dtype='float32')

    k_list = 1.5*np.array([13, 14,  12, 15],dtype='float32')

    phi_mu_list = np.array([-2.06579875,  1.81245307,  1.2113401, 0],dtype='float32')
    theta_mu_list =  np.array([-5.09220198e-04, -8.29039128e-01,  7.28453441e-01, 0],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles':
    
    mu_list = np.array([[ 0.14887695,  0.14887695,  0.9775844 ],
                        [ 0.20918883,  0.20918883, -0.9552383 ],
                        [ 0.96920884,  0.17411795,  0.17411795]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14,  12],dtype='float32')
    
    phi_mu_list = np.array([0.7853982, 0.7853982, 0.1777535],dtype='float32')
    theta_mu_list =  np.array([ 1.3586651 , -1.2704642 ,  0.17500998],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles_2':
    
    mu_list = np.array([[ 0,  0,  1 ],
                        [ 0,  0, -1 ]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14],dtype='float32')
    
    phi_mu_list = np.array([0, 0],dtype='float32')
    theta_mu_list =  np.array([ np.pi/2 , -np.pi/2],dtype='float32')    
    
else:    
    torch.manual_seed(42) # mu created with torch
    np.random.seed(42) # k with numpy
    mu_list, k_list, phi_mu_list, theta_mu_list = create_random_parameters(nr_mixtures, num_dim_data = NUM_DIM_DATA)

# %%
np.save('density_fit_params/128D_mu.npy',mu_list)
np.save('density_fit_params/128D_k.npy',k_list)

# %% [markdown]
# ### 3d and N dim Power Spherical Data

# %%
# Power Spherical 

# print(f'Center parameters \n {mu_list}')
# print(f'Scale parameters \n {k_list}')

power_spherical_data = PowerSphericalData(mu_list=mu_list, k_list=k_list, nr_samples=BATCH_SIZE*ITERS_PER_EPOCH)

print(f'Entropy {power_spherical_data.entropy.detach().numpy()}')

# add parameters to config
config['nr_mixtures'] = len(mu_list)
config['mu_list'] = mu_list
config['k_list'] = k_list
config['phi_mu_list'] = phi_mu_list
config['theta_mu_list'] = theta_mu_list

if NUM_DIM_DATA == 3:
    
    start_time = time.time()
    probs, probs_with_cos, phi_linspace, theta_linspace = plot_power_spherical_density(mu_list, k_list,phi_mu_list,theta_mu_list)
    print("--- %s seconds ---" % (time.time() - start_time))

    dphi = phi_linspace[1] - phi_linspace[0]
    dtheta = theta_linspace[1] - theta_linspace[0]

    print('numerical integral of density w', torch.sum(probs_with_cos) * dphi * dtheta)
# Out:
# Secs for entropy calc 14.226108312606812
# With entropy -127.26254272460938
# Entropy -127.26254272460938

# %% [markdown]
# ### train function

# %%
def get_num_params(model):
    
    total_number_params = 0
    
    for name, parameter in model.named_parameters():
        total_number_params += parameter.numel()
    return total_number_params

def train_model(model, 
                optimizer, 
                dataset, 
                config,
                model_name):
    
    
    epochs = config['epochs']
    config['NUM_PARAMS'] = get_num_params(model)

    # init weights and biases tracking
    ts = time.strftime('%m%d_%H%M%S', time.localtime(time.time()))
    
    if model.flow_type == 'moebius':
        model_name = f"{model_name}_NC_{NUM_CENTERS}_NF_{model.num_flows}"
        
    elif model.flow_type == 'spline':
        model_name = f"{model_name}_NB_{NUM_BINS}_NF_{model.num_flows}"
        
    wandb.init(project=PROJECT_NAME,
               config=config,
               name=model_name,
               id=ts)
    
    best_KL = 1e3
    epoch_of_best_run = 0
    
    # According to w and b documentation this is magic. Okay, let's see
    wandb.watch(model)
    
    print('##### Model #####')
    print(model)
    print('#################\n')
    
    print('##### Config #####')
    pp = pprint.PrettyPrinter(indent=1)
    pp.pprint(config)
    print('##################\n')    
    
    train_loader = DataLoader(dataset, batch_size=config['BATCH_SIZE'], shuffle=True)
    
    # get properties of dataset class
    phi_mu_list, theta_mu_list = dataset.spherical_parameters
    entropy = dataset.entropy
    
    print(f'Entropy of data: {entropy}')

    max_steps = config['iters_per_epoch']
    
    num_dim_data = model.num_dim_data
    
    # initialize loss. 
    loss_fn = Loss_on_sphere(n_dim_sphere = num_dim_data - 1)
    
    for epoch in range(epochs):
        
        print(f"Epoch: {epoch} / {epochs-1}")
        
        if num_dim_data == 3:
        
            # actually the calculation here is partly redundant because we anyway later evalaute the model on a test set            
            eval_and_plot_model(model, 
                                nr_gridpoints = 100, 
                                epoch = epoch, 
                                batch_idx = 0, 
                                phi_mu_list=phi_mu_list, 
                                theta_mu_list=theta_mu_list, 
                                x_conditioner = None)

        start_time = time.time()
        for batch_idx, x_train in enumerate(train_loader): 

            x_train = x_train.float().to(device)

            optimizer.zero_grad()

            z, ldj, _ = model(x_train)

            loss = loss_fn.calc_loss(ldj)
                          
            # calculate gradient with repsect to ldj and not whole nll, 
            # because our prior is uniform and therefore this way is less expensive
            (-torch.mean(ldj)).backward()
#             loss.backward()
            optimizer.step()

            nll = float(loss.detach().cpu().numpy()) 
            KL = nll - entropy
                            
            if batch_idx % config['print_iter'] == 0: 
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} with KL {KL:.2f} and nll loss {nll:.2f}')                
                  
            def eval_model():
                
                nr_datapoints = config['nr_datapoints_eval']

                # KL evaluation based on nr_datapoints samples from data distribution
                test_data = dataset.get_test_set(nr_samples = nr_datapoints).to(device)

                with torch.no_grad():

                    model.eval()
                    z, ldj, _ = model(test_data)

                    nll_test = loss_fn.calc_loss(ldj)
                    KL_test = nll_test - entropy

                    # MC evaluation based on nr_datapoints uniform samples on the sphere
                    x_eval = torch.randn(nr_datapoints, num_dim_data).to(device)
                    x_eval = x_eval / torch.norm(x_eval, dim=1, keepdim=True)

                    z, ldj0, _ = model(x_eval)
                    model.train()                

                print()
                print(f'#### EVALUATION ####')
                print(f'Evaluation based on {nr_datapoints} data points from data distribution samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} KL_test {KL_test} and nll_test {nll_test}')

                print('\nFrom current batch')
                print(f'Epoch: {epoch}, i/N: {batch_idx}/{max_steps} avg ldj from current batch {torch.mean(ldj):.2f}')

                print(f'\nFrom {nr_datapoints} uniform samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum {torch.mean(torch.exp(ldj0)):.2f}')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} avg ldj {torch.mean(ldj0):.2f}')
                print('#####################')
                print()
                
                wandb.log({"KL_train": KL,
                           "neg_log_likel_train": nll,
                           "KL_test": KL_test,
                           "neg_log_likel_test": nll_test,            
                           "MC_integral": torch.mean(torch.exp(ldj0))})  
                
                return KL_test, nll_test
                
                
            if batch_idx % config['eval_iter'] == 0:
                KL_test, nll_test = eval_model()
                
#                 # This part is for additional evaluation of 
#                 model.eval()
#                 print()
#                 print('#####################')

#                 # first, second and both coupling w/o rotation
#                 sldj_test = torch.zeros(nr_datapoints).to(device)       
                
#                 x_out, ldj_first, _ = model.scale[1](x_eval, sldj_test) 
#                 _, ldj_second, _  = model.scale[3](x_eval, sldj_test) 
                
#                 _, ldj_first_second, _  = model.scale[3](x_out, ldj_first)                  

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first flow only moeb {torch.mean(torch.exp(ldj_first)):.2f}')
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum second flow only moeb {torch.mean(torch.exp(ldj_second)):.2f}') 
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first and second flow only moeb {torch.mean(torch.exp(ldj_first_second)):.2f}')
#                 print()
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj1, _ = model.scale[1](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first flow incl rot {torch.mean(torch.exp(ldj1)):.2f}') 
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[2](x_eval, sldj_test)
#                 x_out, ldj2, _ = model.scale[3](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density second flow incl rot {torch.mean(torch.exp(ldj2)):.2f}')   
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj, _ = model.scale[1](x_out, ldj)                
#                 x_out, ldj, _ = model.scale[2](x_out, ldj)
#                 x_out, ldj12, _ = model.scale[3](x_out, ldj)

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first&second flow incl rot {torch.mean(torch.exp(ldj12)):.2f}')                   
                
#                 print('#####################')
#                 print()
#                 model.train()                
                
                # store the metrics in the log. Call logger after eval and plot model because we also log plots inside
                   
            def store_model(best_vs_last):
                if not os.path.exists(f'models_fit_df/dim_{num_dim_data}'):
                    os.makedirs(f'models_fit_df/dim_{num_dim_data}')
                # also store model in the end
                state = {
                    'epoch': epoch,
                    'batch_index': batch_idx,
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'config': config
                }                        

                torch.save(state, f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")
                wandb.save(f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")  
                

            # save the best model but do not save any model during the first 50 iterations
            if not (epoch == 0 and batch_idx < 50):

                if KL_test < best_KL:

                    store_model(best_vs_last='best')

                    best_KL = KL_test
                    epoch_of_best_run = epoch
                    
                    wandb.run.summary["KL_best"] = KL_test
                    wandb.run.summary["nll_best"] = nll_test
                    
                    wandb.run.summary["epoch_of_best_KL"] = epoch_of_best_run
                    wandb.run.summary["batch_id_of_best_KL"] = batch_idx                    
                    
                    wandb.run.summary["KL_current_batch"] = KL
                    wandb.run.summary["nll_current_batch"] = nll
           
        
        wandb.log({"time_per_epoch": time.time()-start_time},commit=False)
        
        # if there was no improvement after a certain amount of epochs terminate training    
        if (epoch - epoch_of_best_run) >= config['lookahead']:
            print()
            print('#### EARLY STOPPING ####')
            print(f'at epoch {epoch} and batch_id {batch_idx}')
            print('########################')
            print()
            break
                
                                        
    # also store model in the end        
    store_model(best_vs_last='last')
    
    wandb.run.summary["last_epoch"] = epoch
    
    _,_ = eval_model()
    
    if num_dim_data == 3:
        eval_and_plot_model(model, 
                            nr_gridpoints = 100, 
                            epoch = epoch, 
                            batch_idx = 0, 
                            phi_mu_list=phi_mu_list, 
                            theta_mu_list=theta_mu_list, 
                            x_conditioner = None)

# %% [markdown]
# ### Coupling Moebius Flow

# %%
cou_moeb = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                              num_dim_data= NUM_DIM_DATA,
                              flow_type = 'moebius', 
                              rezero_flag = True,
                              num_centers = NUM_CENTERS,
                              cap_householder_refl=CAP_HOUSEHOLDER_REFL)

cou_moeb.to(device)

optimizer = optim.AdamW(cou_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Moebius Flow #####')


train_model(model = cou_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_m')

# %% [markdown]
# ### Coupling Spline Flow

# %%
cou_spline = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                           num_dim_data= NUM_DIM_DATA,
                           flow_type = 'spline', 
                           num_centers = NUM_CENTERS,
                           num_bins = NUM_BINS,
                           cap_householder_refl=CAP_HOUSEHOLDER_REFL) 

cou_spline.to(device)

optimizer = optim.AdamW(cou_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Spline Flow #####')

train_model(model = cou_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name = 'cou_s')

# %% [markdown]
# ### Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_m')

# %% [markdown]
# ### Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS,
                                 flow_type= 'spline',
                                 num_dim_data = NUM_DIM_DATA)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_s')

# %% [markdown]
# ### Coupling Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 add_phase_translation=False,
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_m')
# Out:
# ##### Coupling Cylindrical Moebius Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_128" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_128</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_128/runs/1223_110957" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_128/runs/1223_110957</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#     (3): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#     (4): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=16, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 3179920,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([11.87270059, 14.75357153, 13.65996971, 12.99329242]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[ 1.77151188e-01,  1.36733636e-01,  8.28075409e-02,
#         -1.93571314e-01,  6.23704791e-02, -1.13498025e-01,
#         -3.95941362e-03, -1.47525251e-01, -6.91476464e-02,
#          1.51575536e-01, -3.60825695e-02, -1.29040793e-01,
#         -6.69178516e-02, -5.14312796e-02, -7.06832930e-02,
#          7.00955093e-02,  1.50986597e-01, -1.46726118e-02,
#         -4.57282998e-02,  4.04136889e-02, -6.96988776e-02,
#          9.91352573e-02,  7.36216903e-02,  1.54508054e-01,
#          1.17596447e-01,  1.19186789e-01,  5.61233088e-02,
#          1.22709274e-01, -2.12944094e-02,  3.83916381e-03,
#         -2.31286045e-02,  7.90511966e-02, -1.27300143e-01,
#         -8.00971985e-02, -2.05351710e-02,  1.57885820e-01,
#          2.93162987e-02, -3.90282013e-02,  2.81064883e-02,
#         -7.12122545e-02, -1.43195614e-01,  9.15339217e-02,
#         -8.08832124e-02, -5.52660637e-02, -1.17139243e-01,
#          1.95158496e-01, -1.13507979e-01, -4.48564179e-02,
#         -8.40124264e-02, -6.05059266e-02,  7.17313401e-03,
#          4.83402908e-02, -4.48635742e-02,  1.09528653e-01,
#         -7.48358890e-02, -6.76635802e-02, -1.29007757e-01,
#          3.31000146e-03, -5.83579019e-03,  6.21127337e-02,
#         -8.99188779e-03,  1.69582963e-01, -1.08900584e-01,
#          1.27196774e-01,  1.32858545e-01,  7.87343830e-02,
#          2.03919053e-01,  4.80972826e-02,  3.18690017e-02,
#         -1.81416888e-02, -9.69537571e-02,  1.17492676e-01,
#         -1.58303194e-02,  4.81545515e-02,  5.20553347e-03,
#          3.91915850e-02,  5.28631583e-02, -5.89969829e-02,
-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -127.26254272460938
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.21 and nll loss -127.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.209259033203125 and nll_test -127.05328369140625
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.18 and nll loss -127.08
# Epoch: 0/19, i/N: 20/400 with KL 0.14 and nll loss -127.13
# Epoch: 0/19, i/N: 30/400 with KL 0.11 and nll loss -127.15
# Epoch: 0/19, i/N: 40/400 with KL 0.06 and nll loss -127.21
# Epoch: 0/19, i/N: 50/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 60/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 70/400 with KL 0.08 and nll loss -127.18
# Epoch: 0/19, i/N: 80/400 with KL 0.05 and nll loss -127.22
# Epoch: 0/19, i/N: 90/400 with KL 0.05 and nll loss -127.21
# Epoch: 0/19, i/N: 100/400 with KL 0.04 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.0609130859375 and nll_test -127.20162963867188
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.15
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.15
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 120/400 with KL 0.10 and nll loss -127.16
# Epoch: 0/19, i/N: 130/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 140/400 with KL 0.08 and nll loss -127.18
# Epoch: 0/19, i/N: 150/400 with KL 0.04 and nll loss -127.23
# Epoch: 0/19, i/N: 160/400 with KL -0.01 and nll loss -127.27
# Epoch: 0/19, i/N: 170/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 180/400 with KL 0.01 and nll loss -127.26
# Epoch: 0/19, i/N: 190/400 with KL 0.12 and nll loss -127.14
# Epoch: 0/19, i/N: 200/400 with KL 0.03 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.0540313720703125 and nll_test -127.20851135253906
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.09 and nll loss -127.18
# Epoch: 0/19, i/N: 220/400 with KL 0.11 and nll loss -127.16
# Epoch: 0/19, i/N: 230/400 with KL 0.05 and nll loss -127.21
# Epoch: 0/19, i/N: 240/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 250/400 with KL 0.09 and nll loss -127.18
# Epoch: 0/19, i/N: 260/400 with KL 0.02 and nll loss -127.24
# Epoch: 0/19, i/N: 270/400 with KL 0.01 and nll loss -127.26
# Epoch: 0/19, i/N: 280/400 with KL -0.05 and nll loss -127.32
# Epoch: 0/19, i/N: 290/400 with KL 0.04 and nll loss -127.23
# Epoch: 0/19, i/N: 300/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.048431396484375 and nll_test -127.214111328125
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.13
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 320/400 with KL 0.07 and nll loss -127.20
# Epoch: 0/19, i/N: 330/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 340/400 with KL 0.08 and nll loss -127.18
# Epoch: 0/19, i/N: 350/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 360/400 with KL 0.06 and nll loss -127.20
# Epoch: 0/19, i/N: 370/400 with KL 0.02 and nll loss -127.24
# Epoch: 0/19, i/N: 380/400 with KL 0.05 and nll loss -127.22
# Epoch: 0/19, i/N: 390/400 with KL -0.01 and nll loss -127.28
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL -0.00 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.0491485595703125 and nll_test -127.21339416503906
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.20
# #####################
#
# nan in sum squares
# Epoch: 1/19, i/N: 10/400 with KL 0.04 and nll loss -127.23
# Epoch: 1/19, i/N: 20/400 with KL 0.07 and nll loss -127.19
# Epoch: 1/19, i/N: 30/400 with KL 0.08 and nll loss -127.18
# Epoch: 1/19, i/N: 40/400 with KL 0.03 and nll loss -127.23
# Epoch: 1/19, i/N: 50/400 with KL 0.07 and nll loss -127.19
# Epoch: 1/19, i/N: 60/400 with KL 0.04 and nll loss -127.22
# Epoch: 1/19, i/N: 70/400 with KL 0.01 and nll loss -127.25
# Epoch: 1/19, i/N: 80/400 with KL 0.10 and nll loss -127.16
# Epoch: 1/19, i/N: 90/400 with KL 0.14 and nll loss -127.12
# Epoch: 1/19, i/N: 100/400 with KL 0.07 and nll loss -127.19
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.0446624755859375 and nll_test -127.21788024902344
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.12
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.04 and nll loss -127.22
# Epoch: 1/19, i/N: 120/400 with KL 0.02 and nll loss -127.25
# Epoch: 1/19, i/N: 130/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 140/400 with KL 0.08 and nll loss -127.19
# Epoch: 1/19, i/N: 150/400 with KL -0.04 and nll loss -127.30
# Epoch: 1/19, i/N: 160/400 with KL -0.00 and nll loss -127.27
# Epoch: 1/19, i/N: 170/400 with KL -0.00 and nll loss -127.26
# Epoch: 1/19, i/N: 180/400 with KL 0.08 and nll loss -127.18
# Epoch: 1/19, i/N: 190/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 200/400 with KL 0.09 and nll loss -127.18
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.0459136962890625 and nll_test -127.21662902832031
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.14
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.02 and nll loss -127.25
# Epoch: 1/19, i/N: 220/400 with KL -0.02 and nll loss -127.29
# Epoch: 1/19, i/N: 230/400 with KL 0.09 and nll loss -127.18
# Epoch: 1/19, i/N: 240/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 250/400 with KL 0.09 and nll loss -127.17
# Epoch: 1/19, i/N: 260/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 270/400 with KL 0.00 and nll loss -127.26
# Epoch: 1/19, i/N: 280/400 with KL 0.13 and nll loss -127.13
# Epoch: 1/19, i/N: 290/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 300/400 with KL 0.08 and nll loss -127.18
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.0497589111328125 and nll_test -127.21278381347656
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.21
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.08 and nll loss -127.18
# Epoch: 1/19, i/N: 320/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 330/400 with KL 0.01 and nll loss -127.26
# Epoch: 1/19, i/N: 340/400 with KL 0.01 and nll loss -127.25
# Epoch: 1/19, i/N: 350/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 360/400 with KL 0.10 and nll loss -127.16
# Epoch: 1/19, i/N: 370/400 with KL 0.07 and nll loss -127.19
# Epoch: 1/19, i/N: 380/400 with KL 0.01 and nll loss -127.25
# Epoch: 1/19, i/N: 390/400 with KL 0.04 and nll loss -127.22
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.02 and nll loss -127.24
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.04034423828125 and nll_test -127.22219848632812
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.16
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL -0.01 and nll loss -127.27
# Epoch: 2/19, i/N: 20/400 with KL 0.04 and nll loss -127.23
# Epoch: 2/19, i/N: 30/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 40/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 50/400 with KL 0.12 and nll loss -127.15
# Epoch: 2/19, i/N: 60/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 70/400 with KL 0.06 and nll loss -127.20
# Epoch: 2/19, i/N: 80/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 2/19, i/N: 100/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.0408935546875 and nll_test -127.22164916992188
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 120/400 with KL 0.05 and nll loss -127.21
# Epoch: 2/19, i/N: 130/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 140/400 with KL 0.04 and nll loss -127.23
# Epoch: 2/19, i/N: 150/400 with KL 0.11 and nll loss -127.15
# Epoch: 2/19, i/N: 160/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 180/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 190/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 200/400 with KL 0.01 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.0405120849609375 and nll_test -127.22203063964844
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.19
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.05 and nll loss -127.22
# Epoch: 2/19, i/N: 220/400 with KL 0.05 and nll loss -127.22
# Epoch: 2/19, i/N: 230/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 240/400 with KL 0.09 and nll loss -127.18
# Epoch: 2/19, i/N: 250/400 with KL -0.00 and nll loss -127.27
# Epoch: 2/19, i/N: 260/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 270/400 with KL 0.10 and nll loss -127.16
# Epoch: 2/19, i/N: 280/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 290/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 300/400 with KL 0.01 and nll loss -127.25
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.0380706787109375 and nll_test -127.22447204589844
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.16
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 320/400 with KL -0.01 and nll loss -127.27
# Epoch: 2/19, i/N: 330/400 with KL 0.09 and nll loss -127.17
# Epoch: 2/19, i/N: 340/400 with KL 0.07 and nll loss -127.19
# Epoch: 2/19, i/N: 350/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 360/400 with KL 0.04 and nll loss -127.23
# Epoch: 2/19, i/N: 370/400 with KL 0.00 and nll loss -127.26
# Epoch: 2/19, i/N: 380/400 with KL 0.03 and nll loss -127.23
# Epoch: 2/19, i/N: 390/400 with KL 0.02 and nll loss -127.24
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.05 and nll loss -127.21
# nan in sum squares
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.04048919677734375 and nll_test -127.22205352783203
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.19
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.00 and nll loss -127.26
# Epoch: 3/19, i/N: 20/400 with KL 0.08 and nll loss -127.18
# Epoch: 3/19, i/N: 30/400 with KL 0.08 and nll loss -127.19
# Epoch: 3/19, i/N: 40/400 with KL 0.05 and nll loss -127.21
# Epoch: 3/19, i/N: 50/400 with KL 0.03 and nll loss -127.23
# Epoch: 3/19, i/N: 60/400 with KL 0.11 and nll loss -127.16
# Epoch: 3/19, i/N: 70/400 with KL 0.12 and nll loss -127.14
# Epoch: 3/19, i/N: 80/400 with KL 0.00 and nll loss -127.26
# Epoch: 3/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 3/19, i/N: 100/400 with KL 0.02 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.03968048095703125 and nll_test -127.22286224365234
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.05 and nll loss -127.22
# Epoch: 3/19, i/N: 120/400 with KL 0.05 and nll loss -127.22
# Epoch: 3/19, i/N: 130/400 with KL 0.01 and nll loss -127.25
# Epoch: 3/19, i/N: 140/400 with KL 0.03 and nll loss -127.23
# Epoch: 3/19, i/N: 150/400 with KL -0.00 and nll loss -127.27
# Epoch: 3/19, i/N: 160/400 with KL 0.04 and nll loss -127.23
# Epoch: 3/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 3/19, i/N: 180/400 with KL 0.01 and nll loss -127.25
# Epoch: 3/19, i/N: 190/400 with KL 0.08 and nll loss -127.18
# Epoch: 3/19, i/N: 200/400 with KL 0.10 and nll loss -127.16
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.03601837158203125 and nll_test -127.22652435302734
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.17
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.06 and nll loss -127.21
# Epoch: 3/19, i/N: 220/400 with KL 0.08 and nll loss -127.18
# Epoch: 3/19, i/N: 230/400 with KL -0.02 and nll loss -127.28
# Epoch: 3/19, i/N: 240/400 with KL 0.11 and nll loss -127.16
# Epoch: 3/19, i/N: 250/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 260/400 with KL 0.02 and nll loss -127.25
# Epoch: 3/19, i/N: 270/400 with KL 0.07 and nll loss -127.19
# Epoch: 3/19, i/N: 280/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 290/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 300/400 with KL -0.01 and nll loss -127.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.03668212890625 and nll_test -127.22586059570312
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.18
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL -0.01 and nll loss -127.27
# Epoch: 3/19, i/N: 320/400 with KL 0.05 and nll loss -127.21
# Epoch: 3/19, i/N: 330/400 with KL 0.07 and nll loss -127.19
# Epoch: 3/19, i/N: 340/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 350/400 with KL -0.00 and nll loss -127.27
# Epoch: 3/19, i/N: 360/400 with KL -0.01 and nll loss -127.28
# Epoch: 3/19, i/N: 370/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 380/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 390/400 with KL 0.02 and nll loss -127.24
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL -0.00 and nll loss -127.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.03857421875 and nll_test -127.22396850585938
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.19
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.04 and nll loss -127.23
# Epoch: 4/19, i/N: 20/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 30/400 with KL 0.03 and nll loss -127.24
# Epoch: 4/19, i/N: 40/400 with KL 0.00 and nll loss -127.26
# Epoch: 4/19, i/N: 50/400 with KL 0.01 and nll loss -127.25
# Epoch: 4/19, i/N: 60/400 with KL 0.01 and nll loss -127.25
# Epoch: 4/19, i/N: 70/400 with KL 0.08 and nll loss -127.18
# Epoch: 4/19, i/N: 80/400 with KL 0.08 and nll loss -127.18
# Epoch: 4/19, i/N: 90/400 with KL -0.02 and nll loss -127.28
# Epoch: 4/19, i/N: 100/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.0395965576171875 and nll_test -127.22294616699219
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.16
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 120/400 with KL 0.05 and nll loss -127.21
# Epoch: 4/19, i/N: 130/400 with KL -0.02 and nll loss -127.28
# Epoch: 4/19, i/N: 140/400 with KL 0.05 and nll loss -127.21
# Epoch: 4/19, i/N: 150/400 with KL -0.01 and nll loss -127.27
# Epoch: 4/19, i/N: 160/400 with KL 0.05 and nll loss -127.22
# Epoch: 4/19, i/N: 170/400 with KL 0.05 and nll loss -127.22
# Epoch: 4/19, i/N: 180/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 190/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 200/400 with KL -0.00 and nll loss -127.26
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.0387725830078125 and nll_test -127.22377014160156
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.00 and nll loss -127.26
# Epoch: 4/19, i/N: 220/400 with KL -0.02 and nll loss -127.28
# Epoch: 4/19, i/N: 230/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 240/400 with KL 0.03 and nll loss -127.23
# Epoch: 4/19, i/N: 250/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 260/400 with KL 0.05 and nll loss -127.21
# Epoch: 4/19, i/N: 270/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 280/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 290/400 with KL 0.09 and nll loss -127.17
# Epoch: 4/19, i/N: 300/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.0417327880859375 and nll_test -127.22080993652344
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.12
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 320/400 with KL -0.01 and nll loss -127.27
# Epoch: 4/19, i/N: 330/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 340/400 with KL -0.01 and nll loss -127.28
# Epoch: 4/19, i/N: 350/400 with KL 0.01 and nll loss -127.26
# Epoch: 4/19, i/N: 360/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 370/400 with KL 0.06 and nll loss -127.21
# Epoch: 4/19, i/N: 380/400 with KL 0.07 and nll loss -127.20
# Epoch: 4/19, i/N: 390/400 with KL 0.06 and nll loss -127.20
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.09 and nll loss -127.17
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.04055023193359375 and nll_test -127.22199249267578
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.04 and nll loss -127.22
# Epoch: 5/19, i/N: 20/400 with KL 0.05 and nll loss -127.22
# Epoch: 5/19, i/N: 30/400 with KL 0.08 and nll loss -127.19
# Epoch: 5/19, i/N: 40/400 with KL 0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 50/400 with KL -0.05 and nll loss -127.31
# Epoch: 5/19, i/N: 60/400 with KL 0.11 and nll loss -127.15
# Epoch: 5/19, i/N: 70/400 with KL 0.04 and nll loss -127.22
# Epoch: 5/19, i/N: 80/400 with KL -0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 90/400 with KL -0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 100/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.0383758544921875 and nll_test -127.22416687011719
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.16
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.08 and nll loss -127.18
# Epoch: 5/19, i/N: 120/400 with KL 0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 130/400 with KL 0.07 and nll loss -127.19
# Epoch: 5/19, i/N: 140/400 with KL 0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 150/400 with KL 0.02 and nll loss -127.24
# Epoch: 5/19, i/N: 160/400 with KL 0.08 and nll loss -127.19
# Epoch: 5/19, i/N: 170/400 with KL 0.01 and nll loss -127.26
# Epoch: 5/19, i/N: 180/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 190/400 with KL 0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 200/400 with KL 0.05 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.04126739501953125 and nll_test -127.22127532958984
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.18
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.03 and nll loss -127.23
# Epoch: 5/19, i/N: 220/400 with KL 0.07 and nll loss -127.19
# Epoch: 5/19, i/N: 230/400 with KL 0.06 and nll loss -127.20
# Epoch: 5/19, i/N: 240/400 with KL 0.02 and nll loss -127.25
# Epoch: 5/19, i/N: 250/400 with KL 0.09 and nll loss -127.17
# Epoch: 5/19, i/N: 260/400 with KL 0.05 and nll loss -127.22
# Epoch: 5/19, i/N: 270/400 with KL 0.03 and nll loss -127.24
# Epoch: 5/19, i/N: 280/400 with KL 0.05 and nll loss -127.22
# Epoch: 5/19, i/N: 290/400 with KL 0.06 and nll loss -127.20
# Epoch: 5/19, i/N: 300/400 with KL 0.02 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.0386505126953125 and nll_test -127.22389221191406
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.19
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.04 and nll loss -127.23
# Epoch: 5/19, i/N: 320/400 with KL 0.02 and nll loss -127.24
# Epoch: 5/19, i/N: 330/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 340/400 with KL 0.01 and nll loss -127.25
# Epoch: 5/19, i/N: 350/400 with KL 0.01 and nll loss -127.25
# nan in sum squares
# Epoch: 5/19, i/N: 360/400 with KL 0.09 and nll loss -127.17
# Epoch: 5/19, i/N: 370/400 with KL 0.02 and nll loss -127.25
# Epoch: 5/19, i/N: 380/400 with KL 0.01 and nll loss -127.25
# Epoch: 5/19, i/N: 390/400 with KL 0.01 and nll loss -127.26
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.0387725830078125 and nll_test -127.22377014160156
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.13
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.05 and nll loss -127.21
# Epoch: 6/19, i/N: 20/400 with KL 0.15 and nll loss -127.11
# Epoch: 6/19, i/N: 30/400 with KL 0.06 and nll loss -127.20
# Epoch: 6/19, i/N: 40/400 with KL -0.03 and nll loss -127.29
# Epoch: 6/19, i/N: 50/400 with KL 0.07 and nll loss -127.19
# Epoch: 6/19, i/N: 60/400 with KL 0.02 and nll loss -127.24
# Epoch: 6/19, i/N: 70/400 with KL 0.01 and nll loss -127.25
# Epoch: 6/19, i/N: 80/400 with KL 0.09 and nll loss -127.18
# Epoch: 6/19, i/N: 90/400 with KL -0.00 and nll loss -127.26
# Epoch: 6/19, i/N: 100/400 with KL 0.06 and nll loss -127.21
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.03842926025390625 and nll_test -127.22411346435547
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.02 and nll loss -127.24
# Epoch: 6/19, i/N: 120/400 with KL -0.01 and nll loss -127.27
# Epoch: 6/19, i/N: 130/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 140/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 150/400 with KL 0.07 and nll loss -127.19
# Epoch: 6/19, i/N: 160/400 with KL 0.12 and nll loss -127.14
# Epoch: 6/19, i/N: 170/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 180/400 with KL 0.07 and nll loss -127.19
# Epoch: 6/19, i/N: 190/400 with KL 0.00 and nll loss -127.26
# Epoch: 6/19, i/N: 200/400 with KL 0.09 and nll loss -127.18
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.0321197509765625 and nll_test -127.23042297363281
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.18
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL -0.02 and nll loss -127.29
# Epoch: 6/19, i/N: 220/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 230/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 240/400 with KL 0.10 and nll loss -127.17
# Epoch: 6/19, i/N: 250/400 with KL 0.05 and nll loss -127.21
# Epoch: 6/19, i/N: 260/400 with KL -0.03 and nll loss -127.30
# Epoch: 6/19, i/N: 270/400 with KL -0.03 and nll loss -127.29
# Epoch: 6/19, i/N: 280/400 with KL 0.02 and nll loss -127.24
# Epoch: 6/19, i/N: 290/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 300/400 with KL 0.05 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.039093017578125 and nll_test -127.22344970703125
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.17
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL -0.00 and nll loss -127.27
# Epoch: 6/19, i/N: 320/400 with KL 0.01 and nll loss -127.25
# Epoch: 6/19, i/N: 330/400 with KL 0.04 and nll loss -127.23
# Epoch: 6/19, i/N: 340/400 with KL -0.00 and nll loss -127.27
# Epoch: 6/19, i/N: 350/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 360/400 with KL -0.03 and nll loss -127.29
# Epoch: 6/19, i/N: 370/400 with KL 0.07 and nll loss -127.20
# Epoch: 6/19, i/N: 380/400 with KL 0.01 and nll loss -127.25
# Epoch: 6/19, i/N: 390/400 with KL 0.03 and nll loss -127.23
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.03469085693359375 and nll_test -127.22785186767578
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.14
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 20/400 with KL 0.03 and nll loss -127.24
# Epoch: 7/19, i/N: 30/400 with KL 0.03 and nll loss -127.23
# Epoch: 7/19, i/N: 40/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 50/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 60/400 with KL -0.01 and nll loss -127.27
# Epoch: 7/19, i/N: 70/400 with KL 0.05 and nll loss -127.21
# Epoch: 7/19, i/N: 80/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 90/400 with KL -0.00 and nll loss -127.27
# Epoch: 7/19, i/N: 100/400 with KL 0.07 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.0365142822265625 and nll_test -127.22602844238281
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 120/400 with KL -0.03 and nll loss -127.30
# Epoch: 7/19, i/N: 130/400 with KL 0.06 and nll loss -127.21
# Epoch: 7/19, i/N: 140/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 150/400 with KL 0.08 and nll loss -127.18
# Epoch: 7/19, i/N: 160/400 with KL 0.06 and nll loss -127.20
# Epoch: 7/19, i/N: 170/400 with KL 0.05 and nll loss -127.21
# Epoch: 7/19, i/N: 180/400 with KL 0.03 and nll loss -127.23
# Epoch: 7/19, i/N: 190/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 200/400 with KL -0.02 and nll loss -127.29
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.03350830078125 and nll_test -127.22903442382812
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.16
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL -0.05 and nll loss -127.31
# Epoch: 7/19, i/N: 220/400 with KL 0.00 and nll loss -127.26
# Epoch: 7/19, i/N: 230/400 with KL 0.00 and nll loss -127.26
# Epoch: 7/19, i/N: 240/400 with KL 0.01 and nll loss -127.25
# Epoch: 7/19, i/N: 250/400 with KL 0.01 and nll loss -127.25
# Epoch: 7/19, i/N: 260/400 with KL 0.03 and nll loss -127.23
# Epoch: 7/19, i/N: 270/400 with KL 0.05 and nll loss -127.21
# Epoch: 7/19, i/N: 280/400 with KL 0.02 and nll loss -127.25
# Epoch: 7/19, i/N: 290/400 with KL 0.09 and nll loss -127.18
# Epoch: 7/19, i/N: 300/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.03589630126953125 and nll_test -127.22664642333984
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.18
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 320/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 330/400 with KL 0.04 and nll loss -127.22
# ...
# Epoch: 16/19, i/N: 20/400 with KL 0.08 and nll loss -127.19
# Epoch: 16/19, i/N: 30/400 with KL -0.00 and nll loss -127.27
# Epoch: 16/19, i/N: 40/400 with KL 0.06 and nll loss -127.21
# Epoch: 16/19, i/N: 50/400 with KL 0.07 and nll loss -127.20
# Epoch: 16/19, i/N: 60/400 with KL 0.04 and nll loss -127.23
# Epoch: 16/19, i/N: 70/400 with KL 0.03 and nll loss -127.23
# Epoch: 16/19, i/N: 80/400 with KL 0.01 and nll loss -127.25
# Epoch: 16/19, i/N: 90/400 with KL 0.07 and nll loss -127.20
# Epoch: 16/19, i/N: 100/400 with KL -0.01 and nll loss -127.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.03730010986328125 and nll_test -127.2252426147461
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.05 and nll loss -127.22
# Epoch: 16/19, i/N: 120/400 with KL 0.06 and nll loss -127.20
# Epoch: 16/19, i/N: 130/400 with KL -0.00 and nll loss -127.26
# Epoch: 16/19, i/N: 140/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 150/400 with KL 0.06 and nll loss -127.20
# Epoch: 16/19, i/N: 160/400 with KL 0.00 and nll loss -127.26
# Epoch: 16/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 16/19, i/N: 180/400 with KL 0.02 and nll loss -127.24
# Epoch: 16/19, i/N: 190/400 with KL 0.06 and nll loss -127.20
# Epoch: 16/19, i/N: 200/400 with KL 0.05 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.03229522705078125 and nll_test -127.2302474975586
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.16
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.04 and nll loss -127.22
# Epoch: 16/19, i/N: 220/400 with KL 0.05 and nll loss -127.22
# Epoch: 16/19, i/N: 230/400 with KL -0.04 and nll loss -127.30
# Epoch: 16/19, i/N: 240/400 with KL 0.07 and nll loss -127.19
# Epoch: 16/19, i/N: 250/400 with KL -0.05 and nll loss -127.31
# Epoch: 16/19, i/N: 260/400 with KL 0.05 and nll loss -127.21
# Epoch: 16/19, i/N: 270/400 with KL 0.04 and nll loss -127.22
# Epoch: 16/19, i/N: 280/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 290/400 with KL 0.09 and nll loss -127.17
# Epoch: 16/19, i/N: 300/400 with KL 0.05 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.0321197509765625 and nll_test -127.23042297363281
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.19
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.05 and nll loss -127.22
# Epoch: 16/19, i/N: 320/400 with KL 0.01 and nll loss -127.25
# Epoch: 16/19, i/N: 330/400 with KL -0.02 and nll loss -127.28
# Epoch: 16/19, i/N: 340/400 with KL 0.05 and nll loss -127.21
# Epoch: 16/19, i/N: 350/400 with KL 0.06 and nll loss -127.21
# Epoch: 16/19, i/N: 360/400 with KL 0.04 and nll loss -127.23
# Epoch: 16/19, i/N: 370/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 380/400 with KL -0.00 and nll loss -127.26
# Epoch: 16/19, i/N: 390/400 with KL 0.03 and nll loss -127.23
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.032073974609375 and nll_test -127.23046875
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.19
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.04 and nll loss -127.22
# Epoch: 17/19, i/N: 20/400 with KL 0.10 and nll loss -127.17
# Epoch: 17/19, i/N: 30/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 40/400 with KL -0.02 and nll loss -127.28
# Epoch: 17/19, i/N: 50/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 60/400 with KL 0.09 and nll loss -127.17
# Epoch: 17/19, i/N: 70/400 with KL -0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 80/400 with KL 0.09 and nll loss -127.17
# Epoch: 17/19, i/N: 90/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 100/400 with KL 0.02 and nll loss -127.25
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.0318603515625 and nll_test -127.23068237304688
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.19
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 120/400 with KL 0.03 and nll loss -127.24
# Epoch: 17/19, i/N: 130/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 140/400 with KL 0.01 and nll loss -127.25
# Epoch: 17/19, i/N: 150/400 with KL -0.01 and nll loss -127.28
# Epoch: 17/19, i/N: 160/400 with KL 0.03 and nll loss -127.24
# Epoch: 17/19, i/N: 170/400 with KL 0.01 and nll loss -127.26
# Epoch: 17/19, i/N: 180/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 190/400 with KL 0.06 and nll loss -127.21
# Epoch: 17/19, i/N: 200/400 with KL 0.05 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.03173828125 and nll_test -127.23080444335938
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.19
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL -0.01 and nll loss -127.27
# Epoch: 17/19, i/N: 220/400 with KL 0.01 and nll loss -127.25
# Epoch: 17/19, i/N: 230/400 with KL 0.10 and nll loss -127.16
# Epoch: 17/19, i/N: 240/400 with KL 0.10 and nll loss -127.16
# Epoch: 17/19, i/N: 250/400 with KL 0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 260/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 270/400 with KL 0.04 and nll loss -127.22
# Epoch: 17/19, i/N: 280/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 290/400 with KL 0.04 and nll loss -127.23
# Epoch: 17/19, i/N: 300/400 with KL -0.00 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.03399658203125 and nll_test -127.22854614257812
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.20
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.11 and nll loss -127.15
# Epoch: 17/19, i/N: 320/400 with KL 0.10 and nll loss -127.16
# Epoch: 17/19, i/N: 330/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 340/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 350/400 with KL -0.02 and nll loss -127.28
# Epoch: 17/19, i/N: 360/400 with KL 0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 370/400 with KL 0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 380/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 390/400 with KL -0.01 and nll loss -127.27
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.04 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.03093719482421875 and nll_test -127.23160552978516
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.20
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.02 and nll loss -127.25
# Epoch: 18/19, i/N: 20/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 30/400 with KL 0.06 and nll loss -127.20
# Epoch: 18/19, i/N: 40/400 with KL 0.07 and nll loss -127.19
# Epoch: 18/19, i/N: 50/400 with KL 0.02 and nll loss -127.25
# Epoch: 18/19, i/N: 60/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 70/400 with KL -0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 80/400 with KL 0.03 and nll loss -127.24
# Epoch: 18/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 100/400 with KL 0.05 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.03197479248046875 and nll_test -127.2305679321289
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL -0.03 and nll loss -127.29
# Epoch: 18/19, i/N: 120/400 with KL -0.01 and nll loss -127.27
# Epoch: 18/19, i/N: 130/400 with KL 0.07 and nll loss -127.19
# Epoch: 18/19, i/N: 140/400 with KL -0.03 and nll loss -127.29
# Epoch: 18/19, i/N: 150/400 with KL 0.02 and nll loss -127.25
# Epoch: 18/19, i/N: 160/400 with KL 0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 170/400 with KL -0.04 and nll loss -127.30
# Epoch: 18/19, i/N: 180/400 with KL 0.07 and nll loss -127.20
# Epoch: 18/19, i/N: 190/400 with KL -0.01 and nll loss -127.27
# Epoch: 18/19, i/N: 200/400 with KL 0.05 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.03289794921875 and nll_test -127.22964477539062
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.21
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.04 and nll loss -127.22
# Epoch: 18/19, i/N: 220/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 230/400 with KL -0.02 and nll loss -127.28
# Epoch: 18/19, i/N: 240/400 with KL -0.02 and nll loss -127.28
# Epoch: 18/19, i/N: 250/400 with KL 0.04 and nll loss -127.22
# Epoch: 18/19, i/N: 260/400 with KL 0.04 and nll loss -127.23
# Epoch: 18/19, i/N: 270/400 with KL -0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 280/400 with KL 0.09 and nll loss -127.17
# Epoch: 18/19, i/N: 290/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 300/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.0348968505859375 and nll_test -127.22764587402344
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.22
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.03 and nll loss -127.23
# Epoch: 18/19, i/N: 320/400 with KL -0.01 and nll loss -127.27
# Epoch: 18/19, i/N: 330/400 with KL 0.03 and nll loss -127.23
# Epoch: 18/19, i/N: 340/400 with KL 0.04 and nll loss -127.22
# Epoch: 18/19, i/N: 350/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 360/400 with KL 0.05 and nll loss -127.22
# Epoch: 18/19, i/N: 370/400 with KL 0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 380/400 with KL -0.07 and nll loss -127.33
# Epoch: 18/19, i/N: 390/400 with KL 0.07 and nll loss -127.19
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.02 and nll loss -127.25
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.03094482421875 and nll_test -127.23159790039062
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.15
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 20/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 30/400 with KL 0.06 and nll loss -127.20
# Epoch: 19/19, i/N: 40/400 with KL 0.05 and nll loss -127.21
# Epoch: 19/19, i/N: 50/400 with KL 0.07 and nll loss -127.20
# Epoch: 19/19, i/N: 60/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 70/400 with KL 0.10 and nll loss -127.17
# Epoch: 19/19, i/N: 80/400 with KL -0.04 and nll loss -127.31
# Epoch: 19/19, i/N: 90/400 with KL 0.10 and nll loss -127.17
# Epoch: 19/19, i/N: 100/400 with KL 0.05 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.0324859619140625 and nll_test -127.23005676269531
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL -0.00 and nll loss -127.27
# Epoch: 19/19, i/N: 120/400 with KL -0.03 and nll loss -127.29
# Epoch: 19/19, i/N: 130/400 with KL 0.00 and nll loss -127.26
# Epoch: 19/19, i/N: 140/400 with KL 0.07 and nll loss -127.19
# Epoch: 19/19, i/N: 150/400 with KL -0.05 and nll loss -127.31
# Epoch: 19/19, i/N: 160/400 with KL 0.00 and nll loss -127.26
# Epoch: 19/19, i/N: 170/400 with KL -0.00 and nll loss -127.26
# Epoch: 19/19, i/N: 180/400 with KL 0.08 and nll loss -127.18
# Epoch: 19/19, i/N: 190/400 with KL 0.10 and nll loss -127.16
# Epoch: 19/19, i/N: 200/400 with KL 0.05 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.030517578125 and nll_test -127.23202514648438
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.16
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL -0.02 and nll loss -127.28
# Epoch: 19/19, i/N: 220/400 with KL 0.02 and nll loss -127.25
# Epoch: 19/19, i/N: 230/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 240/400 with KL 0.02 and nll loss -127.24
# Epoch: 19/19, i/N: 250/400 with KL 0.03 and nll loss -127.24
# Epoch: 19/19, i/N: 260/400 with KL 0.02 and nll loss -127.25
# Epoch: 19/19, i/N: 270/400 with KL 0.10 and nll loss -127.16
# Epoch: 19/19, i/N: 280/400 with KL 0.04 and nll loss -127.22
# Epoch: 19/19, i/N: 290/400 with KL -0.01 and nll loss -127.27
# Epoch: 19/19, i/N: 300/400 with KL 0.02 and nll loss -127.25
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.03310394287109375 and nll_test -127.22943878173828
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 320/400 with KL 0.01 and nll loss -127.25
# Epoch: 19/19, i/N: 330/400 with KL -0.01 and nll loss -127.27
# Epoch: 19/19, i/N: 340/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 350/400 with KL 0.02 and nll loss -127.24
# Epoch: 19/19, i/N: 360/400 with KL 0.14 and nll loss -127.13
# Epoch: 19/19, i/N: 370/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 380/400 with KL 0.04 and nll loss -127.22
# Epoch: 19/19, i/N: 390/400 with KL -0.01 and nll loss -127.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.0321197509765625 and nll_test -127.23042297363281
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.20
# #####################

# %% [markdown]
# ### Coupling Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='spline',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 num_centers=NUM_CENTERS)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_s')
# Out:
# ##### Coupling Cylindrical Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_128" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_128</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_128/runs/1223_121810" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_128/runs/1223_121810</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (3): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (4): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=126, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1512, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=1638, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=126, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.17 and nll loss -127.09
# Epoch: 0/19, i/N: 20/400 with KL 0.13 and nll loss -127.13
# Epoch: 0/19, i/N: 30/400 with KL 0.01 and nll loss -127.25
# Epoch: 0/19, i/N: 40/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 50/400 with KL 0.08 and nll loss -127.18
# Epoch: 0/19, i/N: 60/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 70/400 with KL 0.09 and nll loss -127.17
# Epoch: 0/19, i/N: 80/400 with KL 0.03 and nll loss -127.23
# Epoch: 0/19, i/N: 90/400 with KL 0.06 and nll loss -127.20
# Epoch: 0/19, i/N: 100/400 with KL 0.11 and nll loss -127.15
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.06224822998046875 and nll_test -127.2002944946289
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.15
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.08 and nll loss -127.19
# Epoch: 0/19, i/N: 120/400 with KL -0.03 and nll loss -127.29
# Epoch: 0/19, i/N: 130/400 with KL 0.06 and nll loss -127.20
# Epoch: 0/19, i/N: 140/400 with KL 0.07 and nll loss -127.20
# Epoch: 0/19, i/N: 150/400 with KL 0.11 and nll loss -127.15
# Epoch: 0/19, i/N: 160/400 with KL 0.06 and nll loss -127.20
# Epoch: 0/19, i/N: 170/400 with KL 0.12 and nll loss -127.14
# Epoch: 0/19, i/N: 180/400 with KL -0.05 and nll loss -127.31
# Epoch: 0/19, i/N: 190/400 with KL 0.11 and nll loss -127.15
# Epoch: 0/19, i/N: 200/400 with KL 0.10 and nll loss -127.16
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.0574493408203125 and nll_test -127.20509338378906
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.15
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 220/400 with KL 0.03 and nll loss -127.24
# Epoch: 0/19, i/N: 230/400 with KL 0.03 and nll loss -127.24
# Epoch: 0/19, i/N: 240/400 with KL 0.05 and nll loss -127.22
# Epoch: 0/19, i/N: 250/400 with KL 0.05 and nll loss -127.21
# Epoch: 0/19, i/N: 260/400 with KL 0.02 and nll loss -127.24
# Epoch: 0/19, i/N: 270/400 with KL 0.04 and nll loss -127.23
# Epoch: 0/19, i/N: 280/400 with KL 0.04 and nll loss -127.22
# Epoch: 0/19, i/N: 290/400 with KL 0.04 and nll loss -127.22
# Epoch: 0/19, i/N: 300/400 with KL 0.04 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.05155181884765625 and nll_test -127.21099090576172
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.02 and nll loss -127.25
# Epoch: 0/19, i/N: 320/400 with KL 0.05 and nll loss -127.21
# Epoch: 0/19, i/N: 330/400 with KL 0.01 and nll loss -127.25
# Epoch: 0/19, i/N: 340/400 with KL 0.10 and nll loss -127.17
# Epoch: 0/19, i/N: 350/400 with KL 0.07 and nll loss -127.19
# Epoch: 0/19, i/N: 360/400 with KL 0.06 and nll loss -127.21
# Epoch: 0/19, i/N: 370/400 with KL 0.05 and nll loss -127.22
# Epoch: 0/19, i/N: 380/400 with KL 0.03 and nll loss -127.24
# Epoch: 0/19, i/N: 390/400 with KL 0.03 and nll loss -127.24
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.0466461181640625 and nll_test -127.21589660644531
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.15
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.04 and nll loss -127.23
# Epoch: 1/19, i/N: 20/400 with KL 0.10 and nll loss -127.16
# Epoch: 1/19, i/N: 30/400 with KL 0.06 and nll loss -127.20
# Epoch: 1/19, i/N: 40/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 50/400 with KL 0.08 and nll loss -127.18
# Epoch: 1/19, i/N: 60/400 with KL 0.07 and nll loss -127.19
# Epoch: 1/19, i/N: 70/400 with KL 0.00 and nll loss -127.26
# Epoch: 1/19, i/N: 80/400 with KL 0.06 and nll loss -127.20
# Epoch: 1/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 1/19, i/N: 100/400 with KL 0.01 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.04636383056640625 and nll_test -127.21617889404297
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.01 and nll loss -127.25
# Epoch: 1/19, i/N: 120/400 with KL 0.03 and nll loss -127.23
# Epoch: 1/19, i/N: 130/400 with KL 0.04 and nll loss -127.22
# Epoch: 1/19, i/N: 140/400 with KL 0.07 and nll loss -127.19
# Epoch: 1/19, i/N: 150/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 160/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 170/400 with KL 0.06 and nll loss -127.20
# Epoch: 1/19, i/N: 180/400 with KL 0.10 and nll loss -127.16
# Epoch: 1/19, i/N: 190/400 with KL 0.06 and nll loss -127.20
# Epoch: 1/19, i/N: 200/400 with KL 0.02 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.04586029052734375 and nll_test -127.21668243408203
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.04 and nll loss -127.22
# Epoch: 1/19, i/N: 220/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 230/400 with KL -0.00 and nll loss -127.26
# Epoch: 1/19, i/N: 240/400 with KL 0.04 and nll loss -127.22
# Epoch: 1/19, i/N: 250/400 with KL 0.00 and nll loss -127.26
# Epoch: 1/19, i/N: 260/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 270/400 with KL 0.13 and nll loss -127.14
# Epoch: 1/19, i/N: 280/400 with KL 0.11 and nll loss -127.16
# Epoch: 1/19, i/N: 290/400 with KL 0.01 and nll loss -127.26
# Epoch: 1/19, i/N: 300/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.04071044921875 and nll_test -127.22183227539062
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.05 and nll loss -127.21
# Epoch: 1/19, i/N: 320/400 with KL 0.06 and nll loss -127.21
# Epoch: 1/19, i/N: 330/400 with KL 0.04 and nll loss -127.23
# Epoch: 1/19, i/N: 340/400 with KL 0.07 and nll loss -127.20
# Epoch: 1/19, i/N: 350/400 with KL 0.06 and nll loss -127.21
# Epoch: 1/19, i/N: 360/400 with KL 0.06 and nll loss -127.21
# Epoch: 1/19, i/N: 370/400 with KL -0.02 and nll loss -127.28
# Epoch: 1/19, i/N: 380/400 with KL 0.02 and nll loss -127.24
# Epoch: 1/19, i/N: 390/400 with KL 0.03 and nll loss -127.24
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.02 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.04166412353515625 and nll_test -127.22087860107422
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 20/400 with KL 0.03 and nll loss -127.23
# Epoch: 2/19, i/N: 30/400 with KL 0.00 and nll loss -127.26
# Epoch: 2/19, i/N: 40/400 with KL 0.03 and nll loss -127.23
# Epoch: 2/19, i/N: 50/400 with KL 0.06 and nll loss -127.21
# Epoch: 2/19, i/N: 60/400 with KL 0.03 and nll loss -127.23
# Epoch: 2/19, i/N: 70/400 with KL 0.01 and nll loss -127.25
# Epoch: 2/19, i/N: 80/400 with KL 0.11 and nll loss -127.16
# Epoch: 2/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 2/19, i/N: 100/400 with KL 0.05 and nll loss -127.21
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.0406951904296875 and nll_test -127.22184753417969
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.20
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.06 and nll loss -127.21
# Epoch: 2/19, i/N: 120/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 130/400 with KL 0.03 and nll loss -127.24
# Epoch: 2/19, i/N: 140/400 with KL 0.08 and nll loss -127.19
# Epoch: 2/19, i/N: 150/400 with KL 0.07 and nll loss -127.19
# Epoch: 2/19, i/N: 160/400 with KL 0.01 and nll loss -127.25
# Epoch: 2/19, i/N: 170/400 with KL 0.12 and nll loss -127.14
# Epoch: 2/19, i/N: 180/400 with KL 0.03 and nll loss -127.24
# Epoch: 2/19, i/N: 190/400 with KL 0.06 and nll loss -127.20
# Epoch: 2/19, i/N: 200/400 with KL -0.03 and nll loss -127.29
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.0404052734375 and nll_test -127.22213745117188
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.19
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.07 and nll loss -127.19
# Epoch: 2/19, i/N: 220/400 with KL 0.02 and nll loss -127.25
# Epoch: 2/19, i/N: 230/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 240/400 with KL 0.07 and nll loss -127.19
# Epoch: 2/19, i/N: 250/400 with KL 0.06 and nll loss -127.20
# Epoch: 2/19, i/N: 260/400 with KL 0.11 and nll loss -127.15
# Epoch: 2/19, i/N: 270/400 with KL 0.00 and nll loss -127.26
# Epoch: 2/19, i/N: 280/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 290/400 with KL 0.08 and nll loss -127.18
# Epoch: 2/19, i/N: 300/400 with KL 0.03 and nll loss -127.24
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.04233551025390625 and nll_test -127.22020721435547
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.14
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.09 and nll loss -127.17
# Epoch: 2/19, i/N: 320/400 with KL 0.13 and nll loss -127.13
# Epoch: 2/19, i/N: 330/400 with KL 0.05 and nll loss -127.22
# Epoch: 2/19, i/N: 340/400 with KL 0.04 and nll loss -127.22
# Epoch: 2/19, i/N: 350/400 with KL 0.05 and nll loss -127.21
# Epoch: 2/19, i/N: 360/400 with KL 0.02 and nll loss -127.24
# Epoch: 2/19, i/N: 370/400 with KL 0.01 and nll loss -127.26
# Epoch: 2/19, i/N: 380/400 with KL 0.07 and nll loss -127.19
# Epoch: 2/19, i/N: 390/400 with KL 0.08 and nll loss -127.19
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.06 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.0393218994140625 and nll_test -127.22322082519531
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.08 and nll loss -127.18
# Epoch: 3/19, i/N: 20/400 with KL 0.05 and nll loss -127.21
# Epoch: 3/19, i/N: 30/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 40/400 with KL 0.04 and nll loss -127.23
# nan in sum squares
# Epoch: 3/19, i/N: 50/400 with KL -0.01 and nll loss -127.27
# Epoch: 3/19, i/N: 60/400 with KL 0.05 and nll loss -127.22
# Epoch: 3/19, i/N: 70/400 with KL 0.03 and nll loss -127.23
# nan in sum squares
# Epoch: 3/19, i/N: 80/400 with KL -0.06 and nll loss -127.32
# Epoch: 3/19, i/N: 90/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 100/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.0394287109375 and nll_test -127.22311401367188
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.15
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL -0.04 and nll loss -127.30
# Epoch: 3/19, i/N: 120/400 with KL 0.03 and nll loss -127.24
# Epoch: 3/19, i/N: 130/400 with KL -0.00 and nll loss -127.27
# Epoch: 3/19, i/N: 140/400 with KL 0.03 and nll loss -127.23
# Epoch: 3/19, i/N: 150/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 160/400 with KL -0.03 and nll loss -127.30
# Epoch: 3/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 3/19, i/N: 180/400 with KL 0.06 and nll loss -127.20
# Epoch: 3/19, i/N: 190/400 with KL -0.03 and nll loss -127.29
# Epoch: 3/19, i/N: 200/400 with KL 0.00 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.0385589599609375 and nll_test -127.22398376464844
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.18
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.04 and nll loss -127.23
# Epoch: 3/19, i/N: 220/400 with KL 0.00 and nll loss -127.26
# Epoch: 3/19, i/N: 230/400 with KL 0.01 and nll loss -127.26
# Epoch: 3/19, i/N: 240/400 with KL 0.02 and nll loss -127.25
# nan in sum squares
# Epoch: 3/19, i/N: 250/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 260/400 with KL 0.07 and nll loss -127.19
# nan in sum squares
# Epoch: 3/19, i/N: 270/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 280/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 290/400 with KL 0.07 and nll loss -127.19
# Epoch: 3/19, i/N: 300/400 with KL 0.10 and nll loss -127.16
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.03885650634765625 and nll_test -127.22368621826172
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.17
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.01 and nll loss -127.26
# Epoch: 3/19, i/N: 320/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 330/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 340/400 with KL 0.02 and nll loss -127.24
# Epoch: 3/19, i/N: 350/400 with KL -0.00 and nll loss -127.26
# Epoch: 3/19, i/N: 360/400 with KL 0.13 and nll loss -127.13
# Epoch: 3/19, i/N: 370/400 with KL 0.02 and nll loss -127.25
# Epoch: 3/19, i/N: 380/400 with KL 0.09 and nll loss -127.17
# Epoch: 3/19, i/N: 390/400 with KL 0.06 and nll loss -127.21
# nan in sum squares
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL -0.02 and nll loss -127.28
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.04019927978515625 and nll_test -127.22234344482422
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.21
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 20/400 with KL 0.12 and nll loss -127.14
# Epoch: 4/19, i/N: 30/400 with KL 0.05 and nll loss -127.22
# Epoch: 4/19, i/N: 40/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 50/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 60/400 with KL 0.09 and nll loss -127.17
# Epoch: 4/19, i/N: 70/400 with KL 0.07 and nll loss -127.19
# Epoch: 4/19, i/N: 80/400 with KL 0.01 and nll loss -127.25
# Epoch: 4/19, i/N: 90/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 100/400 with KL 0.14 and nll loss -127.13
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.0399932861328125 and nll_test -127.22254943847656
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.18
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.05 and nll loss -127.21
# Epoch: 4/19, i/N: 120/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 130/400 with KL 0.03 and nll loss -127.24
# Epoch: 4/19, i/N: 140/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 150/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 160/400 with KL 0.07 and nll loss -127.19
# Epoch: 4/19, i/N: 170/400 with KL 0.01 and nll loss -127.25
# Epoch: 4/19, i/N: 180/400 with KL 0.11 and nll loss -127.15
# Epoch: 4/19, i/N: 190/400 with KL 0.08 and nll loss -127.19
# Epoch: 4/19, i/N: 200/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.03586578369140625 and nll_test -127.22667694091797
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.17
# #####################
#
# nan in sum squares
# Epoch: 4/19, i/N: 210/400 with KL 0.09 and nll loss -127.17
# Epoch: 4/19, i/N: 220/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 230/400 with KL -0.02 and nll loss -127.28
# Epoch: 4/19, i/N: 240/400 with KL 0.06 and nll loss -127.21
# Epoch: 4/19, i/N: 250/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 260/400 with KL 0.12 and nll loss -127.14
# Epoch: 4/19, i/N: 270/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 280/400 with KL 0.07 and nll loss -127.19
# Epoch: 4/19, i/N: 290/400 with KL 0.03 and nll loss -127.24
# Epoch: 4/19, i/N: 300/400 with KL 0.07 and nll loss -127.19
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.0372467041015625 and nll_test -127.22529602050781
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.16
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 320/400 with KL 0.05 and nll loss -127.21
# Epoch: 4/19, i/N: 330/400 with KL 0.06 and nll loss -127.20
# Epoch: 4/19, i/N: 340/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 350/400 with KL 0.08 and nll loss -127.18
# Epoch: 4/19, i/N: 360/400 with KL 0.02 and nll loss -127.24
# Epoch: 4/19, i/N: 370/400 with KL 0.08 and nll loss -127.19
# Epoch: 4/19, i/N: 380/400 with KL 0.04 and nll loss -127.22
# Epoch: 4/19, i/N: 390/400 with KL 0.06 and nll loss -127.21
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.03 and nll loss -127.24
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.04058837890625 and nll_test -127.22195434570312
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.15
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.05 and nll loss -127.22
# Epoch: 5/19, i/N: 20/400 with KL 0.00 and nll loss -127.26
# Epoch: 5/19, i/N: 30/400 with KL 0.02 and nll loss -127.24
# Epoch: 5/19, i/N: 40/400 with KL 0.03 and nll loss -127.24
# Epoch: 5/19, i/N: 50/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 60/400 with KL 0.03 and nll loss -127.23
# Epoch: 5/19, i/N: 70/400 with KL 0.07 and nll loss -127.19
# Epoch: 5/19, i/N: 80/400 with KL -0.02 and nll loss -127.29
# Epoch: 5/19, i/N: 90/400 with KL 0.05 and nll loss -127.21
# Epoch: 5/19, i/N: 100/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.03540802001953125 and nll_test -127.22713470458984
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.16
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.04 and nll loss -127.22
# Epoch: 5/19, i/N: 120/400 with KL 0.10 and nll loss -127.16
# Epoch: 5/19, i/N: 130/400 with KL 0.08 and nll loss -127.18
# Epoch: 5/19, i/N: 140/400 with KL 0.08 and nll loss -127.19
# Epoch: 5/19, i/N: 150/400 with KL 0.04 and nll loss -127.22
# Epoch: 5/19, i/N: 160/400 with KL 0.02 and nll loss -127.24
# Epoch: 5/19, i/N: 170/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 180/400 with KL 0.07 and nll loss -127.19
# Epoch: 5/19, i/N: 190/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 200/400 with KL 0.04 and nll loss -127.22
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.03821563720703125 and nll_test -127.22432708740234
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.18
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.04 and nll loss -127.22
# Epoch: 5/19, i/N: 220/400 with KL 0.03 and nll loss -127.23
# Epoch: 5/19, i/N: 230/400 with KL 0.03 and nll loss -127.23
# Epoch: 5/19, i/N: 240/400 with KL 0.03 and nll loss -127.24
# Epoch: 5/19, i/N: 250/400 with KL 0.06 and nll loss -127.21
# Epoch: 5/19, i/N: 260/400 with KL 0.08 and nll loss -127.18
# Epoch: 5/19, i/N: 270/400 with KL 0.08 and nll loss -127.19
# Epoch: 5/19, i/N: 280/400 with KL 0.03 and nll loss -127.23
# Epoch: 5/19, i/N: 290/400 with KL 0.06 and nll loss -127.20
# Epoch: 5/19, i/N: 300/400 with KL 0.00 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.03936767578125 and nll_test -127.22317504882812
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.20
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL -0.01 and nll loss -127.27
# Epoch: 5/19, i/N: 320/400 with KL 0.07 and nll loss -127.20
# Epoch: 5/19, i/N: 330/400 with KL -0.03 and nll loss -127.29
# Epoch: 5/19, i/N: 340/400 with KL 0.08 and nll loss -127.18
# Epoch: 5/19, i/N: 350/400 with KL -0.05 and nll loss -127.31
# Epoch: 5/19, i/N: 360/400 with KL 0.08 and nll loss -127.18
# Epoch: 5/19, i/N: 370/400 with KL 0.05 and nll loss -127.21
# Epoch: 5/19, i/N: 380/400 with KL 0.02 and nll loss -127.24
# Epoch: 5/19, i/N: 390/400 with KL 0.08 and nll loss -127.19
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.01 and nll loss -127.25
# nan in sum squares
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.03507232666015625 and nll_test -127.22747039794922
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.15
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.07 and nll loss -127.20
# Epoch: 6/19, i/N: 20/400 with KL 0.10 and nll loss -127.17
# Epoch: 6/19, i/N: 30/400 with KL -0.01 and nll loss -127.27
# Epoch: 6/19, i/N: 40/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 50/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 60/400 with KL 0.07 and nll loss -127.19
# Epoch: 6/19, i/N: 70/400 with KL 0.09 and nll loss -127.18
# Epoch: 6/19, i/N: 80/400 with KL 0.02 and nll loss -127.24
# Epoch: 6/19, i/N: 90/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 100/400 with KL -0.03 and nll loss -127.30
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.03760528564453125 and nll_test -127.22493743896484
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.18
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL -0.03 and nll loss -127.29
# Epoch: 6/19, i/N: 120/400 with KL 0.07 and nll loss -127.20
# Epoch: 6/19, i/N: 130/400 with KL 0.01 and nll loss -127.25
# Epoch: 6/19, i/N: 140/400 with KL 0.04 and nll loss -127.23
# Epoch: 6/19, i/N: 150/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 160/400 with KL 0.01 and nll loss -127.25
# Epoch: 6/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 180/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 190/400 with KL 0.06 and nll loss -127.20
# Epoch: 6/19, i/N: 200/400 with KL -0.03 and nll loss -127.30
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.034698486328125 and nll_test -127.22784423828125
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.16
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 220/400 with KL 0.04 and nll loss -127.22
# Epoch: 6/19, i/N: 230/400 with KL -0.05 and nll loss -127.31
# Epoch: 6/19, i/N: 240/400 with KL 0.01 and nll loss -127.26
# Epoch: 6/19, i/N: 250/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 260/400 with KL -0.05 and nll loss -127.31
# Epoch: 6/19, i/N: 270/400 with KL -0.01 and nll loss -127.27
# Epoch: 6/19, i/N: 280/400 with KL 0.04 and nll loss -127.23
# Epoch: 6/19, i/N: 290/400 with KL -0.01 and nll loss -127.27
# Epoch: 6/19, i/N: 300/400 with KL 0.06 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.03508758544921875 and nll_test -127.22745513916016
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.19
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.09 and nll loss -127.17
# Epoch: 6/19, i/N: 320/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 330/400 with KL 0.06 and nll loss -127.20
# Epoch: 6/19, i/N: 340/400 with KL 0.12 and nll loss -127.14
# Epoch: 6/19, i/N: 350/400 with KL 0.08 and nll loss -127.18
# Epoch: 6/19, i/N: 360/400 with KL 0.04 and nll loss -127.23
# Epoch: 6/19, i/N: 370/400 with KL -0.01 and nll loss -127.27
# Epoch: 6/19, i/N: 380/400 with KL 0.03 and nll loss -127.23
# Epoch: 6/19, i/N: 390/400 with KL 0.05 and nll loss -127.22
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.00 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.03963470458984375 and nll_test -127.22290802001953
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.17
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL -0.06 and nll loss -127.32
# Epoch: 7/19, i/N: 20/400 with KL 0.01 and nll loss -127.25
# Epoch: 7/19, i/N: 30/400 with KL 0.04 and nll loss -127.22
# Epoch: 7/19, i/N: 40/400 with KL -0.02 and nll loss -127.29
# Epoch: 7/19, i/N: 50/400 with KL 0.09 and nll loss -127.17
# Epoch: 7/19, i/N: 60/400 with KL 0.04 and nll loss -127.22
# Epoch: 7/19, i/N: 70/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 80/400 with KL 0.03 and nll loss -127.23
# Epoch: 7/19, i/N: 90/400 with KL 0.01 and nll loss -127.25
# Epoch: 7/19, i/N: 100/400 with KL 0.09 and nll loss -127.17
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.03644561767578125 and nll_test -127.2260971069336
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.16
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL -0.00 and nll loss -127.27
# Epoch: 7/19, i/N: 120/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 130/400 with KL 0.08 and nll loss -127.18
# Epoch: 7/19, i/N: 140/400 with KL 0.07 and nll loss -127.20
# Epoch: 7/19, i/N: 150/400 with KL 0.07 and nll loss -127.19
# Epoch: 7/19, i/N: 160/400 with KL 0.02 and nll loss -127.24
# Epoch: 7/19, i/N: 170/400 with KL 0.06 and nll loss -127.20
# Epoch: 7/19, i/N: 180/400 with KL 0.04 and nll loss -127.22
# Epoch: 7/19, i/N: 190/400 with KL -0.00 and nll loss -127.26
# Epoch: 7/19, i/N: 200/400 with KL 0.03 and nll loss -127.23
#
# ...
# Epoch: 16/19, i/N: 50/400 with KL 0.06 and nll loss -127.21
# Epoch: 16/19, i/N: 60/400 with KL 0.05 and nll loss -127.22
# Epoch: 16/19, i/N: 70/400 with KL 0.01 and nll loss -127.25
# Epoch: 16/19, i/N: 80/400 with KL -0.01 and nll loss -127.28
# nan in sum squares
# Epoch: 16/19, i/N: 90/400 with KL -0.01 and nll loss -127.28
# Epoch: 16/19, i/N: 100/400 with KL -0.03 and nll loss -127.30
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.03301239013671875 and nll_test -127.22953033447266
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.22
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.04 and nll loss -127.22
# Epoch: 16/19, i/N: 120/400 with KL 0.07 and nll loss -127.19
# Epoch: 16/19, i/N: 130/400 with KL 0.01 and nll loss -127.25
# Epoch: 16/19, i/N: 140/400 with KL 0.01 and nll loss -127.25
# Epoch: 16/19, i/N: 150/400 with KL -0.01 and nll loss -127.28
# Epoch: 16/19, i/N: 160/400 with KL 0.09 and nll loss -127.17
# Epoch: 16/19, i/N: 170/400 with KL 0.05 and nll loss -127.22
# Epoch: 16/19, i/N: 180/400 with KL 0.05 and nll loss -127.21
# Epoch: 16/19, i/N: 190/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 200/400 with KL 0.09 and nll loss -127.17
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.03577423095703125 and nll_test -127.22676849365234
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.03 and nll loss -127.23
# Epoch: 16/19, i/N: 220/400 with KL 0.02 and nll loss -127.24
# Epoch: 16/19, i/N: 230/400 with KL 0.04 and nll loss -127.22
# Epoch: 16/19, i/N: 240/400 with KL 0.01 and nll loss -127.26
# Epoch: 16/19, i/N: 250/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 260/400 with KL 0.08 and nll loss -127.18
# Epoch: 16/19, i/N: 270/400 with KL 0.07 and nll loss -127.19
# Epoch: 16/19, i/N: 280/400 with KL 0.08 and nll loss -127.19
# Epoch: 16/19, i/N: 290/400 with KL 0.02 and nll loss -127.24
# Epoch: 16/19, i/N: 300/400 with KL 0.02 and nll loss -127.24
# nan in sum squares
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.03182220458984375 and nll_test -127.23072052001953
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.16
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL -0.02 and nll loss -127.28
# Epoch: 16/19, i/N: 320/400 with KL 0.11 and nll loss -127.15
# Epoch: 16/19, i/N: 330/400 with KL 0.08 and nll loss -127.18
# nan in sum squares
# Epoch: 16/19, i/N: 340/400 with KL 0.09 and nll loss -127.18
# Epoch: 16/19, i/N: 350/400 with KL 0.09 and nll loss -127.18
# Epoch: 16/19, i/N: 360/400 with KL -0.01 and nll loss -127.27
# Epoch: 16/19, i/N: 370/400 with KL 0.00 and nll loss -127.26
# Epoch: 16/19, i/N: 380/400 with KL 0.07 and nll loss -127.19
# Epoch: 16/19, i/N: 390/400 with KL 0.05 and nll loss -127.22
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL -0.00 and nll loss -127.26
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.030059814453125 and nll_test -127.23248291015625
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 20/400 with KL 0.01 and nll loss -127.26
# Epoch: 17/19, i/N: 30/400 with KL 0.08 and nll loss -127.18
# Epoch: 17/19, i/N: 40/400 with KL 0.05 and nll loss -127.21
# Epoch: 17/19, i/N: 50/400 with KL 0.07 and nll loss -127.20
# Epoch: 17/19, i/N: 60/400 with KL 0.03 and nll loss -127.23
# Epoch: 17/19, i/N: 70/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 80/400 with KL 0.04 and nll loss -127.22
# Epoch: 17/19, i/N: 90/400 with KL -0.02 and nll loss -127.28
# Epoch: 17/19, i/N: 100/400 with KL 0.09 and nll loss -127.18
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.03314208984375 and nll_test -127.22940063476562
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.15 and nll loss -127.12
# Epoch: 17/19, i/N: 120/400 with KL 0.04 and nll loss -127.22
# Epoch: 17/19, i/N: 130/400 with KL 0.07 and nll loss -127.19
# Epoch: 17/19, i/N: 140/400 with KL 0.06 and nll loss -127.21
# Epoch: 17/19, i/N: 150/400 with KL 0.07 and nll loss -127.19
# Epoch: 17/19, i/N: 160/400 with KL 0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 170/400 with KL -0.01 and nll loss -127.27
# Epoch: 17/19, i/N: 180/400 with KL 0.07 and nll loss -127.19
# Epoch: 17/19, i/N: 190/400 with KL -0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 200/400 with KL 0.02 and nll loss -127.24
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.0351409912109375 and nll_test -127.22740173339844
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.20
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL -0.00 and nll loss -127.26
# Epoch: 17/19, i/N: 220/400 with KL 0.01 and nll loss -127.25
# Epoch: 17/19, i/N: 230/400 with KL 0.08 and nll loss -127.18
# Epoch: 17/19, i/N: 240/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 250/400 with KL 0.07 and nll loss -127.19
# Epoch: 17/19, i/N: 260/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 270/400 with KL 0.01 and nll loss -127.26
# Epoch: 17/19, i/N: 280/400 with KL 0.02 and nll loss -127.24
# Epoch: 17/19, i/N: 290/400 with KL -0.02 and nll loss -127.28
# Epoch: 17/19, i/N: 300/400 with KL 0.03 and nll loss -127.24
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.03644561767578125 and nll_test -127.2260971069336
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 320/400 with KL 0.06 and nll loss -127.20
# Epoch: 17/19, i/N: 330/400 with KL -0.05 and nll loss -127.31
# Epoch: 17/19, i/N: 340/400 with KL 0.06 and nll loss -127.21
# Epoch: 17/19, i/N: 350/400 with KL -0.01 and nll loss -127.27
# Epoch: 17/19, i/N: 360/400 with KL 0.12 and nll loss -127.14
# Epoch: 17/19, i/N: 370/400 with KL -0.00 and nll loss -127.27
# Epoch: 17/19, i/N: 380/400 with KL -0.01 and nll loss -127.27
# Epoch: 17/19, i/N: 390/400 with KL 0.01 and nll loss -127.25
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.01 and nll loss -127.25
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.03577423095703125 and nll_test -127.22676849365234
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.08 and nll loss -127.18
# Epoch: 18/19, i/N: 20/400 with KL 0.07 and nll loss -127.19
# Epoch: 18/19, i/N: 30/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 40/400 with KL -0.01 and nll loss -127.27
# Epoch: 18/19, i/N: 50/400 with KL 0.10 and nll loss -127.16
# Epoch: 18/19, i/N: 60/400 with KL -0.03 and nll loss -127.30
# Epoch: 18/19, i/N: 70/400 with KL 0.04 and nll loss -127.22
# Epoch: 18/19, i/N: 80/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 90/400 with KL 0.02 and nll loss -127.25
# Epoch: 18/19, i/N: 100/400 with KL 0.04 and nll loss -127.23
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.034027099609375 and nll_test -127.228515625
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.17
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 120/400 with KL 0.10 and nll loss -127.16
# Epoch: 18/19, i/N: 130/400 with KL 0.08 and nll loss -127.19
# Epoch: 18/19, i/N: 140/400 with KL 0.04 and nll loss -127.23
# Epoch: 18/19, i/N: 150/400 with KL 0.05 and nll loss -127.21
# Epoch: 18/19, i/N: 160/400 with KL 0.06 and nll loss -127.20
# Epoch: 18/19, i/N: 170/400 with KL 0.04 and nll loss -127.22
# Epoch: 18/19, i/N: 180/400 with KL 0.08 and nll loss -127.19
# Epoch: 18/19, i/N: 190/400 with KL 0.01 and nll loss -127.26
# Epoch: 18/19, i/N: 200/400 with KL 0.01 and nll loss -127.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.0321502685546875 and nll_test -127.23039245605469
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 0.99
# Epoch: 18/19, i/N: 200/400 avg ldj -0.21
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 220/400 with KL 0.09 and nll loss -127.17
# Epoch: 18/19, i/N: 230/400 with KL -0.00 and nll loss -127.27
# Epoch: 18/19, i/N: 240/400 with KL 0.05 and nll loss -127.21
# Epoch: 18/19, i/N: 250/400 with KL 0.03 and nll loss -127.24
# Epoch: 18/19, i/N: 260/400 with KL 0.03 and nll loss -127.23
# Epoch: 18/19, i/N: 270/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 280/400 with KL 0.03 and nll loss -127.24
# nan in sum squares
# Epoch: 18/19, i/N: 290/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 300/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.03271484375 and nll_test -127.22982788085938
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.00 and nll loss -127.26
# Epoch: 18/19, i/N: 320/400 with KL 0.02 and nll loss -127.24
# Epoch: 18/19, i/N: 330/400 with KL 0.05 and nll loss -127.21
# Epoch: 18/19, i/N: 340/400 with KL 0.01 and nll loss -127.25
# Epoch: 18/19, i/N: 350/400 with KL 0.02 and nll loss -127.25
# Epoch: 18/19, i/N: 360/400 with KL 0.10 and nll loss -127.17
# Epoch: 18/19, i/N: 370/400 with KL 0.10 and nll loss -127.17
# Epoch: 18/19, i/N: 380/400 with KL -0.04 and nll loss -127.31
# Epoch: 18/19, i/N: 390/400 with KL 0.04 and nll loss -127.22
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.07 and nll loss -127.19
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.0349273681640625 and nll_test -127.22761535644531
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.18
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL -0.00 and nll loss -127.27
# Epoch: 19/19, i/N: 20/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 30/400 with KL 0.04 and nll loss -127.22
# Epoch: 19/19, i/N: 40/400 with KL 0.06 and nll loss -127.20
# Epoch: 19/19, i/N: 50/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 60/400 with KL 0.16 and nll loss -127.11
# Epoch: 19/19, i/N: 70/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 80/400 with KL 0.00 and nll loss -127.26
# Epoch: 19/19, i/N: 90/400 with KL 0.01 and nll loss -127.26
# Epoch: 19/19, i/N: 100/400 with KL 0.07 and nll loss -127.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.03374481201171875 and nll_test -127.22879791259766
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.20
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.07 and nll loss -127.19
# Epoch: 19/19, i/N: 120/400 with KL 0.12 and nll loss -127.15
# Epoch: 19/19, i/N: 130/400 with KL 0.01 and nll loss -127.25
# Epoch: 19/19, i/N: 140/400 with KL -0.02 and nll loss -127.28
# Epoch: 19/19, i/N: 150/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 160/400 with KL 0.00 and nll loss -127.26
# Epoch: 19/19, i/N: 170/400 with KL 0.08 and nll loss -127.18
# Epoch: 19/19, i/N: 180/400 with KL -0.01 and nll loss -127.27
# Epoch: 19/19, i/N: 190/400 with KL 0.05 and nll loss -127.21
# Epoch: 19/19, i/N: 200/400 with KL 0.03 and nll loss -127.23
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.0312347412109375 and nll_test -127.23130798339844
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.15
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL -0.04 and nll loss -127.30
# Epoch: 19/19, i/N: 220/400 with KL -0.02 and nll loss -127.29
# Epoch: 19/19, i/N: 230/400 with KL 0.01 and nll loss -127.25
# Epoch: 19/19, i/N: 240/400 with KL 0.03 and nll loss -127.23
# Epoch: 19/19, i/N: 250/400 with KL 0.09 and nll loss -127.17
# Epoch: 19/19, i/N: 260/400 with KL -0.02 and nll loss -127.28
# Epoch: 19/19, i/N: 270/400 with KL 0.04 and nll loss -127.23
# Epoch: 19/19, i/N: 280/400 with KL 0.06 and nll loss -127.20
# Epoch: 19/19, i/N: 290/400 with KL 0.01 and nll loss -127.26
# Epoch: 19/19, i/N: 300/400 with KL 0.06 and nll loss -127.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.0326080322265625 and nll_test -127.22993469238281
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.18
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.16
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.06 and nll loss -127.20
# Epoch: 19/19, i/N: 320/400 with KL 0.11 and nll loss -127.15
# Epoch: 19/19, i/N: 330/400 with KL -0.03 and nll loss -127.30
# Epoch: 19/19, i/N: 340/400 with KL 0.05 and nll loss -127.22
# Epoch: 19/19, i/N: 350/400 with KL 0.05 and nll loss -127.21
# Epoch: 19/19, i/N: 360/400 with KL 0.01 and nll loss -127.25
# Epoch: 19/19, i/N: 370/400 with KL -0.02 and nll loss -127.29
# Epoch: 19/19, i/N: 380/400 with KL -0.04 and nll loss -127.30
# Epoch: 19/19, i/N: 390/400 with KL 0.02 and nll loss -127.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.03708648681640625 and nll_test -127.22545623779297
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.18
# #####################
