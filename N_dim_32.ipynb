# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
import yaml
import pprint
import os
import time
# weights and biases for tracking of metrics
import wandb 
# make the plots inline again
# %matplotlib inline
# sometimes have to activate this to plot plots in notebook
# matplotlib.use('Qt5Agg')
from code import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load and pprint config

# %%
stream = open("config_fit_df.yaml", 'r')
config = yaml.load(stream, Loader = yaml.FullLoader)

# This is for the MLPs of the flow
config['HIDDEN_DIM_SPLINE_MLP'] = HIDDEN_DIM_SPLINE_MLP
config['HIDDEN_DIM_MOEBIUS_MLP'] = HIDDEN_DIM_MOEBIUS_MLP
config['HIDDEN_DIM_ROTATION_MLP'] = HIDDEN_DIM_ROTATION_MLP

### Set globabl variables and load data
BATCH_SIZE = config['BATCH_SIZE']

# NUM_FLOWS_COU = config['NUM_FLOWS_COU']
# NUM_FLOWS_CYL = config['NUM_FLOWS_CYL']
# NUM_CENTERS = config['NUM_CENTERS']
# NUM_BINS = config['NUM_BINS']
# NUM_DIM_DATA = config['NUM_DIM_DATA']

# flow params
NUM_DIM_DATA = 32
NUM_CENTERS = 8
NUM_BINS = 12
NUM_FLOWS_COU = 3
NUM_FLOWS_CYL = 3

CAP_HOUSEHOLDER_REFL = False

nr_mixtures = config['nr_mixtures']
epochs = config['epochs']
eval_iter = config['eval_iter']
print_iter = config['print_iter']
lookahead = config['lookahead']
nr_datapoints = config['nr_datapoints_eval']

lr = config['lr']
weight_decay = config['weight_decay']

# data parameters
# nr_mixtures = config['nr_mixtures']

# dataset type

dataset_type = config['dataset_type']

ITERS_PER_EPOCH = config['iters_per_epoch']

PROJECT_NAME = f'DIM_{NUM_DIM_DATA}'

pp = pprint.PrettyPrinter(indent=1)
pp.pprint(config)
# Out:
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'lookahead': 10,
#  'lr': 0.001,
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'print_iter': 10,
#  'weight_decay': 0.01}

# %% [markdown]
# ### get location and scale parameters

# %%
# # code for creating dataset on the poles
# from random import random
# eps = random()*0.2
# mu_list = np.array([[eps, eps, 1+eps],
#                          [eps, eps, -1+eps],
#                          [1, eps, eps]], dtype='float32')

# k_list = 1.5*np.array([13, 14,  12],dtype='float32')

# mu_list = mu_list / np.linalg.norm(mu_list,axis=1,keepdims=True)
# np.linalg.norm(mu_list,axis=1,keepdims=True)


if NUM_DIM_DATA == 3 and dataset_type == 'standard':

    mu_list = np.array([[-4.7503373e-01, -8.7996745e-01, -5.0922018e-04],
                        [-1.6167518e-01,  6.5595394e-01, -7.3728257e-01],
                        [ 2.6248896e-01,  6.9851363e-01,  6.6571641e-01],
                        [ 1.0,  0,  0.0]], dtype='float32')

    k_list = 1.5*np.array([13, 14,  12, 15],dtype='float32')

    phi_mu_list = np.array([-2.06579875,  1.81245307,  1.2113401, 0],dtype='float32')
    theta_mu_list =  np.array([-5.09220198e-04, -8.29039128e-01,  7.28453441e-01, 0],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles':
    
    mu_list = np.array([[ 0.14887695,  0.14887695,  0.9775844 ],
                        [ 0.20918883,  0.20918883, -0.9552383 ],
                        [ 0.96920884,  0.17411795,  0.17411795]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14,  12],dtype='float32')
    
    phi_mu_list = np.array([0.7853982, 0.7853982, 0.1777535],dtype='float32')
    theta_mu_list =  np.array([ 1.3586651 , -1.2704642 ,  0.17500998],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles_2':
    
    mu_list = np.array([[ 0,  0,  1 ],
                        [ 0,  0, -1 ]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14],dtype='float32')
    
    phi_mu_list = np.array([0, 0],dtype='float32')
    theta_mu_list =  np.array([ np.pi/2 , -np.pi/2],dtype='float32')    
    
else:    
    torch.manual_seed(7) # mu created with torch
    np.random.seed(7) # k with numpy
    mu_list, k_list, phi_mu_list, theta_mu_list = create_random_parameters(nr_mixtures, num_dim_data = NUM_DIM_DATA)

# %% [markdown]
# ### 3d and N dim Power Spherical Data

# %%
# Power Spherical 

power_spherical_data = PowerSphericalData(mu_list=mu_list, k_list=k_list, nr_samples=BATCH_SIZE*ITERS_PER_EPOCH)

print(f'Entropy {power_spherical_data.entropy.detach().numpy()}')

# add parameters to config
config['nr_mixtures'] = len(mu_list)
config['mu_list'] = mu_list
config['k_list'] = k_list
config['phi_mu_list'] = phi_mu_list
config['theta_mu_list'] = theta_mu_list

if NUM_DIM_DATA == 3:
    
    start_time = time.time()
    probs, probs_with_cos, phi_linspace, theta_linspace = plot_power_spherical_density(mu_list, k_list,phi_mu_list,theta_mu_list)
    print("--- %s seconds ---" % (time.time() - start_time))

    dphi = phi_linspace[1] - phi_linspace[0]
    dtheta = theta_linspace[1] - theta_linspace[0]

    print('numerical integral of density w', torch.sum(probs_with_cos) * dphi * dtheta)
# Out:
# Secs for entropy calc 1.1794092655181885
# With entropy -9.511178016662598
# Entropy -9.511178016662598

# %%
def bmatrix(a):
    """Returns a LaTeX bmatrix

    :a: numpy array
    :returns: LaTeX bmatrix as a string
    """
    if len(a.shape) > 2:
        raise ValueError('bmatrix can at most display two dimensions')
    lines = str(a).replace('[', '').replace(']', '').splitlines()
    rv = [r'\begin{bmatrix}']
    rv += ['  ' + ' & '.join(l.split()) + r'\\' for l in lines]
    rv +=  [r'\end{bmatrix}']
    return '\n'.join(rv)

print(bmatrix(np.round(k_list,2)))
# Out:
# \begin{bmatrix}
#   10.38 & 13.9 & 12.19 & 13.62\\
# \end{bmatrix}

# %% [markdown]
# ### train function

# %%
def get_num_params(model):
    
    total_number_params = 0
    
    for name, parameter in model.named_parameters():
        total_number_params += parameter.numel()
    return total_number_params

def train_model(model, 
                optimizer, 
                dataset, 
                config,
                model_name):
    
    
    epochs = config['epochs']
    config['NUM_PARAMS'] = get_num_params(model)

    # init weights and biases tracking
    ts = time.strftime('%m%d_%H%M%S', time.localtime(time.time()))
    
    if model.flow_type == 'moebius':
        model_name = f"{model_name}_NC_{NUM_CENTERS}_NF_{model.num_flows}_seed_07"
        
    elif model.flow_type == 'spline':
        model_name = f"{model_name}_NB_{NUM_BINS}_NF_{model.num_flows}_seed_07"
        
    wandb.init(project=PROJECT_NAME,
               config=config,
               name=model_name,
               id=ts)
    
    best_KL = 1e3
    epoch_of_best_run = 0
    
    # According to w and b documentation this is magic. Okay, let's see
    wandb.watch(model)
    
    print('##### Model #####')
    print(model)
    print('#################\n')
    
    print('##### Config #####')
    pp = pprint.PrettyPrinter(indent=1)
    pp.pprint(config)
    print('##################\n')    
    
    train_loader = DataLoader(dataset, batch_size=config['BATCH_SIZE'], shuffle=True)
    
    # get properties of dataset class
    phi_mu_list, theta_mu_list = dataset.spherical_parameters
    entropy = dataset.entropy
    
    print(f'Entropy of data: {entropy}')

    max_steps = config['iters_per_epoch']
    
    num_dim_data = model.num_dim_data
    
    # initialize loss. 
    loss_fn = Loss_on_sphere(n_dim_sphere = num_dim_data - 1)
    
    for epoch in range(epochs):
        
        print(f"Epoch: {epoch} / {epochs-1}")
        
        if num_dim_data == 3:
        
            # actually the calculation here is partly redundant because we anyway later evalaute the model on a test set            
            eval_and_plot_model(model, 
                                nr_gridpoints = 100, 
                                epoch = epoch, 
                                batch_idx = 0, 
                                phi_mu_list=phi_mu_list, 
                                theta_mu_list=theta_mu_list, 
                                x_conditioner = None)

        start_time = time.time()
        for batch_idx, x_train in enumerate(train_loader): 

            x_train = x_train.float().to(device)

            optimizer.zero_grad()

            z, ldj, _ = model(x_train)

            loss = loss_fn.calc_loss(ldj)
                          
            # calculate gradient with repsect to ldj and not whole nll, 
            # because our prior is uniform and therefore this way is less expensive
            (-torch.mean(ldj)).backward()
#             loss.backward()
            optimizer.step()

            nll = float(loss.detach().cpu().numpy()) 
            KL = nll - entropy
                            
            if batch_idx % config['print_iter'] == 0: 
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} with KL {KL:.2f} and nll loss {nll:.2f}')                
                  
            def eval_model():
                
                nr_datapoints = config['nr_datapoints_eval']

                # KL evaluation based on nr_datapoints samples from data distribution
                test_data = dataset.get_test_set(nr_samples = nr_datapoints).to(device)

                with torch.no_grad():

                    model.eval()
                    z, ldj, _ = model(test_data)

                    nll_test = loss_fn.calc_loss(ldj)
                    KL_test = nll_test - entropy

                    # MC evaluation based on nr_datapoints uniform samples on the sphere
                    x_eval = torch.randn(nr_datapoints, num_dim_data).to(device)
                    x_eval = x_eval / torch.norm(x_eval, dim=1, keepdim=True)

                    z, ldj0, _ = model(x_eval)
                    model.train()                

                print()
                print(f'#### EVALUATION ####')
                print(f'Evaluation based on {nr_datapoints} data points from data distribution samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} KL_test {KL_test} and nll_test {nll_test}')

                print('\nFrom current batch')
                print(f'Epoch: {epoch}, i/N: {batch_idx}/{max_steps} avg ldj from current batch {torch.mean(ldj):.2f}')

                print(f'\nFrom {nr_datapoints} uniform samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum {torch.mean(torch.exp(ldj0)):.2f}')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} avg ldj {torch.mean(ldj0):.2f}')
                print('#####################')
                print()
                
                wandb.log({"KL_train": KL,
                           "neg_log_likel_train": nll,
                           "KL_test": KL_test,
                           "neg_log_likel_test": nll_test,            
                           "MC_integral": torch.mean(torch.exp(ldj0))})  
                
                return KL_test, nll_test
                
                
            if batch_idx % config['eval_iter'] == 0:
                KL_test, nll_test = eval_model()
                
#                 # This part is for additional evaluation of 
#                 model.eval()
#                 print()
#                 print('#####################')

#                 # first, second and both coupling w/o rotation
#                 sldj_test = torch.zeros(nr_datapoints).to(device)       
                
#                 x_out, ldj_first, _ = model.scale[1](x_eval, sldj_test) 
#                 _, ldj_second, _  = model.scale[3](x_eval, sldj_test) 
                
#                 _, ldj_first_second, _  = model.scale[3](x_out, ldj_first)                  

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first flow only moeb {torch.mean(torch.exp(ldj_first)):.2f}')
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum second flow only moeb {torch.mean(torch.exp(ldj_second)):.2f}') 
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first and second flow only moeb {torch.mean(torch.exp(ldj_first_second)):.2f}')
#                 print()
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj1, _ = model.scale[1](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first flow incl rot {torch.mean(torch.exp(ldj1)):.2f}') 
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[2](x_eval, sldj_test)
#                 x_out, ldj2, _ = model.scale[3](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density second flow incl rot {torch.mean(torch.exp(ldj2)):.2f}')   
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj, _ = model.scale[1](x_out, ldj)                
#                 x_out, ldj, _ = model.scale[2](x_out, ldj)
#                 x_out, ldj12, _ = model.scale[3](x_out, ldj)

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first&second flow incl rot {torch.mean(torch.exp(ldj12)):.2f}')                   
                
#                 print('#####################')
#                 print()
#                 model.train()                
                
                # store the metrics in the log. Call logger after eval and plot model because we also log plots inside
                   
            def store_model(best_vs_last):
                if not os.path.exists(f'models_fit_df/dim_{num_dim_data}'):
                    os.makedirs(f'models_fit_df/dim_{num_dim_data}')
                # also store model in the end
                state = {
                    'epoch': epoch,
                    'batch_index': batch_idx,
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'config': config
                }                        

                torch.save(state, f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")
                wandb.save(f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")  
                

            # save the best model but do not save any model during the first 50 iterations
            if not (epoch == 0 and batch_idx < 50):

                if KL_test < best_KL:

                    store_model(best_vs_last='best')

                    best_KL = KL_test
                    epoch_of_best_run = epoch
                    
                    wandb.run.summary["KL_best"] = KL_test
                    wandb.run.summary["nll_best"] = nll_test
                    
                    wandb.run.summary["epoch_of_best_KL"] = epoch_of_best_run
                    wandb.run.summary["batch_id_of_best_KL"] = batch_idx                    
                    
                    wandb.run.summary["KL_current_batch"] = KL
                    wandb.run.summary["nll_current_batch"] = nll
           
        
        wandb.log({"time_per_epoch": time.time()-start_time},commit=False)
        
        # if there was no improvement after a certain amount of epochs terminate training    
        if (epoch - epoch_of_best_run) >= config['lookahead']:
            print()
            print('#### EARLY STOPPING ####')
            print(f'at epoch {epoch} and batch_id {batch_idx}')
            print('########################')
            print()
            break
                
                                        
    # also store model in the end        
    store_model(best_vs_last='last')
    
    wandb.run.summary["last_epoch"] = epoch
    
    _,_ = eval_model()
    
    if num_dim_data == 3:
        eval_and_plot_model(model, 
                            nr_gridpoints = 100, 
                            epoch = epoch, 
                            batch_idx = 0, 
                            phi_mu_list=phi_mu_list, 
                            theta_mu_list=theta_mu_list, 
                            x_conditioner = None)

# %% [markdown]
# ### Coupling Moebius Flow

# %%
cou_moeb = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                              num_dim_data= NUM_DIM_DATA,
                              flow_type = 'moebius', 
                              rezero_flag = True,
                              num_centers = NUM_CENTERS,
                              cap_householder_refl=CAP_HOUSEHOLDER_REFL)

cou_moeb.to(device)

optimizer = optim.AdamW(cou_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Moebius Flow #####')


train_model(model = cou_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_m')
# Out:
# ##### Coupling Moebius Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_220439" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_220439</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Coupling_Flow(
#   (scale): ModuleList(
#     (0): Rotation()
#     (1): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=129, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#     (2): Rotation()
#     (3): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=129, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#     (4): Rotation()
#     (5): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=129, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 165153,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.47655576e-01,  7.12287351e-02,  1.61837906e-01,
#         -2.49965787e-01, -3.00656687e-02,  5.13378978e-02,
#         -1.15420990e-01, -1.60892144e-01,  1.66813165e-01,
#         -9.64126736e-02, -2.08793998e-01, -8.28458816e-02,
#          1.27564132e-01,  1.82334691e-01,  4.14802469e-02,
#          1.96271405e-01, -2.84940153e-01, -5.84344044e-02,
#          3.46819907e-01, -5.94147295e-02,  3.57276984e-02,
#          1.40802979e-01,  1.87079117e-01, -1.30439639e-01,
#         -3.76892798e-02, -3.87697071e-02, -3.26900601e-01,
#         -6.21567555e-02, -3.71144861e-01,  1.21363901e-01,
#         -2.38252848e-01, -2.44810417e-01],
#        [-1.38830440e-02, -3.90221574e-03,  2.89825462e-02,
#          3.82002503e-01,  1.59077853e-01, -1.10007562e-01,
#         -1.37695208e-01, -1.00668795e-01, -2.32898831e-01,
#          2.15627357e-01,  2.72735924e-01, -1.75629154e-01,
#         -4.34777588e-02, -4.15739939e-02,  8.32903013e-02,
#          4.32200469e-02, -2.96170041e-02, -4.31307368e-02,
#         -2.40800902e-03, -6.38056844e-02, -4.93000597e-01,
#         -1.76272526e-01, -5.13575971e-02,  1.55285999e-01,
#          2.69974083e-01,  2.60492641e-04, -7.27226809e-02,
#         -3.50454718e-01,  1.90309197e-01, -6.35220185e-02,
#         -5.90479895e-02,  1.25352696e-01],
#        [ 2.60214563e-02,  3.56507376e-02, -1.00506626e-01,
#          1.56339660e-01, -2.42792353e-01, -3.35473359e-01,
#         -1.13739289e-01, -1.20175540e-01, -1.72994345e-01,
#          2.33775198e-01,  9.12943706e-02, -2.81111747e-02,
#         -1.58582807e-01, -7.54978359e-02, -2.02521160e-01,
#          1.15622178e-01, -4.40940171e-01,  7.89586380e-02,
#          1.11749269e-01,  6.01152927e-02, -2.45873649e-02,
#         -1.87052876e-01,  3.42127830e-01,  1.91307142e-01,
#         -7.78181776e-02, -3.38192731e-02,  1.47817269e-01,
#          1.92607939e-01, -1.61186084e-01,  3.18894871e-02,
#          9.78971273e-02,  2.77430654e-01],
#        [-1.12130381e-01,  1.73135325e-01,  2.20798597e-01,
#         -2.30746195e-01,  2.66201477e-02, -3.95676401e-03,
#         -8.50699022e-02,  1.11059688e-01,  8.01334158e-02,
#          3.99493515e-01, -2.53683060e-01,  3.69951695e-01,
#          1.05917104e-01, -3.29163261e-02,  9.61499959e-02,
#         -2.40879774e-01, -2.34925091e-01, -6.56795427e-02,
#          1.30749673e-01,  1.89674515e-02, -1.22393437e-01,
#         -1.02263898e-01,  1.33639634e-01,  1.27292857e-01,
#         -1.70438379e-01,  2.41557494e-01, -2.52882808e-01,
#          1.05931632e-01, -9.00397003e-02,  1.28095791e-01,
#          5.91178760e-02,  2.47614831e-01]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -9.511178016662598
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.62 and nll loss -8.89
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.6206893920898438 and nll_test -8.890488624572754
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch 0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj 0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.61 and nll loss -8.90
# Epoch: 0/19, i/N: 20/400 with KL 0.59 and nll loss -8.92
# Epoch: 0/19, i/N: 30/400 with KL 0.52 and nll loss -8.99
# Epoch: 0/19, i/N: 40/400 with KL 0.46 and nll loss -9.05
# Epoch: 0/19, i/N: 50/400 with KL 0.35 and nll loss -9.16
# Epoch: 0/19, i/N: 60/400 with KL 0.35 and nll loss -9.17
# Epoch: 0/19, i/N: 70/400 with KL 0.33 and nll loss -9.18
# Epoch: 0/19, i/N: 80/400 with KL 0.26 and nll loss -9.25
# Epoch: 0/19, i/N: 90/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 100/400 with KL 0.30 and nll loss -9.21
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.2609987258911133 and nll_test -9.250179290771484
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.36
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.33
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 120/400 with KL 0.40 and nll loss -9.11
# Epoch: 0/19, i/N: 130/400 with KL 0.20 and nll loss -9.31
# Epoch: 0/19, i/N: 140/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 150/400 with KL 0.28 and nll loss -9.24
# Epoch: 0/19, i/N: 160/400 with KL 0.23 and nll loss -9.29
# Epoch: 0/19, i/N: 170/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 180/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 190/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 200/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.19478893280029297 and nll_test -9.316389083862305
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.43
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.43
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.14 and nll loss -9.37
# Epoch: 0/19, i/N: 220/400 with KL 0.23 and nll loss -9.28
# Epoch: 0/19, i/N: 230/400 with KL 0.31 and nll loss -9.20
# Epoch: 0/19, i/N: 240/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 250/400 with KL 0.19 and nll loss -9.32
# Epoch: 0/19, i/N: 260/400 with KL 0.14 and nll loss -9.37
# Epoch: 0/19, i/N: 270/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 0/19, i/N: 290/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 300/400 with KL 0.12 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.1795949935913086 and nll_test -9.331583023071289
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.44
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.42
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 320/400 with KL 0.23 and nll loss -9.28
# Epoch: 0/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 0/19, i/N: 340/400 with KL 0.16 and nll loss -9.35
# Epoch: 0/19, i/N: 350/400 with KL 0.19 and nll loss -9.32
# Epoch: 0/19, i/N: 360/400 with KL 0.11 and nll loss -9.40
# Epoch: 0/19, i/N: 370/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 380/400 with KL 0.19 and nll loss -9.33
# Epoch: 0/19, i/N: 390/400 with KL 0.17 and nll loss -9.34
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.1617136001586914 and nll_test -9.349464416503906
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.45
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 20/400 with KL 0.12 and nll loss -9.39
# Epoch: 1/19, i/N: 30/400 with KL 0.24 and nll loss -9.28
# Epoch: 1/19, i/N: 40/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 50/400 with KL 0.06 and nll loss -9.45
# Epoch: 1/19, i/N: 60/400 with KL 0.12 and nll loss -9.39
# Epoch: 1/19, i/N: 70/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 80/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 90/400 with KL 0.25 and nll loss -9.27
# Epoch: 1/19, i/N: 100/400 with KL 0.08 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.156280517578125 and nll_test -9.354897499084473
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.43
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 120/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 130/400 with KL 0.10 and nll loss -9.41
# Epoch: 1/19, i/N: 140/400 with KL 0.19 and nll loss -9.33
# Epoch: 1/19, i/N: 150/400 with KL 0.06 and nll loss -9.45
# Epoch: 1/19, i/N: 160/400 with KL 0.12 and nll loss -9.39
# Epoch: 1/19, i/N: 170/400 with KL 0.07 and nll loss -9.44
# Epoch: 1/19, i/N: 180/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 190/400 with KL 0.22 and nll loss -9.30
# Epoch: 1/19, i/N: 200/400 with KL 0.25 and nll loss -9.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.1701335906982422 and nll_test -9.341044425964355
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.42
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 220/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 230/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 240/400 with KL 0.10 and nll loss -9.42
# Epoch: 1/19, i/N: 250/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 260/400 with KL 0.07 and nll loss -9.44
# Epoch: 1/19, i/N: 270/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 280/400 with KL 0.11 and nll loss -9.40
# Epoch: 1/19, i/N: 290/400 with KL 0.18 and nll loss -9.34
# Epoch: 1/19, i/N: 300/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.15306472778320312 and nll_test -9.358113288879395
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.07 and nll loss -9.44
# Epoch: 1/19, i/N: 320/400 with KL 0.24 and nll loss -9.27
# Epoch: 1/19, i/N: 330/400 with KL 0.24 and nll loss -9.28
# Epoch: 1/19, i/N: 340/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 350/400 with KL 0.09 and nll loss -9.43
# Epoch: 1/19, i/N: 360/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 370/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 380/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 390/400 with KL 0.09 and nll loss -9.42
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.00 and nll loss -9.51
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.13975048065185547 and nll_test -9.371427536010742
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 20/400 with KL 0.22 and nll loss -9.29
# Epoch: 2/19, i/N: 30/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 40/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 50/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 60/400 with KL 0.06 and nll loss -9.45
# Epoch: 2/19, i/N: 70/400 with KL 0.20 and nll loss -9.32
# Epoch: 2/19, i/N: 80/400 with KL 0.06 and nll loss -9.45
# Epoch: 2/19, i/N: 90/400 with KL 0.24 and nll loss -9.27
# Epoch: 2/19, i/N: 100/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.13105201721191406 and nll_test -9.380125999450684
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 120/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 130/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 140/400 with KL 0.06 and nll loss -9.46
# Epoch: 2/19, i/N: 150/400 with KL 0.05 and nll loss -9.47
# Epoch: 2/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 170/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 180/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 190/400 with KL 0.19 and nll loss -9.33
# Epoch: 2/19, i/N: 200/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.13383007049560547 and nll_test -9.377347946166992
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.48
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.05 and nll loss -9.46
# Epoch: 2/19, i/N: 220/400 with KL 0.13 and nll loss -9.38
# Epoch: 2/19, i/N: 230/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 240/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 250/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 260/400 with KL 0.13 and nll loss -9.38
# Epoch: 2/19, i/N: 270/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 280/400 with KL 0.22 and nll loss -9.29
# Epoch: 2/19, i/N: 290/400 with KL 0.08 and nll loss -9.43
# Epoch: 2/19, i/N: 300/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.1369333267211914 and nll_test -9.374244689941406
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.44
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.01 and nll loss -9.50
# Epoch: 2/19, i/N: 320/400 with KL 0.24 and nll loss -9.27
# Epoch: 2/19, i/N: 330/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 340/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 350/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 360/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 370/400 with KL 0.17 and nll loss -9.35
# Epoch: 2/19, i/N: 380/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 390/400 with KL 0.10 and nll loss -9.41
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.13103771209716797 and nll_test -9.38014030456543
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.11 and nll loss -9.40
# Epoch: 3/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 3/19, i/N: 30/400 with KL 0.06 and nll loss -9.45
# Epoch: 3/19, i/N: 40/400 with KL 0.12 and nll loss -9.40
# Epoch: 3/19, i/N: 50/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 60/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 70/400 with KL 0.07 and nll loss -9.44
# Epoch: 3/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 3/19, i/N: 90/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 100/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.13201332092285156 and nll_test -9.379164695739746
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.49
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.03 and nll loss -9.49
# Epoch: 3/19, i/N: 120/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 130/400 with KL 0.18 and nll loss -9.34
# Epoch: 3/19, i/N: 140/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 150/400 with KL 0.15 and nll loss -9.37
# Epoch: 3/19, i/N: 160/400 with KL 0.17 and nll loss -9.35
# Epoch: 3/19, i/N: 170/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 180/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 190/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 200/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.1190652847290039 and nll_test -9.392112731933594
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.49
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.07 and nll loss -9.44
# Epoch: 3/19, i/N: 220/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 230/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 240/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 250/400 with KL 0.24 and nll loss -9.27
# Epoch: 3/19, i/N: 260/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 270/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 280/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 290/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 300/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.12192630767822266 and nll_test -9.389251708984375
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 3/19, i/N: 330/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 340/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 350/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 360/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 370/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 380/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 390/400 with KL -0.00 and nll loss -9.52
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.11612701416015625 and nll_test -9.395051002502441
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 0.99
# Epoch: 4/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.13 and nll loss -9.39
# Epoch: 4/19, i/N: 20/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 30/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 40/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 50/400 with KL 0.05 and nll loss -9.46
# Epoch: 4/19, i/N: 60/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 70/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 80/400 with KL 0.03 and nll loss -9.48
# Epoch: 4/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.11693191528320312 and nll_test -9.394246101379395
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.50
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.23 and nll loss -9.28
# Epoch: 4/19, i/N: 120/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 130/400 with KL 0.04 and nll loss -9.48
# Epoch: 4/19, i/N: 140/400 with KL 0.21 and nll loss -9.30
# Epoch: 4/19, i/N: 150/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 160/400 with KL 0.16 and nll loss -9.35
# Epoch: 4/19, i/N: 170/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 180/400 with KL 0.06 and nll loss -9.45
# Epoch: 4/19, i/N: 190/400 with KL 0.07 and nll loss -9.44
# Epoch: 4/19, i/N: 200/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.12220573425292969 and nll_test -9.388972282409668
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.48
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.02 and nll loss -9.49
# Epoch: 4/19, i/N: 220/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 230/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 240/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 250/400 with KL 0.24 and nll loss -9.27
# Epoch: 4/19, i/N: 260/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 270/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 280/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 290/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.12099456787109375 and nll_test -9.390183448791504
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.49
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 320/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 330/400 with KL 0.16 and nll loss -9.35
# Epoch: 4/19, i/N: 340/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 350/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 360/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 370/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 380/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 390/400 with KL 0.07 and nll loss -9.45
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.1108245849609375 and nll_test -9.40035343170166
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.07 and nll loss -9.44
# Epoch: 5/19, i/N: 20/400 with KL 0.18 and nll loss -9.33
# Epoch: 5/19, i/N: 30/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 40/400 with KL 0.18 and nll loss -9.33
# Epoch: 5/19, i/N: 50/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 60/400 with KL 0.11 and nll loss -9.41
# Epoch: 5/19, i/N: 70/400 with KL 0.09 and nll loss -9.42
# Epoch: 5/19, i/N: 80/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.11434173583984375 and nll_test -9.396836280822754
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.01
# Epoch: 5/19, i/N: 100/400 avg ldj -0.49
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 120/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 130/400 with KL 0.06 and nll loss -9.45
# Epoch: 5/19, i/N: 140/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 150/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 160/400 with KL -0.00 and nll loss -9.52
# Epoch: 5/19, i/N: 170/400 with KL 0.02 and nll loss -9.49
# Epoch: 5/19, i/N: 180/400 with KL 0.20 and nll loss -9.31
# Epoch: 5/19, i/N: 190/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 200/400 with KL 0.27 and nll loss -9.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.12471485137939453 and nll_test -9.386463165283203
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.47
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.22 and nll loss -9.30
# Epoch: 5/19, i/N: 220/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 230/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 240/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 250/400 with KL 0.12 and nll loss -9.39
# Epoch: 5/19, i/N: 260/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 270/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 280/400 with KL 0.09 and nll loss -9.42
# Epoch: 5/19, i/N: 290/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 300/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.11458396911621094 and nll_test -9.396594047546387
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.50
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.28 and nll loss -9.23
# Epoch: 5/19, i/N: 320/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 330/400 with KL 0.13 and nll loss -9.39
# Epoch: 5/19, i/N: 340/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 350/400 with KL 0.20 and nll loss -9.31
# Epoch: 5/19, i/N: 360/400 with KL 0.03 and nll loss -9.48
# Epoch: 5/19, i/N: 370/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 380/400 with KL 0.04 and nll loss -9.47
# Epoch: 5/19, i/N: 390/400 with KL 0.06 and nll loss -9.45
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.13 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.11350345611572266 and nll_test -9.397674560546875
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 20/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 30/400 with KL 0.05 and nll loss -9.46
# Epoch: 6/19, i/N: 40/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 50/400 with KL 0.07 and nll loss -9.44
# Epoch: 6/19, i/N: 60/400 with KL 0.06 and nll loss -9.45
# Epoch: 6/19, i/N: 70/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 80/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 90/400 with KL 0.07 and nll loss -9.44
# Epoch: 6/19, i/N: 100/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.12172508239746094 and nll_test -9.389452934265137
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.49
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 120/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 130/400 with KL 0.01 and nll loss -9.50
# Epoch: 6/19, i/N: 140/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 150/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 160/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 170/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 180/400 with KL -0.02 and nll loss -9.53
# Epoch: 6/19, i/N: 190/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.10895156860351562 and nll_test -9.402226448059082
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.50
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 220/400 with KL 0.05 and nll loss -9.46
# Epoch: 6/19, i/N: 230/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 240/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 250/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 260/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 270/400 with KL 0.06 and nll loss -9.45
# Epoch: 6/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 290/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 300/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.11194419860839844 and nll_test -9.3992338180542
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.50
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.20 and nll loss -9.31
# Epoch: 6/19, i/N: 320/400 with KL 0.21 and nll loss -9.30
# Epoch: 6/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 340/400 with KL 0.11 and nll loss -9.41
# Epoch: 6/19, i/N: 350/400 with KL 0.14 and nll loss -9.38
# Epoch: 6/19, i/N: 360/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 370/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 380/400 with KL 0.23 and nll loss -9.28
# Epoch: 6/19, i/N: 390/400 with KL 0.10 and nll loss -9.41
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.10707664489746094 and nll_test -9.404101371765137
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 20/400 with KL 0.16 and nll loss -9.36
# Epoch: 7/19, i/N: 30/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 40/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 50/400 with KL 0.03 and nll loss -9.48
# Epoch: 7/19, i/N: 60/400 with KL 0.08 and nll loss -9.44
# Epoch: 7/19, i/N: 70/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 80/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 90/400 with KL 0.06 and nll loss -9.46
# Epoch: 7/19, i/N: 100/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.09992504119873047 and nll_test -9.411252975463867
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 120/400 with KL 0.11 and nll loss -9.41
# Epoch: 7/19, i/N: 130/400 with KL 0.04 and nll loss -9.47
# Epoch: 7/19, i/N: 140/400 with KL -0.01 and nll loss -9.52
# Epoch: 7/19, i/N: 150/400 with KL 0.01 and nll loss -9.50
# Epoch: 7/19, i/N: 160/400 with KL 0.08 and nll loss -9.43
# Epoch: 7/19, i/N: 170/400 with KL 0.21 and nll loss -9.30
# Epoch: 7/19, i/N: 180/400 with KL -0.02 and nll loss -9.53
# Epoch: 7/19, i/N: 190/400 with KL 0.19 and nll loss -9.32
# Epoch: 7/19, i/N: 200/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.1038351058959961 and nll_test -9.407342910766602
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 0.99
# Epoch: 7/19, i/N: 200/400 avg ldj -0.52
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 220/400 with KL 0.05 and nll loss -9.46
# Epoch: 7/19, i/N: 230/400 with KL -0.01 and nll loss -9.52
# Epoch: 7/19, i/N: 240/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 250/400 with KL 0.20 and nll loss -9.31
# Epoch: 7/19, i/N: 260/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 270/400 with KL 0.08 and nll loss -9.43
# Epoch: 7/19, i/N: 280/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 290/400 with KL 0.25 and nll loss -9.26
# Epoch: 7/19, i/N: 300/400 with KL 0.05 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.10479736328125 and nll_test -9.406380653381348
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.49
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.20 and nll loss -9.31
# Epoch: 7/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 330/400 with KL 0.12 and nll loss -9.40
# Epoch: 7/19, i/N: 340/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 350/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 360/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 370/400 with KL 0.19 and nll loss -9.33
# Epoch: 7/19, i/N: 380/400 with KL 0.20 and nll loss -9.31
# Epoch: 7/19, i/N: 390/400 with KL 0.05 and nll loss -9.47
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.09943199157714844 and nll_test -9.41174602508545
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.05 and nll loss -9.46
# Epoch: 8/19, i/N: 20/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 30/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 40/400 with KL -0.01 and nll loss -9.52
# Epoch: 8/19, i/N: 50/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 60/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 70/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 80/400 with KL 0.23 and nll loss -9.28
# Epoch: 8/19, i/N: 90/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.10244178771972656 and nll_test -9.408736228942871
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.55
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 120/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 130/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 140/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 150/400 with KL 0.08 and nll loss -9.43
# Epoch: 8/19, i/N: 160/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 170/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 180/400 with KL 0.08 and nll loss -9.43
# Epoch: 8/19, i/N: 190/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.1058349609375 and nll_test -9.405343055725098
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 220/400 with KL 0.20 and nll loss -9.32
# Epoch: 8/19, i/N: 230/400 with KL 0.08 and nll loss -9.43
# Epoch: 8/19, i/N: 240/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 250/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 260/400 with KL -0.03 and nll loss -9.54
# Epoch: 8/19, i/N: 270/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 280/400 with KL 0.17 and nll loss -9.34
# Epoch: 8/19, i/N: 290/400 with KL 0.00 and nll loss -9.51
# Epoch: 8/19, i/N: 300/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.10677719116210938 and nll_test -9.404400825500488
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.46
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 320/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 330/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 340/400 with KL 0.17 and nll loss -9.34
# Epoch: 8/19, i/N: 350/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 360/400 with KL 0.05 and nll loss -9.47
# Epoch: 8/19, i/N: 370/400 with KL 0.12 and nll loss -9.40
# Epoch: 8/19, i/N: 380/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 390/400 with KL 0.16 and nll loss -9.35
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.10415267944335938 and nll_test -9.407025337219238
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.53
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 20/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 30/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 40/400 with KL 0.04 and nll loss -9.47
# Epoch: 9/19, i/N: 50/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 60/400 with KL 0.05 and nll loss -9.46
# Epoch: 9/19, i/N: 70/400 with KL 0.05 and nll loss -9.46
# Epoch: 9/19, i/N: 80/400 with KL -0.00 and nll loss -9.51
# Epoch: 9/19, i/N: 90/400 with KL 0.17 and nll loss -9.34
# Epoch: 9/19, i/N: 100/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.10413932800292969 and nll_test -9.407038688659668
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.00
# Epoch: 9/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 120/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 130/400 with KL 0.14 and nll loss -9.38
# Epoch: 9/19, i/N: 140/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 150/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 160/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 170/400 with KL -0.00 and nll loss -9.51
# Epoch: 9/19, i/N: 180/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 200/400 with KL 0.11 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.09334468841552734 and nll_test -9.41783332824707
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 1.00
# Epoch: 9/19, i/N: 200/400 avg ldj -0.50
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL -0.02 and nll loss -9.53
# Epoch: 9/19, i/N: 220/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 230/400 with KL 0.08 and nll loss -9.43
# Epoch: 9/19, i/N: 240/400 with KL 0.18 and nll loss -9.33
# Epoch: 9/19, i/N: 250/400 with KL 0.01 and nll loss -9.50
# Epoch: 9/19, i/N: 260/400 with KL 0.17 and nll loss -9.34
# Epoch: 9/19, i/N: 270/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 290/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 300/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.09978103637695312 and nll_test -9.411396980285645
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 1.00
# Epoch: 9/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.09 and nll loss -9.43
# Epoch: 9/19, i/N: 320/400 with KL -0.03 and nll loss -9.54
# Epoch: 9/19, i/N: 330/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 340/400 with KL 0.02 and nll loss -9.49
# Epoch: 9/19, i/N: 350/400 with KL -0.01 and nll loss -9.52
# Epoch: 9/19, i/N: 360/400 with KL -0.01 and nll loss -9.53
# Epoch: 9/19, i/N: 370/400 with KL 0.21 and nll loss -9.30
# Epoch: 9/19, i/N: 380/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 390/400 with KL 0.03 and nll loss -9.48
# Epoch: 10 / 19
# Epoch: 10/19, i/N: 0/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 0/400 KL_test 0.09751605987548828 and nll_test -9.41366195678711
#
# From current batch
# Epoch: 10, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 0/400 MC density sum 1.00
# Epoch: 10/19, i/N: 0/400 avg ldj -0.51
# #####################
#
# Epoch: 10/19, i/N: 10/400 with KL 0.22 and nll loss -9.29
# Epoch: 10/19, i/N: 20/400 with KL 0.07 and nll loss -9.44
# Epoch: 10/19, i/N: 30/400 with KL 0.06 and nll loss -9.45
# Epoch: 10/19, i/N: 40/400 with KL -0.01 and nll loss -9.52
# Epoch: 10/19, i/N: 50/400 with KL 0.19 and nll loss -9.32
# Epoch: 10/19, i/N: 60/400 with KL 0.10 and nll loss -9.42
# Epoch: 10/19, i/N: 70/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 80/400 with KL 0.07 and nll loss -9.44
# Epoch: 10/19, i/N: 90/400 with KL 0.11 and nll loss -9.40
# Epoch: 10/19, i/N: 100/400 with KL 0.07 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 100/400 KL_test 0.09067344665527344 and nll_test -9.420504570007324
#
# From current batch
# Epoch: 10, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 100/400 MC density sum 1.00
# Epoch: 10/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 10/19, i/N: 110/400 with KL 0.04 and nll loss -9.47
# Epoch: 10/19, i/N: 120/400 with KL 0.04 and nll loss -9.47
# Epoch: 10/19, i/N: 130/400 with KL 0.06 and nll loss -9.45
# Epoch: 10/19, i/N: 140/400 with KL 0.09 and nll loss -9.42
# Epoch: 10/19, i/N: 150/400 with KL -0.01 and nll loss -9.52
# Epoch: 10/19, i/N: 160/400 with KL 0.02 and nll loss -9.50
# Epoch: 10/19, i/N: 170/400 with KL 0.08 and nll loss -9.43
# Epoch: 10/19, i/N: 180/400 with KL 0.16 and nll loss -9.35
# Epoch: 10/19, i/N: 190/400 with KL 0.15 and nll loss -9.36
# Epoch: 10/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 200/400 KL_test 0.09635162353515625 and nll_test -9.414826393127441
#
# From current batch
# Epoch: 10, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 200/400 MC density sum 1.00
# Epoch: 10/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 10/19, i/N: 210/400 with KL 0.14 and nll loss -9.37
# Epoch: 10/19, i/N: 220/400 with KL 0.08 and nll loss -9.43
# Epoch: 10/19, i/N: 230/400 with KL 0.01 and nll loss -9.50
# Epoch: 10/19, i/N: 240/400 with KL 0.06 and nll loss -9.46
# Epoch: 10/19, i/N: 250/400 with KL 0.17 and nll loss -9.34
# Epoch: 10/19, i/N: 260/400 with KL 0.18 and nll loss -9.33
# Epoch: 10/19, i/N: 270/400 with KL 0.15 and nll loss -9.36
# Epoch: 10/19, i/N: 280/400 with KL 0.14 and nll loss -9.38
# Epoch: 10/19, i/N: 290/400 with KL 0.10 and nll loss -9.41
# Epoch: 10/19, i/N: 300/400 with KL 0.01 and nll loss -9.50
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 300/400 KL_test 0.09445381164550781 and nll_test -9.41672420501709
#
# From current batch
# Epoch: 10, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 300/400 MC density sum 1.00
# Epoch: 10/19, i/N: 300/400 avg ldj -0.53
# #####################
#
# Epoch: 10/19, i/N: 310/400 with KL 0.02 and nll loss -9.49
# ...
# Epoch: 16/19, i/N: 0/400 KL_test 0.09877967834472656 and nll_test -9.412398338317871
#
# From current batch
# Epoch: 16, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 20/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 30/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 40/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 50/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 60/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 70/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 90/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 100/400 with KL -0.02 and nll loss -9.53
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.0874929428100586 and nll_test -9.423685073852539
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.01
# Epoch: 16/19, i/N: 100/400 avg ldj -0.55
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.05 and nll loss -9.47
# Epoch: 16/19, i/N: 120/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 130/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 140/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 150/400 with KL 0.01 and nll loss -9.50
# Epoch: 16/19, i/N: 160/400 with KL -0.07 and nll loss -9.58
# Epoch: 16/19, i/N: 170/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 180/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 190/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.09031009674072266 and nll_test -9.420867919921875
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.52
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.16 and nll loss -9.35
# Epoch: 16/19, i/N: 220/400 with KL 0.19 and nll loss -9.32
# Epoch: 16/19, i/N: 230/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 240/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 250/400 with KL 0.15 and nll loss -9.36
# Epoch: 16/19, i/N: 260/400 with KL 0.19 and nll loss -9.32
# Epoch: 16/19, i/N: 270/400 with KL -0.03 and nll loss -9.54
# Epoch: 16/19, i/N: 280/400 with KL 0.15 and nll loss -9.36
# Epoch: 16/19, i/N: 290/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 300/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.08678531646728516 and nll_test -9.424392700195312
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 0.99
# Epoch: 16/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.15 and nll loss -9.36
# Epoch: 16/19, i/N: 320/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 330/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 340/400 with KL 0.17 and nll loss -9.34
# Epoch: 16/19, i/N: 350/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 360/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 370/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 380/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 390/400 with KL 0.18 and nll loss -9.33
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.08803653717041016 and nll_test -9.423141479492188
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.54
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.02 and nll loss -9.49
# Epoch: 17/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 30/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 40/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 50/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 60/400 with KL 0.18 and nll loss -9.33
# Epoch: 17/19, i/N: 70/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 80/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 90/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.08379840850830078 and nll_test -9.427379608154297
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.54
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 0.99
# Epoch: 17/19, i/N: 100/400 avg ldj -0.55
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 120/400 with KL 0.01 and nll loss -9.50
# Epoch: 17/19, i/N: 130/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 140/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 150/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 17/19, i/N: 170/400 with KL 0.14 and nll loss -9.37
# Epoch: 17/19, i/N: 180/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 190/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 200/400 with KL 0.08 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.08979320526123047 and nll_test -9.421384811401367
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 0.99
# Epoch: 17/19, i/N: 200/400 avg ldj -0.52
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.16 and nll loss -9.35
# Epoch: 17/19, i/N: 220/400 with KL -0.12 and nll loss -9.63
# Epoch: 17/19, i/N: 230/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 240/400 with KL 0.18 and nll loss -9.33
# Epoch: 17/19, i/N: 250/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 260/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 270/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 280/400 with KL 0.12 and nll loss -9.39
# Epoch: 17/19, i/N: 290/400 with KL -0.02 and nll loss -9.53
# Epoch: 17/19, i/N: 300/400 with KL 0.06 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.09308815002441406 and nll_test -9.418089866638184
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.54
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.00 and nll loss -9.51
# Epoch: 17/19, i/N: 320/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 330/400 with KL 0.15 and nll loss -9.37
# Epoch: 17/19, i/N: 340/400 with KL 0.08 and nll loss -9.44
# Epoch: 17/19, i/N: 350/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 360/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 370/400 with KL 0.18 and nll loss -9.33
# Epoch: 17/19, i/N: 380/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 390/400 with KL 0.07 and nll loss -9.45
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.08912467956542969 and nll_test -9.422053337097168
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.54
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 20/400 with KL 0.24 and nll loss -9.27
# Epoch: 18/19, i/N: 30/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 40/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 50/400 with KL 0.07 and nll loss -9.44
# Epoch: 18/19, i/N: 60/400 with KL -0.01 and nll loss -9.52
# Epoch: 18/19, i/N: 70/400 with KL 0.12 and nll loss -9.39
# Epoch: 18/19, i/N: 80/400 with KL -0.09 and nll loss -9.60
# Epoch: 18/19, i/N: 90/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 100/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.0935811996459961 and nll_test -9.417596817016602
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.55
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL -0.04 and nll loss -9.55
# Epoch: 18/19, i/N: 120/400 with KL 0.12 and nll loss -9.39
# Epoch: 18/19, i/N: 130/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 140/400 with KL 0.07 and nll loss -9.44
# Epoch: 18/19, i/N: 150/400 with KL 0.16 and nll loss -9.35
# Epoch: 18/19, i/N: 160/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 170/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 180/400 with KL -0.00 and nll loss -9.51
# Epoch: 18/19, i/N: 190/400 with KL 0.17 and nll loss -9.34
# Epoch: 18/19, i/N: 200/400 with KL 0.13 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.08951568603515625 and nll_test -9.421662330627441
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.50
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL -0.03 and nll loss -9.54
# Epoch: 18/19, i/N: 220/400 with KL 0.14 and nll loss -9.37
# Epoch: 18/19, i/N: 230/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 240/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 250/400 with KL -0.01 and nll loss -9.52
# Epoch: 18/19, i/N: 260/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 270/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 280/400 with KL 0.13 and nll loss -9.38
# Epoch: 18/19, i/N: 290/400 with KL -0.00 and nll loss -9.52
# Epoch: 18/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.08753490447998047 and nll_test -9.423643112182617
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.49
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 320/400 with KL 0.11 and nll loss -9.41
# Epoch: 18/19, i/N: 330/400 with KL 0.07 and nll loss -9.44
# Epoch: 18/19, i/N: 340/400 with KL 0.00 and nll loss -9.51
# Epoch: 18/19, i/N: 350/400 with KL 0.22 and nll loss -9.29
# Epoch: 18/19, i/N: 360/400 with KL 0.15 and nll loss -9.36
# Epoch: 18/19, i/N: 370/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 380/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 390/400 with KL 0.10 and nll loss -9.41
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.08373355865478516 and nll_test -9.427444458007812
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.54
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.53
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 20/400 with KL 0.10 and nll loss -9.42
# Epoch: 19/19, i/N: 30/400 with KL -0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 40/400 with KL 0.10 and nll loss -9.41
# Epoch: 19/19, i/N: 50/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 60/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 70/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 80/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 90/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.09165000915527344 and nll_test -9.419528007507324
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.18 and nll loss -9.33
# Epoch: 19/19, i/N: 120/400 with KL 0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 130/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 140/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 150/400 with KL -0.01 and nll loss -9.52
# Epoch: 19/19, i/N: 160/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 170/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 180/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 190/400 with KL -0.04 and nll loss -9.56
# Epoch: 19/19, i/N: 200/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.09234333038330078 and nll_test -9.418834686279297
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.55
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.18 and nll loss -9.33
# Epoch: 19/19, i/N: 220/400 with KL 0.16 and nll loss -9.35
# Epoch: 19/19, i/N: 230/400 with KL -0.03 and nll loss -9.54
# Epoch: 19/19, i/N: 240/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 250/400 with KL 0.08 and nll loss -9.43
# Epoch: 19/19, i/N: 260/400 with KL 0.01 and nll loss -9.50
# Epoch: 19/19, i/N: 270/400 with KL 0.15 and nll loss -9.36
# Epoch: 19/19, i/N: 280/400 with KL 0.19 and nll loss -9.32
# Epoch: 19/19, i/N: 290/400 with KL 0.23 and nll loss -9.28
# Epoch: 19/19, i/N: 300/400 with KL 0.22 and nll loss -9.29
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.09044456481933594 and nll_test -9.420733451843262
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.56
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.01 and nll loss -9.50
# Epoch: 19/19, i/N: 320/400 with KL 0.10 and nll loss -9.42
# Epoch: 19/19, i/N: 330/400 with KL 0.17 and nll loss -9.35
# Epoch: 19/19, i/N: 340/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 350/400 with KL 0.15 and nll loss -9.37
# Epoch: 19/19, i/N: 360/400 with KL 0.19 and nll loss -9.32
# Epoch: 19/19, i/N: 370/400 with KL -0.02 and nll loss -9.53
# Epoch: 19/19, i/N: 380/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 390/400 with KL 0.05 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.09450721740722656 and nll_test -9.416670799255371
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.53
# #####################

# %% [markdown]
# ### Coupling Spline Flow

# %%
cou_spline = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                           num_dim_data= NUM_DIM_DATA,
                           flow_type = 'spline', 
                           num_centers = NUM_CENTERS,
                           num_bins = NUM_BINS,
                           cap_householder_refl=CAP_HOUSEHOLDER_REFL) 

cou_spline.to(device)

optimizer = optim.AdamW(cou_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Spline Flow #####')

train_model(model = cou_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name = 'cou_s')
# Out:
# ##### Coupling Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_224021" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_224021</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Coupling_Flow(
#   (scale): ModuleList(
#     (0): Rotation()
#     (1): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=288, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#     (2): Rotation()
#     (3): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=288, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#     (4): Rotation()
#     (5): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=288, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=256, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 226662,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.47655576e-01,  7.12287351e-02,  1.61837906e-01,
#         -2.49965787e-01, -3.00656687e-02,  5.13378978e-02,
#         -1.15420990e-01, -1.60892144e-01,  1.66813165e-01,
#         -9.64126736e-02, -2.08793998e-01, -8.28458816e-02,
#          1.27564132e-01,  1.82334691e-01,  4.14802469e-02,
#          1.96271405e-01, -2.84940153e-01, -5.84344044e-02,
#          3.46819907e-01, -5.94147295e-02,  3.57276984e-02,
#          1.40802979e-01,  1.87079117e-01, -1.30439639e-01,
#         -3.76892798e-02, -3.87697071e-02, -3.26900601e-01,
#         -6.21567555e-02, -3.71144861e-01,  1.21363901e-01,
#         -2.38252848e-01, -2.44810417e-01],
#        [-1.38830440e-02, -3.90221574e-03,  2.89825462e-02,
#          3.82002503e-01,  1.59077853e-01, -1.10007562e-01,
#         -1.37695208e-01, -1.00668795e-01, -2.32898831e-01,
#          2.15627357e-01,  2.72735924e-01, -1.75629154e-01,
#         -4.34777588e-02, -4.15739939e-02,  8.32903013e-02,
#          4.32200469e-02, -2.96170041e-02, -4.31307368e-02,
#         -2.40800902e-03, -6.38056844e-02, -4.93000597e-01,
#         -1.76272526e-01, -5.13575971e-02,  1.55285999e-01,
#          2.69974083e-01,  2.60492641e-04, -7.27226809e-02,
#         -3.50454718e-01,  1.90309197e-01, -6.35220185e-02,
#         -5.90479895e-02,  1.25352696e-01],
#        [ 2.60214563e-02,  3.56507376e-02, -1.00506626e-01,
#          1.56339660e-01, -2.42792353e-01, -3.35473359e-01,
#         -1.13739289e-01, -1.20175540e-01, -1.72994345e-01,
#          2.33775198e-01,  9.12943706e-02, -2.81111747e-02,
#         -1.58582807e-01, -7.54978359e-02, -2.02521160e-01,
#          1.15622178e-01, -4.40940171e-01,  7.89586380e-02,
#          1.11749269e-01,  6.01152927e-02, -2.45873649e-02,
#         -1.87052876e-01,  3.42127830e-01,  1.91307142e-01,
#         -7.78181776e-02, -3.38192731e-02,  1.47817269e-01,
#          1.92607939e-01, -1.61186084e-01,  3.18894871e-02,
#          9.78971273e-02,  2.77430654e-01],
#        [-1.12130381e-01,  1.73135325e-01,  2.20798597e-01,
#         -2.30746195e-01,  2.66201477e-02, -3.95676401e-03,
#         -8.50699022e-02,  1.11059688e-01,  8.01334158e-02,
#          3.99493515e-01, -2.53683060e-01,  3.69951695e-01,
#          1.05917104e-01, -3.29163261e-02,  9.61499959e-02,
#         -2.40879774e-01, -2.34925091e-01, -6.56795427e-02,
#          1.30749673e-01,  1.89674515e-02, -1.22393437e-01,
#         -1.02263898e-01,  1.33639634e-01,  1.27292857e-01,
#         -1.70438379e-01,  2.41557494e-01, -2.52882808e-01,
#          1.05931632e-01, -9.00397003e-02,  1.28095791e-01,
#          5.91178760e-02,  2.47614831e-01]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -9.511178016662598
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.62 and nll loss -8.89
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.6207704544067383 and nll_test -8.89040756225586
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.62 and nll loss -8.89
# Epoch: 0/19, i/N: 20/400 with KL 0.61 and nll loss -8.90
# Epoch: 0/19, i/N: 30/400 with KL 0.59 and nll loss -8.93
# Epoch: 0/19, i/N: 40/400 with KL 0.56 and nll loss -8.96
# Epoch: 0/19, i/N: 50/400 with KL 0.50 and nll loss -9.01
# Epoch: 0/19, i/N: 60/400 with KL 0.45 and nll loss -9.06
# Epoch: 0/19, i/N: 70/400 with KL 0.39 and nll loss -9.12
# Epoch: 0/19, i/N: 80/400 with KL 0.37 and nll loss -9.15
# Epoch: 0/19, i/N: 90/400 with KL 0.39 and nll loss -9.12
# Epoch: 0/19, i/N: 100/400 with KL 0.45 and nll loss -9.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.3678779602050781 and nll_test -9.14330005645752
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.34 and nll loss -9.17
# Epoch: 0/19, i/N: 120/400 with KL 0.42 and nll loss -9.09
# Epoch: 0/19, i/N: 130/400 with KL 0.33 and nll loss -9.18
# Epoch: 0/19, i/N: 140/400 with KL 0.38 and nll loss -9.13
# Epoch: 0/19, i/N: 150/400 with KL 0.35 and nll loss -9.16
# Epoch: 0/19, i/N: 160/400 with KL 0.26 and nll loss -9.25
# Epoch: 0/19, i/N: 170/400 with KL 0.33 and nll loss -9.18
# Epoch: 0/19, i/N: 180/400 with KL 0.31 and nll loss -9.20
# Epoch: 0/19, i/N: 190/400 with KL 0.29 and nll loss -9.22
# Epoch: 0/19, i/N: 200/400 with KL 0.25 and nll loss -9.26
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.3207988739013672 and nll_test -9.19037914276123
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.30
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.32
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.36 and nll loss -9.15
# Epoch: 0/19, i/N: 220/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 230/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 240/400 with KL 0.32 and nll loss -9.19
# Epoch: 0/19, i/N: 250/400 with KL 0.23 and nll loss -9.28
# Epoch: 0/19, i/N: 260/400 with KL 0.33 and nll loss -9.18
# Epoch: 0/19, i/N: 270/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 280/400 with KL 0.40 and nll loss -9.11
# Epoch: 0/19, i/N: 290/400 with KL 0.34 and nll loss -9.17
# Epoch: 0/19, i/N: 300/400 with KL 0.24 and nll loss -9.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.28363513946533203 and nll_test -9.227542877197266
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.34
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.34
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.31 and nll loss -9.20
# Epoch: 0/19, i/N: 320/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 330/400 with KL 0.35 and nll loss -9.16
# Epoch: 0/19, i/N: 340/400 with KL 0.26 and nll loss -9.25
# Epoch: 0/19, i/N: 350/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 360/400 with KL 0.28 and nll loss -9.23
# Epoch: 0/19, i/N: 370/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 380/400 with KL 0.27 and nll loss -9.24
# Epoch: 0/19, i/N: 390/400 with KL 0.24 and nll loss -9.27
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.24 and nll loss -9.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.25169944763183594 and nll_test -9.259478569030762
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.37
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.40
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 20/400 with KL 0.31 and nll loss -9.20
# Epoch: 1/19, i/N: 30/400 with KL 0.27 and nll loss -9.25
# Epoch: 1/19, i/N: 40/400 with KL 0.27 and nll loss -9.24
# Epoch: 1/19, i/N: 50/400 with KL 0.22 and nll loss -9.29
# Epoch: 1/19, i/N: 60/400 with KL 0.31 and nll loss -9.20
# Epoch: 1/19, i/N: 70/400 with KL 0.28 and nll loss -9.24
# Epoch: 1/19, i/N: 80/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 90/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 100/400 with KL 0.24 and nll loss -9.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.23095130920410156 and nll_test -9.280226707458496
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.39
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.39
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.25 and nll loss -9.27
# Epoch: 1/19, i/N: 120/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 130/400 with KL 0.26 and nll loss -9.25
# Epoch: 1/19, i/N: 140/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 150/400 with KL 0.21 and nll loss -9.31
# Epoch: 1/19, i/N: 160/400 with KL 0.26 and nll loss -9.26
# Epoch: 1/19, i/N: 170/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 180/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 190/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 200/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.20926856994628906 and nll_test -9.301909446716309
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.41
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.39
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.26 and nll loss -9.25
# Epoch: 1/19, i/N: 220/400 with KL 0.31 and nll loss -9.20
# Epoch: 1/19, i/N: 230/400 with KL 0.23 and nll loss -9.28
# Epoch: 1/19, i/N: 240/400 with KL 0.25 and nll loss -9.26
# Epoch: 1/19, i/N: 250/400 with KL 0.23 and nll loss -9.28
# Epoch: 1/19, i/N: 260/400 with KL 0.06 and nll loss -9.45
# Epoch: 1/19, i/N: 270/400 with KL 0.16 and nll loss -9.36
# Epoch: 1/19, i/N: 280/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 290/400 with KL 0.35 and nll loss -9.16
# Epoch: 1/19, i/N: 300/400 with KL 0.23 and nll loss -9.28
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.2100849151611328 and nll_test -9.301093101501465
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.41
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.40
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 320/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 330/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 340/400 with KL 0.26 and nll loss -9.25
# Epoch: 1/19, i/N: 350/400 with KL 0.27 and nll loss -9.24
# Epoch: 1/19, i/N: 360/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 370/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 380/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 390/400 with KL 0.22 and nll loss -9.30
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.19413471221923828 and nll_test -9.31704330444336
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.43
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.01
# Epoch: 2/19, i/N: 0/400 avg ldj -0.41
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.25 and nll loss -9.26
# Epoch: 2/19, i/N: 20/400 with KL 0.29 and nll loss -9.22
# Epoch: 2/19, i/N: 30/400 with KL 0.31 and nll loss -9.20
# Epoch: 2/19, i/N: 40/400 with KL 0.17 and nll loss -9.35
# Epoch: 2/19, i/N: 50/400 with KL 0.25 and nll loss -9.26
# Epoch: 2/19, i/N: 60/400 with KL 0.26 and nll loss -9.25
# Epoch: 2/19, i/N: 70/400 with KL 0.28 and nll loss -9.23
# Epoch: 2/19, i/N: 80/400 with KL 0.35 and nll loss -9.16
# Epoch: 2/19, i/N: 90/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 100/400 with KL 0.31 and nll loss -9.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.2101430892944336 and nll_test -9.301034927368164
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.41
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.40
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 120/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 130/400 with KL 0.19 and nll loss -9.32
# Epoch: 2/19, i/N: 140/400 with KL 0.20 and nll loss -9.32
# Epoch: 2/19, i/N: 150/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 160/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 170/400 with KL 0.27 and nll loss -9.24
# Epoch: 2/19, i/N: 180/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 190/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 200/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.18682575225830078 and nll_test -9.324352264404297
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.43
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.43
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.30 and nll loss -9.21
# Epoch: 2/19, i/N: 220/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 230/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 240/400 with KL 0.22 and nll loss -9.29
# Epoch: 2/19, i/N: 250/400 with KL 0.11 and nll loss -9.40
# Epoch: 2/19, i/N: 260/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 270/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 280/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 290/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 300/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.18441200256347656 and nll_test -9.326766014099121
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.44
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.43
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 320/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 330/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 2/19, i/N: 350/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 360/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 370/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 380/400 with KL 0.22 and nll loss -9.29
# Epoch: 2/19, i/N: 390/400 with KL 0.17 and nll loss -9.35
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.17190933227539062 and nll_test -9.339268684387207
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.47
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 20/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 40/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 50/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 60/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 70/400 with KL 0.24 and nll loss -9.27
# Epoch: 3/19, i/N: 80/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 90/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.17246341705322266 and nll_test -9.338714599609375
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.44
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 120/400 with KL 0.18 and nll loss -9.33
# Epoch: 3/19, i/N: 130/400 with KL 0.20 and nll loss -9.31
# Epoch: 3/19, i/N: 140/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 150/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 160/400 with KL 0.24 and nll loss -9.27
# Epoch: 3/19, i/N: 170/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 180/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 190/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 200/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.17415809631347656 and nll_test -9.337019920349121
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.44
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.20 and nll loss -9.31
# Epoch: 3/19, i/N: 220/400 with KL 0.21 and nll loss -9.31
# Epoch: 3/19, i/N: 230/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 240/400 with KL 0.21 and nll loss -9.31
# Epoch: 3/19, i/N: 250/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 260/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 270/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 280/400 with KL 0.21 and nll loss -9.31
# Epoch: 3/19, i/N: 290/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 300/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.1930103302001953 and nll_test -9.318167686462402
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.43
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.38
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.21 and nll loss -9.30
# Epoch: 3/19, i/N: 320/400 with KL 0.20 and nll loss -9.32
# Epoch: 3/19, i/N: 330/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 3/19, i/N: 350/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 360/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 370/400 with KL 0.20 and nll loss -9.31
# Epoch: 3/19, i/N: 380/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.24 and nll loss -9.28
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.17381858825683594 and nll_test -9.337359428405762
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.01
# Epoch: 4/19, i/N: 0/400 avg ldj -0.47
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.17 and nll loss -9.35
# Epoch: 4/19, i/N: 20/400 with KL 0.20 and nll loss -9.31
# Epoch: 4/19, i/N: 30/400 with KL 0.25 and nll loss -9.26
# Epoch: 4/19, i/N: 40/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 50/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 60/400 with KL 0.23 and nll loss -9.28
# Epoch: 4/19, i/N: 70/400 with KL 0.29 and nll loss -9.22
# Epoch: 4/19, i/N: 80/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 90/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 100/400 with KL 0.22 and nll loss -9.29
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.167144775390625 and nll_test -9.344033241271973
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 120/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 130/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 140/400 with KL 0.15 and nll loss -9.36
# Epoch: 4/19, i/N: 150/400 with KL 0.33 and nll loss -9.18
# Epoch: 4/19, i/N: 160/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 170/400 with KL 0.20 and nll loss -9.31
# Epoch: 4/19, i/N: 180/400 with KL 0.05 and nll loss -9.46
# Epoch: 4/19, i/N: 190/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 200/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.16469383239746094 and nll_test -9.346484184265137
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.01
# Epoch: 4/19, i/N: 200/400 avg ldj -0.43
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.07 and nll loss -9.45
# Epoch: 4/19, i/N: 220/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 230/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 240/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 250/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 260/400 with KL 0.24 and nll loss -9.27
# Epoch: 4/19, i/N: 270/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 280/400 with KL 0.25 and nll loss -9.26
# Epoch: 4/19, i/N: 290/400 with KL 0.22 and nll loss -9.30
# Epoch: 4/19, i/N: 300/400 with KL 0.23 and nll loss -9.28
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.1601095199584961 and nll_test -9.351068496704102
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.46
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 320/400 with KL 0.26 and nll loss -9.26
# Epoch: 4/19, i/N: 330/400 with KL 0.13 and nll loss -9.38
# Epoch: 4/19, i/N: 340/400 with KL 0.23 and nll loss -9.28
# Epoch: 4/19, i/N: 350/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 360/400 with KL 0.06 and nll loss -9.46
# Epoch: 4/19, i/N: 370/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 380/400 with KL 0.20 and nll loss -9.31
# Epoch: 4/19, i/N: 390/400 with KL 0.15 and nll loss -9.36
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.1585826873779297 and nll_test -9.352595329284668
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.46
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.25 and nll loss -9.26
# Epoch: 5/19, i/N: 20/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 30/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 40/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 50/400 with KL 0.22 and nll loss -9.29
# Epoch: 5/19, i/N: 60/400 with KL 0.22 and nll loss -9.30
# Epoch: 5/19, i/N: 70/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 90/400 with KL 0.26 and nll loss -9.25
# Epoch: 5/19, i/N: 100/400 with KL 0.27 and nll loss -9.24
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.15514850616455078 and nll_test -9.356029510498047
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.01
# Epoch: 5/19, i/N: 100/400 avg ldj -0.44
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.12 and nll loss -9.40
# Epoch: 5/19, i/N: 120/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 130/400 with KL 0.25 and nll loss -9.26
# Epoch: 5/19, i/N: 140/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 150/400 with KL 0.06 and nll loss -9.45
# Epoch: 5/19, i/N: 160/400 with KL 0.24 and nll loss -9.27
# Epoch: 5/19, i/N: 170/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 180/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 190/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 200/400 with KL 0.21 and nll loss -9.30
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.15053749084472656 and nll_test -9.360640525817871
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.01
# Epoch: 5/19, i/N: 200/400 avg ldj -0.46
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.03 and nll loss -9.48
# Epoch: 5/19, i/N: 220/400 with KL 0.20 and nll loss -9.32
# Epoch: 5/19, i/N: 230/400 with KL 0.21 and nll loss -9.30
# Epoch: 5/19, i/N: 240/400 with KL 0.20 and nll loss -9.31
# Epoch: 5/19, i/N: 250/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 260/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 270/400 with KL 0.24 and nll loss -9.28
# Epoch: 5/19, i/N: 280/400 with KL 0.07 and nll loss -9.44
# Epoch: 5/19, i/N: 290/400 with KL 0.04 and nll loss -9.47
# Epoch: 5/19, i/N: 300/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.14801406860351562 and nll_test -9.363163948059082
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.23 and nll loss -9.28
# Epoch: 5/19, i/N: 320/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 330/400 with KL 0.16 and nll loss -9.35
# Epoch: 5/19, i/N: 340/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 350/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 360/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 370/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 380/400 with KL 0.23 and nll loss -9.28
# Epoch: 5/19, i/N: 390/400 with KL 0.14 and nll loss -9.37
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.1558685302734375 and nll_test -9.35530948638916
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.45
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.02 and nll loss -9.49
# Epoch: 6/19, i/N: 20/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 40/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 50/400 with KL 0.21 and nll loss -9.30
# Epoch: 6/19, i/N: 60/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 70/400 with KL 0.15 and nll loss -9.36
# Epoch: 6/19, i/N: 80/400 with KL 0.15 and nll loss -9.36
# Epoch: 6/19, i/N: 90/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 100/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.1549844741821289 and nll_test -9.356193542480469
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.43
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 120/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 130/400 with KL 0.18 and nll loss -9.33
# Epoch: 6/19, i/N: 140/400 with KL 0.21 and nll loss -9.30
# Epoch: 6/19, i/N: 150/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 160/400 with KL 0.18 and nll loss -9.34
# Epoch: 6/19, i/N: 170/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 180/400 with KL 0.20 and nll loss -9.31
# Epoch: 6/19, i/N: 190/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 200/400 with KL 0.31 and nll loss -9.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.15010738372802734 and nll_test -9.36107063293457
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.46
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.06 and nll loss -9.45
# Epoch: 6/19, i/N: 220/400 with KL 0.27 and nll loss -9.24
# Epoch: 6/19, i/N: 230/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 240/400 with KL 0.01 and nll loss -9.50
# Epoch: 6/19, i/N: 250/400 with KL 0.24 and nll loss -9.27
# Epoch: 6/19, i/N: 260/400 with KL 0.25 and nll loss -9.26
# Epoch: 6/19, i/N: 270/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 280/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 290/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 300/400 with KL 0.24 and nll loss -9.27
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.16226863861083984 and nll_test -9.348909378051758
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 6/19, i/N: 330/400 with KL 0.22 and nll loss -9.29
# Epoch: 6/19, i/N: 340/400 with KL 0.26 and nll loss -9.25
# Epoch: 6/19, i/N: 350/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 360/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 370/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 380/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.1585063934326172 and nll_test -9.35267162322998
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.10 and nll loss -9.42
# Epoch: 7/19, i/N: 20/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 30/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 40/400 with KL 0.09 and nll loss -9.42
# Epoch: 7/19, i/N: 50/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 60/400 with KL 0.20 and nll loss -9.31
# Epoch: 7/19, i/N: 70/400 with KL 0.15 and nll loss -9.37
# Epoch: 7/19, i/N: 80/400 with KL 0.15 and nll loss -9.37
# Epoch: 7/19, i/N: 90/400 with KL 0.19 and nll loss -9.32
# Epoch: 7/19, i/N: 100/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.16383075714111328 and nll_test -9.347347259521484
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.25 and nll loss -9.26
# Epoch: 7/19, i/N: 120/400 with KL 0.28 and nll loss -9.24
# Epoch: 7/19, i/N: 130/400 with KL 0.28 and nll loss -9.23
# Epoch: 7/19, i/N: 140/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 150/400 with KL 0.16 and nll loss -9.35
# Epoch: 7/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 170/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 180/400 with KL 0.30 and nll loss -9.21
# Epoch: 7/19, i/N: 190/400 with KL 0.24 and nll loss -9.27
# Epoch: 7/19, i/N: 200/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.14583110809326172 and nll_test -9.365346908569336
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.46
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.23 and nll loss -9.28
# Epoch: 7/19, i/N: 220/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 230/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 240/400 with KL 0.04 and nll loss -9.47
# Epoch: 7/19, i/N: 250/400 with KL 0.22 and nll loss -9.29
# Epoch: 7/19, i/N: 260/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 270/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 280/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 300/400 with KL 0.23 and nll loss -9.28
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.14708232879638672 and nll_test -9.364095687866211
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 0.99
# Epoch: 7/19, i/N: 300/400 avg ldj -0.46
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 330/400 with KL 0.22 and nll loss -9.29
# Epoch: 7/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 350/400 with KL 0.12 and nll loss -9.40
# Epoch: 7/19, i/N: 360/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 370/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 380/400 with KL 0.18 and nll loss -9.33
# Epoch: 7/19, i/N: 390/400 with KL 0.12 and nll loss -9.39
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.14733123779296875 and nll_test -9.363846778869629
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.08 and nll loss -9.43
# Epoch: 8/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 30/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 40/400 with KL 0.17 and nll loss -9.34
# Epoch: 8/19, i/N: 50/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 60/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 70/400 with KL 0.24 and nll loss -9.27
# Epoch: 8/19, i/N: 80/400 with KL 0.19 and nll loss -9.33
# Epoch: 8/19, i/N: 90/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 100/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.14815521240234375 and nll_test -9.363022804260254
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.17 and nll loss -9.34
# Epoch: 8/19, i/N: 120/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 130/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 140/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 150/400 with KL 0.25 and nll loss -9.26
# Epoch: 8/19, i/N: 160/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 170/400 with KL 0.20 and nll loss -9.31
# Epoch: 8/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 8/19, i/N: 190/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 200/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.15071487426757812 and nll_test -9.36046314239502
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.45
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 220/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 230/400 with KL 0.14 and nll loss -9.38
# Epoch: 8/19, i/N: 240/400 with KL 0.17 and nll loss -9.34
# Epoch: 8/19, i/N: 250/400 with KL 0.19 and nll loss -9.32
# Epoch: 8/19, i/N: 260/400 with KL 0.19 and nll loss -9.32
# Epoch: 8/19, i/N: 270/400 with KL 0.09 and nll loss -9.42
# Epoch: 8/19, i/N: 280/400 with KL 0.20 and nll loss -9.32
# Epoch: 8/19, i/N: 290/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 300/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.14178085327148438 and nll_test -9.369397163391113
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 0.99
# Epoch: 8/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.18 and nll loss -9.33
# Epoch: 8/19, i/N: 320/400 with KL 0.19 and nll loss -9.32
# Epoch: 8/19, i/N: 330/400 with KL 0.08 and nll loss -9.43
# Epoch: 8/19, i/N: 340/400 with KL 0.28 and nll loss -9.23
# Epoch: 8/19, i/N: 350/400 with KL 0.19 and nll loss -9.32
# Epoch: 8/19, i/N: 360/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 370/400 with KL 0.21 and nll loss -9.30
# Epoch: 8/19, i/N: 380/400 with KL 0.27 and nll loss -9.24
# Epoch: 8/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.13319683074951172 and nll_test -9.377981185913086
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 20/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 30/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 40/400 with KL 0.02 and nll loss -9.49
# Epoch: 9/19, i/N: 50/400 with KL 0.23 and nll loss -9.28
# Epoch: 9/19, i/N: 60/400 with KL 0.22 and nll loss -9.29
# Epoch: 9/19, i/N: 70/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 80/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 90/400 with KL 0.18 and nll loss -9.33
# Epoch: 9/19, i/N: 100/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.13620281219482422 and nll_test -9.374975204467773
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.00
# Epoch: 9/19, i/N: 100/400 avg ldj -0.47
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 120/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 130/400 with KL 0.12 and nll loss -9.39
# Epoch: 9/19, i/N: 140/400 with KL 0.18 and nll loss -9.33
# Epoch: 9/19, i/N: 150/400 with KL 0.26 and nll loss -9.25
# Epoch: 9/19, i/N: 160/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 170/400 with KL 0.20 and nll loss -9.31
# Epoch: 9/19, i/N: 180/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 190/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 200/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.13547325134277344 and nll_test -9.375704765319824
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 1.00
# Epoch: 9/19, i/N: 200/400 avg ldj -0.49
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL 0.18 and nll loss -9.34
# Epoch: 9/19, i/N: 220/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 230/400 with KL 0.18 and nll loss -9.33
# Epoch: 9/19, i/N: 240/400 with KL 0.19 and nll loss -9.32
# Epoch: 9/19, i/N: 250/400 with KL 0.20 and nll loss -9.31
# Epoch: 9/19, i/N: 260/400 with KL 0.27 and nll loss -9.24
# Epoch: 9/19, i/N: 270/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 280/400 with KL 0.18 and nll loss -9.34
# Epoch: 9/19, i/N: 290/400 with KL 0.19 and nll loss -9.33
# Epoch: 9/19, i/N: 300/400 with KL 0.22 and nll loss -9.29
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.1648845672607422 and nll_test -9.346293449401855
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 1.00
# Epoch: 9/19, i/N: 300/400 avg ldj -0.46
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 320/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 330/400 with KL 0.21 and nll loss -9.30
# Epoch: 9/19, i/N: 340/400 with KL 0.22 and nll loss -9.29
# Epoch: 9/19, i/N: 350/400 with KL 0.05 and nll loss -9.46
# Epoch: 9/19, i/N: 360/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 370/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 380/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 390/400 with KL 0.19 and nll loss -9.32
# Epoch: 10 / 19
# Epoch: 10/19, i/N: 0/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 0/400 KL_test 0.14230823516845703 and nll_test -9.36886978149414
#
# From current batch
# Epoch: 10, i/N: 0/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 0/400 MC density sum 1.00
# Epoch: 10/19, i/N: 0/400 avg ldj -0.48
# #####################
#
# Epoch: 10/19, i/N: 10/400 with KL 0.21 and nll loss -9.30
# Epoch: 10/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 10/19, i/N: 30/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 40/400 with KL 0.19 and nll loss -9.32
# Epoch: 10/19, i/N: 50/400 with KL 0.23 and nll loss -9.28
# Epoch: 10/19, i/N: 60/400 with KL 0.28 and nll loss -9.23
# Epoch: 10/19, i/N: 70/400 with KL 0.11 and nll loss -9.40
# Epoch: 10/19, i/N: 80/400 with KL 0.03 and nll loss -9.48
# Epoch: 10/19, i/N: 90/400 with KL 0.19 and nll loss -9.32
# Epoch: 10/19, i/N: 100/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 100/400 KL_test 0.14004802703857422 and nll_test -9.371129989624023
#
# From current batch
# Epoch: 10, i/N: 100/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 100/400 MC density sum 1.00
# Epoch: 10/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 10/19, i/N: 110/400 with KL 0.09 and nll loss -9.42
# Epoch: 10/19, i/N: 120/400 with KL 0.13 and nll loss -9.39
# Epoch: 10/19, i/N: 130/400 with KL 0.17 and nll loss -9.34
# Epoch: 10/19, i/N: 140/400 with KL 0.14 and nll loss -9.37
# Epoch: 10/19, i/N: 150/400 with KL 0.14 and nll loss -9.37
# Epoch: 10/19, i/N: 160/400 with KL 0.22 and nll loss -9.29
# Epoch: 10/19, i/N: 170/400 with KL 0.02 and nll loss -9.49
# Epoch: 10/19, i/N: 180/400 with KL 0.20 and nll loss -9.31
# Epoch: 10/19, i/N: 190/400 with KL 0.11 and nll loss -9.40
# Epoch: 10/19, i/N: 200/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 200/400 KL_test 0.14205265045166016 and nll_test -9.369125366210938
#
# From current batch
# Epoch: 10, i/N: 200/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 200/400 MC density sum 1.00
# Epoch: 10/19, i/N: 200/400 avg ldj -0.49
# #####################
#
# Epoch: 10/19, i/N: 210/400 with KL 0.07 and nll loss -9.45
# Epoch: 10/19, i/N: 220/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 230/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 240/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 250/400 with KL 0.09 and nll loss -9.43
# Epoch: 10/19, i/N: 260/400 with KL 0.18 and nll loss -9.33
# Epoch: 10/19, i/N: 270/400 with KL 0.18 and nll loss -9.34
# Epoch: 10/19, i/N: 280/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 290/400 with KL 0.22 and nll loss -9.30
# Epoch: 10/19, i/N: 300/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 300/400 KL_test 0.1349163055419922 and nll_test -9.376261711120605
#
# From current batch
# Epoch: 10, i/N: 300/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 300/400 MC density sum 1.01
# Epoch: 10/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 10/19, i/N: 310/400 with KL 0.17 and nll loss -9.34
# ...
# Epoch: 16/19, i/N: 0/400 KL_test 0.11458778381347656 and nll_test -9.396590232849121
#
# From current batch
# Epoch: 16, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 16/19, i/N: 20/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 30/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 40/400 with KL 0.01 and nll loss -9.51
# Epoch: 16/19, i/N: 50/400 with KL 0.20 and nll loss -9.32
# Epoch: 16/19, i/N: 60/400 with KL 0.17 and nll loss -9.34
# Epoch: 16/19, i/N: 70/400 with KL 0.22 and nll loss -9.30
# Epoch: 16/19, i/N: 80/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 90/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 100/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.11494731903076172 and nll_test -9.396230697631836
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.50
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 120/400 with KL 0.24 and nll loss -9.27
# Epoch: 16/19, i/N: 130/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 140/400 with KL 0.09 and nll loss -9.43
# Epoch: 16/19, i/N: 150/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 160/400 with KL 0.21 and nll loss -9.31
# Epoch: 16/19, i/N: 170/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 180/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 190/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 200/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.11888504028320312 and nll_test -9.392292976379395
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.54
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 220/400 with KL 0.17 and nll loss -9.34
# Epoch: 16/19, i/N: 230/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 240/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 250/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 260/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 270/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 280/400 with KL 0.12 and nll loss -9.39
# Epoch: 16/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 16/19, i/N: 300/400 with KL 0.22 and nll loss -9.29
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.11934757232666016 and nll_test -9.391830444335938
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 0.99
# Epoch: 16/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 320/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 330/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 340/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 350/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 360/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 370/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 380/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 390/400 with KL 0.24 and nll loss -9.27
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.1149454116821289 and nll_test -9.396232604980469
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.16 and nll loss -9.35
# Epoch: 17/19, i/N: 20/400 with KL 0.13 and nll loss -9.38
# Epoch: 17/19, i/N: 30/400 with KL 0.05 and nll loss -9.46
# Epoch: 17/19, i/N: 40/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 50/400 with KL 0.14 and nll loss -9.37
# Epoch: 17/19, i/N: 60/400 with KL 0.19 and nll loss -9.32
# Epoch: 17/19, i/N: 70/400 with KL 0.10 and nll loss -9.41
# Epoch: 17/19, i/N: 80/400 with KL 0.04 and nll loss -9.48
# Epoch: 17/19, i/N: 90/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 100/400 with KL 0.11 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.11227893829345703 and nll_test -9.39889907836914
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 0.99
# Epoch: 17/19, i/N: 100/400 avg ldj -0.50
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 120/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 130/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 140/400 with KL 0.12 and nll loss -9.39
# Epoch: 17/19, i/N: 150/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 160/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 170/400 with KL 0.18 and nll loss -9.33
# Epoch: 17/19, i/N: 180/400 with KL 0.05 and nll loss -9.47
# Epoch: 17/19, i/N: 190/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.1183481216430664 and nll_test -9.392829895019531
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.50
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 220/400 with KL 0.10 and nll loss -9.41
# Epoch: 17/19, i/N: 230/400 with KL 0.15 and nll loss -9.37
# Epoch: 17/19, i/N: 240/400 with KL 0.22 and nll loss -9.29
# Epoch: 17/19, i/N: 250/400 with KL 0.10 and nll loss -9.42
# Epoch: 17/19, i/N: 260/400 with KL 0.10 and nll loss -9.41
# Epoch: 17/19, i/N: 270/400 with KL 0.00 and nll loss -9.51
# Epoch: 17/19, i/N: 280/400 with KL 0.18 and nll loss -9.33
# Epoch: 17/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 17/19, i/N: 300/400 with KL 0.15 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.1202850341796875 and nll_test -9.39089298248291
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.50
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.16 and nll loss -9.35
# Epoch: 17/19, i/N: 320/400 with KL 0.10 and nll loss -9.41
# Epoch: 17/19, i/N: 330/400 with KL 0.05 and nll loss -9.47
# Epoch: 17/19, i/N: 340/400 with KL 0.13 and nll loss -9.38
# Epoch: 17/19, i/N: 350/400 with KL 0.14 and nll loss -9.37
# Epoch: 17/19, i/N: 360/400 with KL 0.03 and nll loss -9.48
# Epoch: 17/19, i/N: 370/400 with KL 0.10 and nll loss -9.42
# Epoch: 17/19, i/N: 380/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 390/400 with KL 0.16 and nll loss -9.36
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.11353492736816406 and nll_test -9.397643089294434
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.24 and nll loss -9.27
# Epoch: 18/19, i/N: 20/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 30/400 with KL 0.15 and nll loss -9.36
# Epoch: 18/19, i/N: 40/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 50/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 60/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 70/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 80/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 90/400 with KL 0.16 and nll loss -9.35
# Epoch: 18/19, i/N: 100/400 with KL 0.17 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.12342166900634766 and nll_test -9.38775634765625
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.52
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 120/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 130/400 with KL 0.00 and nll loss -9.51
# Epoch: 18/19, i/N: 140/400 with KL 0.17 and nll loss -9.34
# Epoch: 18/19, i/N: 150/400 with KL 0.16 and nll loss -9.36
# Epoch: 18/19, i/N: 160/400 with KL 0.14 and nll loss -9.37
# Epoch: 18/19, i/N: 170/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 180/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 200/400 with KL 0.01 and nll loss -9.50
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.12090110778808594 and nll_test -9.390276908874512
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.49
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.10 and nll loss -9.41
# Epoch: 18/19, i/N: 220/400 with KL 0.13 and nll loss -9.38
# Epoch: 18/19, i/N: 230/400 with KL 0.14 and nll loss -9.37
# Epoch: 18/19, i/N: 240/400 with KL 0.12 and nll loss -9.39
# Epoch: 18/19, i/N: 250/400 with KL 0.10 and nll loss -9.41
# Epoch: 18/19, i/N: 260/400 with KL 0.17 and nll loss -9.34
# Epoch: 18/19, i/N: 270/400 with KL 0.13 and nll loss -9.38
# Epoch: 18/19, i/N: 280/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 290/400 with KL 0.14 and nll loss -9.37
# Epoch: 18/19, i/N: 300/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.11861228942871094 and nll_test -9.392565727233887
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.01
# Epoch: 18/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.10 and nll loss -9.41
# Epoch: 18/19, i/N: 320/400 with KL 0.07 and nll loss -9.44
# Epoch: 18/19, i/N: 330/400 with KL 0.18 and nll loss -9.33
# Epoch: 18/19, i/N: 340/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 350/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 360/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 370/400 with KL 0.07 and nll loss -9.44
# Epoch: 18/19, i/N: 380/400 with KL -0.03 and nll loss -9.54
# Epoch: 18/19, i/N: 390/400 with KL 0.22 and nll loss -9.30
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.11227798461914062 and nll_test -9.398900032043457
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.51
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 20/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 30/400 with KL -0.01 and nll loss -9.52
# Epoch: 19/19, i/N: 40/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 50/400 with KL 0.11 and nll loss -9.40
# Epoch: 19/19, i/N: 60/400 with KL 0.03 and nll loss -9.48
# Epoch: 19/19, i/N: 70/400 with KL 0.20 and nll loss -9.31
# Epoch: 19/19, i/N: 80/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 90/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 100/400 with KL 0.05 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.1089162826538086 and nll_test -9.402261734008789
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.50
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 120/400 with KL 0.11 and nll loss -9.40
# Epoch: 19/19, i/N: 130/400 with KL 0.10 and nll loss -9.41
# Epoch: 19/19, i/N: 140/400 with KL 0.19 and nll loss -9.32
# Epoch: 19/19, i/N: 150/400 with KL 0.18 and nll loss -9.33
# Epoch: 19/19, i/N: 160/400 with KL 0.14 and nll loss -9.37
# Epoch: 19/19, i/N: 170/400 with KL 0.20 and nll loss -9.31
# Epoch: 19/19, i/N: 180/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 190/400 with KL 0.18 and nll loss -9.33
# Epoch: 19/19, i/N: 200/400 with KL 0.14 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.10890769958496094 and nll_test -9.402270317077637
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.07 and nll loss -9.45
# Epoch: 19/19, i/N: 220/400 with KL -0.09 and nll loss -9.60
# Epoch: 19/19, i/N: 230/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 240/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 250/400 with KL 0.24 and nll loss -9.27
# Epoch: 19/19, i/N: 260/400 with KL 0.01 and nll loss -9.50
# Epoch: 19/19, i/N: 270/400 with KL 0.22 and nll loss -9.29
# Epoch: 19/19, i/N: 280/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 290/400 with KL 0.17 and nll loss -9.34
# Epoch: 19/19, i/N: 300/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.10713577270507812 and nll_test -9.40404224395752
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.51
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 320/400 with KL 0.08 and nll loss -9.43
# Epoch: 19/19, i/N: 330/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 340/400 with KL 0.20 and nll loss -9.32
# Epoch: 19/19, i/N: 350/400 with KL 0.14 and nll loss -9.38
# Epoch: 19/19, i/N: 360/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 370/400 with KL 0.14 and nll loss -9.37
# Epoch: 19/19, i/N: 380/400 with KL 0.19 and nll loss -9.32
# Epoch: 19/19, i/N: 390/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.10970115661621094 and nll_test -9.401476860046387
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.52
# #####################

# %% [markdown]
# ### Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_m')

# %% [markdown]
# ### Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS,
                                 flow_type= 'spline',
                                 num_dim_data = NUM_DIM_DATA)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_s')

# %% [markdown]
# ### Coupling Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_m')
# Out:
# ##### Coupling Cylindrical Moebius Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_231424" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_231424</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 473439,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.47655576e-01,  7.12287351e-02,  1.61837906e-01,
#         -2.49965787e-01, -3.00656687e-02,  5.13378978e-02,
#         -1.15420990e-01, -1.60892144e-01,  1.66813165e-01,
#         -9.64126736e-02, -2.08793998e-01, -8.28458816e-02,
#          1.27564132e-01,  1.82334691e-01,  4.14802469e-02,
#          1.96271405e-01, -2.84940153e-01, -5.84344044e-02,
#          3.46819907e-01, -5.94147295e-02,  3.57276984e-02,
#          1.40802979e-01,  1.87079117e-01, -1.30439639e-01,
#         -3.76892798e-02, -3.87697071e-02, -3.26900601e-01,
#         -6.21567555e-02, -3.71144861e-01,  1.21363901e-01,
#         -2.38252848e-01, -2.44810417e-01],
#        [-1.38830440e-02, -3.90221574e-03,  2.89825462e-02,
#          3.82002503e-01,  1.59077853e-01, -1.10007562e-01,
#         -1.37695208e-01, -1.00668795e-01, -2.32898831e-01,
#          2.15627357e-01,  2.72735924e-01, -1.75629154e-01,
#         -4.34777588e-02, -4.15739939e-02,  8.32903013e-02,
#          4.32200469e-02, -2.96170041e-02, -4.31307368e-02,
#         -2.40800902e-03, -6.38056844e-02, -4.93000597e-01,
#         -1.76272526e-01, -5.13575971e-02,  1.55285999e-01,
#          2.69974083e-01,  2.60492641e-04, -7.27226809e-02,
#         -3.50454718e-01,  1.90309197e-01, -6.35220185e-02,
#         -5.90479895e-02,  1.25352696e-01],
#        [ 2.60214563e-02,  3.56507376e-02, -1.00506626e-01,
#          1.56339660e-01, -2.42792353e-01, -3.35473359e-01,
#         -1.13739289e-01, -1.20175540e-01, -1.72994345e-01,
#          2.33775198e-01,  9.12943706e-02, -2.81111747e-02,
#         -1.58582807e-01, -7.54978359e-02, -2.02521160e-01,
#          1.15622178e-01, -4.40940171e-01,  7.89586380e-02,
#          1.11749269e-01,  6.01152927e-02, -2.45873649e-02,
#         -1.87052876e-01,  3.42127830e-01,  1.91307142e-01,
#         -7.78181776e-02, -3.38192731e-02,  1.47817269e-01,
#          1.92607939e-01, -1.61186084e-01,  3.18894871e-02,
#          9.78971273e-02,  2.77430654e-01],
#        [-1.12130381e-01,  1.73135325e-01,  2.20798597e-01,
#         -2.30746195e-01,  2.66201477e-02, -3.95676401e-03,
#         -8.50699022e-02,  1.11059688e-01,  8.01334158e-02,
#          3.99493515e-01, -2.53683060e-01,  3.69951695e-01,
#          1.05917104e-01, -3.29163261e-02,  9.61499959e-02,
#         -2.40879774e-01, -2.34925091e-01, -6.56795427e-02,
#          1.30749673e-01,  1.89674515e-02, -1.22393437e-01,
#         -1.02263898e-01,  1.33639634e-01,  1.27292857e-01,
#         -1.70438379e-01,  2.41557494e-01, -2.52882808e-01,
#          1.05931632e-01, -9.00397003e-02,  1.28095791e-01,
#          5.91178760e-02,  2.47614831e-01]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -9.511178016662598
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.62 and nll loss -8.89
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.6206626892089844 and nll_test -8.890515327453613
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch 0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.60 and nll loss -8.91
# Epoch: 0/19, i/N: 20/400 with KL 0.53 and nll loss -8.98
# Epoch: 0/19, i/N: 30/400 with KL 0.41 and nll loss -9.11
# Epoch: 0/19, i/N: 40/400 with KL 0.38 and nll loss -9.13
# Epoch: 0/19, i/N: 50/400 with KL 0.31 and nll loss -9.21
# Epoch: 0/19, i/N: 60/400 with KL 0.27 and nll loss -9.24
# Epoch: 0/19, i/N: 70/400 with KL 0.28 and nll loss -9.23
# Epoch: 0/19, i/N: 80/400 with KL 0.28 and nll loss -9.23
# Epoch: 0/19, i/N: 90/400 with KL 0.21 and nll loss -9.31
# Epoch: 0/19, i/N: 100/400 with KL 0.21 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.1849050521850586 and nll_test -9.326272964477539
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.44
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.41
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.19 and nll loss -9.33
# Epoch: 0/19, i/N: 120/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 130/400 with KL 0.13 and nll loss -9.38
# Epoch: 0/19, i/N: 140/400 with KL 0.14 and nll loss -9.37
# Epoch: 0/19, i/N: 150/400 with KL 0.19 and nll loss -9.32
# Epoch: 0/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 0/19, i/N: 170/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 180/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 190/400 with KL 0.20 and nll loss -9.32
# Epoch: 0/19, i/N: 200/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.16988849639892578 and nll_test -9.341289520263672
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.44
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 220/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 230/400 with KL 0.19 and nll loss -9.32
# Epoch: 0/19, i/N: 240/400 with KL 0.10 and nll loss -9.41
# Epoch: 0/19, i/N: 250/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 260/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 270/400 with KL 0.26 and nll loss -9.26
# Epoch: 0/19, i/N: 280/400 with KL 0.10 and nll loss -9.41
# Epoch: 0/19, i/N: 290/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 300/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.1625213623046875 and nll_test -9.34865665435791
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.48
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 320/400 with KL 0.19 and nll loss -9.32
# Epoch: 0/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 0/19, i/N: 340/400 with KL 0.18 and nll loss -9.33
# Epoch: 0/19, i/N: 350/400 with KL 0.16 and nll loss -9.35
# Epoch: 0/19, i/N: 360/400 with KL 0.27 and nll loss -9.24
# Epoch: 0/19, i/N: 370/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 380/400 with KL 0.18 and nll loss -9.33
# Epoch: 0/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.18 and nll loss -9.33
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.15796279907226562 and nll_test -9.353215217590332
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.48
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 20/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 30/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 40/400 with KL 0.26 and nll loss -9.26
# Epoch: 1/19, i/N: 50/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 60/400 with KL 0.05 and nll loss -9.47
# Epoch: 1/19, i/N: 70/400 with KL 0.22 and nll loss -9.30
# Epoch: 1/19, i/N: 80/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 90/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 100/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.15953540802001953 and nll_test -9.351642608642578
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.47
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.24 and nll loss -9.27
# Epoch: 1/19, i/N: 120/400 with KL 0.07 and nll loss -9.44
# Epoch: 1/19, i/N: 130/400 with KL 0.10 and nll loss -9.41
# Epoch: 1/19, i/N: 140/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 150/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 160/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 170/400 with KL 0.22 and nll loss -9.30
# Epoch: 1/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 200/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.15756702423095703 and nll_test -9.35361099243164
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.21 and nll loss -9.31
# Epoch: 1/19, i/N: 220/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 230/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 240/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 250/400 with KL 0.12 and nll loss -9.39
# Epoch: 1/19, i/N: 260/400 with KL 0.20 and nll loss -9.31
# Epoch: 1/19, i/N: 270/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 290/400 with KL 0.25 and nll loss -9.26
# Epoch: 1/19, i/N: 300/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.1472625732421875 and nll_test -9.36391544342041
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.47
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.17 and nll loss -9.35
# Epoch: 1/19, i/N: 320/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 330/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 340/400 with KL 0.13 and nll loss -9.39
# Epoch: 1/19, i/N: 350/400 with KL 0.11 and nll loss -9.40
# Epoch: 1/19, i/N: 360/400 with KL 0.22 and nll loss -9.29
# Epoch: 1/19, i/N: 370/400 with KL 0.14 and nll loss -9.38
# Epoch: 1/19, i/N: 380/400 with KL 0.24 and nll loss -9.27
# Epoch: 1/19, i/N: 390/400 with KL 0.12 and nll loss -9.40
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.1504497528076172 and nll_test -9.36072826385498
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 20/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 30/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 40/400 with KL 0.15 and nll loss -9.37
# Epoch: 2/19, i/N: 50/400 with KL 0.07 and nll loss -9.45
# Epoch: 2/19, i/N: 60/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 70/400 with KL 0.03 and nll loss -9.48
# Epoch: 2/19, i/N: 80/400 with KL 0.06 and nll loss -9.45
# Epoch: 2/19, i/N: 90/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 100/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.1462879180908203 and nll_test -9.364890098571777
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 0.99
# Epoch: 2/19, i/N: 100/400 avg ldj -0.47
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.08 and nll loss -9.43
# Epoch: 2/19, i/N: 120/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 130/400 with KL 0.24 and nll loss -9.27
# Epoch: 2/19, i/N: 140/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 150/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 160/400 with KL 0.01 and nll loss -9.51
# Epoch: 2/19, i/N: 170/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 180/400 with KL 0.01 and nll loss -9.50
# Epoch: 2/19, i/N: 190/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 200/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.14489078521728516 and nll_test -9.366287231445312
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.43
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.14 and nll loss -9.38
# Epoch: 2/19, i/N: 220/400 with KL -0.01 and nll loss -9.52
# Epoch: 2/19, i/N: 230/400 with KL 0.27 and nll loss -9.24
# Epoch: 2/19, i/N: 240/400 with KL 0.13 and nll loss -9.38
# Epoch: 2/19, i/N: 250/400 with KL 0.12 and nll loss -9.40
# Epoch: 2/19, i/N: 260/400 with KL 0.12 and nll loss -9.39
# Epoch: 2/19, i/N: 270/400 with KL 0.14 and nll loss -9.38
# Epoch: 2/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 300/400 with KL 0.06 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.14345264434814453 and nll_test -9.367725372314453
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.48
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.16 and nll loss -9.36
# Epoch: 2/19, i/N: 320/400 with KL 0.20 and nll loss -9.32
# Epoch: 2/19, i/N: 330/400 with KL 0.01 and nll loss -9.50
# Epoch: 2/19, i/N: 340/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 350/400 with KL 0.09 and nll loss -9.42
# Epoch: 2/19, i/N: 360/400 with KL 0.17 and nll loss -9.34
# Epoch: 2/19, i/N: 370/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 380/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 390/400 with KL 0.19 and nll loss -9.32
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.1406269073486328 and nll_test -9.370551109313965
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.47
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 20/400 with KL 0.18 and nll loss -9.33
# Epoch: 3/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 40/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 50/400 with KL 0.13 and nll loss -9.38
# Epoch: 3/19, i/N: 60/400 with KL 0.14 and nll loss -9.38
# Epoch: 3/19, i/N: 70/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 80/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 90/400 with KL 0.03 and nll loss -9.48
# Epoch: 3/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.136444091796875 and nll_test -9.374733924865723
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 0.99
# Epoch: 3/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 120/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 130/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 140/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 150/400 with KL 0.11 and nll loss -9.40
# Epoch: 3/19, i/N: 160/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 170/400 with KL 0.13 and nll loss -9.38
# Epoch: 3/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 190/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 200/400 with KL 0.24 and nll loss -9.27
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.13676834106445312 and nll_test -9.374409675598145
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.48
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.08 and nll loss -9.44
# Epoch: 3/19, i/N: 220/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 230/400 with KL 0.03 and nll loss -9.48
# Epoch: 3/19, i/N: 240/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 250/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 260/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 270/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 280/400 with KL 0.05 and nll loss -9.46
# Epoch: 3/19, i/N: 290/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 300/400 with KL 0.05 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.13282299041748047 and nll_test -9.378355026245117
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.51
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.01 and nll loss -9.50
# Epoch: 3/19, i/N: 320/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 330/400 with KL 0.18 and nll loss -9.33
# Epoch: 3/19, i/N: 340/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 350/400 with KL 0.03 and nll loss -9.48
# Epoch: 3/19, i/N: 360/400 with KL 0.11 and nll loss -9.41
# Epoch: 3/19, i/N: 370/400 with KL 0.22 and nll loss -9.29
# Epoch: 3/19, i/N: 380/400 with KL 0.13 and nll loss -9.39
# Epoch: 3/19, i/N: 390/400 with KL 0.08 and nll loss -9.43
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.13012027740478516 and nll_test -9.381057739257812
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL -0.00 and nll loss -9.51
# Epoch: 4/19, i/N: 20/400 with KL 0.17 and nll loss -9.35
# Epoch: 4/19, i/N: 30/400 with KL 0.21 and nll loss -9.30
# Epoch: 4/19, i/N: 40/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 50/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 60/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 70/400 with KL 0.24 and nll loss -9.27
# Epoch: 4/19, i/N: 80/400 with KL 0.09 and nll loss -9.42
# nan in sum squares
# Epoch: 4/19, i/N: 90/400 with KL 0.12 and nll loss -9.40
# Epoch: 4/19, i/N: 100/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.12510395050048828 and nll_test -9.38607406616211
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 120/400 with KL 0.07 and nll loss -9.44
# Epoch: 4/19, i/N: 130/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 140/400 with KL 0.15 and nll loss -9.36
# Epoch: 4/19, i/N: 150/400 with KL 0.19 and nll loss -9.33
# Epoch: 4/19, i/N: 160/400 with KL 0.07 and nll loss -9.44
# Epoch: 4/19, i/N: 170/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 180/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 190/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 200/400 with KL 0.22 and nll loss -9.29
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.12798786163330078 and nll_test -9.383190155029297
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.56
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 220/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 230/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 240/400 with KL 0.16 and nll loss -9.35
# Epoch: 4/19, i/N: 250/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 260/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 270/400 with KL 0.22 and nll loss -9.29
# Epoch: 4/19, i/N: 280/400 with KL -0.03 and nll loss -9.54
# Epoch: 4/19, i/N: 290/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 300/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.11823368072509766 and nll_test -9.3929443359375
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.50
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.06 and nll loss -9.46
# Epoch: 4/19, i/N: 320/400 with KL 0.12 and nll loss -9.40
# Epoch: 4/19, i/N: 330/400 with KL 0.18 and nll loss -9.34
# Epoch: 4/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 350/400 with KL 0.00 and nll loss -9.51
# Epoch: 4/19, i/N: 360/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 370/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 380/400 with KL 0.04 and nll loss -9.47
# Epoch: 4/19, i/N: 390/400 with KL 0.12 and nll loss -9.39
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.12199211120605469 and nll_test -9.389185905456543
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 20/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 40/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 50/400 with KL 0.12 and nll loss -9.39
# Epoch: 5/19, i/N: 60/400 with KL 0.13 and nll loss -9.39
# Epoch: 5/19, i/N: 70/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 80/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 90/400 with KL 0.09 and nll loss -9.42
# Epoch: 5/19, i/N: 100/400 with KL 0.03 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.1099395751953125 and nll_test -9.401238441467285
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.52
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.24 and nll loss -9.27
# Epoch: 5/19, i/N: 120/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 130/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 140/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 150/400 with KL 0.09 and nll loss -9.42
# Epoch: 5/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 170/400 with KL 0.18 and nll loss -9.33
# Epoch: 5/19, i/N: 180/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 190/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.11168098449707031 and nll_test -9.399497032165527
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.53
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.04 and nll loss -9.47
# Epoch: 5/19, i/N: 220/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 230/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 240/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 250/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 260/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 270/400 with KL 0.06 and nll loss -9.46
# Epoch: 5/19, i/N: 280/400 with KL 0.07 and nll loss -9.44
# Epoch: 5/19, i/N: 290/400 with KL 0.12 and nll loss -9.39
# Epoch: 5/19, i/N: 300/400 with KL -0.03 and nll loss -9.54
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.10461997985839844 and nll_test -9.4065580368042
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.55
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL -0.01 and nll loss -9.52
# Epoch: 5/19, i/N: 320/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 330/400 with KL 0.06 and nll loss -9.45
# Epoch: 5/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 350/400 with KL 0.06 and nll loss -9.45
# Epoch: 5/19, i/N: 360/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 370/400 with KL 0.25 and nll loss -9.26
# Epoch: 5/19, i/N: 380/400 with KL 0.05 and nll loss -9.46
# Epoch: 5/19, i/N: 390/400 with KL 0.15 and nll loss -9.37
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.1074666976928711 and nll_test -9.403711318969727
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 20/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 30/400 with KL 0.11 and nll loss -9.40
# Epoch: 6/19, i/N: 40/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 50/400 with KL 0.07 and nll loss -9.45
# Epoch: 6/19, i/N: 60/400 with KL 0.04 and nll loss -9.47
# Epoch: 6/19, i/N: 70/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 80/400 with KL 0.11 and nll loss -9.40
# Epoch: 6/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.10544872283935547 and nll_test -9.405729293823242
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 0.99
# Epoch: 6/19, i/N: 100/400 avg ldj -0.52
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 120/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 130/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 140/400 with KL 0.01 and nll loss -9.50
# Epoch: 6/19, i/N: 150/400 with KL 0.11 and nll loss -9.41
# Epoch: 6/19, i/N: 160/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 170/400 with KL 0.07 and nll loss -9.44
# Epoch: 6/19, i/N: 180/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 190/400 with KL 0.18 and nll loss -9.34
# Epoch: 6/19, i/N: 200/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.1133584976196289 and nll_test -9.397819519042969
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.56
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.11 and nll loss -9.40
# Epoch: 6/19, i/N: 220/400 with KL 0.19 and nll loss -9.32
# Epoch: 6/19, i/N: 230/400 with KL 0.05 and nll loss -9.46
# Epoch: 6/19, i/N: 240/400 with KL 0.04 and nll loss -9.47
# Epoch: 6/19, i/N: 250/400 with KL 0.11 and nll loss -9.40
# Epoch: 6/19, i/N: 260/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 270/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 280/400 with KL -0.04 and nll loss -9.55
# Epoch: 6/19, i/N: 290/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 300/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.10331344604492188 and nll_test -9.407864570617676
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.53
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.15 and nll loss -9.37
# Epoch: 6/19, i/N: 320/400 with KL 0.06 and nll loss -9.45
# Epoch: 6/19, i/N: 330/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 340/400 with KL 0.17 and nll loss -9.34
# Epoch: 6/19, i/N: 350/400 with KL 0.15 and nll loss -9.36
# Epoch: 6/19, i/N: 360/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 370/400 with KL 0.04 and nll loss -9.47
# Epoch: 6/19, i/N: 380/400 with KL 0.16 and nll loss -9.35
# Epoch: 6/19, i/N: 390/400 with KL 0.12 and nll loss -9.40
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.09603500366210938 and nll_test -9.415143013000488
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.49
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.07 and nll loss -9.44
# Epoch: 7/19, i/N: 20/400 with KL 0.18 and nll loss -9.33
# Epoch: 7/19, i/N: 30/400 with KL 0.01 and nll loss -9.51
# Epoch: 7/19, i/N: 40/400 with KL 0.09 and nll loss -9.42
# Epoch: 7/19, i/N: 50/400 with KL 0.03 and nll loss -9.48
# Epoch: 7/19, i/N: 60/400 with KL 0.02 and nll loss -9.49
# Epoch: 7/19, i/N: 70/400 with KL 0.08 and nll loss -9.43
# Epoch: 7/19, i/N: 80/400 with KL 0.07 and nll loss -9.44
# Epoch: 7/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 100/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.10386943817138672 and nll_test -9.407308578491211
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.57
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 120/400 with KL 0.05 and nll loss -9.46
# Epoch: 7/19, i/N: 130/400 with KL -0.01 and nll loss -9.52
# Epoch: 7/19, i/N: 140/400 with KL 0.03 and nll loss -9.48
# Epoch: 7/19, i/N: 150/400 with KL 0.07 and nll loss -9.44
# Epoch: 7/19, i/N: 160/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 170/400 with KL 0.07 and nll loss -9.44
# Epoch: 7/19, i/N: 180/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 190/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 200/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.09950447082519531 and nll_test -9.411673545837402
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.50
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.01 and nll loss -9.50
# Epoch: 7/19, i/N: 220/400 with KL 0.05 and nll loss -9.46
# Epoch: 7/19, i/N: 230/400 with KL 0.04 and nll loss -9.47
# Epoch: 7/19, i/N: 240/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 250/400 with KL -0.00 and nll loss -9.52
# Epoch: 7/19, i/N: 260/400 with KL 0.15 and nll loss -9.36
# Epoch: 7/19, i/N: 270/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 280/400 with KL 0.25 and nll loss -9.26
# Epoch: 7/19, i/N: 290/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.09343147277832031 and nll_test -9.417746543884277
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.56
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.11 and nll loss -9.41
# Epoch: 7/19, i/N: 320/400 with KL 0.09 and nll loss -9.42
# Epoch: 7/19, i/N: 330/400 with KL 0.09 and nll loss -9.42
# Epoch: 7/19, i/N: 340/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 350/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 360/400 with KL 0.13 and nll loss -9.38
# Epoch: 7/19, i/N: 370/400 with KL 0.08 and nll loss -9.43
# Epoch: 7/19, i/N: 380/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 390/400 with KL 0.05 and nll loss -9.46
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.09847164154052734 and nll_test -9.41270637512207
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.01
# Epoch: 8/19, i/N: 0/400 avg ldj -0.58
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.09 and nll loss -9.43
# Epoch: 8/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 30/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 40/400 with KL 0.16 and nll loss -9.36
# Epoch: 8/19, i/N: 50/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 60/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 70/400 with KL 0.02 and nll loss -9.49
# Epoch: 8/19, i/N: 80/400 with KL 0.05 and nll loss -9.46
# Epoch: 8/19, i/N: 90/400 with KL -0.00 and nll loss -9.51
# Epoch: 8/19, i/N: 100/400 with KL 0.06 and nll loss -9.45
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.09299468994140625 and nll_test -9.418183326721191
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.01
# Epoch: 8/19, i/N: 100/400 avg ldj -0.53
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL -0.02 and nll loss -9.53
# Epoch: 8/19, i/N: 120/400 with KL 0.02 and nll loss -9.49
# Epoch: 8/19, i/N: 130/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 140/400 with KL 0.20 and nll loss -9.32
# Epoch: 8/19, i/N: 150/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 160/400 with KL 0.13 and nll loss -9.39
# Epoch: 8/19, i/N: 170/400 with KL 0.06 and nll loss -9.46
# Epoch: 8/19, i/N: 180/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 190/400 with KL 0.27 and nll loss -9.24
# Epoch: 8/19, i/N: 200/400 with KL 0.05 and nll loss -9.47
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.09567642211914062 and nll_test -9.415501594543457
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.52
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 220/400 with KL 0.08 and nll loss -9.44
# Epoch: 8/19, i/N: 230/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 240/400 with KL 0.12 and nll loss -9.40
# Epoch: 8/19, i/N: 250/400 with KL 0.18 and nll loss -9.33
# Epoch: 8/19, i/N: 260/400 with KL 0.02 and nll loss -9.50
# Epoch: 8/19, i/N: 270/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 280/400 with KL 0.03 and nll loss -9.48
# Epoch: 8/19, i/N: 290/400 with KL 0.14 and nll loss -9.37
# Epoch: 8/19, i/N: 300/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.09649276733398438 and nll_test -9.414685249328613
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.55
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 320/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 330/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 340/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 350/400 with KL 0.21 and nll loss -9.30
# Epoch: 8/19, i/N: 360/400 with KL 0.05 and nll loss -9.47
# Epoch: 8/19, i/N: 370/400 with KL 0.15 and nll loss -9.36
# Epoch: 8/19, i/N: 380/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.09561634063720703 and nll_test -9.41556167602539
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.01
# Epoch: 9/19, i/N: 0/400 avg ldj -0.56
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 20/400 with KL 0.20 and nll loss -9.31
# Epoch: 9/19, i/N: 30/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 40/400 with KL 0.09 and nll loss -9.43
# Epoch: 9/19, i/N: 50/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 60/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 70/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 80/400 with KL 0.05 and nll loss -9.46
# Epoch: 9/19, i/N: 90/400 with KL 0.09 and nll loss -9.43
# Epoch: 9/19, i/N: 100/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.08996868133544922 and nll_test -9.421209335327148
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.01
# Epoch: 9/19, i/N: 100/400 avg ldj -0.53
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 120/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 130/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 140/400 with KL 0.08 and nll loss -9.43
# Epoch: 9/19, i/N: 150/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 160/400 with KL -0.04 and nll loss -9.55
# Epoch: 9/19, i/N: 170/400 with KL -0.02 and nll loss -9.53
# Epoch: 9/19, i/N: 180/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 190/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 200/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.08981132507324219 and nll_test -9.421366691589355
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 1.00
# Epoch: 9/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL -0.02 and nll loss -9.53
# Epoch: 9/19, i/N: 220/400 with KL 0.12 and nll loss -9.39
# Epoch: 9/19, i/N: 230/400 with KL 0.18 and nll loss -9.33
# Epoch: 9/19, i/N: 240/400 with KL -0.01 and nll loss -9.52
# Epoch: 9/19, i/N: 250/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 260/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 270/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 280/400 with KL 0.01 and nll loss -9.50
# Epoch: 9/19, i/N: 290/400 with KL 0.13 and nll loss -9.38
# Epoch: 9/19, i/N: 300/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.0894613265991211 and nll_test -9.421716690063477
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 1.00
# Epoch: 9/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.04 and nll loss -9.47
# Epoch: 9/19, i/N: 320/400 with KL 0.05 and nll loss -9.46
# Epoch: 9/19, i/N: 330/400 with KL 0.14 and nll loss -9.38
# Epoch: 9/19, i/N: 340/400 with KL 0.04 and nll loss -9.47
# Epoch: 9/19, i/N: 350/400 with KL 0.26 and nll loss -9.26
# Epoch: 9/19, i/N: 360/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 370/400 with KL 0.22 and nll loss -9.30
# Epoch: 9/19, i/N: 380/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 390/400 with KL 0.27 and nll loss -9.24
# Epoch: 10 / 19
# Epoch: 10/19, i/N: 0/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 0/400 KL_test 0.08498859405517578 and nll_test -9.426189422607422
#
# From current batch
# Epoch: 10, i/N: 0/400 avg ldj from current batch 0.54
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 0/400 MC density sum 1.00
# Epoch: 10/19, i/N: 0/400 avg ldj -0.53
# #####################
#
# Epoch: 10/19, i/N: 10/400 with KL 0.07 and nll loss -9.44
# Epoch: 10/19, i/N: 20/400 with KL 0.01 and nll loss -9.50
# Epoch: 10/19, i/N: 30/400 with KL 0.11 and nll loss -9.40
# Epoch: 10/19, i/N: 40/400 with KL 0.07 and nll loss -9.44
# Epoch: 10/19, i/N: 50/400 with KL 0.10 and nll loss -9.42
# Epoch: 10/19, i/N: 60/400 with KL 0.13 and nll loss -9.38
# Epoch: 10/19, i/N: 70/400 with KL 0.15 and nll loss -9.36
# Epoch: 10/19, i/N: 80/400 with KL 0.05 and nll loss -9.46
# Epoch: 10/19, i/N: 90/400 with KL 0.01 and nll loss -9.51
# Epoch: 10/19, i/N: 100/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 100/400 KL_test 0.0892934799194336 and nll_test -9.421884536743164
#
# From current batch
# Epoch: 10, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 100/400 MC density sum 1.00
# Epoch: 10/19, i/N: 100/400 avg ldj -0.58
# #####################
#
# ...
#
# From current batch
# Epoch: 16, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.58
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 20/400 with KL -0.02 and nll loss -9.53
# Epoch: 16/19, i/N: 30/400 with KL 0.12 and nll loss -9.39
# Epoch: 16/19, i/N: 40/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 50/400 with KL 0.01 and nll loss -9.50
# Epoch: 16/19, i/N: 60/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 70/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 80/400 with KL 0.17 and nll loss -9.34
# Epoch: 16/19, i/N: 90/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 100/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.05883026123046875 and nll_test -9.452347755432129
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.61
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 120/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 130/400 with KL 0.01 and nll loss -9.50
# Epoch: 16/19, i/N: 140/400 with KL 0.19 and nll loss -9.32
# Epoch: 16/19, i/N: 150/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 160/400 with KL 0.11 and nll loss -9.41
# Epoch: 16/19, i/N: 170/400 with KL 0.18 and nll loss -9.33
# Epoch: 16/19, i/N: 180/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 190/400 with KL -0.05 and nll loss -9.56
# Epoch: 16/19, i/N: 200/400 with KL -0.05 and nll loss -9.56
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.06116962432861328 and nll_test -9.450008392333984
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.66
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.03 and nll loss -9.49
# Epoch: 16/19, i/N: 220/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 230/400 with KL 0.01 and nll loss -9.50
# Epoch: 16/19, i/N: 240/400 with KL 0.03 and nll loss -9.48
# Epoch: 16/19, i/N: 250/400 with KL 0.10 and nll loss -9.41
# Epoch: 16/19, i/N: 260/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 270/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 280/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 290/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 300/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.06372833251953125 and nll_test -9.447449684143066
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 0.99
# Epoch: 16/19, i/N: 300/400 avg ldj -0.65
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 330/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 340/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 350/400 with KL 0.03 and nll loss -9.48
# Epoch: 16/19, i/N: 360/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 370/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 380/400 with KL 0.12 and nll loss -9.39
# Epoch: 16/19, i/N: 390/400 with KL -0.02 and nll loss -9.53
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.058162689208984375 and nll_test -9.453015327453613
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.57
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 20/400 with KL -0.02 and nll loss -9.53
# Epoch: 17/19, i/N: 30/400 with KL -0.02 and nll loss -9.53
# Epoch: 17/19, i/N: 40/400 with KL -0.01 and nll loss -9.52
# Epoch: 17/19, i/N: 50/400 with KL -0.03 and nll loss -9.54
# Epoch: 17/19, i/N: 60/400 with KL 0.12 and nll loss -9.39
# Epoch: 17/19, i/N: 70/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 80/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 90/400 with KL 0.15 and nll loss -9.36
# Epoch: 17/19, i/N: 100/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.0578155517578125 and nll_test -9.453362464904785
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 0.99
# Epoch: 17/19, i/N: 100/400 avg ldj -0.58
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.01 and nll loss -9.50
# Epoch: 17/19, i/N: 120/400 with KL -0.03 and nll loss -9.54
# Epoch: 17/19, i/N: 130/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 140/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 150/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 160/400 with KL -0.06 and nll loss -9.57
# Epoch: 17/19, i/N: 170/400 with KL -0.03 and nll loss -9.55
# Epoch: 17/19, i/N: 180/400 with KL 0.14 and nll loss -9.38
# Epoch: 17/19, i/N: 190/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 200/400 with KL 0.17 and nll loss -9.34
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.05372428894042969 and nll_test -9.457453727722168
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.59
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 220/400 with KL -0.05 and nll loss -9.57
# Epoch: 17/19, i/N: 230/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 240/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 250/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 260/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 270/400 with KL 0.14 and nll loss -9.37
# Epoch: 17/19, i/N: 280/400 with KL 0.14 and nll loss -9.37
# Epoch: 17/19, i/N: 290/400 with KL 0.10 and nll loss -9.41
# Epoch: 17/19, i/N: 300/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.052825927734375 and nll_test -9.458352088928223
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.57
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.08 and nll loss -9.43
# Epoch: 17/19, i/N: 320/400 with KL -0.07 and nll loss -9.59
# Epoch: 17/19, i/N: 330/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 340/400 with KL 0.12 and nll loss -9.39
# Epoch: 17/19, i/N: 350/400 with KL 0.05 and nll loss -9.46
# Epoch: 17/19, i/N: 360/400 with KL -0.00 and nll loss -9.51
# Epoch: 17/19, i/N: 370/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 380/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 390/400 with KL -0.00 and nll loss -9.51
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL -0.02 and nll loss -9.53
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.057521820068359375 and nll_test -9.453656196594238
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.63
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 18/19, i/N: 20/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 40/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 50/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 60/400 with KL -0.02 and nll loss -9.53
# Epoch: 18/19, i/N: 70/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 18/19, i/N: 90/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 100/400 with KL 0.01 and nll loss -9.50
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.054274559020996094 and nll_test -9.456903457641602
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.58
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 120/400 with KL -0.04 and nll loss -9.55
# Epoch: 18/19, i/N: 130/400 with KL 0.15 and nll loss -9.36
# Epoch: 18/19, i/N: 140/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 150/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 160/400 with KL 0.00 and nll loss -9.51
# Epoch: 18/19, i/N: 170/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 18/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 200/400 with KL 0.04 and nll loss -9.47
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.057648658752441406 and nll_test -9.453529357910156
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 0.99
# Epoch: 18/19, i/N: 200/400 avg ldj -0.62
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.13 and nll loss -9.39
# Epoch: 18/19, i/N: 220/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 230/400 with KL -0.03 and nll loss -9.54
# Epoch: 18/19, i/N: 240/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 250/400 with KL -0.06 and nll loss -9.57
# Epoch: 18/19, i/N: 260/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 270/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 280/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 18/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.0580902099609375 and nll_test -9.45308780670166
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.61
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 320/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 330/400 with KL 0.09 and nll loss -9.42
# Epoch: 18/19, i/N: 340/400 with KL -0.00 and nll loss -9.52
# Epoch: 18/19, i/N: 350/400 with KL 0.21 and nll loss -9.30
# Epoch: 18/19, i/N: 360/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 370/400 with KL 0.05 and nll loss -9.47
# Epoch: 18/19, i/N: 380/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 390/400 with KL 0.02 and nll loss -9.49
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.058933258056640625 and nll_test -9.452244758605957
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.01
# Epoch: 19/19, i/N: 0/400 avg ldj -0.60
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 20/400 with KL 0.03 and nll loss -9.48
# Epoch: 19/19, i/N: 30/400 with KL 0.22 and nll loss -9.29
# Epoch: 19/19, i/N: 40/400 with KL 0.15 and nll loss -9.37
# Epoch: 19/19, i/N: 50/400 with KL -0.03 and nll loss -9.54
# Epoch: 19/19, i/N: 60/400 with KL 0.11 and nll loss -9.40
# Epoch: 19/19, i/N: 70/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 80/400 with KL 0.03 and nll loss -9.48
# Epoch: 19/19, i/N: 90/400 with KL 0.18 and nll loss -9.33
# Epoch: 19/19, i/N: 100/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.047786712646484375 and nll_test -9.463391304016113
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.62
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL -0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 120/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 130/400 with KL 0.08 and nll loss -9.43
# Epoch: 19/19, i/N: 140/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 150/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 160/400 with KL -0.07 and nll loss -9.58
# Epoch: 19/19, i/N: 170/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 180/400 with KL 0.10 and nll loss -9.41
# Epoch: 19/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 200/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.05901527404785156 and nll_test -9.452162742614746
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 0.99
# Epoch: 19/19, i/N: 200/400 avg ldj -0.63
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.03 and nll loss -9.49
# Epoch: 19/19, i/N: 220/400 with KL -0.02 and nll loss -9.53
# Epoch: 19/19, i/N: 230/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 240/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 250/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 260/400 with KL 0.08 and nll loss -9.44
# Epoch: 19/19, i/N: 270/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 280/400 with KL 0.03 and nll loss -9.49
# Epoch: 19/19, i/N: 290/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 300/400 with KL 0.08 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.055606842041015625 and nll_test -9.455571174621582
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.57
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.11 and nll loss -9.40
# Epoch: 19/19, i/N: 320/400 with KL 0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 330/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 19/19, i/N: 350/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 360/400 with KL 0.02 and nll loss -9.49
# Epoch: 19/19, i/N: 370/400 with KL 0.03 and nll loss -9.49
# Epoch: 19/19, i/N: 380/400 with KL 0.03 and nll loss -9.48
# Epoch: 19/19, i/N: 390/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.056255340576171875 and nll_test -9.454922676086426
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.01
# Epoch: 19/19, i/N: 399/400 avg ldj -0.63
# #####################

# %% [markdown]
# ### Coupling Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='spline',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 num_centers=NUM_CENTERS)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_s')
# Out:
# ##### Coupling Cylindrical Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_234401" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_32/runs/1224_234401</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=30, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=360, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=390, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=30, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 480768,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.47655576e-01,  7.12287351e-02,  1.61837906e-01,
#         -2.49965787e-01, -3.00656687e-02,  5.13378978e-02,
#         -1.15420990e-01, -1.60892144e-01,  1.66813165e-01,
#         -9.64126736e-02, -2.08793998e-01, -8.28458816e-02,
#          1.27564132e-01,  1.82334691e-01,  4.14802469e-02,
#          1.96271405e-01, -2.84940153e-01, -5.84344044e-02,
#          3.46819907e-01, -5.94147295e-02,  3.57276984e-02,
#          1.40802979e-01,  1.87079117e-01, -1.30439639e-01,
#         -3.76892798e-02, -3.87697071e-02, -3.26900601e-01,
#         -6.21567555e-02, -3.71144861e-01,  1.21363901e-01,
#         -2.38252848e-01, -2.44810417e-01],
#        [-1.38830440e-02, -3.90221574e-03,  2.89825462e-02,
#          3.82002503e-01,  1.59077853e-01, -1.10007562e-01,
#         -1.37695208e-01, -1.00668795e-01, -2.32898831e-01,
#          2.15627357e-01,  2.72735924e-01, -1.75629154e-01,
#         -4.34777588e-02, -4.15739939e-02,  8.32903013e-02,
#          4.32200469e-02, -2.96170041e-02, -4.31307368e-02,
#         -2.40800902e-03, -6.38056844e-02, -4.93000597e-01,
#         -1.76272526e-01, -5.13575971e-02,  1.55285999e-01,
#          2.69974083e-01,  2.60492641e-04, -7.27226809e-02,
#         -3.50454718e-01,  1.90309197e-01, -6.35220185e-02,
#         -5.90479895e-02,  1.25352696e-01],
#        [ 2.60214563e-02,  3.56507376e-02, -1.00506626e-01,
#          1.56339660e-01, -2.42792353e-01, -3.35473359e-01,
#         -1.13739289e-01, -1.20175540e-01, -1.72994345e-01,
#          2.33775198e-01,  9.12943706e-02, -2.81111747e-02,
#         -1.58582807e-01, -7.54978359e-02, -2.02521160e-01,
#          1.15622178e-01, -4.40940171e-01,  7.89586380e-02,
#          1.11749269e-01,  6.01152927e-02, -2.45873649e-02,
#         -1.87052876e-01,  3.42127830e-01,  1.91307142e-01,
#         -7.78181776e-02, -3.38192731e-02,  1.47817269e-01,
#          1.92607939e-01, -1.61186084e-01,  3.18894871e-02,
#          9.78971273e-02,  2.77430654e-01],
#        [-1.12130381e-01,  1.73135325e-01,  2.20798597e-01,
#         -2.30746195e-01,  2.66201477e-02, -3.95676401e-03,
#         -8.50699022e-02,  1.11059688e-01,  8.01334158e-02,
#          3.99493515e-01, -2.53683060e-01,  3.69951695e-01,
#          1.05917104e-01, -3.29163261e-02,  9.61499959e-02,
#         -2.40879774e-01, -2.34925091e-01, -6.56795427e-02,
#          1.30749673e-01,  1.89674515e-02, -1.22393437e-01,
#         -1.02263898e-01,  1.33639634e-01,  1.27292857e-01,
#         -1.70438379e-01,  2.41557494e-01, -2.52882808e-01,
#          1.05931632e-01, -9.00397003e-02,  1.28095791e-01,
#          5.91178760e-02,  2.47614831e-01]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -9.511178016662598
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.62 and nll loss -8.89
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.6207408905029297 and nll_test -8.890437126159668
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.61 and nll loss -8.90
# Epoch: 0/19, i/N: 20/400 with KL 0.54 and nll loss -8.97
# Epoch: 0/19, i/N: 30/400 with KL 0.41 and nll loss -9.10
# Epoch: 0/19, i/N: 40/400 with KL 0.39 and nll loss -9.12
# Epoch: 0/19, i/N: 50/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 60/400 with KL 0.27 and nll loss -9.24
# Epoch: 0/19, i/N: 70/400 with KL 0.18 and nll loss -9.33
# Epoch: 0/19, i/N: 80/400 with KL 0.16 and nll loss -9.35
# Epoch: 0/19, i/N: 90/400 with KL 0.18 and nll loss -9.34
# Epoch: 0/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.18831348419189453 and nll_test -9.322864532470703
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.43
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.43
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.16 and nll loss -9.36
# Epoch: 0/19, i/N: 120/400 with KL 0.22 and nll loss -9.30
# Epoch: 0/19, i/N: 130/400 with KL 0.25 and nll loss -9.26
# Epoch: 0/19, i/N: 140/400 with KL 0.15 and nll loss -9.36
# Epoch: 0/19, i/N: 150/400 with KL 0.11 and nll loss -9.40
# Epoch: 0/19, i/N: 160/400 with KL 0.13 and nll loss -9.38
# Epoch: 0/19, i/N: 170/400 with KL 0.24 and nll loss -9.28
# Epoch: 0/19, i/N: 180/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 190/400 with KL 0.20 and nll loss -9.31
# Epoch: 0/19, i/N: 200/400 with KL 0.31 and nll loss -9.20
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.17065715789794922 and nll_test -9.340520858764648
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 0.99
# Epoch: 0/19, i/N: 200/400 avg ldj -0.44
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 220/400 with KL 0.17 and nll loss -9.35
# Epoch: 0/19, i/N: 230/400 with KL 0.15 and nll loss -9.36
# Epoch: 0/19, i/N: 240/400 with KL 0.11 and nll loss -9.40
# Epoch: 0/19, i/N: 250/400 with KL 0.18 and nll loss -9.34
# Epoch: 0/19, i/N: 260/400 with KL 0.27 and nll loss -9.24
# Epoch: 0/19, i/N: 270/400 with KL 0.14 and nll loss -9.37
# Epoch: 0/19, i/N: 280/400 with KL 0.22 and nll loss -9.29
# Epoch: 0/19, i/N: 290/400 with KL 0.18 and nll loss -9.33
# Epoch: 0/19, i/N: 300/400 with KL 0.19 and nll loss -9.32
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.1687908172607422 and nll_test -9.342387199401855
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.48
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 320/400 with KL 0.17 and nll loss -9.34
# Epoch: 0/19, i/N: 330/400 with KL 0.18 and nll loss -9.33
# Epoch: 0/19, i/N: 340/400 with KL 0.34 and nll loss -9.17
# Epoch: 0/19, i/N: 350/400 with KL 0.21 and nll loss -9.30
# Epoch: 0/19, i/N: 360/400 with KL 0.14 and nll loss -9.37
# Epoch: 0/19, i/N: 370/400 with KL 0.24 and nll loss -9.28
# Epoch: 0/19, i/N: 380/400 with KL 0.24 and nll loss -9.27
# Epoch: 0/19, i/N: 390/400 with KL 0.13 and nll loss -9.38
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.16640853881835938 and nll_test -9.344769477844238
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.45
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.45
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 20/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 30/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 40/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 50/400 with KL 0.04 and nll loss -9.47
# Epoch: 1/19, i/N: 60/400 with KL 0.27 and nll loss -9.24
# Epoch: 1/19, i/N: 70/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 80/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 90/400 with KL 0.21 and nll loss -9.31
# Epoch: 1/19, i/N: 100/400 with KL 0.21 and nll loss -9.30
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.15921592712402344 and nll_test -9.351962089538574
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.44
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.06 and nll loss -9.45
# Epoch: 1/19, i/N: 120/400 with KL 0.04 and nll loss -9.47
# Epoch: 1/19, i/N: 130/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 140/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 150/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 160/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 170/400 with KL 0.19 and nll loss -9.32
# Epoch: 1/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 190/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 200/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.15378665924072266 and nll_test -9.357391357421875
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 0.99
# Epoch: 1/19, i/N: 200/400 avg ldj -0.45
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 220/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 230/400 with KL 0.13 and nll loss -9.38
# Epoch: 1/19, i/N: 240/400 with KL 0.14 and nll loss -9.37
# Epoch: 1/19, i/N: 250/400 with KL 0.08 and nll loss -9.43
# Epoch: 1/19, i/N: 260/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 270/400 with KL 0.17 and nll loss -9.34
# Epoch: 1/19, i/N: 280/400 with KL 0.21 and nll loss -9.30
# Epoch: 1/19, i/N: 290/400 with KL 0.15 and nll loss -9.36
# Epoch: 1/19, i/N: 300/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.1523752212524414 and nll_test -9.358802795410156
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.49
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.28 and nll loss -9.23
# Epoch: 1/19, i/N: 320/400 with KL 0.16 and nll loss -9.36
# Epoch: 1/19, i/N: 330/400 with KL 0.24 and nll loss -9.27
# Epoch: 1/19, i/N: 340/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 350/400 with KL 0.16 and nll loss -9.35
# Epoch: 1/19, i/N: 360/400 with KL 0.09 and nll loss -9.42
# Epoch: 1/19, i/N: 370/400 with KL 0.18 and nll loss -9.33
# Epoch: 1/19, i/N: 380/400 with KL 0.28 and nll loss -9.23
# Epoch: 1/19, i/N: 390/400 with KL 0.08 and nll loss -9.43
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.1565256118774414 and nll_test -9.354652404785156
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.46
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.48
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.26 and nll loss -9.25
# Epoch: 2/19, i/N: 20/400 with KL 0.12 and nll loss -9.39
# Epoch: 2/19, i/N: 30/400 with KL 0.20 and nll loss -9.31
# Epoch: 2/19, i/N: 40/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 50/400 with KL 0.16 and nll loss -9.36
# Epoch: 2/19, i/N: 60/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 70/400 with KL 0.09 and nll loss -9.43
# Epoch: 2/19, i/N: 80/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 90/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.14793109893798828 and nll_test -9.36324691772461
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.49
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 120/400 with KL 0.26 and nll loss -9.25
# Epoch: 2/19, i/N: 130/400 with KL 0.21 and nll loss -9.30
# Epoch: 2/19, i/N: 140/400 with KL 0.18 and nll loss -9.34
# Epoch: 2/19, i/N: 150/400 with KL 0.07 and nll loss -9.44
# Epoch: 2/19, i/N: 160/400 with KL 0.22 and nll loss -9.29
# Epoch: 2/19, i/N: 170/400 with KL 0.11 and nll loss -9.40
# Epoch: 2/19, i/N: 180/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 190/400 with KL 0.12 and nll loss -9.39
# Epoch: 2/19, i/N: 200/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.15164947509765625 and nll_test -9.359528541564941
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.47
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.47
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 220/400 with KL 0.05 and nll loss -9.46
# Epoch: 2/19, i/N: 230/400 with KL 0.13 and nll loss -9.38
# Epoch: 2/19, i/N: 240/400 with KL 0.19 and nll loss -9.32
# Epoch: 2/19, i/N: 250/400 with KL 0.04 and nll loss -9.47
# Epoch: 2/19, i/N: 260/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 270/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 290/400 with KL 0.16 and nll loss -9.35
# Epoch: 2/19, i/N: 300/400 with KL 0.21 and nll loss -9.30
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.14455604553222656 and nll_test -9.366621971130371
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.48
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.10 and nll loss -9.41
# Epoch: 2/19, i/N: 320/400 with KL 0.23 and nll loss -9.29
# Epoch: 2/19, i/N: 330/400 with KL 0.20 and nll loss -9.32
# Epoch: 2/19, i/N: 340/400 with KL 0.23 and nll loss -9.28
# Epoch: 2/19, i/N: 350/400 with KL 0.18 and nll loss -9.33
# Epoch: 2/19, i/N: 360/400 with KL 0.13 and nll loss -9.38
# Epoch: 2/19, i/N: 370/400 with KL 0.15 and nll loss -9.36
# Epoch: 2/19, i/N: 380/400 with KL 0.14 and nll loss -9.37
# Epoch: 2/19, i/N: 390/400 with KL 0.24 and nll loss -9.27
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.13724136352539062 and nll_test -9.373936653137207
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.47
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 20/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 30/400 with KL 0.20 and nll loss -9.31
# Epoch: 3/19, i/N: 40/400 with KL 0.03 and nll loss -9.48
# Epoch: 3/19, i/N: 50/400 with KL 0.23 and nll loss -9.28
# Epoch: 3/19, i/N: 60/400 with KL 0.12 and nll loss -9.40
# Epoch: 3/19, i/N: 70/400 with KL 0.07 and nll loss -9.44
# Epoch: 3/19, i/N: 80/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 90/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 100/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.14463329315185547 and nll_test -9.366544723510742
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.48
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.53
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 120/400 with KL 0.15 and nll loss -9.37
# Epoch: 3/19, i/N: 130/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 140/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 150/400 with KL 0.24 and nll loss -9.27
# Epoch: 3/19, i/N: 160/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 170/400 with KL 0.15 and nll loss -9.36
# Epoch: 3/19, i/N: 180/400 with KL 0.02 and nll loss -9.49
# Epoch: 3/19, i/N: 190/400 with KL 0.20 and nll loss -9.32
# Epoch: 3/19, i/N: 200/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.13292694091796875 and nll_test -9.378251075744629
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.10 and nll loss -9.41
# Epoch: 3/19, i/N: 220/400 with KL 0.08 and nll loss -9.43
# Epoch: 3/19, i/N: 230/400 with KL 0.27 and nll loss -9.25
# Epoch: 3/19, i/N: 240/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 250/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 260/400 with KL 0.17 and nll loss -9.34
# Epoch: 3/19, i/N: 270/400 with KL 0.16 and nll loss -9.35
# Epoch: 3/19, i/N: 280/400 with KL 0.26 and nll loss -9.25
# Epoch: 3/19, i/N: 290/400 with KL -0.01 and nll loss -9.52
# Epoch: 3/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.13410186767578125 and nll_test -9.377076148986816
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.54
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.06 and nll loss -9.45
# Epoch: 3/19, i/N: 320/400 with KL 0.14 and nll loss -9.37
# Epoch: 3/19, i/N: 330/400 with KL 0.09 and nll loss -9.42
# Epoch: 3/19, i/N: 340/400 with KL 0.20 and nll loss -9.31
# Epoch: 3/19, i/N: 350/400 with KL 0.19 and nll loss -9.32
# Epoch: 3/19, i/N: 360/400 with KL 0.19 and nll loss -9.33
# Epoch: 3/19, i/N: 370/400 with KL 0.12 and nll loss -9.39
# Epoch: 3/19, i/N: 380/400 with KL 0.19 and nll loss -9.33
# Epoch: 3/19, i/N: 390/400 with KL 0.17 and nll loss -9.34
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.1301412582397461 and nll_test -9.381036758422852
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 0.99
# Epoch: 4/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.03 and nll loss -9.48
# Epoch: 4/19, i/N: 20/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 30/400 with KL 0.12 and nll loss -9.39
# Epoch: 4/19, i/N: 40/400 with KL 0.13 and nll loss -9.39
# Epoch: 4/19, i/N: 50/400 with KL 0.03 and nll loss -9.48
# Epoch: 4/19, i/N: 60/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 70/400 with KL 0.09 and nll loss -9.42
# Epoch: 4/19, i/N: 80/400 with KL 0.21 and nll loss -9.30
# Epoch: 4/19, i/N: 90/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 100/400 with KL 0.18 and nll loss -9.33
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.13435745239257812 and nll_test -9.37682056427002
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 120/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 130/400 with KL 0.00 and nll loss -9.51
# Epoch: 4/19, i/N: 140/400 with KL 0.17 and nll loss -9.34
# Epoch: 4/19, i/N: 150/400 with KL 0.08 and nll loss -9.44
# Epoch: 4/19, i/N: 160/400 with KL 0.15 and nll loss -9.36
# Epoch: 4/19, i/N: 170/400 with KL 0.04 and nll loss -9.47
# Epoch: 4/19, i/N: 180/400 with KL 0.18 and nll loss -9.33
# Epoch: 4/19, i/N: 190/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 200/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.13221263885498047 and nll_test -9.378965377807617
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.47
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 220/400 with KL 0.15 and nll loss -9.36
# Epoch: 4/19, i/N: 230/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 240/400 with KL 0.05 and nll loss -9.46
# Epoch: 4/19, i/N: 250/400 with KL 0.10 and nll loss -9.41
# Epoch: 4/19, i/N: 260/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 270/400 with KL 0.16 and nll loss -9.35
# Epoch: 4/19, i/N: 280/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 290/400 with KL 0.11 and nll loss -9.40
# Epoch: 4/19, i/N: 300/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.12723064422607422 and nll_test -9.383947372436523
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 320/400 with KL 0.08 and nll loss -9.43
# Epoch: 4/19, i/N: 330/400 with KL 0.19 and nll loss -9.32
# Epoch: 4/19, i/N: 340/400 with KL 0.06 and nll loss -9.45
# Epoch: 4/19, i/N: 350/400 with KL 0.14 and nll loss -9.37
# Epoch: 4/19, i/N: 360/400 with KL 0.16 and nll loss -9.36
# Epoch: 4/19, i/N: 370/400 with KL 0.02 and nll loss -9.49
# Epoch: 4/19, i/N: 380/400 with KL 0.16 and nll loss -9.35
# Epoch: 4/19, i/N: 390/400 with KL 0.08 and nll loss -9.44
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.12926769256591797 and nll_test -9.38191032409668
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.49
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.01
# Epoch: 5/19, i/N: 0/400 avg ldj -0.50
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 20/400 with KL 0.19 and nll loss -9.32
# Epoch: 5/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 40/400 with KL 0.20 and nll loss -9.31
# Epoch: 5/19, i/N: 50/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 60/400 with KL 0.16 and nll loss -9.35
# Epoch: 5/19, i/N: 70/400 with KL 0.07 and nll loss -9.44
# Epoch: 5/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 90/400 with KL 0.09 and nll loss -9.42
# Epoch: 5/19, i/N: 100/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.11767196655273438 and nll_test -9.393506050109863
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.51
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.26 and nll loss -9.25
# Epoch: 5/19, i/N: 120/400 with KL 0.10 and nll loss -9.41
# Epoch: 5/19, i/N: 130/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 140/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 150/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 160/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 170/400 with KL 0.12 and nll loss -9.39
# Epoch: 5/19, i/N: 180/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 190/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 200/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.1200408935546875 and nll_test -9.39113712310791
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.53
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 220/400 with KL 0.15 and nll loss -9.36
# Epoch: 5/19, i/N: 230/400 with KL 0.04 and nll loss -9.47
# Epoch: 5/19, i/N: 240/400 with KL 0.17 and nll loss -9.34
# Epoch: 5/19, i/N: 250/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 260/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 270/400 with KL 0.11 and nll loss -9.40
# Epoch: 5/19, i/N: 280/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 290/400 with KL 0.05 and nll loss -9.46
# Epoch: 5/19, i/N: 300/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.1201934814453125 and nll_test -9.390984535217285
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.48
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.13 and nll loss -9.38
# Epoch: 5/19, i/N: 320/400 with KL 0.20 and nll loss -9.31
# Epoch: 5/19, i/N: 330/400 with KL 0.07 and nll loss -9.44
# Epoch: 5/19, i/N: 340/400 with KL 0.16 and nll loss -9.35
# Epoch: 5/19, i/N: 350/400 with KL 0.05 and nll loss -9.46
# Epoch: 5/19, i/N: 360/400 with KL 0.08 and nll loss -9.43
# Epoch: 5/19, i/N: 370/400 with KL 0.22 and nll loss -9.29
# Epoch: 5/19, i/N: 380/400 with KL 0.14 and nll loss -9.37
# Epoch: 5/19, i/N: 390/400 with KL -0.03 and nll loss -9.54
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.20 and nll loss -9.31
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.11223411560058594 and nll_test -9.398943901062012
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.57
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 20/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 30/400 with KL 0.15 and nll loss -9.36
# Epoch: 6/19, i/N: 40/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 50/400 with KL 0.15 and nll loss -9.36
# Epoch: 6/19, i/N: 60/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 70/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 80/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 90/400 with KL 0.08 and nll loss -9.43
# Epoch: 6/19, i/N: 100/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.1083078384399414 and nll_test -9.402870178222656
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.48
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 120/400 with KL 0.10 and nll loss -9.42
# Epoch: 6/19, i/N: 130/400 with KL 0.12 and nll loss -9.39
# Epoch: 6/19, i/N: 140/400 with KL 0.13 and nll loss -9.38
# Epoch: 6/19, i/N: 150/400 with KL 0.19 and nll loss -9.32
# Epoch: 6/19, i/N: 160/400 with KL 0.07 and nll loss -9.44
# Epoch: 6/19, i/N: 170/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 180/400 with KL 0.25 and nll loss -9.26
# Epoch: 6/19, i/N: 190/400 with KL 0.18 and nll loss -9.33
# Epoch: 6/19, i/N: 200/400 with KL 0.16 and nll loss -9.35
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.11854076385498047 and nll_test -9.392637252807617
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.50
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.52
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 220/400 with KL 0.14 and nll loss -9.38
# Epoch: 6/19, i/N: 230/400 with KL 0.07 and nll loss -9.44
# Epoch: 6/19, i/N: 240/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 250/400 with KL -0.00 and nll loss -9.51
# Epoch: 6/19, i/N: 260/400 with KL 0.08 and nll loss -9.44
# Epoch: 6/19, i/N: 270/400 with KL 0.09 and nll loss -9.42
# Epoch: 6/19, i/N: 280/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 290/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 300/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.1067819595336914 and nll_test -9.404396057128906
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.51
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 0.99
# Epoch: 6/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.14 and nll loss -9.37
# Epoch: 6/19, i/N: 320/400 with KL 0.18 and nll loss -9.33
# Epoch: 6/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 340/400 with KL 0.03 and nll loss -9.48
# Epoch: 6/19, i/N: 350/400 with KL 0.19 and nll loss -9.32
# Epoch: 6/19, i/N: 360/400 with KL 0.04 and nll loss -9.47
# Epoch: 6/19, i/N: 370/400 with KL 0.10 and nll loss -9.41
# Epoch: 6/19, i/N: 380/400 with KL 0.06 and nll loss -9.45
# Epoch: 6/19, i/N: 390/400 with KL 0.20 and nll loss -9.31
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.02 and nll loss -9.49
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.10118293762207031 and nll_test -9.409995079040527
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.01
# Epoch: 7/19, i/N: 0/400 avg ldj -0.52
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL -0.00 and nll loss -9.51
# Epoch: 7/19, i/N: 20/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 30/400 with KL 0.09 and nll loss -9.42
# Epoch: 7/19, i/N: 40/400 with KL -0.02 and nll loss -9.53
# Epoch: 7/19, i/N: 50/400 with KL 0.16 and nll loss -9.35
# Epoch: 7/19, i/N: 60/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 70/400 with KL 0.05 and nll loss -9.46
# Epoch: 7/19, i/N: 80/400 with KL 0.19 and nll loss -9.32
# Epoch: 7/19, i/N: 90/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 100/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.10231304168701172 and nll_test -9.408864974975586
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.52
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.02 and nll loss -9.49
# Epoch: 7/19, i/N: 120/400 with KL 0.17 and nll loss -9.34
# Epoch: 7/19, i/N: 130/400 with KL 0.02 and nll loss -9.49
# Epoch: 7/19, i/N: 140/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 150/400 with KL 0.12 and nll loss -9.40
# Epoch: 7/19, i/N: 160/400 with KL 0.16 and nll loss -9.35
# Epoch: 7/19, i/N: 170/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 180/400 with KL -0.02 and nll loss -9.53
# Epoch: 7/19, i/N: 190/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 200/400 with KL 0.11 and nll loss -9.40
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.10176849365234375 and nll_test -9.409409523010254
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.51
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 220/400 with KL 0.08 and nll loss -9.44
# Epoch: 7/19, i/N: 230/400 with KL 0.19 and nll loss -9.32
# Epoch: 7/19, i/N: 240/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 250/400 with KL 0.14 and nll loss -9.37
# Epoch: 7/19, i/N: 260/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 270/400 with KL -0.01 and nll loss -9.52
# Epoch: 7/19, i/N: 280/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 290/400 with KL 0.11 and nll loss -9.40
# Epoch: 7/19, i/N: 300/400 with KL 0.09 and nll loss -9.42
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.0962381362915039 and nll_test -9.414939880371094
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.52
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.12 and nll loss -9.39
# Epoch: 7/19, i/N: 320/400 with KL 0.07 and nll loss -9.44
# Epoch: 7/19, i/N: 330/400 with KL 0.07 and nll loss -9.45
# Epoch: 7/19, i/N: 340/400 with KL 0.01 and nll loss -9.50
# Epoch: 7/19, i/N: 350/400 with KL -0.01 and nll loss -9.52
# Epoch: 7/19, i/N: 360/400 with KL 0.16 and nll loss -9.35
# Epoch: 7/19, i/N: 370/400 with KL 0.19 and nll loss -9.32
# Epoch: 7/19, i/N: 380/400 with KL 0.10 and nll loss -9.41
# Epoch: 7/19, i/N: 390/400 with KL 0.03 and nll loss -9.49
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL -0.01 and nll loss -9.52
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.09990215301513672 and nll_test -9.411275863647461
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.01
# Epoch: 8/19, i/N: 0/400 avg ldj -0.60
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 20/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 30/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 40/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 50/400 with KL 0.01 and nll loss -9.50
# Epoch: 8/19, i/N: 60/400 with KL -0.04 and nll loss -9.56
# Epoch: 8/19, i/N: 70/400 with KL 0.01 and nll loss -9.50
# Epoch: 8/19, i/N: 80/400 with KL 0.01 and nll loss -9.50
# Epoch: 8/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 8/19, i/N: 100/400 with KL 0.15 and nll loss -9.36
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.09001731872558594 and nll_test -9.421160697937012
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.54
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.15 and nll loss -9.36
# Epoch: 8/19, i/N: 120/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 130/400 with KL 0.09 and nll loss -9.43
# Epoch: 8/19, i/N: 140/400 with KL 0.29 and nll loss -9.22
# Epoch: 8/19, i/N: 150/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 160/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 170/400 with KL 0.17 and nll loss -9.35
# Epoch: 8/19, i/N: 180/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 190/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 200/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.09807968139648438 and nll_test -9.413098335266113
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.53
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.07 and nll loss -9.45
# Epoch: 8/19, i/N: 220/400 with KL 0.19 and nll loss -9.32
# Epoch: 8/19, i/N: 230/400 with KL 0.07 and nll loss -9.44
# Epoch: 8/19, i/N: 240/400 with KL 0.18 and nll loss -9.33
# Epoch: 8/19, i/N: 250/400 with KL 0.03 and nll loss -9.49
# Epoch: 8/19, i/N: 260/400 with KL -0.06 and nll loss -9.57
# Epoch: 8/19, i/N: 270/400 with KL 0.01 and nll loss -9.50
# Epoch: 8/19, i/N: 280/400 with KL 0.16 and nll loss -9.35
# Epoch: 8/19, i/N: 290/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 300/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.0956411361694336 and nll_test -9.415536880493164
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.58
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.13 and nll loss -9.39
# Epoch: 8/19, i/N: 320/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 8/19, i/N: 340/400 with KL 0.06 and nll loss -9.45
# Epoch: 8/19, i/N: 350/400 with KL 0.04 and nll loss -9.47
# Epoch: 8/19, i/N: 360/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 370/400 with KL 0.11 and nll loss -9.40
# Epoch: 8/19, i/N: 380/400 with KL 0.12 and nll loss -9.39
# Epoch: 8/19, i/N: 390/400 with KL 0.18 and nll loss -9.33
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.09612464904785156 and nll_test -9.415053367614746
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.57
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 20/400 with KL -0.01 and nll loss -9.52
# Epoch: 9/19, i/N: 30/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 40/400 with KL 0.10 and nll loss -9.42
# Epoch: 9/19, i/N: 50/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 60/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 70/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 80/400 with KL 0.13 and nll loss -9.39
# Epoch: 9/19, i/N: 90/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 100/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.08992481231689453 and nll_test -9.421253204345703
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.00
# Epoch: 9/19, i/N: 100/400 avg ldj -0.58
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.16 and nll loss -9.36
# Epoch: 9/19, i/N: 120/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 130/400 with KL 0.10 and nll loss -9.41
# Epoch: 9/19, i/N: 140/400 with KL 0.24 and nll loss -9.27
# Epoch: 9/19, i/N: 150/400 with KL 0.06 and nll loss -9.45
# Epoch: 9/19, i/N: 160/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 170/400 with KL 0.02 and nll loss -9.49
# Epoch: 9/19, i/N: 180/400 with KL 0.06 and nll loss -9.46
# Epoch: 9/19, i/N: 190/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 200/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.09874439239501953 and nll_test -9.412433624267578
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 1.00
# Epoch: 9/19, i/N: 200/400 avg ldj -0.53
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL 0.07 and nll loss -9.44
# Epoch: 9/19, i/N: 220/400 with KL 0.22 and nll loss -9.29
# Epoch: 9/19, i/N: 230/400 with KL 0.14 and nll loss -9.37
# Epoch: 9/19, i/N: 240/400 with KL -0.02 and nll loss -9.53
# Epoch: 9/19, i/N: 250/400 with KL 0.23 and nll loss -9.28
# Epoch: 9/19, i/N: 260/400 with KL 0.02 and nll loss -9.49
# Epoch: 9/19, i/N: 270/400 with KL 0.12 and nll loss -9.39
# Epoch: 9/19, i/N: 280/400 with KL 0.12 and nll loss -9.39
# Epoch: 9/19, i/N: 290/400 with KL 0.03 and nll loss -9.48
# Epoch: 9/19, i/N: 300/400 with KL 0.04 and nll loss -9.47
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.09508895874023438 and nll_test -9.416089057922363
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 0.99
# Epoch: 9/19, i/N: 300/400 avg ldj -0.59
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.06 and nll loss -9.46
# Epoch: 9/19, i/N: 320/400 with KL 0.20 and nll loss -9.32
# Epoch: 9/19, i/N: 330/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 340/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 350/400 with KL 0.15 and nll loss -9.36
# Epoch: 9/19, i/N: 360/400 with KL 0.09 and nll loss -9.42
# Epoch: 9/19, i/N: 370/400 with KL 0.16 and nll loss -9.35
# Epoch: 9/19, i/N: 380/400 with KL 0.01 and nll loss -9.50
# Epoch: 9/19, i/N: 390/400 with KL 0.09 and nll loss -9.42
# Epoch: 10 / 19
# Epoch: 10/19, i/N: 0/400 with KL 0.10 and nll loss -9.41
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 0/400 KL_test 0.089202880859375 and nll_test -9.421975135803223
#
# From current batch
# Epoch: 10, i/N: 0/400 avg ldj from current batch 0.53
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 0/400 MC density sum 1.00
# Epoch: 10/19, i/N: 0/400 avg ldj -0.56
# #####################
#
# Epoch: 10/19, i/N: 10/400 with KL 0.05 and nll loss -9.46
# Epoch: 10/19, i/N: 20/400 with KL 0.17 and nll loss -9.35
# Epoch: 10/19, i/N: 30/400 with KL 0.12 and nll loss -9.39
# Epoch: 10/19, i/N: 40/400 with KL 0.20 and nll loss -9.31
# Epoch: 10/19, i/N: 50/400 with KL 0.13 and nll loss -9.39
# Epoch: 10/19, i/N: 60/400 with KL 0.02 and nll loss -9.49
# Epoch: 10/19, i/N: 70/400 with KL 0.07 and nll loss -9.45
# Epoch: 10/19, i/N: 80/400 with KL 0.20 and nll loss -9.32
# Epoch: 10/19, i/N: 90/400 with KL -0.01 and nll loss -9.52
# Epoch: 10/19, i/N: 100/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 10/19, i/N: 100/400 KL_test 0.09640884399414062 and nll_test -9.414769172668457
#
# From current batch
# Epoch: 10, i/N: 100/400 avg ldj from current batch 0.52
#
# From 100000 uniform samples
# Epoch: 10/19, i/N: 100/400 MC density sum 1.00
# Epoch: 10/19, i/N: 100/400 avg ldj -0.63
# #####################
#
# ...
#
# From current batch
# Epoch: 16, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.63
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 20/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 30/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 40/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 50/400 with KL 0.07 and nll loss -9.45
# Epoch: 16/19, i/N: 60/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 70/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 80/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 90/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 100/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.0650014877319336 and nll_test -9.446176528930664
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.59
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.09 and nll loss -9.42
# Epoch: 16/19, i/N: 120/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 130/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 140/400 with KL 0.16 and nll loss -9.35
# Epoch: 16/19, i/N: 150/400 with KL 0.05 and nll loss -9.47
# Epoch: 16/19, i/N: 160/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 170/400 with KL 0.07 and nll loss -9.44
# Epoch: 16/19, i/N: 180/400 with KL -0.00 and nll loss -9.52
# Epoch: 16/19, i/N: 190/400 with KL 0.06 and nll loss -9.45
# Epoch: 16/19, i/N: 200/400 with KL 0.04 and nll loss -9.47
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.06278324127197266 and nll_test -9.448394775390625
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.61
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL -0.00 and nll loss -9.51
# Epoch: 16/19, i/N: 220/400 with KL 0.15 and nll loss -9.36
# Epoch: 16/19, i/N: 230/400 with KL 0.01 and nll loss -9.50
# Epoch: 16/19, i/N: 240/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 250/400 with KL 0.11 and nll loss -9.40
# Epoch: 16/19, i/N: 260/400 with KL 0.07 and nll loss -9.45
# Epoch: 16/19, i/N: 270/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 280/400 with KL 0.02 and nll loss -9.49
# Epoch: 16/19, i/N: 290/400 with KL 0.13 and nll loss -9.38
# Epoch: 16/19, i/N: 300/400 with KL 0.05 and nll loss -9.46
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.06861495971679688 and nll_test -9.4425630569458
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.55
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 0.99
# Epoch: 16/19, i/N: 300/400 avg ldj -0.61
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.05 and nll loss -9.46
# Epoch: 16/19, i/N: 320/400 with KL 0.03 and nll loss -9.49
# Epoch: 16/19, i/N: 330/400 with KL 0.02 and nll loss -9.50
# Epoch: 16/19, i/N: 340/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 350/400 with KL 0.16 and nll loss -9.35
# Epoch: 16/19, i/N: 360/400 with KL 0.01 and nll loss -9.51
# Epoch: 16/19, i/N: 370/400 with KL 0.08 and nll loss -9.43
# Epoch: 16/19, i/N: 380/400 with KL 0.04 and nll loss -9.47
# Epoch: 16/19, i/N: 390/400 with KL 0.08 and nll loss -9.43
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.14 and nll loss -9.37
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.05814838409423828 and nll_test -9.45302963256836
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.01
# Epoch: 17/19, i/N: 0/400 avg ldj -0.62
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 20/400 with KL 0.03 and nll loss -9.48
# Epoch: 17/19, i/N: 30/400 with KL 0.19 and nll loss -9.32
# Epoch: 17/19, i/N: 40/400 with KL -0.04 and nll loss -9.55
# Epoch: 17/19, i/N: 50/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 60/400 with KL 0.05 and nll loss -9.46
# Epoch: 17/19, i/N: 70/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 80/400 with KL 0.13 and nll loss -9.38
# Epoch: 17/19, i/N: 90/400 with KL 0.17 and nll loss -9.34
# Epoch: 17/19, i/N: 100/400 with KL -0.01 and nll loss -9.52
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.05289268493652344 and nll_test -9.458285331726074
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.01
# Epoch: 17/19, i/N: 100/400 avg ldj -0.57
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.04 and nll loss -9.47
# Epoch: 17/19, i/N: 120/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 130/400 with KL 0.13 and nll loss -9.38
# Epoch: 17/19, i/N: 140/400 with KL 0.05 and nll loss -9.46
# Epoch: 17/19, i/N: 150/400 with KL 0.06 and nll loss -9.46
# Epoch: 17/19, i/N: 160/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 170/400 with KL 0.05 and nll loss -9.46
# Epoch: 17/19, i/N: 180/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 190/400 with KL 0.16 and nll loss -9.36
# Epoch: 17/19, i/N: 200/400 with KL 0.04 and nll loss -9.47
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.06261253356933594 and nll_test -9.448565483093262
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.57
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.13 and nll loss -9.38
# Epoch: 17/19, i/N: 220/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 230/400 with KL 0.02 and nll loss -9.49
# Epoch: 17/19, i/N: 240/400 with KL -0.07 and nll loss -9.58
# Epoch: 17/19, i/N: 250/400 with KL 0.03 and nll loss -9.48
# Epoch: 17/19, i/N: 260/400 with KL 0.07 and nll loss -9.44
# Epoch: 17/19, i/N: 270/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 280/400 with KL 0.06 and nll loss -9.45
# Epoch: 17/19, i/N: 290/400 with KL 0.04 and nll loss -9.48
# Epoch: 17/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.06097698211669922 and nll_test -9.450201034545898
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.61
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 320/400 with KL 0.11 and nll loss -9.40
# Epoch: 17/19, i/N: 330/400 with KL 0.09 and nll loss -9.42
# Epoch: 17/19, i/N: 340/400 with KL 0.13 and nll loss -9.39
# Epoch: 17/19, i/N: 350/400 with KL 0.01 and nll loss -9.50
# Epoch: 17/19, i/N: 360/400 with KL 0.12 and nll loss -9.39
# Epoch: 17/19, i/N: 370/400 with KL 0.03 and nll loss -9.48
# Epoch: 17/19, i/N: 380/400 with KL -0.02 and nll loss -9.54
# Epoch: 17/19, i/N: 390/400 with KL 0.08 and nll loss -9.43
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.09 and nll loss -9.42
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.06215476989746094 and nll_test -9.449023246765137
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 0.99
# Epoch: 18/19, i/N: 0/400 avg ldj -0.63
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.06 and nll loss -9.46
# Epoch: 18/19, i/N: 20/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 30/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 40/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 50/400 with KL 0.10 and nll loss -9.41
# Epoch: 18/19, i/N: 60/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 70/400 with KL 0.02 and nll loss -9.49
# Epoch: 18/19, i/N: 80/400 with KL 0.12 and nll loss -9.39
# Epoch: 18/19, i/N: 90/400 with KL -0.03 and nll loss -9.54
# Epoch: 18/19, i/N: 100/400 with KL 0.13 and nll loss -9.38
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.05696392059326172 and nll_test -9.454214096069336
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.59
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 120/400 with KL -0.02 and nll loss -9.53
# Epoch: 18/19, i/N: 130/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 140/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 150/400 with KL 0.13 and nll loss -9.38
# Epoch: 18/19, i/N: 160/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 170/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 180/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 190/400 with KL 0.08 and nll loss -9.44
# Epoch: 18/19, i/N: 200/400 with KL 0.01 and nll loss -9.50
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.06009197235107422 and nll_test -9.451086044311523
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.57
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL -0.01 and nll loss -9.52
# Epoch: 18/19, i/N: 220/400 with KL 0.06 and nll loss -9.45
# Epoch: 18/19, i/N: 230/400 with KL -0.02 and nll loss -9.53
# Epoch: 18/19, i/N: 240/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 250/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 260/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 270/400 with KL -0.03 and nll loss -9.54
# Epoch: 18/19, i/N: 280/400 with KL 0.08 and nll loss -9.43
# Epoch: 18/19, i/N: 290/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 300/400 with KL 0.07 and nll loss -9.44
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.05970478057861328 and nll_test -9.451473236083984
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.01
# Epoch: 18/19, i/N: 300/400 avg ldj -0.65
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.03 and nll loss -9.48
# Epoch: 18/19, i/N: 320/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 330/400 with KL 0.04 and nll loss -9.47
# Epoch: 18/19, i/N: 340/400 with KL 0.11 and nll loss -9.40
# Epoch: 18/19, i/N: 350/400 with KL -0.04 and nll loss -9.55
# Epoch: 18/19, i/N: 360/400 with KL 0.05 and nll loss -9.46
# Epoch: 18/19, i/N: 370/400 with KL 0.01 and nll loss -9.50
# Epoch: 18/19, i/N: 380/400 with KL 0.05 and nll loss -9.47
# Epoch: 18/19, i/N: 390/400 with KL -0.01 and nll loss -9.52
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL -0.04 and nll loss -9.55
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.055416107177734375 and nll_test -9.455761909484863
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.01
# Epoch: 19/19, i/N: 0/400 avg ldj -0.63
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 20/400 with KL 0.04 and nll loss -9.48
# Epoch: 19/19, i/N: 30/400 with KL 0.01 and nll loss -9.50
# Epoch: 19/19, i/N: 40/400 with KL 0.11 and nll loss -9.41
# Epoch: 19/19, i/N: 50/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 60/400 with KL 0.16 and nll loss -9.35
# Epoch: 19/19, i/N: 70/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 80/400 with KL 0.15 and nll loss -9.36
# Epoch: 19/19, i/N: 90/400 with KL 0.08 and nll loss -9.43
# Epoch: 19/19, i/N: 100/400 with KL 0.12 and nll loss -9.39
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.060990333557128906 and nll_test -9.450187683105469
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 0.99
# Epoch: 19/19, i/N: 100/400 avg ldj -0.63
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 120/400 with KL 0.09 and nll loss -9.43
# Epoch: 19/19, i/N: 130/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 140/400 with KL -0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 150/400 with KL -0.00 and nll loss -9.51
# Epoch: 19/19, i/N: 160/400 with KL 0.12 and nll loss -9.39
# Epoch: 19/19, i/N: 170/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 180/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 190/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 200/400 with KL 0.08 and nll loss -9.43
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.05572509765625 and nll_test -9.455452919006348
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.01
# Epoch: 19/19, i/N: 200/400 avg ldj -0.61
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 220/400 with KL 0.20 and nll loss -9.31
# Epoch: 19/19, i/N: 230/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 240/400 with KL -0.08 and nll loss -9.59
# Epoch: 19/19, i/N: 250/400 with KL 0.13 and nll loss -9.38
# Epoch: 19/19, i/N: 260/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 270/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 280/400 with KL 0.09 and nll loss -9.42
# Epoch: 19/19, i/N: 290/400 with KL 0.05 and nll loss -9.46
# Epoch: 19/19, i/N: 300/400 with KL 0.06 and nll loss -9.45
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.05862903594970703 and nll_test -9.45254898071289
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.56
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.01
# Epoch: 19/19, i/N: 300/400 avg ldj -0.60
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.14 and nll loss -9.37
# Epoch: 19/19, i/N: 320/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 330/400 with KL 0.10 and nll loss -9.41
# Epoch: 19/19, i/N: 340/400 with KL 0.20 and nll loss -9.31
# Epoch: 19/19, i/N: 350/400 with KL 0.04 and nll loss -9.47
# Epoch: 19/19, i/N: 360/400 with KL 0.07 and nll loss -9.44
# Epoch: 19/19, i/N: 370/400 with KL -0.09 and nll loss -9.61
# Epoch: 19/19, i/N: 380/400 with KL 0.06 and nll loss -9.45
# Epoch: 19/19, i/N: 390/400 with KL 0.03 and nll loss -9.48
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.051644325256347656 and nll_test -9.45953369140625
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.57
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 0.99
# Epoch: 19/19, i/N: 399/400 avg ldj -0.57
# #####################
