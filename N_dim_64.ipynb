# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
import yaml
import pprint
import os
import time
# weights and biases for tracking of metrics
import wandb 
# make the plots inline again
# %matplotlib inline
# sometimes have to activate this to plot plots in notebook
# matplotlib.use('Qt5Agg')
from code import *

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Load and pprint config

# %%
stream = open("config_fit_df.yaml", 'r')
config = yaml.load(stream, Loader = yaml.FullLoader)

# This is for the MLPs of the flow
config['HIDDEN_DIM_SPLINE_MLP'] = HIDDEN_DIM_SPLINE_MLP
config['HIDDEN_DIM_MOEBIUS_MLP'] = HIDDEN_DIM_MOEBIUS_MLP
config['HIDDEN_DIM_ROTATION_MLP'] = HIDDEN_DIM_ROTATION_MLP

### Set globabl variables and load data
BATCH_SIZE = config['BATCH_SIZE']

# NUM_FLOWS_COU = config['NUM_FLOWS_COU']
# NUM_FLOWS_CYL = config['NUM_FLOWS_CYL']
# NUM_CENTERS = config['NUM_CENTERS']
# NUM_BINS = config['NUM_BINS']
# NUM_DIM_DATA = config['NUM_DIM_DATA']

# flow params
NUM_DIM_DATA = 64
NUM_CENTERS = 8
NUM_BINS = 12
NUM_FLOWS_COU = 4
NUM_FLOWS_CYL = 4

CAP_HOUSEHOLDER_REFL = False

nr_mixtures = config['nr_mixtures']
epochs = config['epochs']
eval_iter = config['eval_iter']
print_iter = config['print_iter']
lookahead = config['lookahead']
nr_datapoints = config['nr_datapoints_eval']

lr = config['lr']
weight_decay = config['weight_decay']

# data parameters
# nr_mixtures = config['nr_mixtures']

# dataset type

dataset_type = config['dataset_type']

ITERS_PER_EPOCH = config['iters_per_epoch']

PROJECT_NAME = f'DIM_{NUM_DIM_DATA}'

pp = pprint.PrettyPrinter(indent=1)
pp.pprint(config)
# Out:
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'lookahead': 10,
#  'lr': 0.001,
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'print_iter': 10,
#  'weight_decay': 0.01}

# %% [markdown]
# ### get location and scale parameters

# %%
# # code for creating dataset on the poles
# from random import random
# eps = random()*0.2
# mu_list = np.array([[eps, eps, 1+eps],
#                          [eps, eps, -1+eps],
#                          [1, eps, eps]], dtype='float32')

# k_list = 1.5*np.array([13, 14,  12],dtype='float32')

# mu_list = mu_list / np.linalg.norm(mu_list,axis=1,keepdims=True)
# np.linalg.norm(mu_list,axis=1,keepdims=True)


if NUM_DIM_DATA == 3 and dataset_type == 'standard':

    mu_list = np.array([[-4.7503373e-01, -8.7996745e-01, -5.0922018e-04],
                        [-1.6167518e-01,  6.5595394e-01, -7.3728257e-01],
                        [ 2.6248896e-01,  6.9851363e-01,  6.6571641e-01],
                        [ 1.0,  0,  0.0]], dtype='float32')

    k_list = 1.5*np.array([13, 14,  12, 15],dtype='float32')

    phi_mu_list = np.array([-2.06579875,  1.81245307,  1.2113401, 0],dtype='float32')
    theta_mu_list =  np.array([-5.09220198e-04, -8.29039128e-01,  7.28453441e-01, 0],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles':
    
    mu_list = np.array([[ 0.14887695,  0.14887695,  0.9775844 ],
                        [ 0.20918883,  0.20918883, -0.9552383 ],
                        [ 0.96920884,  0.17411795,  0.17411795]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14,  12],dtype='float32')
    
    phi_mu_list = np.array([0.7853982, 0.7853982, 0.1777535],dtype='float32')
    theta_mu_list =  np.array([ 1.3586651 , -1.2704642 ,  0.17500998],dtype='float32')
    
elif NUM_DIM_DATA == 3 and dataset_type == 'poles_2':
    
    mu_list = np.array([[ 0,  0,  1 ],
                        [ 0,  0, -1 ]], dtype='float32')
    
    k_list = 1.5*np.array([13, 14],dtype='float32')
    
    phi_mu_list = np.array([0, 0],dtype='float32')
    theta_mu_list =  np.array([ np.pi/2 , -np.pi/2],dtype='float32')    
    
else:    
    torch.manual_seed(7) # mu created with torch
    np.random.seed(7) # k with numpy
    mu_list, k_list, phi_mu_list, theta_mu_list = create_random_parameters(nr_mixtures, num_dim_data = NUM_DIM_DATA)

# %% [markdown]
# ### 3d and N dim Power Spherical Data

# %%
# Power Spherical 

power_spherical_data = PowerSphericalData(mu_list=mu_list, k_list=k_list, nr_samples=BATCH_SIZE*ITERS_PER_EPOCH)

print(f'Entropy {power_spherical_data.entropy.detach().numpy()}')

# add parameters to config
config['nr_mixtures'] = len(mu_list)
config['mu_list'] = mu_list
config['k_list'] = k_list
config['phi_mu_list'] = phi_mu_list
config['theta_mu_list'] = theta_mu_list

if NUM_DIM_DATA == 3:
    
    start_time = time.time()
    probs, probs_with_cos, phi_linspace, theta_linspace = plot_power_spherical_density(mu_list, k_list,phi_mu_list,theta_mu_list)
    print("--- %s seconds ---" % (time.time() - start_time))

    dphi = phi_linspace[1] - phi_linspace[0]
    dtheta = theta_linspace[1] - theta_linspace[0]

    print('numerical integral of density w', torch.sum(probs_with_cos) * dphi * dtheta)
# Out:
# Secs for entropy calc 1.7070157527923584
# With entropy -41.10647964477539
# Entropy -41.10647964477539

# %% [markdown]
# ### train function

# %%
def get_num_params(model):
    
    total_number_params = 0
    
    for name, parameter in model.named_parameters():
        total_number_params += parameter.numel()
    return total_number_params

def train_model(model, 
                optimizer, 
                dataset, 
                config,
                model_name):
    
    
    epochs = config['epochs']
    config['NUM_PARAMS'] = get_num_params(model)

    # init weights and biases tracking
    ts = time.strftime('%m%d_%H%M%S', time.localtime(time.time()))
    
    if model.flow_type == 'moebius':
        model_name = f"{model_name}_NC_{NUM_CENTERS}_NF_{model.num_flows}_seed_07"
        
    elif model.flow_type == 'spline':
        model_name = f"{model_name}_NB_{NUM_BINS}_NF_{model.num_flows}_seed_07"
        
    wandb.init(project=PROJECT_NAME,
               config=config,
               name=model_name,
               id=ts)
    
    best_KL = 1e3
    epoch_of_best_run = 0
    
    # According to w and b documentation this is magic. Okay, let's see
    wandb.watch(model)
    
    print('##### Model #####')
    print(model)
    print('#################\n')
    
    print('##### Config #####')
    pp = pprint.PrettyPrinter(indent=1)
    pp.pprint(config)
    print('##################\n')    
    
    train_loader = DataLoader(dataset, batch_size=config['BATCH_SIZE'], shuffle=True)
    
    # get properties of dataset class
    phi_mu_list, theta_mu_list = dataset.spherical_parameters
    entropy = dataset.entropy
    
    print(f'Entropy of data: {entropy}')

    max_steps = config['iters_per_epoch']
    
    num_dim_data = model.num_dim_data
    
    # initialize loss. 
    loss_fn = Loss_on_sphere(n_dim_sphere = num_dim_data - 1)
    
    for epoch in range(epochs):
        
        print(f"Epoch: {epoch} / {epochs-1}")
        
        if num_dim_data == 3:
        
            # actually the calculation here is partly redundant because we anyway later evalaute the model on a test set            
            eval_and_plot_model(model, 
                                nr_gridpoints = 100, 
                                epoch = epoch, 
                                batch_idx = 0, 
                                phi_mu_list=phi_mu_list, 
                                theta_mu_list=theta_mu_list, 
                                x_conditioner = None)

        start_time = time.time()
        for batch_idx, x_train in enumerate(train_loader): 

            x_train = x_train.float().to(device)

            optimizer.zero_grad()

            z, ldj, _ = model(x_train)

            loss = loss_fn.calc_loss(ldj)
                          
            # calculate gradient with repsect to ldj and not whole nll, 
            # because our prior is uniform and therefore this way is less expensive
            (-torch.mean(ldj)).backward()
#             loss.backward()
            optimizer.step()

            nll = float(loss.detach().cpu().numpy()) 
            KL = nll - entropy
                            
            if batch_idx % config['print_iter'] == 0: 
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} with KL {KL:.2f} and nll loss {nll:.2f}')                
                  
            def eval_model():
                
                nr_datapoints = config['nr_datapoints_eval']

                # KL evaluation based on nr_datapoints samples from data distribution
                test_data = dataset.get_test_set(nr_samples = nr_datapoints).to(device)

                with torch.no_grad():

                    model.eval()
                    z, ldj, _ = model(test_data)

                    nll_test = loss_fn.calc_loss(ldj)
                    KL_test = nll_test - entropy

                    # MC evaluation based on nr_datapoints uniform samples on the sphere
                    x_eval = torch.randn(nr_datapoints, num_dim_data).to(device)
                    x_eval = x_eval / torch.norm(x_eval, dim=1, keepdim=True)

                    z, ldj0, _ = model(x_eval)
                    model.train()                

                print()
                print(f'#### EVALUATION ####')
                print(f'Evaluation based on {nr_datapoints} data points from data distribution samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} KL_test {KL_test} and nll_test {nll_test}')

                print('\nFrom current batch')
                print(f'Epoch: {epoch}, i/N: {batch_idx}/{max_steps} avg ldj from current batch {torch.mean(ldj):.2f}')

                print(f'\nFrom {nr_datapoints} uniform samples')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum {torch.mean(torch.exp(ldj0)):.2f}')
                print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} avg ldj {torch.mean(ldj0):.2f}')
                print('#####################')
                print()
                
                wandb.log({"KL_train": KL,
                           "neg_log_likel_train": nll,
                           "KL_test": KL_test,
                           "neg_log_likel_test": nll_test,            
                           "MC_integral": torch.mean(torch.exp(ldj0))})  
                
                return KL_test, nll_test
                
                
            if batch_idx % config['eval_iter'] == 0:
                KL_test, nll_test = eval_model()
                
#                 # This part is for additional evaluation of 
#                 model.eval()
#                 print()
#                 print('#####################')

#                 # first, second and both coupling w/o rotation
#                 sldj_test = torch.zeros(nr_datapoints).to(device)       
                
#                 x_out, ldj_first, _ = model.scale[1](x_eval, sldj_test) 
#                 _, ldj_second, _  = model.scale[3](x_eval, sldj_test) 
                
#                 _, ldj_first_second, _  = model.scale[3](x_out, ldj_first)                  

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first flow only moeb {torch.mean(torch.exp(ldj_first)):.2f}')
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum second flow only moeb {torch.mean(torch.exp(ldj_second)):.2f}') 
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density sum first and second flow only moeb {torch.mean(torch.exp(ldj_first_second)):.2f}')
#                 print()
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj1, _ = model.scale[1](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first flow incl rot {torch.mean(torch.exp(ldj1)):.2f}') 
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[2](x_eval, sldj_test)
#                 x_out, ldj2, _ = model.scale[3](x_out, ldj)
                
#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density second flow incl rot {torch.mean(torch.exp(ldj2)):.2f}')   
                
#                 sldj_test = torch.zeros(nr_datapoints).to(device)
#                 x_out, ldj, _ = model.scale[0](x_eval, sldj_test)
#                 x_out, ldj, _ = model.scale[1](x_out, ldj)                
#                 x_out, ldj, _ = model.scale[2](x_out, ldj)
#                 x_out, ldj12, _ = model.scale[3](x_out, ldj)

#                 print(f'Epoch: {epoch}/{epochs-1}, i/N: {batch_idx}/{max_steps} MC density first&second flow incl rot {torch.mean(torch.exp(ldj12)):.2f}')                   
                
#                 print('#####################')
#                 print()
#                 model.train()                
                
                # store the metrics in the log. Call logger after eval and plot model because we also log plots inside
                   
            def store_model(best_vs_last):
                if not os.path.exists(f'models_fit_df/dim_{num_dim_data}'):
                    os.makedirs(f'models_fit_df/dim_{num_dim_data}')
                # also store model in the end
                state = {
                    'epoch': epoch,
                    'batch_index': batch_idx,
                    'state_dict': model.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'config': config
                }                        

                torch.save(state, f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")
                wandb.save(f"models_fit_df/dim_{num_dim_data}/{best_vs_last}_{model_name}_model.t7")  
                

            # save the best model but do not save any model during the first 50 iterations
            if not (epoch == 0 and batch_idx < 50):

                if KL_test < best_KL:

                    store_model(best_vs_last='best')

                    best_KL = KL_test
                    epoch_of_best_run = epoch
                    
                    wandb.run.summary["KL_best"] = KL_test
                    wandb.run.summary["nll_best"] = nll_test
                    
                    wandb.run.summary["epoch_of_best_KL"] = epoch_of_best_run
                    wandb.run.summary["batch_id_of_best_KL"] = batch_idx                    
                    
                    wandb.run.summary["KL_current_batch"] = KL
                    wandb.run.summary["nll_current_batch"] = nll
           
        
        wandb.log({"time_per_epoch": time.time()-start_time},commit=False)
        
        # if there was no improvement after a certain amount of epochs terminate training    
        if (epoch - epoch_of_best_run) >= config['lookahead']:
            print()
            print('#### EARLY STOPPING ####')
            print(f'at epoch {epoch} and batch_id {batch_idx}')
            print('########################')
            print()
            break
                
                                        
    # also store model in the end        
    store_model(best_vs_last='last')
    
    wandb.run.summary["last_epoch"] = epoch
    
    _,_ = eval_model()
    
    if num_dim_data == 3:
        eval_and_plot_model(model, 
                            nr_gridpoints = 100, 
                            epoch = epoch, 
                            batch_idx = 0, 
                            phi_mu_list=phi_mu_list, 
                            theta_mu_list=theta_mu_list, 
                            x_conditioner = None)

# %% [markdown]
# ### Coupling Moebius Flow

# %%
cou_moeb = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                              num_dim_data= NUM_DIM_DATA,
                              flow_type = 'moebius', 
                              num_centers = NUM_CENTERS,
                              cap_householder_refl=CAP_HOUSEHOLDER_REFL)

cou_moeb.to(device)

optimizer = optim.AdamW(cou_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Moebius Flow #####')


train_model(model = cou_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_m')
# Out:
# ##### Coupling Moebius Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_184627" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_184627</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Coupling_Flow(
#   (scale): ModuleList(
#     (0): Rotation()
#     (1): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=257, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (2): Rotation()
#     (3): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=257, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (4): Rotation()
#     (5): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=257, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (6): Rotation()
#     (7): Coupling(
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=257, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 64,
#  'HIDDEN_DIM_ROTATION_MLP': 64,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 366380,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.00157917e-01,  4.83159684e-02,  1.09778091e-01,
#         -1.69557109e-01, -2.03941818e-02,  3.48235853e-02,
#         -7.82925114e-02, -1.09136559e-01,  1.13152914e-01,
#         -6.53987676e-02, -1.41629413e-01, -5.61961234e-02,
#          8.65294561e-02,  1.23681501e-01,  2.81369332e-02,
#          1.33135065e-01, -1.93280950e-01, -3.96372974e-02,
#          2.35255316e-01, -4.03022729e-02,  2.42348555e-02,
#          9.55096558e-02,  1.26899734e-01, -8.84799734e-02,
#         -2.55654398e-02, -2.62983181e-02, -2.21743613e-01,
#         -4.21622470e-02, -2.51755446e-01,  8.23237151e-02,
#         -1.61611959e-01, -1.66060105e-01, -1.02007817e-02,
#         -2.86721345e-03,  2.12953743e-02,  2.80682266e-01,
#          1.16884917e-01, -8.08297545e-02, -1.01173684e-01,
#         -7.39679560e-02, -1.71126023e-01,  1.58435538e-01,
#          2.00396940e-01, -1.29046246e-01, -3.19459550e-02,
#         -3.05471364e-02,  6.11988381e-02,  3.17565985e-02,
#         -2.17615534e-02, -3.16909775e-02, -1.76932185e-03,
#         -4.68822122e-02, -3.62239808e-01, -1.29518971e-01,
#         -3.77357900e-02,  1.14098795e-01,  1.98367640e-01,
#          1.91400992e-04, -5.34341186e-02, -2.57502019e-01,
#          1.39832631e-01, -4.66737896e-02, -4.33864258e-02,
#          9.21048298e-02],
#        [ 1.90074500e-02,  2.60411873e-02, -7.34153613e-02,
#          1.14198759e-01, -1.77348390e-01, -2.45047510e-01,
#         -8.30812007e-02, -8.77825767e-02, -1.26364231e-01,
#          1.70761779e-01,  6.66862428e-02, -2.05338895e-02,
#         -1.15837276e-01, -5.51476181e-02, -1.47932172e-01,
#          8.44565630e-02, -3.22086036e-01,  5.76755702e-02,
#          8.16275850e-02,  4.39113937e-02, -1.79599132e-02,
#         -1.36633322e-01,  2.49908283e-01,  1.39740869e-01,
#         -5.68425208e-02, -2.47033890e-02,  1.07973561e-01,
#          1.40691027e-01, -1.17738850e-01,  2.32937708e-02,
#          7.15092421e-02,  2.02650025e-01, -7.65809119e-02,
#          1.18245028e-01,  1.50797278e-01, -1.57591119e-01,
#          1.81805771e-02, -2.70232349e-03, -5.80996014e-02,
#          7.58496597e-02,  5.47281615e-02,  2.72839308e-01,
#         -1.73256159e-01,  2.52663344e-01,  7.23374635e-02,
#         -2.24806350e-02,  6.56668916e-02, -1.64511994e-01,
#         -1.60445154e-01, -4.48567010e-02,  8.92971903e-02,
#          1.29540684e-02, -8.35901946e-02, -6.98424652e-02,
#          9.12709311e-02,  8.69363174e-02, -1.16403118e-01,
#          1.64974838e-01, -1.72709599e-01,  7.23473877e-02,
#         -6.14937842e-02,  8.74846950e-02,  4.03753258e-02,
#          1.69111788e-01],
#        [ 8.03996921e-02,  1.88394841e-02,  7.91436583e-02,
#         -1.03894427e-01, -3.16554010e-02, -1.12420239e-01,
#         -3.01579207e-01, -1.05891101e-01,  2.05421910e-01,
#         -2.17842519e-01, -4.68437485e-02,  7.77946189e-02,
#          1.79144815e-02, -2.14141190e-01, -1.28987297e-01,
#          1.79710582e-01,  3.69543321e-02, -2.11171061e-02,
#          1.62856132e-01, -1.59821570e-01,  2.95013607e-01,
#         -7.50024766e-02,  1.13670453e-01,  1.04433009e-02,
#          9.55903437e-03, -7.75749460e-02, -5.82263321e-02,
#          7.62394210e-03,  1.02248378e-01, -1.53147265e-01,
#         -7.49353617e-02,  1.87370479e-02,  9.64044780e-02,
#         -1.45118386e-01, -1.11712189e-02,  2.03258339e-02,
#          1.98214769e-01, -5.88899516e-02,  2.33828742e-02,
#         -1.01145782e-01, -9.51767862e-02, -1.00689523e-01,
#         -9.76603106e-02,  3.26669775e-02, -1.06782429e-01,
#         -1.69287287e-02,  1.34891734e-01,  2.10845172e-02,
#         -6.64624944e-02, -1.19874842e-01,  1.15675263e-01,
#          2.91244667e-02,  9.90839899e-02, -9.76498947e-02,
#          4.12934907e-02,  2.06514955e-01,  4.34264876e-02,
#          1.07311860e-01,  2.16698542e-01, -1.09591521e-01,
#         -3.03995848e-01, -1.80847108e-01, -1.39791742e-01,
#         -6.19465660e-04],
#        [-4.84134592e-02,  2.52364427e-02, -1.57797530e-01,
#          1.19816773e-01,  1.73902944e-01, -1.13306522e-01,
#         -1.93215534e-01, -3.63163911e-02, -3.56696576e-01,
#         -3.12909251e-03,  1.00029714e-01,  8.97102579e-02,
#          1.01910129e-01,  7.79635534e-02,  9.18881036e-03,
#         -1.32722501e-02,  8.26334730e-02, -1.22652352e-01,
#         -1.19253814e-01, -1.16538182e-01, -9.13126916e-02,
#         -4.08998579e-01,  5.43543324e-02, -1.43570259e-01,
#         -1.53310671e-01, -2.48359591e-01, -7.12860748e-02,
#          1.55420944e-01, -3.80727760e-02, -9.34401825e-02,
#          2.00530961e-01, -6.45856699e-03,  6.38035312e-02,
#          8.77265632e-02,  1.80304080e-01, -3.99558507e-02,
#         -1.94207835e-03, -7.79024139e-02,  5.40511608e-02,
#         -6.76667765e-02, -1.74297363e-01, -2.57477742e-02,
#         -1.10576358e-02, -1.15368016e-01, -5.66938594e-02,
#          4.62486409e-02, -3.27315815e-02,  1.74612537e-01,
#         -9.70561430e-02,  1.16726570e-01, -5.90321943e-02,
#         -6.55079111e-02, -8.50142390e-02,  2.71943569e-01,
#          1.02150232e-01,  8.64362717e-03,  8.47468153e-02,
#         -3.54529545e-02, -5.58530279e-02,  1.31824212e-02,
#          1.06705502e-01, -1.09613128e-01,  1.26093216e-02,
#         -4.06794176e-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -41.10647964477539
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.34 and nll loss -40.77
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.3387107849121094 and nll_test -40.76776885986328
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch 0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj 0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.34 and nll loss -40.77
# Epoch: 0/19, i/N: 20/400 with KL 0.33 and nll loss -40.78
# Epoch: 0/19, i/N: 30/400 with KL 0.31 and nll loss -40.80
# Epoch: 0/19, i/N: 40/400 with KL 0.27 and nll loss -40.83
# Epoch: 0/19, i/N: 50/400 with KL 0.20 and nll loss -40.90
# Epoch: 0/19, i/N: 60/400 with KL 0.17 and nll loss -40.94
# Epoch: 0/19, i/N: 70/400 with KL 0.18 and nll loss -40.92
# Epoch: 0/19, i/N: 80/400 with KL 0.23 and nll loss -40.88
# Epoch: 0/19, i/N: 90/400 with KL 0.10 and nll loss -41.00
# Epoch: 0/19, i/N: 100/400 with KL 0.19 and nll loss -40.91
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.1519622802734375 and nll_test -40.95451736450195
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.19
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.20
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.15 and nll loss -40.96
# Epoch: 0/19, i/N: 120/400 with KL 0.20 and nll loss -40.90
# Epoch: 0/19, i/N: 130/400 with KL 0.16 and nll loss -40.94
# Epoch: 0/19, i/N: 140/400 with KL 0.11 and nll loss -40.99
# Epoch: 0/19, i/N: 150/400 with KL 0.15 and nll loss -40.96
# Epoch: 0/19, i/N: 160/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 170/400 with KL 0.10 and nll loss -41.00
# Epoch: 0/19, i/N: 180/400 with KL 0.09 and nll loss -41.02
# Epoch: 0/19, i/N: 190/400 with KL 0.14 and nll loss -40.96
# Epoch: 0/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.14073944091796875 and nll_test -40.96574020385742
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.20
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.19
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 0/19, i/N: 220/400 with KL 0.15 and nll loss -40.96
# Epoch: 0/19, i/N: 230/400 with KL 0.20 and nll loss -40.91
# Epoch: 0/19, i/N: 240/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 250/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 260/400 with KL 0.15 and nll loss -40.95
# Epoch: 0/19, i/N: 270/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 280/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 290/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 300/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.12248992919921875 and nll_test -40.98398971557617
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.20
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.17 and nll loss -40.94
# Epoch: 0/19, i/N: 320/400 with KL 0.12 and nll loss -40.99
# Epoch: 0/19, i/N: 330/400 with KL 0.17 and nll loss -40.93
# Epoch: 0/19, i/N: 340/400 with KL 0.03 and nll loss -41.08
# Epoch: 0/19, i/N: 350/400 with KL 0.07 and nll loss -41.03
# Epoch: 0/19, i/N: 360/400 with KL 0.12 and nll loss -40.99
# Epoch: 0/19, i/N: 370/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 380/400 with KL 0.12 and nll loss -40.99
# Epoch: 0/19, i/N: 390/400 with KL 0.06 and nll loss -41.05
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.1058502197265625 and nll_test -41.00062942504883
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.21
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.12 and nll loss -40.98
# Epoch: 1/19, i/N: 20/400 with KL 0.11 and nll loss -41.00
# Epoch: 1/19, i/N: 30/400 with KL 0.10 and nll loss -41.01
# Epoch: 1/19, i/N: 40/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 50/400 with KL 0.09 and nll loss -41.01
# Epoch: 1/19, i/N: 60/400 with KL 0.09 and nll loss -41.01
# Epoch: 1/19, i/N: 70/400 with KL 0.08 and nll loss -41.02
# Epoch: 1/19, i/N: 80/400 with KL 0.13 and nll loss -40.98
# Epoch: 1/19, i/N: 90/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 100/400 with KL 0.19 and nll loss -40.91
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.096710205078125 and nll_test -41.009769439697266
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.23
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.06 and nll loss -41.04
# Epoch: 1/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 1/19, i/N: 130/400 with KL 0.11 and nll loss -41.00
# Epoch: 1/19, i/N: 140/400 with KL 0.15 and nll loss -40.96
# Epoch: 1/19, i/N: 150/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 160/400 with KL 0.03 and nll loss -41.08
# Epoch: 1/19, i/N: 170/400 with KL 0.13 and nll loss -40.97
# Epoch: 1/19, i/N: 180/400 with KL 0.14 and nll loss -40.96
# Epoch: 1/19, i/N: 190/400 with KL 0.05 and nll loss -41.05
# Epoch: 1/19, i/N: 200/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.09491348266601562 and nll_test -41.011566162109375
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.03 and nll loss -41.07
# Epoch: 1/19, i/N: 220/400 with KL 0.15 and nll loss -40.95
# Epoch: 1/19, i/N: 230/400 with KL 0.15 and nll loss -40.96
# Epoch: 1/19, i/N: 240/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 250/400 with KL 0.10 and nll loss -41.01
# Epoch: 1/19, i/N: 260/400 with KL 0.05 and nll loss -41.05
# Epoch: 1/19, i/N: 270/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 280/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 290/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 300/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.09267425537109375 and nll_test -41.0138053894043
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 320/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 330/400 with KL 0.07 and nll loss -41.03
# Epoch: 1/19, i/N: 340/400 with KL 0.01 and nll loss -41.09
# Epoch: 1/19, i/N: 350/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 360/400 with KL 0.03 and nll loss -41.08
# Epoch: 1/19, i/N: 370/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 380/400 with KL 0.06 and nll loss -41.05
# Epoch: 1/19, i/N: 390/400 with KL 0.03 and nll loss -41.07
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.05 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.09496307373046875 and nll_test -41.01151657104492
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 20/400 with KL 0.10 and nll loss -41.00
# Epoch: 2/19, i/N: 30/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 40/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 50/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 60/400 with KL 0.02 and nll loss -41.09
# Epoch: 2/19, i/N: 70/400 with KL 0.01 and nll loss -41.10
# Epoch: 2/19, i/N: 80/400 with KL 0.03 and nll loss -41.07
# Epoch: 2/19, i/N: 90/400 with KL 0.13 and nll loss -40.97
# Epoch: 2/19, i/N: 100/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.08782196044921875 and nll_test -41.01865768432617
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.07 and nll loss -41.03
# Epoch: 2/19, i/N: 120/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 130/400 with KL 0.18 and nll loss -40.93
# Epoch: 2/19, i/N: 140/400 with KL 0.04 and nll loss -41.06
# Epoch: 2/19, i/N: 150/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 160/400 with KL -0.01 and nll loss -41.11
# Epoch: 2/19, i/N: 170/400 with KL 0.07 and nll loss -41.03
# Epoch: 2/19, i/N: 180/400 with KL 0.03 and nll loss -41.07
# Epoch: 2/19, i/N: 190/400 with KL 0.03 and nll loss -41.07
# Epoch: 2/19, i/N: 200/400 with KL 0.15 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.0847015380859375 and nll_test -41.02177810668945
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.02 and nll loss -41.08
# Epoch: 2/19, i/N: 220/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 230/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 240/400 with KL 0.03 and nll loss -41.07
# Epoch: 2/19, i/N: 250/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 260/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 270/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 280/400 with KL 0.16 and nll loss -40.95
# Epoch: 2/19, i/N: 290/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 300/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.08356857299804688 and nll_test -41.022911071777344
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 320/400 with KL 0.02 and nll loss -41.09
# Epoch: 2/19, i/N: 330/400 with KL 0.16 and nll loss -40.95
# Epoch: 2/19, i/N: 340/400 with KL 0.23 and nll loss -40.88
# Epoch: 2/19, i/N: 350/400 with KL 0.15 and nll loss -40.96
# Epoch: 2/19, i/N: 360/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 370/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 380/400 with KL 0.10 and nll loss -41.00
# Epoch: 2/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.08449554443359375 and nll_test -41.0219841003418
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.06 and nll loss -41.04
# Epoch: 3/19, i/N: 20/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 30/400 with KL 0.15 and nll loss -40.95
# Epoch: 3/19, i/N: 40/400 with KL 0.12 and nll loss -40.98
# Epoch: 3/19, i/N: 50/400 with KL 0.05 and nll loss -41.05
# Epoch: 3/19, i/N: 60/400 with KL 0.11 and nll loss -40.99
# Epoch: 3/19, i/N: 70/400 with KL 0.11 and nll loss -40.99
# Epoch: 3/19, i/N: 80/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 90/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 100/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.07895660400390625 and nll_test -41.027523040771484
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.09 and nll loss -41.01
# Epoch: 3/19, i/N: 120/400 with KL 0.02 and nll loss -41.09
# Epoch: 3/19, i/N: 130/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 140/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 150/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 160/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 170/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 180/400 with KL 0.08 and nll loss -41.02
# Epoch: 3/19, i/N: 190/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 200/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.08092498779296875 and nll_test -41.02555465698242
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.06 and nll loss -41.04
# Epoch: 3/19, i/N: 220/400 with KL 0.13 and nll loss -40.98
# Epoch: 3/19, i/N: 230/400 with KL 0.06 and nll loss -41.04
# Epoch: 3/19, i/N: 240/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 250/400 with KL -0.00 and nll loss -41.11
# Epoch: 3/19, i/N: 260/400 with KL -0.01 and nll loss -41.11
# Epoch: 3/19, i/N: 270/400 with KL -0.01 and nll loss -41.11
# Epoch: 3/19, i/N: 280/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 290/400 with KL 0.15 and nll loss -40.96
# Epoch: 3/19, i/N: 300/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.07486724853515625 and nll_test -41.031612396240234
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.09 and nll loss -41.01
# Epoch: 3/19, i/N: 320/400 with KL 0.03 and nll loss -41.07
# Epoch: 3/19, i/N: 330/400 with KL 0.05 and nll loss -41.05
# Epoch: 3/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 350/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 360/400 with KL 0.05 and nll loss -41.06
# Epoch: 3/19, i/N: 370/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 380/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 390/400 with KL 0.05 and nll loss -41.06
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.08160018920898438 and nll_test -41.024879455566406
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 20/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 30/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 40/400 with KL 0.02 and nll loss -41.09
# Epoch: 4/19, i/N: 50/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 60/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 70/400 with KL 0.02 and nll loss -41.09
# Epoch: 4/19, i/N: 80/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 90/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 100/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.07424163818359375 and nll_test -41.0322380065918
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.16 and nll loss -40.95
# Epoch: 4/19, i/N: 120/400 with KL 0.04 and nll loss -41.07
# Epoch: 4/19, i/N: 130/400 with KL 0.12 and nll loss -40.98
# Epoch: 4/19, i/N: 140/400 with KL 0.14 and nll loss -40.96
# Epoch: 4/19, i/N: 150/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 160/400 with KL 0.01 and nll loss -41.10
# Epoch: 4/19, i/N: 170/400 with KL 0.06 and nll loss -41.04
# Epoch: 4/19, i/N: 180/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 190/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 200/400 with KL 0.16 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.07097244262695312 and nll_test -41.03550720214844
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL -0.00 and nll loss -41.11
# Epoch: 4/19, i/N: 220/400 with KL 0.18 and nll loss -40.93
# Epoch: 4/19, i/N: 230/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 240/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 250/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 260/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 270/400 with KL 0.19 and nll loss -40.91
# Epoch: 4/19, i/N: 280/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 290/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 300/400 with KL 0.11 and nll loss -40.99
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.080352783203125 and nll_test -41.026126861572266
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL -0.03 and nll loss -41.14
# Epoch: 4/19, i/N: 320/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 330/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 340/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 350/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 360/400 with KL 0.07 and nll loss -41.03
# Epoch: 4/19, i/N: 370/400 with KL 0.07 and nll loss -41.03
# Epoch: 4/19, i/N: 380/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 390/400 with KL 0.10 and nll loss -41.00
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.09 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.07953262329101562 and nll_test -41.026947021484375
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.25
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 5/19, i/N: 30/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 40/400 with KL 0.09 and nll loss -41.01
# Epoch: 5/19, i/N: 50/400 with KL 0.08 and nll loss -41.02
# Epoch: 5/19, i/N: 60/400 with KL 0.05 and nll loss -41.05
# Epoch: 5/19, i/N: 70/400 with KL 0.01 and nll loss -41.10
# Epoch: 5/19, i/N: 80/400 with KL 0.05 and nll loss -41.05
# Epoch: 5/19, i/N: 90/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 100/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.07386016845703125 and nll_test -41.03261947631836
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 130/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 140/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 150/400 with KL 0.08 and nll loss -41.03
# Epoch: 5/19, i/N: 160/400 with KL 0.04 and nll loss -41.06
# Epoch: 5/19, i/N: 170/400 with KL 0.08 and nll loss -41.03
# Epoch: 5/19, i/N: 180/400 with KL 0.14 and nll loss -40.96
# Epoch: 5/19, i/N: 190/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 200/400 with KL 0.12 and nll loss -40.99
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.07033920288085938 and nll_test -41.03614044189453
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 220/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 230/400 with KL 0.04 and nll loss -41.06
# Epoch: 5/19, i/N: 240/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 250/400 with KL 0.08 and nll loss -41.03
# Epoch: 5/19, i/N: 260/400 with KL 0.08 and nll loss -41.03
# Epoch: 5/19, i/N: 270/400 with KL 0.13 and nll loss -40.97
# Epoch: 5/19, i/N: 280/400 with KL 0.04 and nll loss -41.06
# Epoch: 5/19, i/N: 290/400 with KL 0.06 and nll loss -41.04
# Epoch: 5/19, i/N: 300/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.06739044189453125 and nll_test -41.03908920288086
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL -0.03 and nll loss -41.14
# Epoch: 5/19, i/N: 320/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 330/400 with KL 0.02 and nll loss -41.09
# Epoch: 5/19, i/N: 340/400 with KL 0.03 and nll loss -41.08
# Epoch: 5/19, i/N: 350/400 with KL 0.07 and nll loss -41.03
# Epoch: 5/19, i/N: 360/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 370/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 380/400 with KL 0.16 and nll loss -40.95
# Epoch: 5/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.07074737548828125 and nll_test -41.03573226928711
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 30/400 with KL -0.11 and nll loss -41.21
# Epoch: 6/19, i/N: 40/400 with KL -0.04 and nll loss -41.15
# Epoch: 6/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 6/19, i/N: 60/400 with KL 0.05 and nll loss -41.06
# Epoch: 6/19, i/N: 70/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 80/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 90/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 100/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.0728607177734375 and nll_test -41.03361892700195
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.28
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.02 and nll loss -41.09
# Epoch: 6/19, i/N: 120/400 with KL 0.03 and nll loss -41.07
# Epoch: 6/19, i/N: 130/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 140/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 150/400 with KL -0.00 and nll loss -41.11
# Epoch: 6/19, i/N: 160/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 170/400 with KL -0.01 and nll loss -41.12
# Epoch: 6/19, i/N: 180/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 200/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.07007598876953125 and nll_test -41.03640365600586
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.11 and nll loss -41.00
# Epoch: 6/19, i/N: 220/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 230/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 240/400 with KL 0.20 and nll loss -40.91
# Epoch: 6/19, i/N: 250/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 260/400 with KL 0.02 and nll loss -41.09
# Epoch: 6/19, i/N: 270/400 with KL 0.14 and nll loss -40.96
# Epoch: 6/19, i/N: 280/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 290/400 with KL 0.12 and nll loss -40.98
# Epoch: 6/19, i/N: 300/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.06390762329101562 and nll_test -41.042572021484375
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.13 and nll loss -40.98
# Epoch: 6/19, i/N: 320/400 with KL 0.03 and nll loss -41.08
# Epoch: 6/19, i/N: 330/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 350/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 360/400 with KL -0.01 and nll loss -41.11
# Epoch: 6/19, i/N: 370/400 with KL 0.04 and nll loss -41.07
# Epoch: 6/19, i/N: 380/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 390/400 with KL 0.08 and nll loss -41.02
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL -0.01 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.06791305541992188 and nll_test -41.03856658935547
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 20/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 30/400 with KL 0.11 and nll loss -41.00
# Epoch: 7/19, i/N: 40/400 with KL 0.03 and nll loss -41.08
# Epoch: 7/19, i/N: 50/400 with KL 0.05 and nll loss -41.05
# Epoch: 7/19, i/N: 60/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 70/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 80/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 90/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 100/400 with KL 0.01 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.068511962890625 and nll_test -41.037967681884766
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 120/400 with KL 0.07 and nll loss -41.04
# Epoch: 7/19, i/N: 130/400 with KL 0.15 and nll loss -40.96
# Epoch: 7/19, i/N: 140/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 150/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 160/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 170/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 180/400 with KL 0.03 and nll loss -41.08
# Epoch: 7/19, i/N: 190/400 with KL 0.05 and nll loss -41.05
# Epoch: 7/19, i/N: 200/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.06936264038085938 and nll_test -41.03711700439453
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 220/400 with KL 0.15 and nll loss -40.96
# Epoch: 7/19, i/N: 230/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 240/400 with KL 0.10 and nll loss -41.00
# Epoch: 7/19, i/N: 250/400 with KL 0.17 and nll loss -40.94
# Epoch: 7/19, i/N: 260/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 270/400 with KL 0.01 and nll loss -41.10
# Epoch: 7/19, i/N: 280/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 290/400 with KL 0.04 and nll loss -41.06
# Epoch: 7/19, i/N: 300/400 with KL 0.11 and nll loss -40.99
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.06328201293945312 and nll_test -41.04319763183594
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.03 and nll loss -41.07
# Epoch: 7/19, i/N: 320/400 with KL 0.01 and nll loss -41.10
# Epoch: 7/19, i/N: 330/400 with KL 0.01 and nll loss -41.09
# Epoch: 7/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 350/400 with KL -0.02 and nll loss -41.13
# Epoch: 7/19, i/N: 360/400 with KL -0.01 and nll loss -41.12
# Epoch: 7/19, i/N: 370/400 with KL -0.02 and nll loss -41.13
# Epoch: 7/19, i/N: 380/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 390/400 with KL 0.14 and nll loss -40.96
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.06421279907226562 and nll_test -41.042266845703125
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.25
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.09 and nll loss -41.01
# Epoch: 8/19, i/N: 20/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 30/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 40/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 50/400 with KL 0.07 and nll loss -41.03
# Epoch: 8/19, i/N: 60/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 70/400 with KL 0.11 and nll loss -40.99
# Epoch: 8/19, i/N: 80/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 90/400 with KL 0.08 and nll loss -41.02
# Epoch: 8/19, i/N: 100/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.06359100341796875 and nll_test -41.04288864135742
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.09 and nll loss -41.01
# Epoch: 8/19, i/N: 120/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 130/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 140/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 150/400 with KL 0.17 and nll loss -40.94
# Epoch: 8/19, i/N: 160/400 with KL 0.09 and nll loss -41.02
# Epoch: 8/19, i/N: 170/400 with KL -0.01 and nll loss -41.11
# Epoch: 8/19, i/N: 180/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 190/400 with KL 0.05 and nll loss -41.05
# Epoch: 8/19, i/N: 200/400 with KL -0.03 and nll loss -41.13
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.070281982421875 and nll_test -41.036197662353516
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.13 and nll loss -40.97
# Epoch: 8/19, i/N: 220/400 with KL 0.05 and nll loss -41.05
# Epoch: 8/19, i/N: 230/400 with KL -0.01 and nll loss -41.12
# Epoch: 8/19, i/N: 240/400 with KL 0.09 and nll loss -41.02
# Epoch: 8/19, i/N: 250/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 260/400 with KL 0.11 and nll loss -41.00
# Epoch: 8/19, i/N: 270/400 with KL 0.09 and nll loss -41.01
# Epoch: 8/19, i/N: 280/400 with KL 0.11 and nll loss -41.00
# Epoch: 8/19, i/N: 290/400 with KL 0.11 and nll loss -41.00
# Epoch: 8/19, i/N: 300/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.06722640991210938 and nll_test -41.03925323486328
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 320/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 330/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 340/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 350/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 360/400 with KL 0.14 and nll loss -40.96
# Epoch: 8/19, i/N: 370/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 380/400 with KL 0.19 and nll loss -40.91
# Epoch: 8/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.14 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.06505584716796875 and nll_test -41.04142379760742
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.25
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.09 and nll loss -41.01
# Epoch: 9/19, i/N: 20/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 30/400 with KL 0.10 and nll loss -41.01
# Epoch: 9/19, i/N: 40/400 with KL -0.02 and nll loss -41.12
# Epoch: 9/19, i/N: 50/400 with KL -0.04 and nll loss -41.14
# Epoch: 9/19, i/N: 60/400 with KL 0.09 and nll loss -41.01
# Epoch: 9/19, i/N: 70/400 with KL 0.10 and nll loss -41.01
# Epoch: 9/19, i/N: 80/400 with KL 0.01 and nll loss -41.10
# Epoch: 9/19, i/N: 90/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 100/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.06521987915039062 and nll_test -41.041259765625
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.00
# Epoch: 9/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.05 and nll loss -41.05
# Epoch: 9/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 130/400 with KL -0.01 and nll loss -41.12
# Epoch: 9/19, i/N: 140/400 with KL 0.06 and nll loss -41.04
# Epoch: 9/19, i/N: 150/400 with KL 0.15 and nll loss -40.96
# Epoch: 9/19, i/N: 160/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 170/400 with KL 0.05 and nll loss -41.05
# Epoch: 9/19, i/N: 180/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 190/400 with KL 0.06 and nll loss -41.05
# Epoch: 9/19, i/N: 200/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.0647125244140625 and nll_test -41.04176712036133
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 0.99
# Epoch: 9/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL 0.12 and nll loss -40.98
# Epoch: 9/19, i/N: 220/400 with KL 0.03 and nll loss -41.08
# Epoch: 9/19, i/N: 230/400 with KL 0.11 and nll loss -40.99
# Epoch: 9/19, i/N: 240/400 with KL -0.00 and nll loss -41.11
# Epoch: 9/19, i/N: 250/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 260/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 270/400 with KL 0.10 and nll loss -41.00
# Epoch: 9/19, i/N: 280/400 with KL 0.03 and nll loss -41.08
# Epoch: 9/19, i/N: 290/400 with KL 0.11 and nll loss -41.00
# Epoch: 9/19, i/N: 300/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.06203460693359375 and nll_test -41.0444450378418
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 1.00
# Epoch: 9/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.01 and nll loss -41.10
# Epoch: 9/19, i/N: 320/400 with KL 0.03 and nll loss -41.08
# Epoch: 9/19, i/N: 330/400 with KL 0.03 and nll loss -41.07
# Epoch: 9/19, i/N: 340/400 with KL -0.01 and nll loss -41.12
# Epoch: 9/19, i/N: 350/400 with KL 0.16 and nll loss -40.94
# Epoch: 9/19, i/N: 360/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 370/400 with KL 0.11 and nll loss -41.00
# ...
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 20/400 with KL 0.05 and nll loss -41.05
# Epoch: 16/19, i/N: 30/400 with KL 0.12 and nll loss -40.99
# Epoch: 16/19, i/N: 40/400 with KL 0.15 and nll loss -40.96
# Epoch: 16/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 60/400 with KL 0.14 and nll loss -40.97
# Epoch: 16/19, i/N: 70/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 80/400 with KL 0.05 and nll loss -41.05
# Epoch: 16/19, i/N: 90/400 with KL 0.02 and nll loss -41.08
# Epoch: 16/19, i/N: 100/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.055240631103515625 and nll_test -41.051239013671875
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.28
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.21 and nll loss -40.90
# Epoch: 16/19, i/N: 120/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 130/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 140/400 with KL 0.00 and nll loss -41.10
# Epoch: 16/19, i/N: 150/400 with KL 0.01 and nll loss -41.10
# Epoch: 16/19, i/N: 160/400 with KL 0.01 and nll loss -41.09
# Epoch: 16/19, i/N: 170/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 180/400 with KL 0.04 and nll loss -41.07
# Epoch: 16/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 200/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.05724334716796875 and nll_test -41.04923629760742
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.28
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.01 and nll loss -41.09
# Epoch: 16/19, i/N: 220/400 with KL -0.02 and nll loss -41.13
# Epoch: 16/19, i/N: 230/400 with KL 0.01 and nll loss -41.09
# Epoch: 16/19, i/N: 240/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 250/400 with KL 0.12 and nll loss -40.99
# Epoch: 16/19, i/N: 260/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 270/400 with KL 0.02 and nll loss -41.08
# Epoch: 16/19, i/N: 280/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 290/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 300/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.058086395263671875 and nll_test -41.04839324951172
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL -0.02 and nll loss -41.13
# Epoch: 16/19, i/N: 320/400 with KL 0.09 and nll loss -41.01
# Epoch: 16/19, i/N: 330/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 340/400 with KL 0.03 and nll loss -41.07
# Epoch: 16/19, i/N: 350/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 360/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 370/400 with KL 0.03 and nll loss -41.08
# Epoch: 16/19, i/N: 380/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 390/400 with KL 0.02 and nll loss -41.09
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.050807952880859375 and nll_test -41.05567169189453
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.29
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 20/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 40/400 with KL 0.08 and nll loss -41.02
# Epoch: 17/19, i/N: 50/400 with KL -0.01 and nll loss -41.11
# Epoch: 17/19, i/N: 60/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 70/400 with KL 0.11 and nll loss -41.00
# Epoch: 17/19, i/N: 80/400 with KL -0.02 and nll loss -41.13
# Epoch: 17/19, i/N: 90/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 100/400 with KL -0.03 and nll loss -41.14
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.0580291748046875 and nll_test -41.0484504699707
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.29
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.13 and nll loss -40.98
# Epoch: 17/19, i/N: 120/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 130/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 140/400 with KL 0.04 and nll loss -41.07
# Epoch: 17/19, i/N: 150/400 with KL 0.03 and nll loss -41.08
# Epoch: 17/19, i/N: 160/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 170/400 with KL 0.11 and nll loss -40.99
# Epoch: 17/19, i/N: 180/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 190/400 with KL 0.04 and nll loss -41.06
# Epoch: 17/19, i/N: 200/400 with KL 0.01 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.052463531494140625 and nll_test -41.05401611328125
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.29
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 0.99
# Epoch: 17/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.01 and nll loss -41.10
# Epoch: 17/19, i/N: 220/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 230/400 with KL 0.11 and nll loss -40.99
# Epoch: 17/19, i/N: 240/400 with KL -0.00 and nll loss -41.11
# Epoch: 17/19, i/N: 250/400 with KL 0.02 and nll loss -41.08
# Epoch: 17/19, i/N: 260/400 with KL -0.00 and nll loss -41.11
# Epoch: 17/19, i/N: 270/400 with KL 0.03 and nll loss -41.08
# Epoch: 17/19, i/N: 280/400 with KL 0.07 and nll loss -41.04
# Epoch: 17/19, i/N: 290/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 300/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.059123992919921875 and nll_test -41.04735565185547
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.01 and nll loss -41.10
# Epoch: 17/19, i/N: 320/400 with KL 0.01 and nll loss -41.10
# Epoch: 17/19, i/N: 330/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 340/400 with KL 0.00 and nll loss -41.11
# Epoch: 17/19, i/N: 350/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 360/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 370/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 380/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 390/400 with KL -0.10 and nll loss -41.21
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.060047149658203125 and nll_test -41.04643249511719
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 20/400 with KL 0.17 and nll loss -40.94
# Epoch: 18/19, i/N: 30/400 with KL 0.04 and nll loss -41.06
# Epoch: 18/19, i/N: 40/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 60/400 with KL -0.03 and nll loss -41.14
# Epoch: 18/19, i/N: 70/400 with KL -0.01 and nll loss -41.12
# Epoch: 18/19, i/N: 80/400 with KL -0.03 and nll loss -41.14
# Epoch: 18/19, i/N: 90/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 100/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.057369232177734375 and nll_test -41.049110412597656
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.28
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 120/400 with KL -0.01 and nll loss -41.12
# Epoch: 18/19, i/N: 130/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 140/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 150/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 160/400 with KL -0.03 and nll loss -41.13
# Epoch: 18/19, i/N: 170/400 with KL 0.05 and nll loss -41.06
# Epoch: 18/19, i/N: 180/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 190/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 200/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.056884765625 and nll_test -41.04959487915039
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 220/400 with KL 0.05 and nll loss -41.06
# Epoch: 18/19, i/N: 230/400 with KL -0.00 and nll loss -41.11
# Epoch: 18/19, i/N: 240/400 with KL 0.08 and nll loss -41.02
# Epoch: 18/19, i/N: 250/400 with KL 0.13 and nll loss -40.97
# Epoch: 18/19, i/N: 260/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 270/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 280/400 with KL -0.02 and nll loss -41.13
# Epoch: 18/19, i/N: 290/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 300/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.057018280029296875 and nll_test -41.049461364746094
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 320/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 330/400 with KL 0.10 and nll loss -41.00
# Epoch: 18/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 18/19, i/N: 350/400 with KL 0.15 and nll loss -40.96
# Epoch: 18/19, i/N: 360/400 with KL -0.04 and nll loss -41.15
# Epoch: 18/19, i/N: 370/400 with KL 0.07 and nll loss -41.03
# Epoch: 18/19, i/N: 380/400 with KL 0.02 and nll loss -41.09
# Epoch: 18/19, i/N: 390/400 with KL 0.02 and nll loss -41.08
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.057170867919921875 and nll_test -41.04930877685547
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 20/400 with KL 0.17 and nll loss -40.94
# Epoch: 19/19, i/N: 30/400 with KL 0.07 and nll loss -41.04
# Epoch: 19/19, i/N: 40/400 with KL 0.08 and nll loss -41.02
# Epoch: 19/19, i/N: 50/400 with KL -0.03 and nll loss -41.14
# Epoch: 19/19, i/N: 60/400 with KL 0.02 and nll loss -41.08
# Epoch: 19/19, i/N: 70/400 with KL 0.10 and nll loss -41.00
# Epoch: 19/19, i/N: 80/400 with KL -0.00 and nll loss -41.11
# Epoch: 19/19, i/N: 90/400 with KL 0.03 and nll loss -41.07
# Epoch: 19/19, i/N: 100/400 with KL 0.02 and nll loss -41.08
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.05780029296875 and nll_test -41.04867935180664
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.30
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.21 and nll loss -40.90
# Epoch: 19/19, i/N: 120/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 130/400 with KL -0.01 and nll loss -41.12
# Epoch: 19/19, i/N: 140/400 with KL 0.01 and nll loss -41.09
# Epoch: 19/19, i/N: 150/400 with KL 0.10 and nll loss -41.00
# Epoch: 19/19, i/N: 160/400 with KL 0.04 and nll loss -41.07
# Epoch: 19/19, i/N: 170/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 180/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 190/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 200/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.059520721435546875 and nll_test -41.046958923339844
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 0.99
# Epoch: 19/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 220/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 230/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 240/400 with KL 0.15 and nll loss -40.96
# Epoch: 19/19, i/N: 250/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 260/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 270/400 with KL -0.02 and nll loss -41.13
# Epoch: 19/19, i/N: 280/400 with KL 0.12 and nll loss -40.99
# Epoch: 19/19, i/N: 290/400 with KL 0.15 and nll loss -40.95
# Epoch: 19/19, i/N: 300/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.056728363037109375 and nll_test -41.04975128173828
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.13 and nll loss -40.97
# Epoch: 19/19, i/N: 320/400 with KL 0.12 and nll loss -40.98
# Epoch: 19/19, i/N: 330/400 with KL 0.04 and nll loss -41.07
# Epoch: 19/19, i/N: 340/400 with KL 0.19 and nll loss -40.92
# Epoch: 19/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 360/400 with KL 0.05 and nll loss -41.05
# Epoch: 19/19, i/N: 370/400 with KL 0.01 and nll loss -41.09
# Epoch: 19/19, i/N: 380/400 with KL -0.02 and nll loss -41.13
# Epoch: 19/19, i/N: 390/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.056812286376953125 and nll_test -41.04966735839844
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.27
# #####################

# %% [markdown]
# ### Coupling Spline Flow

# %%
cou_spline = Coupling_Flow(num_flows = NUM_FLOWS_COU, 
                           num_dim_data= NUM_DIM_DATA,
                           flow_type = 'spline', 
                           num_centers = NUM_CENTERS,
                           num_bins = NUM_BINS,
                           cap_householder_refl=CAP_HOUSEHOLDER_REFL) 

cou_spline.to(device)

optimizer = optim.AdamW(cou_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Spline Flow #####')

train_model(model = cou_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name = 'cou_s')
# Out:
# ##### Coupling Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_194522" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_194522</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Coupling_Flow(
#   (scale): ModuleList(
#     (0): Rotation()
#     (1): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=576, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (2): Rotation()
#     (3): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=576, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (4): Rotation()
#     (5): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=576, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#     (6): Rotation()
#     (7): Coupling(
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=576, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=32, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=1024, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 64,
#  'HIDDEN_DIM_ROTATION_MLP': 64,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 605192,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.00157917e-01,  4.83159684e-02,  1.09778091e-01,
#         -1.69557109e-01, -2.03941818e-02,  3.48235853e-02,
#         -7.82925114e-02, -1.09136559e-01,  1.13152914e-01,
#         -6.53987676e-02, -1.41629413e-01, -5.61961234e-02,
#          8.65294561e-02,  1.23681501e-01,  2.81369332e-02,
#          1.33135065e-01, -1.93280950e-01, -3.96372974e-02,
#          2.35255316e-01, -4.03022729e-02,  2.42348555e-02,
#          9.55096558e-02,  1.26899734e-01, -8.84799734e-02,
#         -2.55654398e-02, -2.62983181e-02, -2.21743613e-01,
#         -4.21622470e-02, -2.51755446e-01,  8.23237151e-02,
#         -1.61611959e-01, -1.66060105e-01, -1.02007817e-02,
#         -2.86721345e-03,  2.12953743e-02,  2.80682266e-01,
#          1.16884917e-01, -8.08297545e-02, -1.01173684e-01,
#         -7.39679560e-02, -1.71126023e-01,  1.58435538e-01,
#          2.00396940e-01, -1.29046246e-01, -3.19459550e-02,
#         -3.05471364e-02,  6.11988381e-02,  3.17565985e-02,
#         -2.17615534e-02, -3.16909775e-02, -1.76932185e-03,
#         -4.68822122e-02, -3.62239808e-01, -1.29518971e-01,
#         -3.77357900e-02,  1.14098795e-01,  1.98367640e-01,
#          1.91400992e-04, -5.34341186e-02, -2.57502019e-01,
#          1.39832631e-01, -4.66737896e-02, -4.33864258e-02,
#          9.21048298e-02],
#        [ 1.90074500e-02,  2.60411873e-02, -7.34153613e-02,
#          1.14198759e-01, -1.77348390e-01, -2.45047510e-01,
#         -8.30812007e-02, -8.77825767e-02, -1.26364231e-01,
#          1.70761779e-01,  6.66862428e-02, -2.05338895e-02,
#         -1.15837276e-01, -5.51476181e-02, -1.47932172e-01,
#          8.44565630e-02, -3.22086036e-01,  5.76755702e-02,
#          8.16275850e-02,  4.39113937e-02, -1.79599132e-02,
#         -1.36633322e-01,  2.49908283e-01,  1.39740869e-01,
#         -5.68425208e-02, -2.47033890e-02,  1.07973561e-01,
#          1.40691027e-01, -1.17738850e-01,  2.32937708e-02,
#          7.15092421e-02,  2.02650025e-01, -7.65809119e-02,
#          1.18245028e-01,  1.50797278e-01, -1.57591119e-01,
#          1.81805771e-02, -2.70232349e-03, -5.80996014e-02,
#          7.58496597e-02,  5.47281615e-02,  2.72839308e-01,
#         -1.73256159e-01,  2.52663344e-01,  7.23374635e-02,
#         -2.24806350e-02,  6.56668916e-02, -1.64511994e-01,
#         -1.60445154e-01, -4.48567010e-02,  8.92971903e-02,
#          1.29540684e-02, -8.35901946e-02, -6.98424652e-02,
#          9.12709311e-02,  8.69363174e-02, -1.16403118e-01,
#          1.64974838e-01, -1.72709599e-01,  7.23473877e-02,
#         -6.14937842e-02,  8.74846950e-02,  4.03753258e-02,
#          1.69111788e-01],
#        [ 8.03996921e-02,  1.88394841e-02,  7.91436583e-02,
#         -1.03894427e-01, -3.16554010e-02, -1.12420239e-01,
#         -3.01579207e-01, -1.05891101e-01,  2.05421910e-01,
#         -2.17842519e-01, -4.68437485e-02,  7.77946189e-02,
#          1.79144815e-02, -2.14141190e-01, -1.28987297e-01,
#          1.79710582e-01,  3.69543321e-02, -2.11171061e-02,
#          1.62856132e-01, -1.59821570e-01,  2.95013607e-01,
#         -7.50024766e-02,  1.13670453e-01,  1.04433009e-02,
#          9.55903437e-03, -7.75749460e-02, -5.82263321e-02,
#          7.62394210e-03,  1.02248378e-01, -1.53147265e-01,
#         -7.49353617e-02,  1.87370479e-02,  9.64044780e-02,
#         -1.45118386e-01, -1.11712189e-02,  2.03258339e-02,
#          1.98214769e-01, -5.88899516e-02,  2.33828742e-02,
#         -1.01145782e-01, -9.51767862e-02, -1.00689523e-01,
#         -9.76603106e-02,  3.26669775e-02, -1.06782429e-01,
#         -1.69287287e-02,  1.34891734e-01,  2.10845172e-02,
#         -6.64624944e-02, -1.19874842e-01,  1.15675263e-01,
#          2.91244667e-02,  9.90839899e-02, -9.76498947e-02,
#          4.12934907e-02,  2.06514955e-01,  4.34264876e-02,
#          1.07311860e-01,  2.16698542e-01, -1.09591521e-01,
#         -3.03995848e-01, -1.80847108e-01, -1.39791742e-01,
#         -6.19465660e-04],
#        [-4.84134592e-02,  2.52364427e-02, -1.57797530e-01,
#          1.19816773e-01,  1.73902944e-01, -1.13306522e-01,
#         -1.93215534e-01, -3.63163911e-02, -3.56696576e-01,
#         -3.12909251e-03,  1.00029714e-01,  8.97102579e-02,
#          1.01910129e-01,  7.79635534e-02,  9.18881036e-03,
#         -1.32722501e-02,  8.26334730e-02, -1.22652352e-01,
#         -1.19253814e-01, -1.16538182e-01, -9.13126916e-02,
#         -4.08998579e-01,  5.43543324e-02, -1.43570259e-01,
#         -1.53310671e-01, -2.48359591e-01, -7.12860748e-02,
#          1.55420944e-01, -3.80727760e-02, -9.34401825e-02,
#          2.00530961e-01, -6.45856699e-03,  6.38035312e-02,
#          8.77265632e-02,  1.80304080e-01, -3.99558507e-02,
#         -1.94207835e-03, -7.79024139e-02,  5.40511608e-02,
#         -6.76667765e-02, -1.74297363e-01, -2.57477742e-02,
#         -1.10576358e-02, -1.15368016e-01, -5.66938594e-02,
#          4.62486409e-02, -3.27315815e-02,  1.74612537e-01,
#         -9.70561430e-02,  1.16726570e-01, -5.90321943e-02,
#         -6.55079111e-02, -8.50142390e-02,  2.71943569e-01,
#          1.02150232e-01,  8.64362717e-03,  8.47468153e-02,
#         -3.54529545e-02, -5.58530279e-02,  1.31824212e-02,
#          1.06705502e-01, -1.09613128e-01,  1.26093216e-02,
#         -4.06794176e-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -41.10647964477539
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.34 and nll loss -40.77
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.3387794494628906 and nll_test -40.7677001953125
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.34 and nll loss -40.77
# Epoch: 0/19, i/N: 20/400 with KL 0.33 and nll loss -40.77
# Epoch: 0/19, i/N: 30/400 with KL 0.33 and nll loss -40.78
# Epoch: 0/19, i/N: 40/400 with KL 0.31 and nll loss -40.80
# Epoch: 0/19, i/N: 50/400 with KL 0.27 and nll loss -40.83
# Epoch: 0/19, i/N: 60/400 with KL 0.25 and nll loss -40.86
# Epoch: 0/19, i/N: 70/400 with KL 0.25 and nll loss -40.86
# Epoch: 0/19, i/N: 80/400 with KL 0.25 and nll loss -40.86
# Epoch: 0/19, i/N: 90/400 with KL 0.16 and nll loss -40.94
# Epoch: 0/19, i/N: 100/400 with KL 0.27 and nll loss -40.84
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.20415496826171875 and nll_test -40.90232467651367
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.13
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.14
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.19 and nll loss -40.91
# Epoch: 0/19, i/N: 120/400 with KL 0.20 and nll loss -40.91
# Epoch: 0/19, i/N: 130/400 with KL 0.18 and nll loss -40.93
# Epoch: 0/19, i/N: 140/400 with KL 0.23 and nll loss -40.88
# Epoch: 0/19, i/N: 150/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 160/400 with KL 0.24 and nll loss -40.87
# Epoch: 0/19, i/N: 170/400 with KL 0.19 and nll loss -40.92
# Epoch: 0/19, i/N: 180/400 with KL 0.17 and nll loss -40.93
# Epoch: 0/19, i/N: 190/400 with KL 0.15 and nll loss -40.96
# Epoch: 0/19, i/N: 200/400 with KL 0.19 and nll loss -40.92
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.18484878540039062 and nll_test -40.921630859375
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.15
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.16
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.18 and nll loss -40.93
# Epoch: 0/19, i/N: 220/400 with KL 0.21 and nll loss -40.90
# Epoch: 0/19, i/N: 230/400 with KL 0.13 and nll loss -40.97
# Epoch: 0/19, i/N: 240/400 with KL 0.20 and nll loss -40.90
# Epoch: 0/19, i/N: 250/400 with KL 0.19 and nll loss -40.92
# Epoch: 0/19, i/N: 260/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 270/400 with KL 0.27 and nll loss -40.83
# Epoch: 0/19, i/N: 280/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 290/400 with KL 0.21 and nll loss -40.90
# Epoch: 0/19, i/N: 300/400 with KL 0.19 and nll loss -40.92
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.17514419555664062 and nll_test -40.93133544921875
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.16
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.15
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.22 and nll loss -40.89
# Epoch: 0/19, i/N: 320/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 330/400 with KL 0.18 and nll loss -40.93
# Epoch: 0/19, i/N: 340/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 350/400 with KL 0.20 and nll loss -40.91
# Epoch: 0/19, i/N: 360/400 with KL 0.22 and nll loss -40.89
# Epoch: 0/19, i/N: 370/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 380/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 390/400 with KL 0.14 and nll loss -40.97
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.22 and nll loss -40.89
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.17252731323242188 and nll_test -40.93395233154297
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.17
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.15
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.18 and nll loss -40.92
# Epoch: 1/19, i/N: 20/400 with KL 0.15 and nll loss -40.96
# Epoch: 1/19, i/N: 30/400 with KL 0.17 and nll loss -40.94
# Epoch: 1/19, i/N: 40/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 50/400 with KL 0.18 and nll loss -40.92
# Epoch: 1/19, i/N: 60/400 with KL 0.13 and nll loss -40.97
# Epoch: 1/19, i/N: 70/400 with KL 0.24 and nll loss -40.86
# Epoch: 1/19, i/N: 80/400 with KL 0.11 and nll loss -40.99
# Epoch: 1/19, i/N: 90/400 with KL 0.18 and nll loss -40.93
# Epoch: 1/19, i/N: 100/400 with KL 0.17 and nll loss -40.94
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.15241622924804688 and nll_test -40.954063415527344
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.19
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.19
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 120/400 with KL 0.18 and nll loss -40.93
# Epoch: 1/19, i/N: 130/400 with KL 0.17 and nll loss -40.94
# Epoch: 1/19, i/N: 140/400 with KL 0.16 and nll loss -40.94
# Epoch: 1/19, i/N: 150/400 with KL 0.16 and nll loss -40.95
# Epoch: 1/19, i/N: 160/400 with KL 0.17 and nll loss -40.94
# Epoch: 1/19, i/N: 170/400 with KL 0.17 and nll loss -40.94
# Epoch: 1/19, i/N: 180/400 with KL 0.13 and nll loss -40.97
# Epoch: 1/19, i/N: 190/400 with KL 0.19 and nll loss -40.92
# Epoch: 1/19, i/N: 200/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.14449310302734375 and nll_test -40.96198654174805
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.19
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.18
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 220/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 230/400 with KL 0.17 and nll loss -40.93
# Epoch: 1/19, i/N: 240/400 with KL 0.11 and nll loss -41.00
# Epoch: 1/19, i/N: 250/400 with KL 0.23 and nll loss -40.87
# Epoch: 1/19, i/N: 260/400 with KL 0.15 and nll loss -40.96
# Epoch: 1/19, i/N: 270/400 with KL 0.15 and nll loss -40.96
# Epoch: 1/19, i/N: 280/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 290/400 with KL 0.18 and nll loss -40.93
# Epoch: 1/19, i/N: 300/400 with KL 0.14 and nll loss -40.97
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.14035415649414062 and nll_test -40.96612548828125
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.20
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.19
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.04 and nll loss -41.07
# Epoch: 1/19, i/N: 320/400 with KL 0.19 and nll loss -40.92
# Epoch: 1/19, i/N: 330/400 with KL 0.17 and nll loss -40.94
# Epoch: 1/19, i/N: 340/400 with KL 0.16 and nll loss -40.94
# Epoch: 1/19, i/N: 350/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 360/400 with KL 0.08 and nll loss -41.02
# Epoch: 1/19, i/N: 370/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 380/400 with KL 0.14 and nll loss -40.96
# Epoch: 1/19, i/N: 390/400 with KL 0.06 and nll loss -41.05
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.20 and nll loss -40.90
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.13275146484375 and nll_test -40.97372817993164
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.21
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.20
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.10 and nll loss -41.00
# Epoch: 2/19, i/N: 20/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 30/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 40/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 50/400 with KL 0.14 and nll loss -40.97
# Epoch: 2/19, i/N: 60/400 with KL 0.18 and nll loss -40.93
# Epoch: 2/19, i/N: 70/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 80/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 90/400 with KL 0.18 and nll loss -40.93
# Epoch: 2/19, i/N: 100/400 with KL 0.09 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.1306915283203125 and nll_test -40.97578811645508
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.21
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.20
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 120/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 130/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 140/400 with KL 0.14 and nll loss -40.97
# Epoch: 2/19, i/N: 150/400 with KL 0.17 and nll loss -40.94
# Epoch: 2/19, i/N: 160/400 with KL 0.19 and nll loss -40.92
# Epoch: 2/19, i/N: 170/400 with KL 0.15 and nll loss -40.96
# Epoch: 2/19, i/N: 180/400 with KL 0.15 and nll loss -40.96
# Epoch: 2/19, i/N: 190/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 200/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.12465667724609375 and nll_test -40.9818229675293
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.21
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.07 and nll loss -41.03
# Epoch: 2/19, i/N: 220/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 230/400 with KL 0.06 and nll loss -41.05
# Epoch: 2/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 250/400 with KL 0.12 and nll loss -40.98
# Epoch: 2/19, i/N: 260/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 270/400 with KL 0.17 and nll loss -40.94
# Epoch: 2/19, i/N: 280/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 290/400 with KL 0.20 and nll loss -40.91
# Epoch: 2/19, i/N: 300/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.1230010986328125 and nll_test -40.98347854614258
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.21
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 320/400 with KL 0.16 and nll loss -40.95
# Epoch: 2/19, i/N: 330/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 340/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 350/400 with KL 0.14 and nll loss -40.97
# Epoch: 2/19, i/N: 360/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 370/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 380/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 390/400 with KL 0.16 and nll loss -40.95
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.11861038208007812 and nll_test -40.98786926269531
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.16 and nll loss -40.94
# Epoch: 3/19, i/N: 20/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 30/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 40/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 50/400 with KL 0.09 and nll loss -41.01
# Epoch: 3/19, i/N: 60/400 with KL 0.10 and nll loss -41.01
# Epoch: 3/19, i/N: 70/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 80/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 90/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 100/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.11908721923828125 and nll_test -40.98739242553711
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.22
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 120/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 130/400 with KL 0.15 and nll loss -40.96
# Epoch: 3/19, i/N: 140/400 with KL 0.12 and nll loss -40.98
# Epoch: 3/19, i/N: 150/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 160/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 170/400 with KL 0.14 and nll loss -40.97
# Epoch: 3/19, i/N: 180/400 with KL 0.20 and nll loss -40.91
# Epoch: 3/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 200/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.11501312255859375 and nll_test -40.9914665222168
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.23
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.04 and nll loss -41.06
# Epoch: 3/19, i/N: 220/400 with KL 0.13 and nll loss -40.98
# Epoch: 3/19, i/N: 230/400 with KL 0.10 and nll loss -41.01
# Epoch: 3/19, i/N: 240/400 with KL 0.19 and nll loss -40.92
# Epoch: 3/19, i/N: 250/400 with KL 0.14 and nll loss -40.96
# Epoch: 3/19, i/N: 260/400 with KL 0.15 and nll loss -40.95
# Epoch: 3/19, i/N: 270/400 with KL 0.11 and nll loss -40.99
# Epoch: 3/19, i/N: 280/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 290/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 300/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.11797332763671875 and nll_test -40.98850631713867
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.22
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.23
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 320/400 with KL 0.19 and nll loss -40.92
# Epoch: 3/19, i/N: 330/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 340/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 350/400 with KL 0.18 and nll loss -40.92
# Epoch: 3/19, i/N: 360/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 370/400 with KL 0.16 and nll loss -40.95
# Epoch: 3/19, i/N: 380/400 with KL 0.14 and nll loss -40.96
# Epoch: 3/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.15 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.11060714721679688 and nll_test -40.995872497558594
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.21
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.11 and nll loss -40.99
# Epoch: 4/19, i/N: 20/400 with KL 0.13 and nll loss -40.97
# Epoch: 4/19, i/N: 30/400 with KL 0.12 and nll loss -40.99
# Epoch: 4/19, i/N: 40/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 50/400 with KL 0.10 and nll loss -41.00
# Epoch: 4/19, i/N: 60/400 with KL 0.15 and nll loss -40.96
# Epoch: 4/19, i/N: 70/400 with KL 0.15 and nll loss -40.95
# Epoch: 4/19, i/N: 80/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 90/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 100/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.10990524291992188 and nll_test -40.99657440185547
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.21
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.14 and nll loss -40.97
# Epoch: 4/19, i/N: 120/400 with KL 0.19 and nll loss -40.92
# Epoch: 4/19, i/N: 130/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 140/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 150/400 with KL 0.06 and nll loss -41.04
# Epoch: 4/19, i/N: 160/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 170/400 with KL 0.17 and nll loss -40.94
# Epoch: 4/19, i/N: 180/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 190/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 200/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.10587692260742188 and nll_test -41.00060272216797
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.02 and nll loss -41.08
# Epoch: 4/19, i/N: 220/400 with KL 0.14 and nll loss -40.97
# Epoch: 4/19, i/N: 230/400 with KL 0.19 and nll loss -40.92
# Epoch: 4/19, i/N: 240/400 with KL 0.11 and nll loss -40.99
# Epoch: 4/19, i/N: 250/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 260/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 270/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 280/400 with KL 0.18 and nll loss -40.93
# Epoch: 4/19, i/N: 290/400 with KL 0.11 and nll loss -40.99
# Epoch: 4/19, i/N: 300/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.11104965209960938 and nll_test -40.99542999267578
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.23
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.12 and nll loss -40.98
# Epoch: 4/19, i/N: 320/400 with KL 0.12 and nll loss -40.99
# Epoch: 4/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 340/400 with KL 0.19 and nll loss -40.92
# Epoch: 4/19, i/N: 350/400 with KL 0.12 and nll loss -40.99
# Epoch: 4/19, i/N: 360/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 370/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 380/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.10643768310546875 and nll_test -41.00004196166992
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.23
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.11 and nll loss -40.99
# Epoch: 5/19, i/N: 20/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 30/400 with KL 0.06 and nll loss -41.05
# Epoch: 5/19, i/N: 40/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 50/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 60/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 70/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 80/400 with KL 0.08 and nll loss -41.02
# Epoch: 5/19, i/N: 90/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 100/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.1068267822265625 and nll_test -40.99965286254883
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.23
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.08 and nll loss -41.02
# Epoch: 5/19, i/N: 120/400 with KL 0.06 and nll loss -41.05
# Epoch: 5/19, i/N: 130/400 with KL 0.15 and nll loss -40.96
# Epoch: 5/19, i/N: 140/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 150/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 160/400 with KL 0.11 and nll loss -40.99
# Epoch: 5/19, i/N: 170/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 180/400 with KL 0.15 and nll loss -40.95
# Epoch: 5/19, i/N: 190/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 200/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.10372161865234375 and nll_test -41.00275802612305
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.23
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.06 and nll loss -41.04
# Epoch: 5/19, i/N: 220/400 with KL 0.18 and nll loss -40.93
# Epoch: 5/19, i/N: 230/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 240/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 250/400 with KL 0.01 and nll loss -41.10
# Epoch: 5/19, i/N: 260/400 with KL 0.06 and nll loss -41.04
# Epoch: 5/19, i/N: 270/400 with KL 0.07 and nll loss -41.03
# Epoch: 5/19, i/N: 280/400 with KL 0.10 and nll loss -41.00
# Epoch: 5/19, i/N: 290/400 with KL 0.11 and nll loss -40.99
# Epoch: 5/19, i/N: 300/400 with KL -0.02 and nll loss -41.13
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.11149978637695312 and nll_test -40.99497985839844
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 320/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 330/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 340/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 350/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 360/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 370/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 380/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 390/400 with KL 0.04 and nll loss -41.07
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.10241317749023438 and nll_test -41.004066467285156
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.23
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.13 and nll loss -40.98
# Epoch: 6/19, i/N: 20/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 30/400 with KL 0.06 and nll loss -41.05
# Epoch: 6/19, i/N: 40/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 50/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 60/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 70/400 with KL 0.15 and nll loss -40.96
# Epoch: 6/19, i/N: 80/400 with KL 0.04 and nll loss -41.06
# Epoch: 6/19, i/N: 90/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 100/400 with KL 0.17 and nll loss -40.94
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.10424423217773438 and nll_test -41.002235412597656
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.23
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.23
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.16 and nll loss -40.94
# Epoch: 6/19, i/N: 120/400 with KL -0.02 and nll loss -41.12
# Epoch: 6/19, i/N: 130/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 140/400 with KL 0.06 and nll loss -41.04
# Epoch: 6/19, i/N: 150/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 160/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 170/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 180/400 with KL 0.15 and nll loss -40.96
# Epoch: 6/19, i/N: 190/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 200/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.100189208984375 and nll_test -41.006290435791016
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 220/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 230/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 240/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 250/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 260/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 270/400 with KL 0.18 and nll loss -40.93
# Epoch: 6/19, i/N: 280/400 with KL 0.13 and nll loss -40.97
# Epoch: 6/19, i/N: 290/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 300/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.10286331176757812 and nll_test -41.00361633300781
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.23
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.17 and nll loss -40.94
# Epoch: 6/19, i/N: 320/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 330/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 340/400 with KL 0.13 and nll loss -40.97
# Epoch: 6/19, i/N: 350/400 with KL 0.14 and nll loss -40.96
# Epoch: 6/19, i/N: 360/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 370/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 380/400 with KL 0.09 and nll loss -41.01
# Epoch: 6/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL -0.02 and nll loss -41.12
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.096954345703125 and nll_test -41.009525299072266
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 20/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 30/400 with KL -0.05 and nll loss -41.15
# Epoch: 7/19, i/N: 40/400 with KL 0.04 and nll loss -41.07
# Epoch: 7/19, i/N: 50/400 with KL 0.10 and nll loss -41.00
# Epoch: 7/19, i/N: 60/400 with KL 0.14 and nll loss -40.97
# Epoch: 7/19, i/N: 70/400 with KL 0.12 and nll loss -40.98
# Epoch: 7/19, i/N: 80/400 with KL 0.15 and nll loss -40.95
# Epoch: 7/19, i/N: 90/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 100/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.09990310668945312 and nll_test -41.00657653808594
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.22
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.10 and nll loss -41.00
# Epoch: 7/19, i/N: 120/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 130/400 with KL 0.15 and nll loss -40.96
# Epoch: 7/19, i/N: 140/400 with KL 0.11 and nll loss -40.99
# Epoch: 7/19, i/N: 150/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 160/400 with KL 0.16 and nll loss -40.95
# Epoch: 7/19, i/N: 170/400 with KL 0.11 and nll loss -41.00
# Epoch: 7/19, i/N: 180/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 200/400 with KL 0.16 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.09621047973632812 and nll_test -41.01026916503906
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.23
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.00 and nll loss -41.10
# Epoch: 7/19, i/N: 220/400 with KL 0.11 and nll loss -40.99
# Epoch: 7/19, i/N: 230/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 240/400 with KL 0.11 and nll loss -40.99
# Epoch: 7/19, i/N: 250/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 260/400 with KL 0.05 and nll loss -41.05
# Epoch: 7/19, i/N: 270/400 with KL 0.16 and nll loss -40.94
# Epoch: 7/19, i/N: 280/400 with KL 0.14 and nll loss -40.97
# Epoch: 7/19, i/N: 290/400 with KL 0.17 and nll loss -40.93
# Epoch: 7/19, i/N: 300/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.0933074951171875 and nll_test -41.0131721496582
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 320/400 with KL 0.09 and nll loss -41.01
# Epoch: 7/19, i/N: 330/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 350/400 with KL 0.09 and nll loss -41.01
# Epoch: 7/19, i/N: 360/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 370/400 with KL 0.13 and nll loss -40.98
# Epoch: 7/19, i/N: 380/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 390/400 with KL 0.10 and nll loss -41.01
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.09655380249023438 and nll_test -41.009925842285156
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.25
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.00 and nll loss -41.11
# Epoch: 8/19, i/N: 20/400 with KL 0.09 and nll loss -41.02
# Epoch: 8/19, i/N: 30/400 with KL 0.13 and nll loss -40.97
# Epoch: 8/19, i/N: 40/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 50/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 60/400 with KL 0.03 and nll loss -41.07
# Epoch: 8/19, i/N: 70/400 with KL 0.17 and nll loss -40.94
# Epoch: 8/19, i/N: 80/400 with KL 0.17 and nll loss -40.93
# Epoch: 8/19, i/N: 90/400 with KL 0.11 and nll loss -40.99
# Epoch: 8/19, i/N: 100/400 with KL 0.10 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.09600448608398438 and nll_test -41.010475158691406
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.11 and nll loss -40.99
# Epoch: 8/19, i/N: 120/400 with KL 0.13 and nll loss -40.97
# Epoch: 8/19, i/N: 130/400 with KL 0.12 and nll loss -40.99
# Epoch: 8/19, i/N: 140/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 150/400 with KL 0.17 and nll loss -40.94
# Epoch: 8/19, i/N: 160/400 with KL 0.16 and nll loss -40.95
# Epoch: 8/19, i/N: 170/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 180/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 190/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 200/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.09154129028320312 and nll_test -41.01493835449219
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 220/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 230/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 250/400 with KL 0.13 and nll loss -40.97
# Epoch: 8/19, i/N: 260/400 with KL 0.07 and nll loss -41.04
# Epoch: 8/19, i/N: 270/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 280/400 with KL 0.08 and nll loss -41.02
# Epoch: 8/19, i/N: 290/400 with KL 0.07 and nll loss -41.03
# Epoch: 8/19, i/N: 300/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.09057235717773438 and nll_test -41.015907287597656
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 320/400 with KL 0.06 and nll loss -41.04
# Epoch: 8/19, i/N: 330/400 with KL 0.12 and nll loss -40.99
# Epoch: 8/19, i/N: 340/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 350/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 360/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 370/400 with KL 0.02 and nll loss -41.09
# Epoch: 8/19, i/N: 380/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 390/400 with KL 0.12 and nll loss -40.99
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.09461212158203125 and nll_test -41.01186752319336
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.22
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 20/400 with KL 0.06 and nll loss -41.05
# Epoch: 9/19, i/N: 30/400 with KL 0.14 and nll loss -40.97
# Epoch: 9/19, i/N: 40/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 50/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 60/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 70/400 with KL 0.12 and nll loss -40.99
# Epoch: 9/19, i/N: 80/400 with KL 0.17 and nll loss -40.94
# Epoch: 9/19, i/N: 90/400 with KL 0.09 and nll loss -41.01
# Epoch: 9/19, i/N: 100/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 100/400 KL_test 0.09516143798828125 and nll_test -41.01131820678711
#
# From current batch
# Epoch: 9, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 100/400 MC density sum 1.00
# Epoch: 9/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 9/19, i/N: 110/400 with KL 0.11 and nll loss -40.99
# Epoch: 9/19, i/N: 120/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 130/400 with KL 0.10 and nll loss -41.01
# Epoch: 9/19, i/N: 140/400 with KL 0.16 and nll loss -40.94
# Epoch: 9/19, i/N: 150/400 with KL 0.16 and nll loss -40.94
# Epoch: 9/19, i/N: 160/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 170/400 with KL 0.08 and nll loss -41.02
# Epoch: 9/19, i/N: 180/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 190/400 with KL 0.13 and nll loss -40.97
# Epoch: 9/19, i/N: 200/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 200/400 KL_test 0.09246444702148438 and nll_test -41.014015197753906
#
# From current batch
# Epoch: 9, i/N: 200/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 200/400 MC density sum 1.00
# Epoch: 9/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 9/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 220/400 with KL 0.01 and nll loss -41.10
# Epoch: 9/19, i/N: 230/400 with KL 0.16 and nll loss -40.95
# Epoch: 9/19, i/N: 240/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 250/400 with KL 0.12 and nll loss -40.99
# Epoch: 9/19, i/N: 260/400 with KL 0.02 and nll loss -41.08
# Epoch: 9/19, i/N: 270/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 280/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 290/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 300/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 300/400 KL_test 0.09249114990234375 and nll_test -41.01398849487305
#
# From current batch
# Epoch: 9, i/N: 300/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 300/400 MC density sum 1.00
# Epoch: 9/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 9/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 9/19, i/N: 320/400 with KL 0.10 and nll loss -41.01
# Epoch: 9/19, i/N: 330/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 9/19, i/N: 350/400 with KL 0.11 and nll loss -41.00
# Epoch: 9/19, i/N: 360/400 with KL 0.13 and nll loss -40.98
# Epoch: 9/19, i/N: 370/400 with KL 0.10 and nll loss -41.00
# ...
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 20/400 with KL 0.12 and nll loss -40.99
# Epoch: 16/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 40/400 with KL 0.08 and nll loss -41.02
# Epoch: 16/19, i/N: 50/400 with KL 0.16 and nll loss -40.95
# Epoch: 16/19, i/N: 60/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 70/400 with KL 0.13 and nll loss -40.98
# Epoch: 16/19, i/N: 80/400 with KL 0.14 and nll loss -40.97
# Epoch: 16/19, i/N: 90/400 with KL -0.02 and nll loss -41.13
# Epoch: 16/19, i/N: 100/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.08339691162109375 and nll_test -41.0230827331543
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL -0.03 and nll loss -41.14
# Epoch: 16/19, i/N: 120/400 with KL 0.17 and nll loss -40.94
# Epoch: 16/19, i/N: 130/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 140/400 with KL 0.01 and nll loss -41.10
# Epoch: 16/19, i/N: 150/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 160/400 with KL 0.07 and nll loss -41.03
# Epoch: 16/19, i/N: 170/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 180/400 with KL 0.09 and nll loss -41.01
# Epoch: 16/19, i/N: 190/400 with KL 0.16 and nll loss -40.95
# Epoch: 16/19, i/N: 200/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.07637405395507812 and nll_test -41.03010559082031
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.24
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.13 and nll loss -40.97
# Epoch: 16/19, i/N: 220/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 230/400 with KL 0.09 and nll loss -41.01
# Epoch: 16/19, i/N: 240/400 with KL 0.14 and nll loss -40.97
# Epoch: 16/19, i/N: 250/400 with KL 0.14 and nll loss -40.96
# Epoch: 16/19, i/N: 260/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 270/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 280/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 290/400 with KL 0.13 and nll loss -40.97
# Epoch: 16/19, i/N: 300/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.08116531372070312 and nll_test -41.02531433105469
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.11 and nll loss -40.99
# Epoch: 16/19, i/N: 320/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 330/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 340/400 with KL 0.10 and nll loss -41.01
# Epoch: 16/19, i/N: 350/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 360/400 with KL 0.03 and nll loss -41.08
# Epoch: 16/19, i/N: 370/400 with KL 0.16 and nll loss -40.94
# Epoch: 16/19, i/N: 380/400 with KL 0.04 and nll loss -41.07
# Epoch: 16/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.10 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.086639404296875 and nll_test -41.019840240478516
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.23
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 20/400 with KL 0.01 and nll loss -41.09
# Epoch: 17/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 40/400 with KL 0.03 and nll loss -41.08
# Epoch: 17/19, i/N: 50/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 60/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 70/400 with KL 0.12 and nll loss -40.99
# Epoch: 17/19, i/N: 80/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 90/400 with KL 0.14 and nll loss -40.97
# Epoch: 17/19, i/N: 100/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.08005905151367188 and nll_test -41.02642059326172
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 120/400 with KL 0.11 and nll loss -41.00
# Epoch: 17/19, i/N: 130/400 with KL 0.09 and nll loss -41.01
# Epoch: 17/19, i/N: 140/400 with KL 0.07 and nll loss -41.04
# Epoch: 17/19, i/N: 150/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 160/400 with KL 0.11 and nll loss -40.99
# Epoch: 17/19, i/N: 170/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 180/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 190/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 200/400 with KL 0.20 and nll loss -40.91
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.07822418212890625 and nll_test -41.028255462646484
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 220/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 230/400 with KL 0.13 and nll loss -40.97
# Epoch: 17/19, i/N: 240/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 250/400 with KL -0.03 and nll loss -41.14
# Epoch: 17/19, i/N: 260/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 270/400 with KL 0.09 and nll loss -41.01
# Epoch: 17/19, i/N: 280/400 with KL 0.16 and nll loss -40.95
# Epoch: 17/19, i/N: 290/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 300/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.0828857421875 and nll_test -41.02359390258789
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 320/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 340/400 with KL 0.03 and nll loss -41.08
# Epoch: 17/19, i/N: 350/400 with KL 0.07 and nll loss -41.04
# Epoch: 17/19, i/N: 360/400 with KL 0.10 and nll loss -41.00
# Epoch: 17/19, i/N: 370/400 with KL 0.04 and nll loss -41.07
# Epoch: 17/19, i/N: 380/400 with KL 0.07 and nll loss -41.04
# Epoch: 17/19, i/N: 390/400 with KL 0.10 and nll loss -41.01
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.07811737060546875 and nll_test -41.02836227416992
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.12 and nll loss -40.99
# Epoch: 18/19, i/N: 20/400 with KL 0.09 and nll loss -41.02
# Epoch: 18/19, i/N: 30/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 40/400 with KL 0.12 and nll loss -40.98
# Epoch: 18/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 60/400 with KL -0.01 and nll loss -41.11
# Epoch: 18/19, i/N: 70/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 80/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 90/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 100/400 with KL 0.14 and nll loss -40.97
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.08148574829101562 and nll_test -41.024993896484375
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.17 and nll loss -40.94
# Epoch: 18/19, i/N: 120/400 with KL 0.10 and nll loss -41.00
# Epoch: 18/19, i/N: 130/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 140/400 with KL 0.15 and nll loss -40.96
# Epoch: 18/19, i/N: 150/400 with KL 0.12 and nll loss -40.99
# Epoch: 18/19, i/N: 160/400 with KL 0.19 and nll loss -40.92
# Epoch: 18/19, i/N: 170/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 180/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 190/400 with KL 0.11 and nll loss -40.99
# Epoch: 18/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.08106613159179688 and nll_test -41.025413513183594
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.23
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.11 and nll loss -41.00
# Epoch: 18/19, i/N: 220/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 230/400 with KL -0.00 and nll loss -41.11
# Epoch: 18/19, i/N: 240/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 250/400 with KL 0.11 and nll loss -41.00
# Epoch: 18/19, i/N: 260/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 270/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 280/400 with KL 0.08 and nll loss -41.03
# Epoch: 18/19, i/N: 290/400 with KL 0.16 and nll loss -40.95
# Epoch: 18/19, i/N: 300/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.07851409912109375 and nll_test -41.0279655456543
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 320/400 with KL 0.05 and nll loss -41.05
# Epoch: 18/19, i/N: 330/400 with KL 0.13 and nll loss -40.98
# Epoch: 18/19, i/N: 340/400 with KL 0.18 and nll loss -40.93
# Epoch: 18/19, i/N: 350/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 360/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 370/400 with KL 0.12 and nll loss -40.98
# Epoch: 18/19, i/N: 380/400 with KL 0.13 and nll loss -40.97
# Epoch: 18/19, i/N: 390/400 with KL 0.07 and nll loss -41.03
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.16 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.08215713500976562 and nll_test -41.024322509765625
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 20/400 with KL 0.07 and nll loss -41.03
# Epoch: 19/19, i/N: 30/400 with KL 0.09 and nll loss -41.01
# Epoch: 19/19, i/N: 40/400 with KL 0.05 and nll loss -41.06
# Epoch: 19/19, i/N: 50/400 with KL 0.03 and nll loss -41.07
# Epoch: 19/19, i/N: 60/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 70/400 with KL 0.18 and nll loss -40.93
# Epoch: 19/19, i/N: 80/400 with KL 0.01 and nll loss -41.10
# Epoch: 19/19, i/N: 90/400 with KL 0.07 and nll loss -41.04
# Epoch: 19/19, i/N: 100/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.07580947875976562 and nll_test -41.030670166015625
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.11 and nll loss -41.00
# Epoch: 19/19, i/N: 120/400 with KL 0.04 and nll loss -41.07
# Epoch: 19/19, i/N: 130/400 with KL 0.08 and nll loss -41.02
# Epoch: 19/19, i/N: 140/400 with KL 0.09 and nll loss -41.01
# Epoch: 19/19, i/N: 150/400 with KL 0.13 and nll loss -40.97
# Epoch: 19/19, i/N: 160/400 with KL 0.08 and nll loss -41.02
# Epoch: 19/19, i/N: 170/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 180/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 190/400 with KL 0.14 and nll loss -40.96
# Epoch: 19/19, i/N: 200/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.07751846313476562 and nll_test -41.028961181640625
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.07 and nll loss -41.04
# Epoch: 19/19, i/N: 220/400 with KL 0.13 and nll loss -40.98
# Epoch: 19/19, i/N: 230/400 with KL 0.02 and nll loss -41.08
# Epoch: 19/19, i/N: 240/400 with KL 0.12 and nll loss -40.98
# Epoch: 19/19, i/N: 250/400 with KL 0.16 and nll loss -40.94
# Epoch: 19/19, i/N: 260/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 270/400 with KL 0.19 and nll loss -40.92
# Epoch: 19/19, i/N: 280/400 with KL 0.05 and nll loss -41.05
# Epoch: 19/19, i/N: 290/400 with KL 0.13 and nll loss -40.97
# Epoch: 19/19, i/N: 300/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.0780792236328125 and nll_test -41.02840042114258
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL -0.01 and nll loss -41.11
# Epoch: 19/19, i/N: 320/400 with KL 0.07 and nll loss -41.04
# Epoch: 19/19, i/N: 330/400 with KL 0.01 and nll loss -41.09
# Epoch: 19/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 350/400 with KL 0.09 and nll loss -41.01
# Epoch: 19/19, i/N: 360/400 with KL 0.08 and nll loss -41.02
# Epoch: 19/19, i/N: 370/400 with KL 0.04 and nll loss -41.07
# Epoch: 19/19, i/N: 380/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 390/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.08025360107421875 and nll_test -41.02622604370117
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.26
# #####################

# %% [markdown]
# ### Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_m')

# %% [markdown]
# ### Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_CYL,
                                 num_bins=NUM_BINS,
                                 flow_type= 'spline',
                                 num_dim_data = NUM_DIM_DATA)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='ar_cyl_s')
# Out:
# ##### Cylindrical Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64/runs/1218_173108" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64/runs/1218_173108</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_masked(
#           (input): MaskedLinear(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_masked(
#           (input): MaskedLinear(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_masked(
#           (input): MaskedLinear(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (3): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_masked(
#           (input): MaskedLinear(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): MaskedLinear(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 128,
#  'HIDDEN_DIM_ROTATION_MLP': 128,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 1301120,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([11.87270059, 14.75357153, 13.65996971, 12.99329242]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[ 2.29462236e-01,  1.77109778e-01,  1.07259817e-01,
#         -2.50731081e-01,  8.07878897e-02, -1.47012919e-01,
#         -5.12859086e-03, -1.91088036e-01, -8.95662829e-02,
#          1.96334362e-01, -4.67374101e-02, -1.67145297e-01,
#         -8.66780579e-02, -6.66184425e-02, -9.15553942e-02,
#          9.07940418e-02,  1.95571497e-01, -1.90052949e-02,
#         -5.92314340e-02,  5.23474663e-02, -9.02802870e-02,
#          1.28408954e-01,  9.53614786e-02,  2.00132802e-01,
#          1.52321562e-01,  1.54381514e-01,  7.26959854e-02,
#          1.58944160e-01, -2.75824443e-02,  4.97283228e-03,
#         -2.99582593e-02,  1.02394260e-01, -1.64890662e-01,
#         -1.03749134e-01, -2.65990123e-02,  2.04508007e-01,
#          3.79731245e-02, -5.05528562e-02,  3.64060663e-02,
#         -9.22405571e-02, -1.85479909e-01,  1.18563019e-01,
#         -1.04767255e-01, -7.15856105e-02, -1.51729345e-01,
#          2.52786934e-01, -1.47025809e-01, -5.81020936e-02,
#         -1.08820491e-01, -7.83727467e-02,  9.29129217e-03,
#          6.26147166e-02, -5.81113622e-02,  1.41871423e-01,
#         -9.69342142e-02, -8.76439959e-02, -1.67102516e-01,
#          4.28741332e-03, -7.55904336e-03,  8.04540366e-02,
#         -1.16471071e-02,  2.19659194e-01, -1.41057894e-01,
#          1.64756760e-01],
#        [ 2.09032208e-01,  1.23876281e-01,  3.20834845e-01,
#          7.56735802e-02,  5.01409061e-02, -2.85431203e-02,
#         -1.52541623e-01,  1.84856415e-01, -2.49065403e-02,
#          7.57636800e-02,  8.19009542e-03,  6.16618507e-02,
#          8.31719413e-02, -9.28225517e-02, -3.19145769e-01,
#         -1.08600341e-01,  1.57202897e-03, -4.89975810e-02,
#         -1.93923369e-01, -8.46712589e-02,  7.75572434e-02,
#          7.58843422e-02,  1.65069759e-01,  7.47001776e-03,
#          1.07609361e-01, -6.96590543e-02, -1.51800632e-01,
#          8.73512924e-02, -2.49122366e-01, -1.19733103e-01,
#          1.93058878e-01,  6.99418187e-02, -3.62994492e-01,
#          7.05871955e-02,  1.13487020e-01,  4.14368883e-03,
#          9.26824212e-02,  8.43641609e-02,  1.54326230e-01,
#         -6.51126951e-02, -2.67981216e-02,  1.08883239e-01,
#          5.85464239e-02,  2.58143172e-02,  3.83179896e-02,
#          1.84158161e-01, -1.89610626e-04, -4.39149439e-02,
#         -2.10752815e-01, -1.48023395e-02, -8.66648406e-02,
#          6.90041035e-02,  1.05038323e-01,  1.31847141e-02,
#         -5.62765598e-02,  7.63607845e-02, -1.83489837e-03,
#          3.48359086e-02,  1.91706549e-02,  1.10544026e-01,
#          1.58388302e-01,  4.91637252e-02,  1.04140110e-01,
#          5.95082939e-02],
#        [ 2.27253109e-01,  1.19073063e-01, -1.69031948e-01,
#         -1.32958472e-01, -1.60081312e-02,  1.92450032e-01,
#          7.70479068e-02,  6.77824691e-02,  1.34329200e-01,
#          2.18462292e-03, -2.12501660e-01,  1.08902365e-01,
#         -4.41693850e-02,  1.21570587e-01, -8.08029994e-02,
#          7.49382973e-02, -1.14461310e-01,  1.12788402e-01,
#          1.90542594e-01,  1.70703351e-01,  3.17117684e-02,
#         -2.47564074e-02, -8.62340033e-02,  1.22734522e-02,
#          4.10400406e-02,  1.13863543e-01, -5.48008010e-02,
#          1.88847661e-01, -2.91853011e-01, -4.91352789e-02,
#         -1.40677363e-01,  9.55933407e-02, -2.23651335e-01,
#          2.68981922e-02,  2.92537920e-03, -4.07103747e-02,
#          3.37536149e-02, -8.60033184e-02,  2.05723178e-02,
#         -1.28730282e-01, -1.88537359e-01,  1.59204796e-01,
#          1.51665330e-01,  6.15397235e-03, -1.82028666e-01,
#          8.90468732e-02,  9.12607759e-02,  2.38476545e-01,
#          4.21490800e-03,  1.41905155e-02, -9.48080570e-02,
#         -2.44270097e-02, -1.09668791e-01, -1.87220082e-01,
#         -1.33678168e-01, -6.14976995e-02, -6.10476695e-02,
#         -1.76665649e-01, -2.26722822e-01,  1.50451446e-02,
#          1.20373338e-01, -6.54042810e-02,  8.28766748e-02,
#          8.35360512e-02],
#        [ 2.29469970e-01, -1.19178116e-01,  1.24467306e-01,
#         -4.35839482e-02, -1.51998147e-01,  4.63051610e-02,
#          6.19158968e-02,  1.75065100e-01,  6.80321380e-02,
#          2.73135930e-01, -6.73460886e-02, -1.20530210e-01,
#          2.39456948e-02,  1.38206869e-01,  1.68965489e-01,
#          5.94673678e-02, -1.05350323e-01, -1.32070139e-01,
#         -6.40052035e-02, -7.65920058e-02,  1.99566651e-02,
#          5.70015013e-02, -1.91776659e-02, -2.99829006e-01,
#         -5.14701121e-02,  1.39732167e-01, -2.30307445e-01,
#          1.95025578e-01,  4.00163531e-02, -6.47016689e-02,
#          1.33850142e-01,  2.18510926e-01, -5.82608685e-04,
#          2.15555280e-01,  1.99054815e-02, -1.37115538e-01,
#         -7.40580335e-02,  1.08073037e-02,  5.17171249e-02,
#          2.57251054e-01, -9.30966996e-03, -1.17179230e-01,
#         -2.64946461e-01, -1.39805794e-01,  2.27907673e-03,
#          1.01164514e-02,  2.49798894e-02,  5.29803634e-02,
#         -1.20158300e-01,  3.57179455e-02, -6.96891919e-02,
#          5.98227233e-02, -1.12755671e-01, -3.50703881e-03,
#         -4.56829481e-02,  1.89310968e-01,  1.62357047e-01,
#         -9.24605206e-02,  1.10431761e-01,  6.63417727e-02,
#          6.97998554e-02,  7.31330365e-02,  6.54107109e-02,
#          2.87684649e-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -41.217529296875
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.45 and nll loss -40.77
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2b015c6ac2c2> in <module>
#      10 print('##### Cylindrical Spline Flow #####')
#      11
# ---> 12 train_model(model = cyl_spline,
#      13             optimizer = optimizer,
#      14             dataset = power_spherical_data,
#
# <ipython-input-6-0d1a2409755c> in train_model(model, optimizer, dataset, config, model_name)
#     145
#     146             if batch_idx % config['eval_iter'] == 0:
# --> 147                 KL_test, nll_test = eval_model()
#     148
#     149 #                 # This part is for additional evaluation of
#
# <ipython-input-6-0d1a2409755c> in eval_model()
#     109
#     110                     model.eval()
# --> 111                     z, ldj, _ = model(test_data)
#     112
#     113                     nll_test = loss_fn.calc_loss(ldj)
#
# ~/ENTER/envs/flow_lab/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/hyperspherical_flow/code/flow_models.py in forward(self, x, x_conditioner, inverse)
#    1066         for block in self.scale if not inverse else reversed(self.scale):
#    1067
# -> 1068             x_cylinder, sldj, x_conditioner = block(x=x_cylinder,
#    1069                                                     sldj=sldj,
#    1070                                                     x_conditioner=x_conditioner,
#
# ~/ENTER/envs/flow_lab/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/hyperspherical_flow/code/flow_models.py in forward(self, x, sldj, x_conditioner, inverse)
#     951                                                             inverse=inverse)
#     952         # (B, 1)
# --> 953         theta = T_2(sphere).unsqueeze(-1)
#     954
#     955         # (B, 1)
#
# ~/hyperspherical_flow/code/transformations.py in T_2(x)
#     177     theta = torch.atan2(x[...,1], x[...,0])
#     178
# --> 179     return set_to_zero(theta, boundary) % (2*math.pi)
#
# ~/hyperspherical_flow/code/transformations.py in forward(ctx, input_, boundary)
#     137
#     138         # set values within (- boundary, boundary) to zero
# --> 139         input_[torch.abs(input_) <= boundary] = 0
#     140
#     141         return input_
#
# KeyboardInterrupt:

# %% [markdown]
# ### Coupling Cylindrical Moebius flow

# %%
cyl_moeb = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='moebius',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 num_centers=NUM_CENTERS)

cyl_moeb.to(device)

optimizer = optim.AdamW(cyl_moeb.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Moebius Flow #####')

train_model(model = cyl_moeb, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_m')
# Out:
# ##### Coupling Cylindrical Moebius Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_203948" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_203948</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (3): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Moebius_Flow(
#         (param_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=17, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 64,
#  'HIDDEN_DIM_ROTATION_MLP': 64,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 1253716,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.00157917e-01,  4.83159684e-02,  1.09778091e-01,
#         -1.69557109e-01, -2.03941818e-02,  3.48235853e-02,
#         -7.82925114e-02, -1.09136559e-01,  1.13152914e-01,
#         -6.53987676e-02, -1.41629413e-01, -5.61961234e-02,
#          8.65294561e-02,  1.23681501e-01,  2.81369332e-02,
#          1.33135065e-01, -1.93280950e-01, -3.96372974e-02,
#          2.35255316e-01, -4.03022729e-02,  2.42348555e-02,
#          9.55096558e-02,  1.26899734e-01, -8.84799734e-02,
#         -2.55654398e-02, -2.62983181e-02, -2.21743613e-01,
#         -4.21622470e-02, -2.51755446e-01,  8.23237151e-02,
#         -1.61611959e-01, -1.66060105e-01, -1.02007817e-02,
#         -2.86721345e-03,  2.12953743e-02,  2.80682266e-01,
#          1.16884917e-01, -8.08297545e-02, -1.01173684e-01,
#         -7.39679560e-02, -1.71126023e-01,  1.58435538e-01,
#          2.00396940e-01, -1.29046246e-01, -3.19459550e-02,
#         -3.05471364e-02,  6.11988381e-02,  3.17565985e-02,
#         -2.17615534e-02, -3.16909775e-02, -1.76932185e-03,
#         -4.68822122e-02, -3.62239808e-01, -1.29518971e-01,
#         -3.77357900e-02,  1.14098795e-01,  1.98367640e-01,
#          1.91400992e-04, -5.34341186e-02, -2.57502019e-01,
#          1.39832631e-01, -4.66737896e-02, -4.33864258e-02,
#          9.21048298e-02],
#        [ 1.90074500e-02,  2.60411873e-02, -7.34153613e-02,
#          1.14198759e-01, -1.77348390e-01, -2.45047510e-01,
#         -8.30812007e-02, -8.77825767e-02, -1.26364231e-01,
#          1.70761779e-01,  6.66862428e-02, -2.05338895e-02,
#         -1.15837276e-01, -5.51476181e-02, -1.47932172e-01,
#          8.44565630e-02, -3.22086036e-01,  5.76755702e-02,
#          8.16275850e-02,  4.39113937e-02, -1.79599132e-02,
#         -1.36633322e-01,  2.49908283e-01,  1.39740869e-01,
#         -5.68425208e-02, -2.47033890e-02,  1.07973561e-01,
#          1.40691027e-01, -1.17738850e-01,  2.32937708e-02,
#          7.15092421e-02,  2.02650025e-01, -7.65809119e-02,
#          1.18245028e-01,  1.50797278e-01, -1.57591119e-01,
#          1.81805771e-02, -2.70232349e-03, -5.80996014e-02,
#          7.58496597e-02,  5.47281615e-02,  2.72839308e-01,
#         -1.73256159e-01,  2.52663344e-01,  7.23374635e-02,
#         -2.24806350e-02,  6.56668916e-02, -1.64511994e-01,
#         -1.60445154e-01, -4.48567010e-02,  8.92971903e-02,
#          1.29540684e-02, -8.35901946e-02, -6.98424652e-02,
#          9.12709311e-02,  8.69363174e-02, -1.16403118e-01,
#          1.64974838e-01, -1.72709599e-01,  7.23473877e-02,
#         -6.14937842e-02,  8.74846950e-02,  4.03753258e-02,
#          1.69111788e-01],
#        [ 8.03996921e-02,  1.88394841e-02,  7.91436583e-02,
#         -1.03894427e-01, -3.16554010e-02, -1.12420239e-01,
#         -3.01579207e-01, -1.05891101e-01,  2.05421910e-01,
#         -2.17842519e-01, -4.68437485e-02,  7.77946189e-02,
#          1.79144815e-02, -2.14141190e-01, -1.28987297e-01,
#          1.79710582e-01,  3.69543321e-02, -2.11171061e-02,
#          1.62856132e-01, -1.59821570e-01,  2.95013607e-01,
#         -7.50024766e-02,  1.13670453e-01,  1.04433009e-02,
#          9.55903437e-03, -7.75749460e-02, -5.82263321e-02,
#          7.62394210e-03,  1.02248378e-01, -1.53147265e-01,
#         -7.49353617e-02,  1.87370479e-02,  9.64044780e-02,
#         -1.45118386e-01, -1.11712189e-02,  2.03258339e-02,
#          1.98214769e-01, -5.88899516e-02,  2.33828742e-02,
#         -1.01145782e-01, -9.51767862e-02, -1.00689523e-01,
#         -9.76603106e-02,  3.26669775e-02, -1.06782429e-01,
#         -1.69287287e-02,  1.34891734e-01,  2.10845172e-02,
#         -6.64624944e-02, -1.19874842e-01,  1.15675263e-01,
#          2.91244667e-02,  9.90839899e-02, -9.76498947e-02,
#          4.12934907e-02,  2.06514955e-01,  4.34264876e-02,
#          1.07311860e-01,  2.16698542e-01, -1.09591521e-01,
#         -3.03995848e-01, -1.80847108e-01, -1.39791742e-01,
#         -6.19465660e-04],
#        [-4.84134592e-02,  2.52364427e-02, -1.57797530e-01,
#          1.19816773e-01,  1.73902944e-01, -1.13306522e-01,
#         -1.93215534e-01, -3.63163911e-02, -3.56696576e-01,
#         -3.12909251e-03,  1.00029714e-01,  8.97102579e-02,
#          1.01910129e-01,  7.79635534e-02,  9.18881036e-03,
#         -1.32722501e-02,  8.26334730e-02, -1.22652352e-01,
#         -1.19253814e-01, -1.16538182e-01, -9.13126916e-02,
#         -4.08998579e-01,  5.43543324e-02, -1.43570259e-01,
#         -1.53310671e-01, -2.48359591e-01, -7.12860748e-02,
#          1.55420944e-01, -3.80727760e-02, -9.34401825e-02,
#          2.00530961e-01, -6.45856699e-03,  6.38035312e-02,
#          8.77265632e-02,  1.80304080e-01, -3.99558507e-02,
#         -1.94207835e-03, -7.79024139e-02,  5.40511608e-02,
#         -6.76667765e-02, -1.74297363e-01, -2.57477742e-02,
#         -1.10576358e-02, -1.15368016e-01, -5.66938594e-02,
#          4.62486409e-02, -3.27315815e-02,  1.74612537e-01,
#         -9.70561430e-02,  1.16726570e-01, -5.90321943e-02,
#         -6.55079111e-02, -8.50142390e-02,  2.71943569e-01,
#          1.02150232e-01,  8.64362717e-03,  8.47468153e-02,
#         -3.54529545e-02, -5.58530279e-02,  1.31824212e-02,
#          1.06705502e-01, -1.09613128e-01,  1.26093216e-02,
#         -4.06794176e-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -41.10647964477539
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.34 and nll loss -40.77
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.33881378173828125 and nll_test -40.76766586303711
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.32 and nll loss -40.78
# Epoch: 0/19, i/N: 20/400 with KL 0.23 and nll loss -40.88
# Epoch: 0/19, i/N: 30/400 with KL 0.16 and nll loss -40.94
# Epoch: 0/19, i/N: 40/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 50/400 with KL 0.17 and nll loss -40.94
# Epoch: 0/19, i/N: 60/400 with KL 0.08 and nll loss -41.02
# Epoch: 0/19, i/N: 70/400 with KL 0.14 and nll loss -40.96
# Epoch: 0/19, i/N: 80/400 with KL 0.10 and nll loss -41.01
# Epoch: 0/19, i/N: 90/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 100/400 with KL 0.13 and nll loss -40.97
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.10123825073242188 and nll_test -41.00524139404297
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.22
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 120/400 with KL 0.15 and nll loss -40.96
# Epoch: 0/19, i/N: 130/400 with KL 0.12 and nll loss -40.99
# Epoch: 0/19, i/N: 140/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 150/400 with KL 0.11 and nll loss -40.99
# Epoch: 0/19, i/N: 160/400 with KL 0.07 and nll loss -41.04
# Epoch: 0/19, i/N: 170/400 with KL 0.20 and nll loss -40.91
# Epoch: 0/19, i/N: 180/400 with KL 0.06 and nll loss -41.04
# Epoch: 0/19, i/N: 190/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 200/400 with KL -0.02 and nll loss -41.13
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.08684921264648438 and nll_test -41.019630432128906
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.10 and nll loss -41.01
# Epoch: 0/19, i/N: 220/400 with KL 0.08 and nll loss -41.03
# Epoch: 0/19, i/N: 230/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 240/400 with KL -0.01 and nll loss -41.12
# Epoch: 0/19, i/N: 250/400 with KL 0.20 and nll loss -40.90
# Epoch: 0/19, i/N: 260/400 with KL 0.07 and nll loss -41.04
# Epoch: 0/19, i/N: 270/400 with KL 0.02 and nll loss -41.09
# Epoch: 0/19, i/N: 280/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 290/400 with KL 0.02 and nll loss -41.09
# Epoch: 0/19, i/N: 300/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.08130264282226562 and nll_test -41.025177001953125
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 0.99
# Epoch: 0/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.05 and nll loss -41.06
# Epoch: 0/19, i/N: 320/400 with KL 0.06 and nll loss -41.05
# Epoch: 0/19, i/N: 330/400 with KL 0.06 and nll loss -41.04
# Epoch: 0/19, i/N: 340/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 350/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 360/400 with KL 0.06 and nll loss -41.04
# Epoch: 0/19, i/N: 370/400 with KL 0.11 and nll loss -40.99
# Epoch: 0/19, i/N: 380/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 390/400 with KL 0.10 and nll loss -41.01
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.08213424682617188 and nll_test -41.02434539794922
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 20/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 30/400 with KL 0.07 and nll loss -41.03
# Epoch: 1/19, i/N: 40/400 with KL 0.06 and nll loss -41.05
# Epoch: 1/19, i/N: 50/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 60/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 70/400 with KL -0.01 and nll loss -41.11
# Epoch: 1/19, i/N: 80/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 90/400 with KL 0.05 and nll loss -41.05
# Epoch: 1/19, i/N: 100/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.07406234741210938 and nll_test -41.03241729736328
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 120/400 with KL 0.00 and nll loss -41.11
# Epoch: 1/19, i/N: 130/400 with KL 0.01 and nll loss -41.10
# Epoch: 1/19, i/N: 140/400 with KL 0.14 and nll loss -40.96
# Epoch: 1/19, i/N: 150/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 160/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 170/400 with KL 0.01 and nll loss -41.09
# Epoch: 1/19, i/N: 180/400 with KL 0.12 and nll loss -40.98
# Epoch: 1/19, i/N: 190/400 with KL 0.10 and nll loss -41.01
# Epoch: 1/19, i/N: 200/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.07715606689453125 and nll_test -41.02932357788086
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 0.99
# Epoch: 1/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 220/400 with KL 0.05 and nll loss -41.05
# Epoch: 1/19, i/N: 230/400 with KL 0.15 and nll loss -40.95
# Epoch: 1/19, i/N: 240/400 with KL 0.09 and nll loss -41.01
# Epoch: 1/19, i/N: 250/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 260/400 with KL 0.01 and nll loss -41.09
# Epoch: 1/19, i/N: 270/400 with KL 0.13 and nll loss -40.97
# Epoch: 1/19, i/N: 280/400 with KL 0.04 and nll loss -41.07
# Epoch: 1/19, i/N: 290/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 300/400 with KL 0.16 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.07667922973632812 and nll_test -41.02980041503906
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 320/400 with KL 0.06 and nll loss -41.05
# Epoch: 1/19, i/N: 330/400 with KL 0.03 and nll loss -41.08
# Epoch: 1/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 1/19, i/N: 350/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 360/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 370/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 380/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 390/400 with KL 0.06 and nll loss -41.04
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.07378005981445312 and nll_test -41.03269958496094
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 20/400 with KL 0.03 and nll loss -41.08
# Epoch: 2/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 40/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 50/400 with KL 0.07 and nll loss -41.03
# Epoch: 2/19, i/N: 60/400 with KL 0.04 and nll loss -41.07
# Epoch: 2/19, i/N: 70/400 with KL 0.04 and nll loss -41.07
# Epoch: 2/19, i/N: 80/400 with KL 0.14 and nll loss -40.97
# Epoch: 2/19, i/N: 90/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 100/400 with KL 0.09 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.07918167114257812 and nll_test -41.02729797363281
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 120/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 130/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 140/400 with KL 0.02 and nll loss -41.08
# Epoch: 2/19, i/N: 150/400 with KL -0.03 and nll loss -41.13
# Epoch: 2/19, i/N: 160/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 170/400 with KL 0.07 and nll loss -41.03
# Epoch: 2/19, i/N: 180/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 190/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 200/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.0706787109375 and nll_test -41.03580093383789
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.06 and nll loss -41.05
# Epoch: 2/19, i/N: 220/400 with KL 0.15 and nll loss -40.95
# Epoch: 2/19, i/N: 230/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 240/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 250/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 260/400 with KL -0.02 and nll loss -41.13
# Epoch: 2/19, i/N: 270/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 280/400 with KL 0.01 and nll loss -41.10
# Epoch: 2/19, i/N: 290/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 300/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.07220077514648438 and nll_test -41.034278869628906
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 320/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 330/400 with KL 0.17 and nll loss -40.94
# Epoch: 2/19, i/N: 340/400 with KL 0.02 and nll loss -41.08
# Epoch: 2/19, i/N: 350/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 360/400 with KL 0.16 and nll loss -40.94
# Epoch: 2/19, i/N: 370/400 with KL 0.19 and nll loss -40.92
# Epoch: 2/19, i/N: 380/400 with KL 0.04 and nll loss -41.07
# Epoch: 2/19, i/N: 390/400 with KL 0.01 and nll loss -41.09
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.10 and nll loss -41.01
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.07394027709960938 and nll_test -41.03253936767578
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 20/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 30/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 40/400 with KL 0.11 and nll loss -40.99
# Epoch: 3/19, i/N: 50/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 60/400 with KL 0.08 and nll loss -41.02
# Epoch: 3/19, i/N: 70/400 with KL 0.08 and nll loss -41.02
# Epoch: 3/19, i/N: 80/400 with KL 0.05 and nll loss -41.05
# Epoch: 3/19, i/N: 90/400 with KL 0.03 and nll loss -41.08
# Epoch: 3/19, i/N: 100/400 with KL 0.09 and nll loss -41.01
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.07231903076171875 and nll_test -41.03416061401367
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL 0.05 and nll loss -41.06
# Epoch: 3/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 3/19, i/N: 130/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 140/400 with KL 0.15 and nll loss -40.96
# Epoch: 3/19, i/N: 150/400 with KL 0.10 and nll loss -41.01
# Epoch: 3/19, i/N: 160/400 with KL 0.14 and nll loss -40.97
# Epoch: 3/19, i/N: 170/400 with KL -0.01 and nll loss -41.12
# Epoch: 3/19, i/N: 180/400 with KL 0.04 and nll loss -41.06
# Epoch: 3/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 200/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.07246780395507812 and nll_test -41.03401184082031
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.10 and nll loss -41.01
# Epoch: 3/19, i/N: 220/400 with KL 0.15 and nll loss -40.95
# Epoch: 3/19, i/N: 230/400 with KL 0.10 and nll loss -41.01
# Epoch: 3/19, i/N: 240/400 with KL 0.10 and nll loss -41.00
# Epoch: 3/19, i/N: 250/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 260/400 with KL 0.13 and nll loss -40.98
# Epoch: 3/19, i/N: 270/400 with KL 0.05 and nll loss -41.06
# Epoch: 3/19, i/N: 280/400 with KL 0.04 and nll loss -41.06
# Epoch: 3/19, i/N: 290/400 with KL 0.03 and nll loss -41.07
# Epoch: 3/19, i/N: 300/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.069061279296875 and nll_test -41.037418365478516
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 0.99
# Epoch: 3/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 320/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 330/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 340/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 350/400 with KL 0.04 and nll loss -41.06
# Epoch: 3/19, i/N: 360/400 with KL 0.03 and nll loss -41.07
# Epoch: 3/19, i/N: 370/400 with KL 0.17 and nll loss -40.93
# Epoch: 3/19, i/N: 380/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 390/400 with KL 0.04 and nll loss -41.07
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.06874465942382812 and nll_test -41.03773498535156
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.30
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 20/400 with KL 0.14 and nll loss -40.97
# Epoch: 4/19, i/N: 30/400 with KL 0.06 and nll loss -41.04
# Epoch: 4/19, i/N: 40/400 with KL 0.09 and nll loss -41.01
# Epoch: 4/19, i/N: 50/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 60/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 70/400 with KL -0.08 and nll loss -41.19
# Epoch: 4/19, i/N: 80/400 with KL 0.10 and nll loss -41.00
# Epoch: 4/19, i/N: 90/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 100/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.06682968139648438 and nll_test -41.039649963378906
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.25
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 120/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 130/400 with KL 0.05 and nll loss -41.05
# Epoch: 4/19, i/N: 140/400 with KL 0.10 and nll loss -41.00
# Epoch: 4/19, i/N: 150/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 160/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 170/400 with KL 0.01 and nll loss -41.10
# Epoch: 4/19, i/N: 180/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 190/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 200/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.06962966918945312 and nll_test -41.03684997558594
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 0.99
# Epoch: 4/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 4/19, i/N: 220/400 with KL 0.12 and nll loss -40.98
# Epoch: 4/19, i/N: 230/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 250/400 with KL 0.04 and nll loss -41.06
# Epoch: 4/19, i/N: 260/400 with KL 0.02 and nll loss -41.08
# Epoch: 4/19, i/N: 270/400 with KL 0.14 and nll loss -40.96
# Epoch: 4/19, i/N: 280/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 290/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 300/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.06674575805664062 and nll_test -41.03973388671875
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 1.00
# Epoch: 4/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 320/400 with KL 0.00 and nll loss -41.10
# Epoch: 4/19, i/N: 330/400 with KL 0.02 and nll loss -41.09
# Epoch: 4/19, i/N: 340/400 with KL 0.16 and nll loss -40.95
# Epoch: 4/19, i/N: 350/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 360/400 with KL 0.19 and nll loss -40.92
# Epoch: 4/19, i/N: 370/400 with KL -0.00 and nll loss -41.11
# Epoch: 4/19, i/N: 380/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.03 and nll loss -41.08
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.06980133056640625 and nll_test -41.036678314208984
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.29
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.14 and nll loss -40.96
# Epoch: 5/19, i/N: 20/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 30/400 with KL 0.03 and nll loss -41.07
# Epoch: 5/19, i/N: 40/400 with KL 0.11 and nll loss -40.99
# Epoch: 5/19, i/N: 50/400 with KL 0.13 and nll loss -40.97
# Epoch: 5/19, i/N: 60/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 70/400 with KL 0.17 and nll loss -40.94
# Epoch: 5/19, i/N: 80/400 with KL 0.03 and nll loss -41.07
# Epoch: 5/19, i/N: 90/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 100/400 with KL 0.10 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.06795120239257812 and nll_test -41.03852844238281
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.28
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.05 and nll loss -41.05
# Epoch: 5/19, i/N: 120/400 with KL 0.02 and nll loss -41.09
# Epoch: 5/19, i/N: 130/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 140/400 with KL 0.12 and nll loss -40.98
# Epoch: 5/19, i/N: 150/400 with KL 0.10 and nll loss -41.00
# Epoch: 5/19, i/N: 160/400 with KL 0.06 and nll loss -41.04
# Epoch: 5/19, i/N: 170/400 with KL 0.03 and nll loss -41.07
# Epoch: 5/19, i/N: 180/400 with KL 0.12 and nll loss -40.98
# Epoch: 5/19, i/N: 190/400 with KL 0.15 and nll loss -40.96
# Epoch: 5/19, i/N: 200/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.07038116455078125 and nll_test -41.03609848022461
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.01
# Epoch: 5/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.18 and nll loss -40.93
# Epoch: 5/19, i/N: 220/400 with KL 0.07 and nll loss -41.03
# Epoch: 5/19, i/N: 230/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 240/400 with KL 0.03 and nll loss -41.08
# Epoch: 5/19, i/N: 250/400 with KL 0.15 and nll loss -40.95
# Epoch: 5/19, i/N: 260/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 270/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 280/400 with KL 0.14 and nll loss -40.96
# Epoch: 5/19, i/N: 290/400 with KL 0.06 and nll loss -41.05
# Epoch: 5/19, i/N: 300/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.06612777709960938 and nll_test -41.04035186767578
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.03 and nll loss -41.08
# Epoch: 5/19, i/N: 320/400 with KL -0.00 and nll loss -41.11
# Epoch: 5/19, i/N: 330/400 with KL -0.01 and nll loss -41.11
# Epoch: 5/19, i/N: 340/400 with KL 0.20 and nll loss -40.90
# Epoch: 5/19, i/N: 350/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 360/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 370/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 380/400 with KL 0.08 and nll loss -41.02
# Epoch: 5/19, i/N: 390/400 with KL 0.05 and nll loss -41.05
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.02 and nll loss -41.08
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.06336212158203125 and nll_test -41.04311752319336
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.25
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL -0.02 and nll loss -41.12
# Epoch: 6/19, i/N: 20/400 with KL 0.15 and nll loss -40.96
# Epoch: 6/19, i/N: 30/400 with KL 0.10 and nll loss -41.00
# Epoch: 6/19, i/N: 40/400 with KL 0.13 and nll loss -40.97
# Epoch: 6/19, i/N: 50/400 with KL 0.03 and nll loss -41.08
# Epoch: 6/19, i/N: 60/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 70/400 with KL 0.11 and nll loss -40.99
# Epoch: 6/19, i/N: 80/400 with KL 0.02 and nll loss -41.08
# Epoch: 6/19, i/N: 90/400 with KL 0.06 and nll loss -41.04
# Epoch: 6/19, i/N: 100/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.06997299194335938 and nll_test -41.03650665283203
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.06 and nll loss -41.04
# Epoch: 6/19, i/N: 120/400 with KL 0.00 and nll loss -41.10
# Epoch: 6/19, i/N: 130/400 with KL 0.03 and nll loss -41.08
# Epoch: 6/19, i/N: 140/400 with KL 0.06 and nll loss -41.05
# Epoch: 6/19, i/N: 150/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 160/400 with KL 0.11 and nll loss -40.99
# Epoch: 6/19, i/N: 170/400 with KL -0.02 and nll loss -41.13
# Epoch: 6/19, i/N: 180/400 with KL 0.04 and nll loss -41.06
# Epoch: 6/19, i/N: 190/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 200/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.067535400390625 and nll_test -41.038944244384766
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.02 and nll loss -41.08
# Epoch: 6/19, i/N: 220/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 230/400 with KL 0.04 and nll loss -41.07
# Epoch: 6/19, i/N: 240/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 250/400 with KL 0.17 and nll loss -40.94
# Epoch: 6/19, i/N: 260/400 with KL 0.11 and nll loss -40.99
# Epoch: 6/19, i/N: 270/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 280/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 290/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 300/400 with KL -0.05 and nll loss -41.16
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.07118988037109375 and nll_test -41.0352897644043
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.32
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.04 and nll loss -41.07
# Epoch: 6/19, i/N: 320/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 330/400 with KL 0.07 and nll loss -41.03
# Epoch: 6/19, i/N: 340/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 6/19, i/N: 360/400 with KL 0.15 and nll loss -40.96
# Epoch: 6/19, i/N: 370/400 with KL 0.02 and nll loss -41.08
# Epoch: 6/19, i/N: 380/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 390/400 with KL 0.10 and nll loss -41.01
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.06687164306640625 and nll_test -41.039608001708984
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 20/400 with KL 0.12 and nll loss -40.98
# Epoch: 7/19, i/N: 30/400 with KL 0.02 and nll loss -41.08
# Epoch: 7/19, i/N: 40/400 with KL -0.01 and nll loss -41.12
# Epoch: 7/19, i/N: 50/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 60/400 with KL 0.11 and nll loss -41.00
# Epoch: 7/19, i/N: 70/400 with KL 0.13 and nll loss -40.98
# Epoch: 7/19, i/N: 80/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 90/400 with KL 0.01 and nll loss -41.10
# Epoch: 7/19, i/N: 100/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.0698699951171875 and nll_test -41.0366096496582
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.10 and nll loss -41.00
# Epoch: 7/19, i/N: 120/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 130/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 140/400 with KL 0.13 and nll loss -40.97
# Epoch: 7/19, i/N: 150/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 160/400 with KL -0.01 and nll loss -41.11
# Epoch: 7/19, i/N: 170/400 with KL -0.03 and nll loss -41.13
# Epoch: 7/19, i/N: 180/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 190/400 with KL 0.02 and nll loss -41.09
# Epoch: 7/19, i/N: 200/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.06928253173828125 and nll_test -41.03719711303711
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 220/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 230/400 with KL 0.11 and nll loss -41.00
# Epoch: 7/19, i/N: 240/400 with KL 0.00 and nll loss -41.10
# Epoch: 7/19, i/N: 250/400 with KL 0.01 and nll loss -41.09
# Epoch: 7/19, i/N: 260/400 with KL 0.00 and nll loss -41.10
# Epoch: 7/19, i/N: 270/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 280/400 with KL 0.12 and nll loss -40.98
# Epoch: 7/19, i/N: 290/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 300/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.0699005126953125 and nll_test -41.03657913208008
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.20
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 320/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 330/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 340/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 350/400 with KL 0.05 and nll loss -41.05
# Epoch: 7/19, i/N: 360/400 with KL 0.05 and nll loss -41.05
# Epoch: 7/19, i/N: 370/400 with KL 0.03 and nll loss -41.08
# Epoch: 7/19, i/N: 380/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.15 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.06878662109375 and nll_test -41.03769302368164
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 20/400 with KL -0.00 and nll loss -41.11
# Epoch: 8/19, i/N: 30/400 with KL 0.14 and nll loss -40.97
# Epoch: 8/19, i/N: 40/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 50/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 60/400 with KL 0.07 and nll loss -41.04
# Epoch: 8/19, i/N: 70/400 with KL 0.07 and nll loss -41.04
# Epoch: 8/19, i/N: 80/400 with KL 0.14 and nll loss -40.97
# Epoch: 8/19, i/N: 90/400 with KL 0.03 and nll loss -41.07
# Epoch: 8/19, i/N: 100/400 with KL 0.16 and nll loss -40.95
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.06668853759765625 and nll_test -41.039791107177734
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.29
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.00 and nll loss -41.10
# Epoch: 8/19, i/N: 120/400 with KL 0.15 and nll loss -40.96
# Epoch: 8/19, i/N: 130/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 140/400 with KL -0.00 and nll loss -41.11
# Epoch: 8/19, i/N: 150/400 with KL 0.12 and nll loss -40.98
# Epoch: 8/19, i/N: 160/400 with KL 0.14 and nll loss -40.96
# Epoch: 8/19, i/N: 170/400 with KL 0.07 and nll loss -41.04
# Epoch: 8/19, i/N: 180/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 190/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 200/400 with KL 0.01 and nll loss -41.10
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.06905364990234375 and nll_test -41.03742599487305
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.28
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 220/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 230/400 with KL 0.02 and nll loss -41.09
# Epoch: 8/19, i/N: 240/400 with KL 0.09 and nll loss -41.02
# Epoch: 8/19, i/N: 250/400 with KL -0.10 and nll loss -41.20
# Epoch: 8/19, i/N: 260/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 270/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 280/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 290/400 with KL 0.12 and nll loss -40.99
# Epoch: 8/19, i/N: 300/400 with KL 0.15 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.06639862060546875 and nll_test -41.04008102416992
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 320/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 330/400 with KL 0.18 and nll loss -40.92
# Epoch: 8/19, i/N: 340/400 with KL -0.01 and nll loss -41.12
# Epoch: 8/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 360/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 370/400 with KL 0.03 and nll loss -41.08
# Epoch: 8/19, i/N: 380/400 with KL 0.11 and nll loss -41.00
# Epoch: 8/19, i/N: 390/400 with KL 0.08 and nll loss -41.03
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.04 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.06528854370117188 and nll_test -41.04119110107422
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.09 and nll loss -41.01
# Epoch: 9/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 9/19, i/N: 30/400 with KL 0.04 and nll loss -41.06
# Epoch: 9/19, i/N: 40/400 with KL -0.06 and nll loss -41.16
# Epoch: 9/19, i/N: 50/400 with KL 0.08 and nll loss -41.03
# Epoch: 9/19, i/N: 60/400 with KL 0.13 and nll loss -40.98
# Epoch: 9/19, i/N: 70/400 with KL 0.11 and nll loss -41.00
# Epoch: 9/19, i/N: 80/400 with KL -0.01 and nll loss -41.11
# Epoch: 9/19, i/N: 90/400 with KL 0.08 and nll loss -41.02
# Epoch: 9/19, i/N: 100/400 with KL 0.12 and nll loss -40.99
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# ...
# Epoch: 16/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 20/400 with KL -0.03 and nll loss -41.14
# Epoch: 16/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 40/400 with KL 0.11 and nll loss -40.99
# Epoch: 16/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 60/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 70/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 80/400 with KL 0.04 and nll loss -41.06
# Epoch: 16/19, i/N: 90/400 with KL -0.02 and nll loss -41.13
# Epoch: 16/19, i/N: 100/400 with KL -0.05 and nll loss -41.16
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.06525802612304688 and nll_test -41.041221618652344
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.03 and nll loss -41.08
# Epoch: 16/19, i/N: 120/400 with KL 0.08 and nll loss -41.02
# Epoch: 16/19, i/N: 130/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 140/400 with KL 0.01 and nll loss -41.10
# Epoch: 16/19, i/N: 150/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 160/400 with KL 0.13 and nll loss -40.98
# Epoch: 16/19, i/N: 170/400 with KL 0.00 and nll loss -41.10
# Epoch: 16/19, i/N: 180/400 with KL -0.01 and nll loss -41.11
# Epoch: 16/19, i/N: 190/400 with KL 0.04 and nll loss -41.06
# Epoch: 16/19, i/N: 200/400 with KL 0.01 and nll loss -41.10
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.06621170043945312 and nll_test -41.04026794433594
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 220/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 230/400 with KL 0.13 and nll loss -40.97
# Epoch: 16/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 250/400 with KL 0.11 and nll loss -40.99
# Epoch: 16/19, i/N: 260/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 270/400 with KL -0.00 and nll loss -41.11
# Epoch: 16/19, i/N: 280/400 with KL 0.02 and nll loss -41.08
# Epoch: 16/19, i/N: 290/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 300/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.06367111206054688 and nll_test -41.042808532714844
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.13 and nll loss -40.97
# Epoch: 16/19, i/N: 320/400 with KL 0.08 and nll loss -41.02
# Epoch: 16/19, i/N: 330/400 with KL 0.03 and nll loss -41.08
# Epoch: 16/19, i/N: 340/400 with KL 0.11 and nll loss -40.99
# Epoch: 16/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 16/19, i/N: 360/400 with KL 0.00 and nll loss -41.11
# Epoch: 16/19, i/N: 370/400 with KL 0.01 and nll loss -41.10
# Epoch: 16/19, i/N: 380/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.09 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.06620407104492188 and nll_test -41.04027557373047
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.06 and nll loss -41.04
# Epoch: 17/19, i/N: 20/400 with KL 0.04 and nll loss -41.07
# Epoch: 17/19, i/N: 30/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 40/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 50/400 with KL 0.12 and nll loss -40.98
# Epoch: 17/19, i/N: 60/400 with KL 0.01 and nll loss -41.10
# Epoch: 17/19, i/N: 70/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 80/400 with KL 0.06 and nll loss -41.04
# Epoch: 17/19, i/N: 90/400 with KL 0.01 and nll loss -41.09
# Epoch: 17/19, i/N: 100/400 with KL 0.09 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.06571197509765625 and nll_test -41.040767669677734
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.29
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 130/400 with KL 0.11 and nll loss -41.00
# Epoch: 17/19, i/N: 140/400 with KL 0.08 and nll loss -41.02
# Epoch: 17/19, i/N: 150/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 160/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 170/400 with KL 0.02 and nll loss -41.08
# Epoch: 17/19, i/N: 180/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 190/400 with KL -0.00 and nll loss -41.11
# Epoch: 17/19, i/N: 200/400 with KL 0.00 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.06425094604492188 and nll_test -41.04222869873047
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 220/400 with KL 0.07 and nll loss -41.03
# Epoch: 17/19, i/N: 230/400 with KL 0.04 and nll loss -41.06
# Epoch: 17/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 250/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 260/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 270/400 with KL 0.07 and nll loss -41.04
# Epoch: 17/19, i/N: 280/400 with KL 0.11 and nll loss -41.00
# Epoch: 17/19, i/N: 290/400 with KL 0.14 and nll loss -40.97
# Epoch: 17/19, i/N: 300/400 with KL 0.17 and nll loss -40.93
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.05966949462890625 and nll_test -41.046810150146484
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 320/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 330/400 with KL 0.13 and nll loss -40.98
# Epoch: 17/19, i/N: 340/400 with KL -0.01 and nll loss -41.11
# Epoch: 17/19, i/N: 350/400 with KL 0.13 and nll loss -40.98
# Epoch: 17/19, i/N: 360/400 with KL 0.15 and nll loss -40.95
# Epoch: 17/19, i/N: 370/400 with KL 0.04 and nll loss -41.06
# Epoch: 17/19, i/N: 380/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 390/400 with KL 0.06 and nll loss -41.05
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.062213897705078125 and nll_test -41.04426574707031
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 20/400 with KL 0.14 and nll loss -40.97
# Epoch: 18/19, i/N: 30/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 40/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 50/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 60/400 with KL 0.02 and nll loss -41.09
# Epoch: 18/19, i/N: 70/400 with KL 0.05 and nll loss -41.06
# Epoch: 18/19, i/N: 80/400 with KL 0.04 and nll loss -41.06
# Epoch: 18/19, i/N: 90/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 100/400 with KL 0.03 and nll loss -41.08
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.063232421875 and nll_test -41.04324722290039
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.29
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.16 and nll loss -40.95
# Epoch: 18/19, i/N: 120/400 with KL 0.01 and nll loss -41.09
# Epoch: 18/19, i/N: 130/400 with KL 0.05 and nll loss -41.05
# Epoch: 18/19, i/N: 140/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 150/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 160/400 with KL 0.11 and nll loss -40.99
# Epoch: 18/19, i/N: 170/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 180/400 with KL 0.13 and nll loss -40.98
# Epoch: 18/19, i/N: 190/400 with KL 0.08 and nll loss -41.03
# Epoch: 18/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.0648193359375 and nll_test -41.04166030883789
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.31
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL -0.02 and nll loss -41.13
# Epoch: 18/19, i/N: 220/400 with KL 0.04 and nll loss -41.06
# Epoch: 18/19, i/N: 230/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 240/400 with KL 0.11 and nll loss -41.00
# Epoch: 18/19, i/N: 250/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 260/400 with KL 0.11 and nll loss -41.00
# Epoch: 18/19, i/N: 270/400 with KL -0.03 and nll loss -41.14
# Epoch: 18/19, i/N: 280/400 with KL 0.01 and nll loss -41.09
# Epoch: 18/19, i/N: 290/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 300/400 with KL 0.00 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.06321334838867188 and nll_test -41.04326629638672
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.29
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.12 and nll loss -40.99
# Epoch: 18/19, i/N: 320/400 with KL 0.09 and nll loss -41.02
# Epoch: 18/19, i/N: 330/400 with KL 0.04 and nll loss -41.06
# Epoch: 18/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 350/400 with KL 0.08 and nll loss -41.03
# Epoch: 18/19, i/N: 360/400 with KL 0.09 and nll loss -41.02
# Epoch: 18/19, i/N: 370/400 with KL 0.07 and nll loss -41.03
# Epoch: 18/19, i/N: 380/400 with KL 0.03 and nll loss -41.07
# Epoch: 18/19, i/N: 390/400 with KL 0.12 and nll loss -40.98
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL 0.06 and nll loss -41.05
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.06499099731445312 and nll_test -41.04148864746094
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.14 and nll loss -40.96
# Epoch: 19/19, i/N: 20/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 30/400 with KL 0.05 and nll loss -41.06
# Epoch: 19/19, i/N: 40/400 with KL 0.07 and nll loss -41.03
# Epoch: 19/19, i/N: 50/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 60/400 with KL 0.02 and nll loss -41.08
# Epoch: 19/19, i/N: 70/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 80/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 90/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 100/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.06576919555664062 and nll_test -41.04071044921875
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.32
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.03 and nll loss -41.07
# Epoch: 19/19, i/N: 120/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 130/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 140/400 with KL 0.07 and nll loss -41.03
# Epoch: 19/19, i/N: 150/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 160/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 170/400 with KL 0.05 and nll loss -41.05
# Epoch: 19/19, i/N: 180/400 with KL 0.16 and nll loss -40.94
# Epoch: 19/19, i/N: 190/400 with KL 0.02 and nll loss -41.08
# Epoch: 19/19, i/N: 200/400 with KL 0.05 and nll loss -41.06
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.06320571899414062 and nll_test -41.04327392578125
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL 0.01 and nll loss -41.10
# Epoch: 19/19, i/N: 220/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 230/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 240/400 with KL 0.11 and nll loss -41.00
# Epoch: 19/19, i/N: 250/400 with KL 0.07 and nll loss -41.04
# Epoch: 19/19, i/N: 260/400 with KL 0.01 and nll loss -41.10
# Epoch: 19/19, i/N: 270/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 280/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 290/400 with KL -0.01 and nll loss -41.11
# Epoch: 19/19, i/N: 300/400 with KL 0.04 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.057056427001953125 and nll_test -41.04942321777344
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 320/400 with KL -0.02 and nll loss -41.12
# Epoch: 19/19, i/N: 330/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 340/400 with KL 0.05 and nll loss -41.06
# Epoch: 19/19, i/N: 350/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 360/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 370/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 380/400 with KL 0.06 and nll loss -41.04
# nan in sum squares
# Epoch: 19/19, i/N: 390/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.0631866455078125 and nll_test -41.04329299926758
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.26
# #####################

# %% [markdown]
# ### Coupling Cylindrical Spline flow

# %%
cyl_spline = Cylindrical_Flow(num_flows=NUM_FLOWS_COU,
                                 num_bins=NUM_BINS, 
                                 flow_type='spline',
                                 num_dim_data=NUM_DIM_DATA, 
                                 mask_type='coupling',
                                 num_centers=NUM_CENTERS)

cyl_spline.to(device)

optimizer = optim.AdamW(cyl_spline.parameters(), lr=lr, weight_decay=weight_decay)

print('##### Coupling Cylindrical Spline Flow #####')

train_model(model = cyl_spline, 
            optimizer = optimizer,
            dataset = power_spherical_data,
            config = config,
            model_name='cou_cyl_s')
# Out:
# ##### Coupling Cylindrical Spline Flow #####
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64</a><br/>
#                 Run page: <a href="https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_211459" target="_blank">https://app.wandb.ai/simon-passenheim/DIM_64/runs/1224_211459</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# ##### Model #####
# Cylindrical_Flow(
#   (scale): ModuleList(
#     (0): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (1): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (2): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#     (3): _Cylindrical_Flow(
#       (interval_spline): Interval_Spline_Flow(
#         (params_predictor): MLP_simple_coupling(
#           (input): Linear_conditional(
#             (linear): Linear(in_features=62, out_features=128, bias=True)
#           )
#           (relu): ReLU()
#           (out_widths): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_heights): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=744, bias=True)
#           )
#           (out_derivatives): Linear_conditional(
#             (linear): Linear(in_features=128, out_features=806, bias=True)
#           )
#         )
#       )
#       (circle_transf): Circular_Spline_Flow(
#         (params_predictor): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=128, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=128, out_features=36, bias=True)
#           )
#         )
#       )
#       (cond_rotation): Rotation(
#         (householder_params): MLP(
#           (nn): Sequential(
#             (0): Linear(in_features=62, out_features=64, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=64, out_features=4, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# #################
#
# ##### Config #####
# {'BATCH_SIZE': 256,
#  'HIDDEN_DIM_MOEBIUS_MLP': 64,
#  'HIDDEN_DIM_ROTATION_MLP': 64,
#  'HIDDEN_DIM_SPLINE_MLP': 128,
#  'NUM_PARAMS': 1283968,
#  'dataset_type': 'standard',
#  'epochs': 20,
#  'eval_iter': 100,
#  'iters_per_epoch': 400,
#  'k_list': array([10.38154145, 13.89959396, 12.19204616, 13.61732589]),
#  'lookahead': 10,
#  'lr': 0.001,
#  'mu_list': array([[-1.00157917e-01,  4.83159684e-02,  1.09778091e-01,
#         -1.69557109e-01, -2.03941818e-02,  3.48235853e-02,
#         -7.82925114e-02, -1.09136559e-01,  1.13152914e-01,
#         -6.53987676e-02, -1.41629413e-01, -5.61961234e-02,
#          8.65294561e-02,  1.23681501e-01,  2.81369332e-02,
#          1.33135065e-01, -1.93280950e-01, -3.96372974e-02,
#          2.35255316e-01, -4.03022729e-02,  2.42348555e-02,
#          9.55096558e-02,  1.26899734e-01, -8.84799734e-02,
#         -2.55654398e-02, -2.62983181e-02, -2.21743613e-01,
#         -4.21622470e-02, -2.51755446e-01,  8.23237151e-02,
#         -1.61611959e-01, -1.66060105e-01, -1.02007817e-02,
#         -2.86721345e-03,  2.12953743e-02,  2.80682266e-01,
#          1.16884917e-01, -8.08297545e-02, -1.01173684e-01,
#         -7.39679560e-02, -1.71126023e-01,  1.58435538e-01,
#          2.00396940e-01, -1.29046246e-01, -3.19459550e-02,
#         -3.05471364e-02,  6.11988381e-02,  3.17565985e-02,
#         -2.17615534e-02, -3.16909775e-02, -1.76932185e-03,
#         -4.68822122e-02, -3.62239808e-01, -1.29518971e-01,
#         -3.77357900e-02,  1.14098795e-01,  1.98367640e-01,
#          1.91400992e-04, -5.34341186e-02, -2.57502019e-01,
#          1.39832631e-01, -4.66737896e-02, -4.33864258e-02,
#          9.21048298e-02],
#        [ 1.90074500e-02,  2.60411873e-02, -7.34153613e-02,
#          1.14198759e-01, -1.77348390e-01, -2.45047510e-01,
#         -8.30812007e-02, -8.77825767e-02, -1.26364231e-01,
#          1.70761779e-01,  6.66862428e-02, -2.05338895e-02,
#         -1.15837276e-01, -5.51476181e-02, -1.47932172e-01,
#          8.44565630e-02, -3.22086036e-01,  5.76755702e-02,
#          8.16275850e-02,  4.39113937e-02, -1.79599132e-02,
#         -1.36633322e-01,  2.49908283e-01,  1.39740869e-01,
#         -5.68425208e-02, -2.47033890e-02,  1.07973561e-01,
#          1.40691027e-01, -1.17738850e-01,  2.32937708e-02,
#          7.15092421e-02,  2.02650025e-01, -7.65809119e-02,
#          1.18245028e-01,  1.50797278e-01, -1.57591119e-01,
#          1.81805771e-02, -2.70232349e-03, -5.80996014e-02,
#          7.58496597e-02,  5.47281615e-02,  2.72839308e-01,
#         -1.73256159e-01,  2.52663344e-01,  7.23374635e-02,
#         -2.24806350e-02,  6.56668916e-02, -1.64511994e-01,
#         -1.60445154e-01, -4.48567010e-02,  8.92971903e-02,
#          1.29540684e-02, -8.35901946e-02, -6.98424652e-02,
#          9.12709311e-02,  8.69363174e-02, -1.16403118e-01,
#          1.64974838e-01, -1.72709599e-01,  7.23473877e-02,
#         -6.14937842e-02,  8.74846950e-02,  4.03753258e-02,
#          1.69111788e-01],
#        [ 8.03996921e-02,  1.88394841e-02,  7.91436583e-02,
#         -1.03894427e-01, -3.16554010e-02, -1.12420239e-01,
#         -3.01579207e-01, -1.05891101e-01,  2.05421910e-01,
#         -2.17842519e-01, -4.68437485e-02,  7.77946189e-02,
#          1.79144815e-02, -2.14141190e-01, -1.28987297e-01,
#          1.79710582e-01,  3.69543321e-02, -2.11171061e-02,
#          1.62856132e-01, -1.59821570e-01,  2.95013607e-01,
#         -7.50024766e-02,  1.13670453e-01,  1.04433009e-02,
#          9.55903437e-03, -7.75749460e-02, -5.82263321e-02,
#          7.62394210e-03,  1.02248378e-01, -1.53147265e-01,
#         -7.49353617e-02,  1.87370479e-02,  9.64044780e-02,
#         -1.45118386e-01, -1.11712189e-02,  2.03258339e-02,
#          1.98214769e-01, -5.88899516e-02,  2.33828742e-02,
#         -1.01145782e-01, -9.51767862e-02, -1.00689523e-01,
#         -9.76603106e-02,  3.26669775e-02, -1.06782429e-01,
#         -1.69287287e-02,  1.34891734e-01,  2.10845172e-02,
#         -6.64624944e-02, -1.19874842e-01,  1.15675263e-01,
#          2.91244667e-02,  9.90839899e-02, -9.76498947e-02,
#          4.12934907e-02,  2.06514955e-01,  4.34264876e-02,
#          1.07311860e-01,  2.16698542e-01, -1.09591521e-01,
#         -3.03995848e-01, -1.80847108e-01, -1.39791742e-01,
#         -6.19465660e-04],
#        [-4.84134592e-02,  2.52364427e-02, -1.57797530e-01,
#          1.19816773e-01,  1.73902944e-01, -1.13306522e-01,
#         -1.93215534e-01, -3.63163911e-02, -3.56696576e-01,
#         -3.12909251e-03,  1.00029714e-01,  8.97102579e-02,
#          1.01910129e-01,  7.79635534e-02,  9.18881036e-03,
#         -1.32722501e-02,  8.26334730e-02, -1.22652352e-01,
#         -1.19253814e-01, -1.16538182e-01, -9.13126916e-02,
#         -4.08998579e-01,  5.43543324e-02, -1.43570259e-01,
#         -1.53310671e-01, -2.48359591e-01, -7.12860748e-02,
#          1.55420944e-01, -3.80727760e-02, -9.34401825e-02,
#          2.00530961e-01, -6.45856699e-03,  6.38035312e-02,
#          8.77265632e-02,  1.80304080e-01, -3.99558507e-02,
#         -1.94207835e-03, -7.79024139e-02,  5.40511608e-02,
#         -6.76667765e-02, -1.74297363e-01, -2.57477742e-02,
#         -1.10576358e-02, -1.15368016e-01, -5.66938594e-02,
#          4.62486409e-02, -3.27315815e-02,  1.74612537e-01,
#         -9.70561430e-02,  1.16726570e-01, -5.90321943e-02,
#         -6.55079111e-02, -8.50142390e-02,  2.71943569e-01,
#          1.02150232e-01,  8.64362717e-03,  8.47468153e-02,
#         -3.54529545e-02, -5.58530279e-02,  1.31824212e-02,
#          1.06705502e-01, -1.09613128e-01,  1.26093216e-02,
#         -4.06794176e-02]], dtype=float32),
#  'nr_datapoints_eval': 100000,
#  'nr_mixtures': 4,
#  'phi_mu_list': None,
#  'print_iter': 10,
#  'theta_mu_list': None,
#  'weight_decay': 0.01}
# ##################
#
# Entropy of data: -41.10647964477539
# Epoch: 0 / 19
# Epoch: 0/19, i/N: 0/400 with KL 0.34 and nll loss -40.77
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 0/400 KL_test 0.33879852294921875 and nll_test -40.76768112182617
#
# From current batch
# Epoch: 0, i/N: 0/400 avg ldj from current batch -0.00
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 0/400 MC density sum 1.00
# Epoch: 0/19, i/N: 0/400 avg ldj -0.00
# #####################
#
# Epoch: 0/19, i/N: 10/400 with KL 0.32 and nll loss -40.79
# Epoch: 0/19, i/N: 20/400 with KL 0.26 and nll loss -40.85
# Epoch: 0/19, i/N: 30/400 with KL 0.17 and nll loss -40.94
# Epoch: 0/19, i/N: 40/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 50/400 with KL 0.07 and nll loss -41.03
# Epoch: 0/19, i/N: 60/400 with KL 0.08 and nll loss -41.02
# Epoch: 0/19, i/N: 70/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 80/400 with KL 0.07 and nll loss -41.04
# Epoch: 0/19, i/N: 90/400 with KL 0.06 and nll loss -41.05
# Epoch: 0/19, i/N: 100/400 with KL 0.10 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 100/400 KL_test 0.1027679443359375 and nll_test -41.00371170043945
#
# From current batch
# Epoch: 0, i/N: 100/400 avg ldj from current batch 0.24
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 100/400 MC density sum 1.00
# Epoch: 0/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 0/19, i/N: 110/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 120/400 with KL 0.14 and nll loss -40.97
# Epoch: 0/19, i/N: 130/400 with KL 0.07 and nll loss -41.04
# Epoch: 0/19, i/N: 140/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 150/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 160/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 170/400 with KL 0.09 and nll loss -41.02
# Epoch: 0/19, i/N: 180/400 with KL 0.07 and nll loss -41.04
# Epoch: 0/19, i/N: 190/400 with KL 0.02 and nll loss -41.08
# Epoch: 0/19, i/N: 200/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 200/400 KL_test 0.08379364013671875 and nll_test -41.02268600463867
#
# From current batch
# Epoch: 0, i/N: 200/400 avg ldj from current batch 0.25
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 200/400 MC density sum 1.00
# Epoch: 0/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 0/19, i/N: 210/400 with KL 0.04 and nll loss -41.07
# Epoch: 0/19, i/N: 220/400 with KL 0.12 and nll loss -40.99
# Epoch: 0/19, i/N: 230/400 with KL 0.07 and nll loss -41.03
# Epoch: 0/19, i/N: 240/400 with KL 0.08 and nll loss -41.02
# Epoch: 0/19, i/N: 250/400 with KL 0.06 and nll loss -41.04
# Epoch: 0/19, i/N: 260/400 with KL 0.05 and nll loss -41.06
# Epoch: 0/19, i/N: 270/400 with KL 0.08 and nll loss -41.03
# Epoch: 0/19, i/N: 280/400 with KL 0.05 and nll loss -41.05
# Epoch: 0/19, i/N: 290/400 with KL 0.05 and nll loss -41.05
# Epoch: 0/19, i/N: 300/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 0/19, i/N: 300/400 KL_test 0.081207275390625 and nll_test -41.025272369384766
#
# From current batch
# Epoch: 0, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 0/19, i/N: 300/400 MC density sum 1.00
# Epoch: 0/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 0/19, i/N: 310/400 with KL 0.01 and nll loss -41.10
# Epoch: 0/19, i/N: 320/400 with KL 0.16 and nll loss -40.95
# Epoch: 0/19, i/N: 330/400 with KL 0.08 and nll loss -41.03
# Epoch: 0/19, i/N: 340/400 with KL 0.12 and nll loss -40.98
# Epoch: 0/19, i/N: 350/400 with KL 0.02 and nll loss -41.08
# Epoch: 0/19, i/N: 360/400 with KL 0.13 and nll loss -40.98
# Epoch: 0/19, i/N: 370/400 with KL 0.08 and nll loss -41.02
# Epoch: 0/19, i/N: 380/400 with KL 0.11 and nll loss -41.00
# Epoch: 0/19, i/N: 390/400 with KL 0.17 and nll loss -40.93
# Epoch: 1 / 19
# Epoch: 1/19, i/N: 0/400 with KL 0.01 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 0/400 KL_test 0.07765960693359375 and nll_test -41.0288200378418
#
# From current batch
# Epoch: 1, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 0/400 MC density sum 1.00
# Epoch: 1/19, i/N: 0/400 avg ldj -0.24
# #####################
#
# Epoch: 1/19, i/N: 10/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 30/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 40/400 with KL 0.10 and nll loss -41.01
# Epoch: 1/19, i/N: 50/400 with KL 0.12 and nll loss -40.98
# Epoch: 1/19, i/N: 60/400 with KL 0.11 and nll loss -40.99
# Epoch: 1/19, i/N: 70/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 80/400 with KL 0.05 and nll loss -41.05
# Epoch: 1/19, i/N: 90/400 with KL 0.04 and nll loss -41.07
# Epoch: 1/19, i/N: 100/400 with KL 0.10 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 100/400 KL_test 0.08200454711914062 and nll_test -41.02447509765625
#
# From current batch
# Epoch: 1, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 100/400 MC density sum 1.00
# Epoch: 1/19, i/N: 100/400 avg ldj -0.30
# #####################
#
# Epoch: 1/19, i/N: 110/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 120/400 with KL 0.00 and nll loss -41.11
# Epoch: 1/19, i/N: 130/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 140/400 with KL 0.12 and nll loss -40.98
# Epoch: 1/19, i/N: 150/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 160/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 170/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 180/400 with KL 0.08 and nll loss -41.03
# Epoch: 1/19, i/N: 190/400 with KL 0.12 and nll loss -40.99
# Epoch: 1/19, i/N: 200/400 with KL 0.09 and nll loss -41.02
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 200/400 KL_test 0.0750732421875 and nll_test -41.03140640258789
#
# From current batch
# Epoch: 1, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 200/400 MC density sum 1.00
# Epoch: 1/19, i/N: 200/400 avg ldj -0.25
# #####################
#
# Epoch: 1/19, i/N: 210/400 with KL 0.06 and nll loss -41.05
# Epoch: 1/19, i/N: 220/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 230/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 240/400 with KL 0.04 and nll loss -41.06
# Epoch: 1/19, i/N: 250/400 with KL 0.08 and nll loss -41.02
# Epoch: 1/19, i/N: 260/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 270/400 with KL 0.14 and nll loss -40.97
# Epoch: 1/19, i/N: 280/400 with KL 0.11 and nll loss -41.00
# Epoch: 1/19, i/N: 290/400 with KL 0.10 and nll loss -41.00
# Epoch: 1/19, i/N: 300/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 1/19, i/N: 300/400 KL_test 0.07793426513671875 and nll_test -41.02854537963867
#
# From current batch
# Epoch: 1, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 1/19, i/N: 300/400 MC density sum 1.00
# Epoch: 1/19, i/N: 300/400 avg ldj -0.22
# #####################
#
# Epoch: 1/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 320/400 with KL 0.07 and nll loss -41.04
# Epoch: 1/19, i/N: 330/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 340/400 with KL 0.03 and nll loss -41.08
# Epoch: 1/19, i/N: 350/400 with KL -0.04 and nll loss -41.15
# Epoch: 1/19, i/N: 360/400 with KL 0.09 and nll loss -41.02
# Epoch: 1/19, i/N: 370/400 with KL -0.00 and nll loss -41.11
# Epoch: 1/19, i/N: 380/400 with KL 0.04 and nll loss -41.07
# Epoch: 1/19, i/N: 390/400 with KL 0.10 and nll loss -41.01
# Epoch: 2 / 19
# Epoch: 2/19, i/N: 0/400 with KL 0.14 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 0/400 KL_test 0.07464981079101562 and nll_test -41.031829833984375
#
# From current batch
# Epoch: 2, i/N: 0/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 0/400 MC density sum 1.00
# Epoch: 2/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 2/19, i/N: 10/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 20/400 with KL 0.03 and nll loss -41.07
# Epoch: 2/19, i/N: 30/400 with KL 0.08 and nll loss -41.02
# Epoch: 2/19, i/N: 40/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 50/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 60/400 with KL 0.09 and nll loss -41.02
# Epoch: 2/19, i/N: 70/400 with KL 0.10 and nll loss -41.01
# Epoch: 2/19, i/N: 80/400 with KL 0.12 and nll loss -40.98
# Epoch: 2/19, i/N: 90/400 with KL 0.19 and nll loss -40.92
# Epoch: 2/19, i/N: 100/400 with KL 0.06 and nll loss -41.04
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 100/400 KL_test 0.07633209228515625 and nll_test -41.030147552490234
#
# From current batch
# Epoch: 2, i/N: 100/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 100/400 MC density sum 1.00
# Epoch: 2/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 2/19, i/N: 110/400 with KL 0.14 and nll loss -40.96
# Epoch: 2/19, i/N: 120/400 with KL 0.11 and nll loss -41.00
# Epoch: 2/19, i/N: 130/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 140/400 with KL 0.05 and nll loss -41.05
# Epoch: 2/19, i/N: 150/400 with KL 0.00 and nll loss -41.11
# Epoch: 2/19, i/N: 160/400 with KL 0.12 and nll loss -40.99
# Epoch: 2/19, i/N: 170/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 180/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 190/400 with KL 0.04 and nll loss -41.06
# Epoch: 2/19, i/N: 200/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 200/400 KL_test 0.07435989379882812 and nll_test -41.03211975097656
#
# From current batch
# Epoch: 2, i/N: 200/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 200/400 MC density sum 1.00
# Epoch: 2/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 2/19, i/N: 210/400 with KL 0.04 and nll loss -41.07
# Epoch: 2/19, i/N: 220/400 with KL 0.01 and nll loss -41.10
# Epoch: 2/19, i/N: 230/400 with KL 0.03 and nll loss -41.08
# Epoch: 2/19, i/N: 240/400 with KL 0.05 and nll loss -41.05
# Epoch: 2/19, i/N: 250/400 with KL 0.02 and nll loss -41.08
# Epoch: 2/19, i/N: 260/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 270/400 with KL 0.13 and nll loss -40.97
# Epoch: 2/19, i/N: 280/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 290/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 300/400 with KL -0.00 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 2/19, i/N: 300/400 KL_test 0.06768417358398438 and nll_test -41.038795471191406
#
# From current batch
# Epoch: 2, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 2/19, i/N: 300/400 MC density sum 1.00
# Epoch: 2/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 2/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 320/400 with KL 0.03 and nll loss -41.08
# Epoch: 2/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 2/19, i/N: 340/400 with KL 0.08 and nll loss -41.03
# Epoch: 2/19, i/N: 350/400 with KL 0.13 and nll loss -40.98
# Epoch: 2/19, i/N: 360/400 with KL 0.09 and nll loss -41.01
# Epoch: 2/19, i/N: 370/400 with KL 0.05 and nll loss -41.06
# Epoch: 2/19, i/N: 380/400 with KL 0.07 and nll loss -41.04
# Epoch: 2/19, i/N: 390/400 with KL -0.05 and nll loss -41.16
# Epoch: 3 / 19
# Epoch: 3/19, i/N: 0/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 0/400 KL_test 0.0712738037109375 and nll_test -41.03520584106445
#
# From current batch
# Epoch: 3, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 0/400 MC density sum 1.00
# Epoch: 3/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 3/19, i/N: 10/400 with KL -0.03 and nll loss -41.14
# Epoch: 3/19, i/N: 20/400 with KL 0.12 and nll loss -40.99
# Epoch: 3/19, i/N: 30/400 with KL 0.08 and nll loss -41.03
# Epoch: 3/19, i/N: 40/400 with KL 0.17 and nll loss -40.94
# Epoch: 3/19, i/N: 50/400 with KL 0.04 and nll loss -41.06
# Epoch: 3/19, i/N: 60/400 with KL 0.07 and nll loss -41.03
# Epoch: 3/19, i/N: 70/400 with KL 0.00 and nll loss -41.11
# Epoch: 3/19, i/N: 80/400 with KL -0.01 and nll loss -41.12
# Epoch: 3/19, i/N: 90/400 with KL 0.11 and nll loss -40.99
# Epoch: 3/19, i/N: 100/400 with KL 0.10 and nll loss -41.01
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 100/400 KL_test 0.06974029541015625 and nll_test -41.036739349365234
#
# From current batch
# Epoch: 3, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 100/400 MC density sum 1.00
# Epoch: 3/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 3/19, i/N: 110/400 with KL -0.01 and nll loss -41.11
# Epoch: 3/19, i/N: 120/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 130/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 140/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 150/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 160/400 with KL 0.05 and nll loss -41.05
# Epoch: 3/19, i/N: 170/400 with KL 0.04 and nll loss -41.07
# Epoch: 3/19, i/N: 180/400 with KL 0.05 and nll loss -41.05
# Epoch: 3/19, i/N: 190/400 with KL -0.01 and nll loss -41.11
# Epoch: 3/19, i/N: 200/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 200/400 KL_test 0.06946945190429688 and nll_test -41.037010192871094
#
# From current batch
# Epoch: 3, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 200/400 MC density sum 1.00
# Epoch: 3/19, i/N: 200/400 avg ldj -0.28
# #####################
#
# Epoch: 3/19, i/N: 210/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 220/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 230/400 with KL 0.03 and nll loss -41.08
# Epoch: 3/19, i/N: 240/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 250/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 260/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 270/400 with KL 0.07 and nll loss -41.04
# Epoch: 3/19, i/N: 280/400 with KL 0.05 and nll loss -41.06
# Epoch: 3/19, i/N: 290/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 300/400 with KL 0.13 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 3/19, i/N: 300/400 KL_test 0.07454299926757812 and nll_test -41.03193664550781
#
# From current batch
# Epoch: 3, i/N: 300/400 avg ldj from current batch 0.26
#
# From 100000 uniform samples
# Epoch: 3/19, i/N: 300/400 MC density sum 1.00
# Epoch: 3/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 3/19, i/N: 310/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 320/400 with KL 0.13 and nll loss -40.98
# Epoch: 3/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 3/19, i/N: 340/400 with KL 0.14 and nll loss -40.96
# Epoch: 3/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# nan in sum squares
# Epoch: 3/19, i/N: 360/400 with KL 0.09 and nll loss -41.02
# Epoch: 3/19, i/N: 370/400 with KL 0.08 and nll loss -41.02
# Epoch: 3/19, i/N: 380/400 with KL 0.11 and nll loss -41.00
# Epoch: 3/19, i/N: 390/400 with KL -0.00 and nll loss -41.11
# Epoch: 4 / 19
# Epoch: 4/19, i/N: 0/400 with KL -0.03 and nll loss -41.13
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 0/400 KL_test 0.07359695434570312 and nll_test -41.03288269042969
#
# From current batch
# Epoch: 4, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 0/400 MC density sum 1.00
# Epoch: 4/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 4/19, i/N: 10/400 with KL 0.11 and nll loss -41.00
# Epoch: 4/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 30/400 with KL 0.20 and nll loss -40.90
# Epoch: 4/19, i/N: 40/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 50/400 with KL 0.14 and nll loss -40.97
# Epoch: 4/19, i/N: 60/400 with KL 0.01 and nll loss -41.10
# Epoch: 4/19, i/N: 70/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 80/400 with KL 0.10 and nll loss -41.00
# Epoch: 4/19, i/N: 90/400 with KL 0.03 and nll loss -41.07
# Epoch: 4/19, i/N: 100/400 with KL 0.14 and nll loss -40.97
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 100/400 KL_test 0.0710601806640625 and nll_test -41.03541946411133
#
# From current batch
# Epoch: 4, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 100/400 MC density sum 1.00
# Epoch: 4/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 4/19, i/N: 110/400 with KL 0.13 and nll loss -40.98
# Epoch: 4/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 130/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 140/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 150/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 160/400 with KL 0.12 and nll loss -40.99
# Epoch: 4/19, i/N: 170/400 with KL 0.15 and nll loss -40.96
# Epoch: 4/19, i/N: 180/400 with KL 0.03 and nll loss -41.08
# Epoch: 4/19, i/N: 190/400 with KL 0.17 and nll loss -40.93
# Epoch: 4/19, i/N: 200/400 with KL -0.00 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 200/400 KL_test 0.06923675537109375 and nll_test -41.0372428894043
#
# From current batch
# Epoch: 4, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 200/400 MC density sum 1.00
# Epoch: 4/19, i/N: 200/400 avg ldj -0.23
# #####################
#
# Epoch: 4/19, i/N: 210/400 with KL 0.12 and nll loss -40.99
# Epoch: 4/19, i/N: 220/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 230/400 with KL 0.05 and nll loss -41.06
# Epoch: 4/19, i/N: 240/400 with KL -0.01 and nll loss -41.12
# Epoch: 4/19, i/N: 250/400 with KL 0.07 and nll loss -41.04
# Epoch: 4/19, i/N: 260/400 with KL 0.07 and nll loss -41.03
# Epoch: 4/19, i/N: 270/400 with KL 0.04 and nll loss -41.07
# Epoch: 4/19, i/N: 280/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 290/400 with KL -0.00 and nll loss -41.11
# Epoch: 4/19, i/N: 300/400 with KL 0.00 and nll loss -41.11
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 4/19, i/N: 300/400 KL_test 0.0664825439453125 and nll_test -41.03999710083008
#
# From current batch
# Epoch: 4, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 4/19, i/N: 300/400 MC density sum 0.99
# Epoch: 4/19, i/N: 300/400 avg ldj -0.29
# #####################
#
# Epoch: 4/19, i/N: 310/400 with KL 0.04 and nll loss -41.07
# Epoch: 4/19, i/N: 320/400 with KL 0.10 and nll loss -41.00
# Epoch: 4/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 340/400 with KL 0.12 and nll loss -40.98
# Epoch: 4/19, i/N: 350/400 with KL 0.10 and nll loss -41.01
# Epoch: 4/19, i/N: 360/400 with KL 0.06 and nll loss -41.05
# Epoch: 4/19, i/N: 370/400 with KL 0.08 and nll loss -41.03
# Epoch: 4/19, i/N: 380/400 with KL -0.04 and nll loss -41.15
# Epoch: 4/19, i/N: 390/400 with KL 0.09 and nll loss -41.02
# Epoch: 5 / 19
# Epoch: 5/19, i/N: 0/400 with KL 0.12 and nll loss -40.99
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 0/400 KL_test 0.06587982177734375 and nll_test -41.04059982299805
#
# From current batch
# Epoch: 5, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 0/400 MC density sum 1.00
# Epoch: 5/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 5/19, i/N: 10/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 20/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 30/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 40/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 50/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 60/400 with KL 0.10 and nll loss -41.00
# Epoch: 5/19, i/N: 70/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 80/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 90/400 with KL 0.02 and nll loss -41.08
# Epoch: 5/19, i/N: 100/400 with KL 0.09 and nll loss -41.02
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 100/400 KL_test 0.07282257080078125 and nll_test -41.03365707397461
#
# From current batch
# Epoch: 5, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 100/400 MC density sum 1.00
# Epoch: 5/19, i/N: 100/400 avg ldj -0.32
# #####################
#
# Epoch: 5/19, i/N: 110/400 with KL 0.02 and nll loss -41.08
# Epoch: 5/19, i/N: 120/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 130/400 with KL 0.14 and nll loss -40.97
# Epoch: 5/19, i/N: 140/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 150/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 160/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 170/400 with KL 0.02 and nll loss -41.08
# Epoch: 5/19, i/N: 180/400 with KL 0.03 and nll loss -41.08
# Epoch: 5/19, i/N: 190/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 200/400 with KL 0.08 and nll loss -41.03
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 200/400 KL_test 0.07130050659179688 and nll_test -41.035179138183594
#
# From current batch
# Epoch: 5, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 200/400 MC density sum 1.00
# Epoch: 5/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 5/19, i/N: 210/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 220/400 with KL 0.11 and nll loss -41.00
# Epoch: 5/19, i/N: 230/400 with KL 0.03 and nll loss -41.08
# Epoch: 5/19, i/N: 240/400 with KL 0.10 and nll loss -41.01
# Epoch: 5/19, i/N: 250/400 with KL 0.00 and nll loss -41.11
# Epoch: 5/19, i/N: 260/400 with KL 0.07 and nll loss -41.04
# Epoch: 5/19, i/N: 270/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 280/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 290/400 with KL 0.09 and nll loss -41.02
# Epoch: 5/19, i/N: 300/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 5/19, i/N: 300/400 KL_test 0.06831741333007812 and nll_test -41.03816223144531
#
# From current batch
# Epoch: 5, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 5/19, i/N: 300/400 MC density sum 1.00
# Epoch: 5/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 5/19, i/N: 310/400 with KL 0.05 and nll loss -41.05
# Epoch: 5/19, i/N: 320/400 with KL 0.04 and nll loss -41.07
# Epoch: 5/19, i/N: 330/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 340/400 with KL 0.12 and nll loss -40.99
# Epoch: 5/19, i/N: 350/400 with KL 0.05 and nll loss -41.06
# Epoch: 5/19, i/N: 360/400 with KL 0.02 and nll loss -41.09
# Epoch: 5/19, i/N: 370/400 with KL 0.09 and nll loss -41.01
# Epoch: 5/19, i/N: 380/400 with KL 0.13 and nll loss -40.98
# Epoch: 5/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 6 / 19
# Epoch: 6/19, i/N: 0/400 with KL 0.15 and nll loss -40.96
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 0/400 KL_test 0.06464004516601562 and nll_test -41.041839599609375
#
# From current batch
# Epoch: 6, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 0/400 MC density sum 1.00
# Epoch: 6/19, i/N: 0/400 avg ldj -0.30
# #####################
#
# Epoch: 6/19, i/N: 10/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 20/400 with KL 0.20 and nll loss -40.90
# Epoch: 6/19, i/N: 30/400 with KL 0.12 and nll loss -40.98
# Epoch: 6/19, i/N: 40/400 with KL 0.02 and nll loss -41.09
# Epoch: 6/19, i/N: 50/400 with KL 0.03 and nll loss -41.08
# Epoch: 6/19, i/N: 60/400 with KL 0.01 and nll loss -41.10
# Epoch: 6/19, i/N: 70/400 with KL 0.04 and nll loss -41.06
# Epoch: 6/19, i/N: 80/400 with KL 0.08 and nll loss -41.03
# Epoch: 6/19, i/N: 90/400 with KL 0.04 and nll loss -41.07
# Epoch: 6/19, i/N: 100/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 100/400 KL_test 0.06635665893554688 and nll_test -41.040122985839844
#
# From current batch
# Epoch: 6, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 100/400 MC density sum 1.00
# Epoch: 6/19, i/N: 100/400 avg ldj -0.31
# #####################
#
# Epoch: 6/19, i/N: 110/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 120/400 with KL 0.09 and nll loss -41.01
# Epoch: 6/19, i/N: 130/400 with KL 0.04 and nll loss -41.07
# Epoch: 6/19, i/N: 140/400 with KL 0.11 and nll loss -41.00
# Epoch: 6/19, i/N: 150/400 with KL 0.02 and nll loss -41.09
# Epoch: 6/19, i/N: 160/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 170/400 with KL -0.03 and nll loss -41.14
# Epoch: 6/19, i/N: 180/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 190/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 200/400 with KL 0.12 and nll loss -40.99
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 200/400 KL_test 0.06793594360351562 and nll_test -41.038543701171875
#
# From current batch
# Epoch: 6, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 200/400 MC density sum 1.00
# Epoch: 6/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 6/19, i/N: 210/400 with KL 0.03 and nll loss -41.08
# Epoch: 6/19, i/N: 220/400 with KL 0.10 and nll loss -41.01
# Epoch: 6/19, i/N: 230/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 240/400 with KL 0.06 and nll loss -41.05
# Epoch: 6/19, i/N: 250/400 with KL 0.09 and nll loss -41.01
# Epoch: 6/19, i/N: 260/400 with KL 0.09 and nll loss -41.02
# Epoch: 6/19, i/N: 270/400 with KL 0.11 and nll loss -41.00
# Epoch: 6/19, i/N: 280/400 with KL 0.05 and nll loss -41.05
# Epoch: 6/19, i/N: 290/400 with KL 0.02 and nll loss -41.09
# Epoch: 6/19, i/N: 300/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 6/19, i/N: 300/400 KL_test 0.06704330444335938 and nll_test -41.03943634033203
#
# From current batch
# Epoch: 6, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 6/19, i/N: 300/400 MC density sum 1.00
# Epoch: 6/19, i/N: 300/400 avg ldj -0.25
# #####################
#
# Epoch: 6/19, i/N: 310/400 with KL 0.07 and nll loss -41.04
# Epoch: 6/19, i/N: 320/400 with KL 0.05 and nll loss -41.06
# Epoch: 6/19, i/N: 330/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 340/400 with KL 0.05 and nll loss -41.06
# Epoch: 6/19, i/N: 350/400 with KL 0.06 and nll loss -41.04
# Epoch: 6/19, i/N: 360/400 with KL 0.12 and nll loss -40.99
# Epoch: 6/19, i/N: 370/400 with KL 0.08 and nll loss -41.02
# Epoch: 6/19, i/N: 380/400 with KL 0.06 and nll loss -41.04
# Epoch: 6/19, i/N: 390/400 with KL 0.01 and nll loss -41.09
# Epoch: 7 / 19
# Epoch: 7/19, i/N: 0/400 with KL -0.01 and nll loss -41.12
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 0/400 KL_test 0.06450653076171875 and nll_test -41.04197311401367
#
# From current batch
# Epoch: 7, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 0/400 MC density sum 1.00
# Epoch: 7/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 7/19, i/N: 10/400 with KL 0.11 and nll loss -40.99
# Epoch: 7/19, i/N: 20/400 with KL 0.10 and nll loss -41.01
# Epoch: 7/19, i/N: 30/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 40/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 50/400 with KL 0.11 and nll loss -41.00
# Epoch: 7/19, i/N: 60/400 with KL 0.01 and nll loss -41.10
# Epoch: 7/19, i/N: 70/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 80/400 with KL 0.02 and nll loss -41.09
# Epoch: 7/19, i/N: 90/400 with KL 0.03 and nll loss -41.08
# Epoch: 7/19, i/N: 100/400 with KL 0.07 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 100/400 KL_test 0.06582260131835938 and nll_test -41.04065704345703
#
# From current batch
# Epoch: 7, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 100/400 MC density sum 1.00
# Epoch: 7/19, i/N: 100/400 avg ldj -0.26
# #####################
#
# Epoch: 7/19, i/N: 110/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 120/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 130/400 with KL 0.02 and nll loss -41.08
# Epoch: 7/19, i/N: 140/400 with KL 0.07 and nll loss -41.04
# Epoch: 7/19, i/N: 150/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 160/400 with KL 0.02 and nll loss -41.08
# Epoch: 7/19, i/N: 170/400 with KL 0.06 and nll loss -41.04
# Epoch: 7/19, i/N: 180/400 with KL 0.08 and nll loss -41.03
# Epoch: 7/19, i/N: 190/400 with KL 0.02 and nll loss -41.08
# Epoch: 7/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 200/400 KL_test 0.06813430786132812 and nll_test -41.03834533691406
#
# From current batch
# Epoch: 7, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 200/400 MC density sum 1.00
# Epoch: 7/19, i/N: 200/400 avg ldj -0.27
# #####################
#
# Epoch: 7/19, i/N: 210/400 with KL 0.04 and nll loss -41.07
# Epoch: 7/19, i/N: 220/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 230/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 240/400 with KL 0.04 and nll loss -41.07
# Epoch: 7/19, i/N: 250/400 with KL 0.07 and nll loss -41.04
# Epoch: 7/19, i/N: 260/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 270/400 with KL 0.03 and nll loss -41.07
# Epoch: 7/19, i/N: 280/400 with KL 0.05 and nll loss -41.06
# Epoch: 7/19, i/N: 290/400 with KL 0.17 and nll loss -40.94
# Epoch: 7/19, i/N: 300/400 with KL 0.05 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 7/19, i/N: 300/400 KL_test 0.07043075561523438 and nll_test -41.036048889160156
#
# From current batch
# Epoch: 7, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 7/19, i/N: 300/400 MC density sum 1.00
# Epoch: 7/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 7/19, i/N: 310/400 with KL 0.12 and nll loss -40.99
# Epoch: 7/19, i/N: 320/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 330/400 with KL -0.02 and nll loss -41.13
# Epoch: 7/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 360/400 with KL 0.09 and nll loss -41.02
# Epoch: 7/19, i/N: 370/400 with KL 0.07 and nll loss -41.03
# Epoch: 7/19, i/N: 380/400 with KL 0.06 and nll loss -41.05
# Epoch: 7/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 8 / 19
# Epoch: 8/19, i/N: 0/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 0/400 KL_test 0.06494522094726562 and nll_test -41.041534423828125
#
# From current batch
# Epoch: 8, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 0/400 MC density sum 1.00
# Epoch: 8/19, i/N: 0/400 avg ldj -0.29
# #####################
#
# Epoch: 8/19, i/N: 10/400 with KL 0.13 and nll loss -40.98
# Epoch: 8/19, i/N: 20/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 30/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 40/400 with KL 0.04 and nll loss -41.06
# Epoch: 8/19, i/N: 50/400 with KL 0.08 and nll loss -41.02
# Epoch: 8/19, i/N: 60/400 with KL 0.07 and nll loss -41.03
# Epoch: 8/19, i/N: 70/400 with KL 0.14 and nll loss -40.96
# Epoch: 8/19, i/N: 80/400 with KL 0.00 and nll loss -41.11
# Epoch: 8/19, i/N: 90/400 with KL 0.02 and nll loss -41.09
# Epoch: 8/19, i/N: 100/400 with KL 0.08 and nll loss -41.03
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 100/400 KL_test 0.06614303588867188 and nll_test -41.04033660888672
#
# From current batch
# Epoch: 8, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 100/400 MC density sum 1.00
# Epoch: 8/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 8/19, i/N: 110/400 with KL 0.03 and nll loss -41.07
# Epoch: 8/19, i/N: 120/400 with KL 0.12 and nll loss -40.99
# Epoch: 8/19, i/N: 130/400 with KL -0.00 and nll loss -41.11
# Epoch: 8/19, i/N: 140/400 with KL 0.01 and nll loss -41.10
# Epoch: 8/19, i/N: 150/400 with KL 0.09 and nll loss -41.02
# Epoch: 8/19, i/N: 160/400 with KL 0.05 and nll loss -41.05
# Epoch: 8/19, i/N: 170/400 with KL 0.06 and nll loss -41.04
# Epoch: 8/19, i/N: 180/400 with KL 0.08 and nll loss -41.03
# Epoch: 8/19, i/N: 190/400 with KL 0.14 and nll loss -40.97
# Epoch: 8/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 200/400 KL_test 0.0606689453125 and nll_test -41.04581069946289
#
# From current batch
# Epoch: 8, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 200/400 MC density sum 1.00
# Epoch: 8/19, i/N: 200/400 avg ldj -0.26
# #####################
#
# Epoch: 8/19, i/N: 210/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 220/400 with KL 0.18 and nll loss -40.92
# Epoch: 8/19, i/N: 230/400 with KL 0.06 and nll loss -41.04
# Epoch: 8/19, i/N: 240/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 250/400 with KL 0.04 and nll loss -41.07
# Epoch: 8/19, i/N: 260/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 270/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 280/400 with KL 0.10 and nll loss -41.01
# Epoch: 8/19, i/N: 290/400 with KL 0.07 and nll loss -41.04
# Epoch: 8/19, i/N: 300/400 with KL 0.05 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 8/19, i/N: 300/400 KL_test 0.0649566650390625 and nll_test -41.04152297973633
#
# From current batch
# Epoch: 8, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 8/19, i/N: 300/400 MC density sum 1.00
# Epoch: 8/19, i/N: 300/400 avg ldj -0.30
# #####################
#
# Epoch: 8/19, i/N: 310/400 with KL 0.05 and nll loss -41.06
# Epoch: 8/19, i/N: 320/400 with KL -0.01 and nll loss -41.11
# Epoch: 8/19, i/N: 330/400 with KL 0.07 and nll loss -41.03
# Epoch: 8/19, i/N: 340/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 350/400 with KL 0.06 and nll loss -41.05
# Epoch: 8/19, i/N: 360/400 with KL 0.05 and nll loss -41.05
# Epoch: 8/19, i/N: 370/400 with KL 0.10 and nll loss -41.00
# Epoch: 8/19, i/N: 380/400 with KL 0.09 and nll loss -41.01
# Epoch: 8/19, i/N: 390/400 with KL 0.06 and nll loss -41.05
# Epoch: 9 / 19
# Epoch: 9/19, i/N: 0/400 with KL 0.03 and nll loss -41.07
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 9/19, i/N: 0/400 KL_test 0.06607437133789062 and nll_test -41.0404052734375
#
# From current batch
# Epoch: 9, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 9/19, i/N: 0/400 MC density sum 1.00
# Epoch: 9/19, i/N: 0/400 avg ldj -0.30
# #####################
#
# Epoch: 9/19, i/N: 10/400 with KL 0.02 and nll loss -41.09
# Epoch: 9/19, i/N: 20/400 with KL 0.03 and nll loss -41.08
# Epoch: 9/19, i/N: 30/400 with KL 0.15 and nll loss -40.95
# Epoch: 9/19, i/N: 40/400 with KL 0.10 and nll loss -41.01
# Epoch: 9/19, i/N: 50/400 with KL 0.00 and nll loss -41.10
# Epoch: 9/19, i/N: 60/400 with KL 0.09 and nll loss -41.01
# Epoch: 9/19, i/N: 70/400 with KL 0.05 and nll loss -41.06
# Epoch: 9/19, i/N: 80/400 with KL 0.13 and nll loss -40.98
# Epoch: 9/19, i/N: 90/400 with KL 0.22 and nll loss -40.88
# Epoch: 9/19, i/N: 100/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# ...
# Epoch: 16/19, i/N: 0/400 MC density sum 1.00
# Epoch: 16/19, i/N: 0/400 avg ldj -0.27
# #####################
#
# Epoch: 16/19, i/N: 10/400 with KL 0.02 and nll loss -41.09
# Epoch: 16/19, i/N: 20/400 with KL 0.11 and nll loss -40.99
# Epoch: 16/19, i/N: 30/400 with KL 0.04 and nll loss -41.07
# Epoch: 16/19, i/N: 40/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 50/400 with KL 0.10 and nll loss -41.01
# Epoch: 16/19, i/N: 60/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 70/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 80/400 with KL 0.00 and nll loss -41.11
# Epoch: 16/19, i/N: 90/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 100/400 with KL 0.16 and nll loss -40.95
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 100/400 KL_test 0.06035614013671875 and nll_test -41.04612350463867
#
# From current batch
# Epoch: 16, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 100/400 MC density sum 1.00
# Epoch: 16/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 16/19, i/N: 110/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 120/400 with KL 0.13 and nll loss -40.97
# Epoch: 16/19, i/N: 130/400 with KL 0.03 and nll loss -41.08
# Epoch: 16/19, i/N: 140/400 with KL 0.06 and nll loss -41.04
# Epoch: 16/19, i/N: 150/400 with KL 0.16 and nll loss -40.94
# Epoch: 16/19, i/N: 160/400 with KL 0.05 and nll loss -41.06
# Epoch: 16/19, i/N: 170/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 180/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 190/400 with KL 0.09 and nll loss -41.02
# Epoch: 16/19, i/N: 200/400 with KL 0.01 and nll loss -41.10
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 200/400 KL_test 0.0618133544921875 and nll_test -41.0446662902832
#
# From current batch
# Epoch: 16, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 200/400 MC density sum 1.00
# Epoch: 16/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 16/19, i/N: 210/400 with KL 0.10 and nll loss -41.01
# Epoch: 16/19, i/N: 220/400 with KL 0.05 and nll loss -41.05
# Epoch: 16/19, i/N: 230/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 240/400 with KL 0.08 and nll loss -41.02
# Epoch: 16/19, i/N: 250/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 260/400 with KL 0.08 and nll loss -41.03
# Epoch: 16/19, i/N: 270/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 280/400 with KL 0.00 and nll loss -41.11
# Epoch: 16/19, i/N: 290/400 with KL 0.10 and nll loss -41.00
# Epoch: 16/19, i/N: 300/400 with KL 0.02 and nll loss -41.09
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 16/19, i/N: 300/400 KL_test 0.06727218627929688 and nll_test -41.039207458496094
#
# From current batch
# Epoch: 16, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 16/19, i/N: 300/400 MC density sum 1.00
# Epoch: 16/19, i/N: 300/400 avg ldj -0.26
# #####################
#
# Epoch: 16/19, i/N: 310/400 with KL 0.03 and nll loss -41.07
# Epoch: 16/19, i/N: 320/400 with KL 0.10 and nll loss -41.01
# Epoch: 16/19, i/N: 330/400 with KL 0.04 and nll loss -41.06
# Epoch: 16/19, i/N: 340/400 with KL 0.07 and nll loss -41.03
# Epoch: 16/19, i/N: 350/400 with KL 0.04 and nll loss -41.07
# Epoch: 16/19, i/N: 360/400 with KL 0.12 and nll loss -40.99
# Epoch: 16/19, i/N: 370/400 with KL 0.07 and nll loss -41.04
# Epoch: 16/19, i/N: 380/400 with KL 0.10 and nll loss -41.00
# Epoch: 16/19, i/N: 390/400 with KL 0.09 and nll loss -41.01
# Epoch: 17 / 19
# Epoch: 17/19, i/N: 0/400 with KL 0.13 and nll loss -40.97
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 0/400 KL_test 0.057895660400390625 and nll_test -41.048583984375
#
# From current batch
# Epoch: 17, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 0/400 MC density sum 1.00
# Epoch: 17/19, i/N: 0/400 avg ldj -0.30
# #####################
#
# Epoch: 17/19, i/N: 10/400 with KL 0.14 and nll loss -40.96
# Epoch: 17/19, i/N: 20/400 with KL -0.03 and nll loss -41.14
# Epoch: 17/19, i/N: 30/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 40/400 with KL 0.07 and nll loss -41.03
# Epoch: 17/19, i/N: 50/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 60/400 with KL 0.08 and nll loss -41.02
# Epoch: 17/19, i/N: 70/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 80/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 90/400 with KL 0.04 and nll loss -41.07
# Epoch: 17/19, i/N: 100/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 100/400 KL_test 0.06281280517578125 and nll_test -41.04366683959961
#
# From current batch
# Epoch: 17, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 100/400 MC density sum 1.00
# Epoch: 17/19, i/N: 100/400 avg ldj -0.27
# #####################
#
# Epoch: 17/19, i/N: 110/400 with KL 0.05 and nll loss -41.06
# Epoch: 17/19, i/N: 120/400 with KL 0.16 and nll loss -40.95
# Epoch: 17/19, i/N: 130/400 with KL 0.04 and nll loss -41.06
# Epoch: 17/19, i/N: 140/400 with KL -0.03 and nll loss -41.14
# Epoch: 17/19, i/N: 150/400 with KL 0.12 and nll loss -40.99
# Epoch: 17/19, i/N: 160/400 with KL 0.02 and nll loss -41.09
# Epoch: 17/19, i/N: 170/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 180/400 with KL 0.07 and nll loss -41.03
# Epoch: 17/19, i/N: 190/400 with KL 0.08 and nll loss -41.02
# Epoch: 17/19, i/N: 200/400 with KL 0.06 and nll loss -41.05
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 200/400 KL_test 0.061908721923828125 and nll_test -41.04457092285156
#
# From current batch
# Epoch: 17, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 200/400 MC density sum 1.00
# Epoch: 17/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 17/19, i/N: 210/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 220/400 with KL 0.03 and nll loss -41.08
# Epoch: 17/19, i/N: 230/400 with KL 0.15 and nll loss -40.96
# Epoch: 17/19, i/N: 240/400 with KL 0.12 and nll loss -40.99
# Epoch: 17/19, i/N: 250/400 with KL 0.09 and nll loss -41.02
# Epoch: 17/19, i/N: 260/400 with KL 0.11 and nll loss -41.00
# Epoch: 17/19, i/N: 270/400 with KL 0.08 and nll loss -41.03
# Epoch: 17/19, i/N: 280/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 290/400 with KL 0.09 and nll loss -41.01
# Epoch: 17/19, i/N: 300/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 17/19, i/N: 300/400 KL_test 0.06634140014648438 and nll_test -41.040138244628906
#
# From current batch
# Epoch: 17, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 17/19, i/N: 300/400 MC density sum 1.00
# Epoch: 17/19, i/N: 300/400 avg ldj -0.28
# #####################
#
# Epoch: 17/19, i/N: 310/400 with KL 0.10 and nll loss -41.01
# Epoch: 17/19, i/N: 320/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 330/400 with KL 0.06 and nll loss -41.04
# Epoch: 17/19, i/N: 340/400 with KL 0.06 and nll loss -41.05
# Epoch: 17/19, i/N: 350/400 with KL 0.03 and nll loss -41.07
# Epoch: 17/19, i/N: 360/400 with KL 0.13 and nll loss -40.98
# Epoch: 17/19, i/N: 370/400 with KL -0.00 and nll loss -41.11
# Epoch: 17/19, i/N: 380/400 with KL 0.05 and nll loss -41.05
# Epoch: 17/19, i/N: 390/400 with KL 0.07 and nll loss -41.03
# Epoch: 18 / 19
# Epoch: 18/19, i/N: 0/400 with KL 0.07 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 0/400 KL_test 0.06407546997070312 and nll_test -41.04240417480469
#
# From current batch
# Epoch: 18, i/N: 0/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 0/400 MC density sum 1.00
# Epoch: 18/19, i/N: 0/400 avg ldj -0.26
# #####################
#
# Epoch: 18/19, i/N: 10/400 with KL 0.08 and nll loss -41.02
# Epoch: 18/19, i/N: 20/400 with KL 0.08 and nll loss -41.03
# Epoch: 18/19, i/N: 30/400 with KL 0.17 and nll loss -40.93
# Epoch: 18/19, i/N: 40/400 with KL 0.13 and nll loss -40.98
# Epoch: 18/19, i/N: 50/400 with KL 0.01 and nll loss -41.10
# Epoch: 18/19, i/N: 60/400 with KL 0.15 and nll loss -40.96
# Epoch: 18/19, i/N: 70/400 with KL 0.01 and nll loss -41.09
# Epoch: 18/19, i/N: 80/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 90/400 with KL 0.04 and nll loss -41.07
# Epoch: 18/19, i/N: 100/400 with KL -0.03 and nll loss -41.14
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 100/400 KL_test 0.06653976440429688 and nll_test -41.039939880371094
#
# From current batch
# Epoch: 18, i/N: 100/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 100/400 MC density sum 1.00
# Epoch: 18/19, i/N: 100/400 avg ldj -0.30
# #####################
#
# Epoch: 18/19, i/N: 110/400 with KL 0.05 and nll loss -41.05
# Epoch: 18/19, i/N: 120/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 130/400 with KL 0.17 and nll loss -40.93
# Epoch: 18/19, i/N: 140/400 with KL -0.02 and nll loss -41.13
# Epoch: 18/19, i/N: 150/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 160/400 with KL 0.04 and nll loss -41.06
# Epoch: 18/19, i/N: 170/400 with KL 0.02 and nll loss -41.08
# Epoch: 18/19, i/N: 180/400 with KL 0.16 and nll loss -40.95
# Epoch: 18/19, i/N: 190/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 200/400 with KL 0.11 and nll loss -41.00
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 200/400 KL_test 0.0641937255859375 and nll_test -41.04228591918945
#
# From current batch
# Epoch: 18, i/N: 200/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 200/400 MC density sum 1.00
# Epoch: 18/19, i/N: 200/400 avg ldj -0.30
# #####################
#
# Epoch: 18/19, i/N: 210/400 with KL 0.09 and nll loss -41.01
# Epoch: 18/19, i/N: 220/400 with KL 0.02 and nll loss -41.09
# Epoch: 18/19, i/N: 230/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 240/400 with KL 0.12 and nll loss -40.99
# Epoch: 18/19, i/N: 250/400 with KL 0.07 and nll loss -41.03
# Epoch: 18/19, i/N: 260/400 with KL 0.01 and nll loss -41.09
# Epoch: 18/19, i/N: 270/400 with KL 0.10 and nll loss -41.01
# Epoch: 18/19, i/N: 280/400 with KL 0.11 and nll loss -41.00
# Epoch: 18/19, i/N: 290/400 with KL 0.10 and nll loss -41.00
# Epoch: 18/19, i/N: 300/400 with KL 0.06 and nll loss -41.04
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 18/19, i/N: 300/400 KL_test 0.0665283203125 and nll_test -41.03995132446289
#
# From current batch
# Epoch: 18, i/N: 300/400 avg ldj from current batch 0.27
#
# From 100000 uniform samples
# Epoch: 18/19, i/N: 300/400 MC density sum 1.00
# Epoch: 18/19, i/N: 300/400 avg ldj -0.24
# #####################
#
# Epoch: 18/19, i/N: 310/400 with KL 0.06 and nll loss -41.05
# Epoch: 18/19, i/N: 320/400 with KL 0.03 and nll loss -41.08
# Epoch: 18/19, i/N: 330/400 with KL 0.07 and nll loss -41.04
# Epoch: 18/19, i/N: 340/400 with KL -0.00 and nll loss -41.11
# Epoch: 18/19, i/N: 350/400 with KL 0.16 and nll loss -40.94
# Epoch: 18/19, i/N: 360/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 370/400 with KL 0.16 and nll loss -40.95
# Epoch: 18/19, i/N: 380/400 with KL 0.06 and nll loss -41.04
# Epoch: 18/19, i/N: 390/400 with KL 0.04 and nll loss -41.07
# Epoch: 19 / 19
# Epoch: 19/19, i/N: 0/400 with KL -0.02 and nll loss -41.12
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 0/400 KL_test 0.061061859130859375 and nll_test -41.04541778564453
#
# From current batch
# Epoch: 19, i/N: 0/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 0/400 MC density sum 1.00
# Epoch: 19/19, i/N: 0/400 avg ldj -0.28
# #####################
#
# Epoch: 19/19, i/N: 10/400 with KL 0.15 and nll loss -40.96
# Epoch: 19/19, i/N: 20/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 30/400 with KL -0.01 and nll loss -41.12
# Epoch: 19/19, i/N: 40/400 with KL 0.10 and nll loss -41.01
# Epoch: 19/19, i/N: 50/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 60/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 70/400 with KL 0.03 and nll loss -41.07
# Epoch: 19/19, i/N: 80/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 90/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 100/400 with KL 0.08 and nll loss -41.02
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 100/400 KL_test 0.060657501220703125 and nll_test -41.04582214355469
#
# From current batch
# Epoch: 19, i/N: 100/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 100/400 MC density sum 1.00
# Epoch: 19/19, i/N: 100/400 avg ldj -0.24
# #####################
#
# Epoch: 19/19, i/N: 110/400 with KL 0.11 and nll loss -41.00
# Epoch: 19/19, i/N: 120/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 130/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 140/400 with KL -0.00 and nll loss -41.11
# Epoch: 19/19, i/N: 150/400 with KL 0.09 and nll loss -41.01
# Epoch: 19/19, i/N: 160/400 with KL -0.02 and nll loss -41.13
# Epoch: 19/19, i/N: 170/400 with KL 0.12 and nll loss -40.98
# Epoch: 19/19, i/N: 180/400 with KL 0.04 and nll loss -41.06
# Epoch: 19/19, i/N: 190/400 with KL 0.11 and nll loss -40.99
# Epoch: 19/19, i/N: 200/400 with KL 0.11 and nll loss -40.99
# nan in sum squares
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 200/400 KL_test 0.061798095703125 and nll_test -41.044681549072266
#
# From current batch
# Epoch: 19, i/N: 200/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 200/400 MC density sum 1.00
# Epoch: 19/19, i/N: 200/400 avg ldj -0.29
# #####################
#
# Epoch: 19/19, i/N: 210/400 with KL -0.00 and nll loss -41.11
# Epoch: 19/19, i/N: 220/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 230/400 with KL 0.09 and nll loss -41.02
# Epoch: 19/19, i/N: 240/400 with KL 0.08 and nll loss -41.03
# Epoch: 19/19, i/N: 250/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 260/400 with KL 0.03 and nll loss -41.08
# Epoch: 19/19, i/N: 270/400 with KL 0.09 and nll loss -41.01
# Epoch: 19/19, i/N: 280/400 with KL 0.07 and nll loss -41.03
# Epoch: 19/19, i/N: 290/400 with KL 0.01 and nll loss -41.10
# Epoch: 19/19, i/N: 300/400 with KL 0.05 and nll loss -41.06
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 300/400 KL_test 0.06310272216796875 and nll_test -41.04337692260742
#
# From current batch
# Epoch: 19, i/N: 300/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 300/400 MC density sum 1.00
# Epoch: 19/19, i/N: 300/400 avg ldj -0.27
# #####################
#
# Epoch: 19/19, i/N: 310/400 with KL 0.07 and nll loss -41.03
# Epoch: 19/19, i/N: 320/400 with KL 0.02 and nll loss -41.09
# Epoch: 19/19, i/N: 330/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 340/400 with KL 0.04 and nll loss -41.07
# Epoch: 19/19, i/N: 350/400 with KL 0.12 and nll loss -40.98
# Epoch: 19/19, i/N: 360/400 with KL 0.01 and nll loss -41.09
# Epoch: 19/19, i/N: 370/400 with KL 0.15 and nll loss -40.96
# Epoch: 19/19, i/N: 380/400 with KL 0.06 and nll loss -41.05
# Epoch: 19/19, i/N: 390/400 with KL 0.12 and nll loss -40.98
#
# #### EVALUATION ####
# Evaluation based on 100000 data points from data distribution samples
# Epoch: 19/19, i/N: 399/400 KL_test 0.059383392333984375 and nll_test -41.047096252441406
#
# From current batch
# Epoch: 19, i/N: 399/400 avg ldj from current batch 0.28
#
# From 100000 uniform samples
# Epoch: 19/19, i/N: 399/400 MC density sum 1.00
# Epoch: 19/19, i/N: 399/400 avg ldj -0.22
# #####################
